# %% [markdown]
# # CR Vs DB Verify
# check if the results from cr search are in the DB
# - get list of CSV search results files
# - join searches as a set (unique references)
# - open DB
# - search if occurrences in DB
# - create a list of new candidates

# %%
# Connecting to the db
import lib.handle_db as dbh

# read and write csv files
import lib.handle_csv as csv_rw

# date functions
from datetime import datetime, date, timedelta

# managing files and file paths
from pathlib import Path

# import custom functions (common to various notebooks)
import processing_functions as pr_fns

# %%
# get list of CSV search results files
base_dir = './pub_search_crossref'
csv_flies_list = ['cr_ol_202204.csv','cr_online_lookup.csv','cr_archive_lookup.csv']
collect_csv = {}
out_file = Path(base_dir, "cr_all202204.csv")

# %%
# join searches as a set (unique references)
for a_csv in csv_flies_list:
    a_file = Path(base_dir,a_csv)
    if a_file.is_file():
        print("**********************************************")
        print("checking ", a_file)
        csv_data, csv_headings = csv_rw.get_csv_data(a_file)
        print("Found: ", a_file, " entries: ", len(csv_data))
        for an_id in csv_data:
            a_doi = csv_data[an_id]['doi']
            alt_doi = "";
            if ("/anie." in a_doi):
                alt_doi = a_doi.replace("/anie.","/ange.")
            elif ("/ange." in a_doi):
                alt_doi = a_doi.replace("/ange.","/anie.")
            new_id = len(collect_csv)+1
            already_collected = False
            for collected_id in collect_csv:
                if a_doi == collect_csv[collected_id]['doi'] or \
                   alt_doi == collect_csv[collected_id]['doi']:
                    print ('reviewing:', csv_data[an_id]['doi'],"\nFound ", collect_csv[collected_id])
                    collect_csv[collected_id]['occurrence'] += 1
                    collect_csv[collected_id]['alt_doi'] = alt_doi
                    already_collected = True
                    break
            if not already_collected: 
                print("adding", new_id, a_doi)
                collect_csv[new_id] = csv_data[an_id]
                collect_csv[new_id]['occurrence'] = 1
                collect_csv[new_id]['alt_doi'] = ''
# WRITE TO FILE
if len(collect_csv) > 0:
    csv_rw.write_csv_data(collect_csv, out_file)
# Out:
# **********************************************
# checking  pub_search_crossref\cr_ol_202204.csv
# Found:  pub_search_crossref\cr_ol_202204.csv  entries:  45
# adding 1 10.1016/j.catcom.2022.106421
# adding 2 10.1002/anie.202015016
# reviewing: 10.1002/ange.202015016
# Found  {'authors': 'Omori, Naomi, Candeo, Alessia, Mosca, Sara, Lezcano‐Gonzalez, Ines, Robinson, Ian K., Li, Luxi, Greenaway, Alex G., Collier, Paul, Beale, Andrew M.', 'year': '2021', 'title': 'Multimodal Imaging of Autofluorescent Sites Reveals Varied Chemical Speciation in SSZ‐13 Crystals', 'doi': '10.1002/anie.202015016', 'award': 'EP/K014714/1', 'ukch_affi': 'FALSE', 'search': '2022-03-01 to 2022-03-07', 'occurrence': 1, 'alt_doi': ''}
# adding 3 10.1039/d1cy02001c
# adding 4 10.1002/chem.202104198
# adding 5 10.1021/acs.chemrev.1c00493
# adding 6 10.1021/acscatal.9b01820
# adding 7 10.1098/rsos.211353
# adding 8 10.1021/acs.nanolett.9b01733
# adding 9 10.1016/j.catcom.2021.106392
# adding 10 10.1021/acs.jcim.8b00940
# adding 11 10.1021/acscatal.9b00160
# adding 12 10.1016/j.fuel.2022.123420
# adding 13 10.1021/acs.jpcc.9b09050
# adding 14 10.1021/acs.est.0c04279
# adding 15 10.1021/acscatal.0c05413
# adding 16 10.1021/acs.inorgchem.1c00327
# adding 17 10.1021/jacs.9b02731
# adding 18 10.1021/acs.iecr.9b04263
# adding 19 10.1021/acs.jpcc.1c10180
# adding 20 10.1021/acs.jpcc.9b05475
# adding 21 10.1098/rsos.211516
# adding 22 10.1039/d1cy02361f
# adding 23 10.1021/acs.inorgchem.1c03365
# adding 24 10.1021/acs.jcim.1c01109
# adding 25 10.1021/acsaem.0c02060
# adding 26 10.1021/acs.organomet.1c00055
# adding 27 10.1021/acsenergylett.0c02614
# adding 28 10.1021/acscatal.1c04449
# adding 29 10.1021/acs.jpcc.1c07517
# adding 30 10.1021/acsami.1c21554
# adding 31 10.1021/acs.energyfuels.1c03346
# adding 32 10.1021/acs.macromol.2c00068
# adding 33 10.1021/acscatal.0c00596
# adding 34 10.1002/cctc.202101828
# adding 35 10.1039/d1ee03523a
# adding 36 10.1021/acssuschemeng.1c07301
# adding 37 10.1021/acsnano.1c09864
# adding 38 10.1021/acscatal.1c05694
# adding 39 10.1021/jacs.2c01225
# adding 40 10.1021/acscatal.2c00552
# adding 41 10.26434/chemrxiv-2022-w89tc
# adding 42 10.1039/d2cp01019d
# adding 43 10.1002/smll.202107020
# adding 44 10.1016/j.xcrp.2022.100844
# **********************************************
# checking  pub_search_crossref\cr_online_lookup.csv
# Found:  pub_search_crossref\cr_online_lookup.csv  entries:  171
# adding 45 10.1016/j.apcata.2018.10.010
# adding 46 10.1039/c9cp02968k
# adding 47 10.3390/catal11010138
# adding 48 10.1002/chem.202004408
# adding 49 10.1002/ange.202006807
# reviewing: 10.1002/anie.202006807
# Found  {'authors': 'Chen, Thomas T. D., Carrodeguas, Leticia Peña, Sulley, Gregory S., Gregory, Georgina L., Williams, Charlotte K.', 'year': '2020', 'title': 'Bio‐based and Degradable Block Polyester Pressure‐Sensitive Adhesives', 'doi': '10.1002/ange.202006807', 'award': 'EP/K014668/1', 'ukch_affi': 'False', 'search': '2021-01-22 to 2021-01-28', 'occurrence': 1, 'alt_doi': ''}
# adding 50 10.1002/cplu.201500195
# adding 51 10.1098/rsta.2020.0056
# adding 52 10.1098/rsta.2020.0063
# adding 53 10.1098/rspa.2016.0054
# adding 54 10.1098/rspa.2016.0078
# adding 55 10.1098/rsta.2020.0058
# adding 56 10.1098/rspa.2016.0095
# adding 57 10.1098/rspa.2016.0126
# adding 58 10.1007/s11244-020-01245-8
# adding 59 10.1039/d0cy02164d
# adding 60 10.1002/celc.201902005
# adding 61 10.1039/d1cy00048a
# adding 62 10.1039/d0ob02566f
# adding 63 10.1039/d1cp00979f
# adding 64 10.1002/ange.202101180
# adding 65 10.1039/d1fd00023c
# reviewing: 10.1002/anie.202101180
# Found  {'authors': 'Plajer, Alex J., Williams, Charlotte K.', 'year': '2021', 'title': 'Heterotrimetallic Carbon Dioxide Copolymerization and Switchable Catalysts: Sodium is the Key to High Activity and Unusual Selectivity', 'doi': '10.1002/ange.202101180', 'award': 'EP/R027129/1', 'ukch_affi': 'False', 'search': '2021-05-28 to 2021-06-03', 'occurrence': 1, 'alt_doi': ''}
# adding 66 10.1039/d0fd00014k
# adding 67 10.1021/acssuschemeng.1c01451
# adding 68 10.1002/cctc.202100286
# adding 69 10.1039/d1fd00027f
# adding 70 10.1002/ange.201801400
# reviewing: 10.1002/anie.201801400
# Found  {'authors': 'Stößer, Tim, Williams, Charlotte K.', 'year': '2018', 'title': 'Selektive Katalyse für Polymerisationen mit Monomermischungen: Verwendung eines kommerziellen Cr‐Salen‐Katalysators zur Herstellung von ABA‐Blockpolyestern', 'doi': '10.1002/ange.201801400', 'award': 'EP/K014668/1', 'ukch_affi': 'False', 'search': '2021-06-11 to 2021-06-17', 'occurrence': 1, 'alt_doi': ''}
# adding 71 10.1002/ange.201902857
# adding 72 10.1002/ange.201901592
# adding 73 10.1002/ange.201810245
# adding 74 10.1002/ange.201701745
# reviewing: 10.1002/anie.201902857
# Found  {'authors': "Clément, Pierrick, Xu, Xinzhao, Stoppiello, Craig T., Rance, Graham A., Attanzio, Antonio, O'Shea, James N., Temperton, Robert H., Khlobystov, Andrei N., Lovelock, Kevin R. J., Seymour, Jake M., Fogarty, Richard M., Baker, Alastair, Bourne, Richard A., Hall, Brendan, Chamberlain, Thomas W., Palma, Matteo", 'year': '2019', 'title': 'Direct Synthesis of Multiplexed Metal‐Nanowire‐Based Devices by Using Carbon Nanotubes as Vector Templates', 'doi': '10.1002/ange.201902857', 'award': 'EP/K014714/1', 'ukch_affi': 'False', 'search': '2021-06-25 to 2021-07-01', 'occurrence': 1, 'alt_doi': ''}
# adding 75 10.1039/d1cy00382h
# adding 76 10.1002/ange.201703550
# adding 77 10.1002/celc.201800052
# adding 78 10.1002/chem.201805250
# reviewing: 10.1002/celc.201800052
# Found  {'authors': 'Gobaille-Shaw, Gael. P. A., Celorrio, Veronica, Calvillo, Laura, Morris, Louis J., Granozzi, Gaetano, Fermín, David. J.', 'year': '2018', 'title': 'Effect of Ba Content on the Activity of La<sub>1-<i>x</i>\n                        </sub>\nBa<sub>\n                            <i>x</i>\n                        </sub>\nMnO<sub>3</sub>\n Towards the Oxygen Reduction Reaction', 'doi': '10.1002/celc.201800052', 'award': 'EP/K014714/1', 'ukch_affi': 'True', 'search': '2021-07-02 to 2021-07-08', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1002/chem.201805250
# Found  {'authors': 'Limb, Michael A. L., Suardíaz, Reynier, Grant, Ian M., Mulholland, Adrian J.', 'year': '2018', 'title': 'Quantum Mechanics/Molecular Mechanics Simulations Show Saccharide Distortion is Required for Reaction in Hen Egg‐White Lysozyme', 'doi': '10.1002/chem.201805250', 'award': 'EP/M013219/1', 'ukch_affi': 'False', 'search': '2021-07-02 to 2021-07-08', 'occurrence': 1, 'alt_doi': ''}
# adding 79 10.1002/ange.202011839
# adding 80 10.1002/cctc.201600729
# adding 81 10.1002/pssa.201600440
# adding 82 10.1002/chem.201801871
# adding 83 10.1039/d1gc00901j
# adding 84 10.1002/cssc.201501264
# adding 85 10.1002/cctc.201902135
# adding 86 10.1002/celc.201800478
# adding 87 10.1002/jctb.4662
# reviewing: 10.1002/anie.202011839
# Found  {'authors': 'Protchenko, Andrey V., Vasko, Petra, Fuentes, M. Ángeles, Hicks, Jamie, Vidovic, Dragoslav, Aldridge, Simon', 'year': '2020', 'title': 'Approaching a “Naked” Boryl Anion: Amide Metathesis as a Route to Calcium, Strontium, and Potassium Boryl Complexes', 'doi': '10.1002/ange.202011839', 'award': 'EP/K014714/1', 'ukch_affi': 'False', 'search': '2021-07-02 to 2021-07-08', 'occurrence': 1, 'alt_doi': ''}
# adding 88 10.1002/cphc.201600149
# adding 89 10.1002/cssc.201600246
# adding 90 10.1002/chem.201701013
# adding 91 10.1002/cctc.201500545
# adding 92 10.1039/d1dt01216a
# adding 93 10.1039/d1gc01852c
# adding 94 10.1021/jacs.1c03036
# adding 95 10.1039/d1fd00004g
# adding 96 10.3390/molecules26164791
# adding 97 10.1007/s11244-021-01450-z
# adding 98 10.1021/acs.organomet.8b00063
# adding 99 10.1021/jacs.5b13070
# adding 100 10.1021/acscatal.8b02232
# adding 101 10.1021/acssuschemeng.8b03568
# adding 102 10.1021/acscatal.5b00625
# adding 103 10.1021/acscatal.5b01936
# adding 104 10.1021/acs.jctc.6b01131
# adding 105 10.1021/jacs.0c07980
# adding 106 10.1021/acscatal.8b01509
# adding 107 10.1021/om5008055
# adding 108 10.1021/acscatal.5b02602
# adding 109 10.1021/jacs.6b01170
# adding 110 10.1039/d1cp02535j
# adding 111 10.1021/acs.chemmater.5b00866
# adding 112 10.1002/anie.201504227
# adding 113 10.1021/acscatal.6b00982
# adding 114 10.1021/acscatal.8b04564
# adding 115 10.1021/acsomega.9b03503
# adding 116 10.1021/acs.iecr.8b00230
# adding 117 10.1021/acs.jpcc.7b04502
# adding 118 10.1021/acscatal.6b03190
# adding 119 10.1021/acscatal.5b00481
# adding 120 10.1021/acs.jpcc.8b07846
# adding 121 10.1021/jacs.5b08614
# adding 122 10.1021/acscatal.7b03805
# adding 123 10.1021/acscatal.9b00685
# adding 124 10.1021/acs.biochem.8b00169
# adding 125 10.1021/acsomega.0c00697
# adding 126 10.1021/acscatal.6b03641
# adding 127 10.1021/jacs.9b13106
# adding 128 10.1021/acscatal.8b00624
# adding 129 10.1021/acscatal.9b05129
# adding 130 10.1021/acs.chemrev.9b00662
# adding 131 10.1021/acs.macromol.8b01224
# adding 132 10.1021/acscatal.5b00754
# adding 133 10.1021/acscatal.5b01595
# adding 134 10.1021/jacs.6b00710
# adding 135 10.1021/acs.inorgchem.8b02923
# adding 136 10.1021/acs.jpcc.6b04781
# adding 137 10.1021/acscatal.5b00480
# adding 138 10.1021/acscatal.0c01454
# adding 139 10.1039/d1ta01464a
# adding 140 10.1021/acsmacrolett.1c00216
# adding 141 10.1021/acs.jctc.8b01036
# adding 142 10.1021/acscatal.1c00997
# adding 143 10.1021/acscatal.8b00389
# adding 144 10.1021/jp5081753
# adding 145 10.1021/acs.organomet.9b00845
# adding 146 10.1021/acscatal.0c00414
# adding 147 10.1021/acs.chemmater.7b02552
# adding 148 10.1021/acs.jchemed.9b00181
# adding 149 10.1021/jacs.1c03250
# adding 150 10.1021/jacs.8b01920
# adding 151 10.1021/acsomega.9b03351
# adding 152 10.1021/acscatal.8b03169
# adding 153 10.1002/chem.202101140
# adding 154 10.1021/acs.jpcc.5b08048
# adding 155 10.1021/acs.jpcc.8b08420
# adding 156 10.1021/jacsau.1c00145
# adding 157 10.1021/acs.oprd.8b00211
# adding 158 10.1021/acscatal.0c05356
# adding 159 10.1002/smtd.202100512
# adding 160 10.1021/acscatal.1c01776
# adding 161 10.1038/s41557-021-00763-6
# adding 162 10.1002/anie.201713115
# reviewing: 10.1002/ange.201713115
# Found  {'authors': 'Falkowska, Marta, Bowron, Daniel T., Manyar, Haresh, Youngs, Tristan G. A., Hardacre, Christopher', 'year': '2018', 'title': 'Confinement Effects on the Benzene Orientational Structure', 'doi': '10.1002/anie.201713115', 'award': 'EP/K014668/1, EP/K014854/1, EP/K014714/1, EP/M013219/1', 'ukch_affi': 'False', 'search': '2021-10-08 to 2021-10-14', 'occurrence': 1, 'alt_doi': ''}
# adding 163 10.1021/acscatal.0c03620
# adding 164 10.1038/s41467-021-26508-0
# adding 165 10.1016/j.catcom.2021.106356
# adding 166 10.26434/chemrxiv-2021-bv7tb
# adding 167 10.1038/s41467-019-10481-w
# adding 168 10.1088/1361-648x/abfe16
# adding 169 10.1002/cctc.202101036
# adding 170 10.1016/j.jechem.2021.05.005
# adding 171 10.1021/acs.jpcc.1c06920
# adding 172 10.1002/anie.202104495
# reviewing: 10.1002/ange.202104495
# Found  {'authors': 'Plajer, Alex J., Williams, Charlotte K.', 'year': '2021', 'title': 'Heterocycle/Heteroallene Ring‐Opening Copolymerization: Selective Catalysis Delivering Alternating Copolymers', 'doi': '10.1002/anie.202104495', 'award': 'EP/R027129/1', 'ukch_affi': 'False', 'search': '2021-12-24 to 2021-12-30', 'occurrence': 1, 'alt_doi': ''}
# adding 173 10.1126/science.aal3439
# adding 174 10.1021/acscatal.1c04296
# adding 175 10.1016/j.catcom.2021.106384
# adding 176 10.1088/1361-6463/abe9e1
# adding 177 10.1016/j.catcom.2021.106385
# adding 178 10.1016/j.catcom.2021.106395
# adding 179 10.1021/jacsau.1c00462
# adding 180 10.1107/s1600576720013576
# adding 181 10.3390/en15041418
# adding 182 10.1039/d1gc04414a
# adding 183 10.1128/aac.00564-19
# adding 184 10.1039/d1cy00238d
# adding 185 10.1098/rsos.211423
# reviewing: 10.1002/anie.202015016
# Found  {'authors': 'Omori, Naomi, Candeo, Alessia, Mosca, Sara, Lezcano‐Gonzalez, Ines, Robinson, Ian K., Li, Luxi, Greenaway, Alex G., Collier, Paul, Beale, Andrew M.', 'year': '2021', 'title': 'Multimodal Imaging of Autofluorescent Sites Reveals Varied Chemical Speciation in SSZ‐13 Crystals', 'doi': '10.1002/anie.202015016', 'award': 'EP/K014714/1', 'ukch_affi': 'FALSE', 'search': '2022-03-01 to 2022-03-07', 'occurrence': 2, 'alt_doi': '10.1002/anie.202015016'}
# reviewing: 10.1002/ange.202015016
# Found  {'authors': 'Omori, Naomi, Candeo, Alessia, Mosca, Sara, Lezcano‐Gonzalez, Ines, Robinson, Ian K., Li, Luxi, Greenaway, Alex G., Collier, Paul, Beale, Andrew M.', 'year': '2021', 'title': 'Multimodal Imaging of Autofluorescent Sites Reveals Varied Chemical Speciation in SSZ‐13 Crystals', 'doi': '10.1002/anie.202015016', 'award': 'EP/K014714/1', 'ukch_affi': 'FALSE', 'search': '2022-03-01 to 2022-03-07', 'occurrence': 3, 'alt_doi': '10.1002/ange.202015016'}
# reviewing: 10.1002/chem.202104198
# Found  {'authors': 'Reis, Natalia V., Deacy, Arron C., Rosetto, Gloria, Durr, Christopher B., Williams, Charlotte K.', 'year': '2022', 'title': 'Heterodinuclear Mg(II)M(II) (M=Cr, Mn, Fe, Co, Ni, Cu and Zn) Complexes for the Ring Opening Copolymerization of Carbon Dioxide/Epoxide and Anhydride/Epoxide', 'doi': '10.1002/chem.202104198', 'award': 'EP/R027129/1', 'ukch_affi': 'FALSE', 'search': '2022-03-08 to 2022-03-14', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1016/j.catcom.2022.106421
# Found  {'authors': 'Shi, Yiping, Weller, Andrew S., Blacker, A. John, Dyer, Philip W.', 'year': '2022', 'title': 'Conversion of butanol to propene in flow: A triple dehydration, isomerisation and metathesis cascade', 'doi': '10.1016/j.catcom.2022.106421', 'award': 'EP/R026815/1', 'ukch_affi': 'FALSE', 'search': '2022-03-01 to 2022-03-07', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1021/acs.chemrev.1c00493
# Found  {'authors': 'Crawley, James W. M., Gow, Isla E., Lawes, Naomi, Kowalec, Igor, Kabalan, Lara, Catlow, C. Richard A., Logsdail, Andrew J., Taylor, Stuart H., Dummer, Nicholas F., Hutchings, Graham J.', 'year': '2022', 'title': 'Heterogeneous Trimetallic Nanoparticles as Catalysts', 'doi': '10.1021/acs.chemrev.1c00493', 'award': '', 'ukch_affi': 'TRUE', 'search': '2022-03-08 to 2022-03-14', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1039/d1cy02001c
# Found  {'authors': "Porter, A. J., Botchway, C. H., Kwakye-Awuah, B., Hernandez-Tamargo, C., Matam, S. K., McHugh, S. L., Silverwood, I. P., de Leeuw, N. H., O'Malley, A. J.", 'year': '2022', 'title': 'Local and nanoscale methanol mobility in different H-FER catalysts', 'doi': '10.1039/d1cy02001c', 'award': 'EP/R026815/1, EP/R026645/1, EP/R026939/1, EP/R027129/1', 'ukch_affi': 'TRUE', 'search': '2022-03-01 to 2022-03-07', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1098/rsos.211353
# Found  {'authors': 'Tedstone, Aleksander A., Bin Jumah, Abdulrahman, Asuquo, Edidiong, Garforth, Arthur A.', 'year': '2022', 'title': 'Transition metal chalcogenide bifunctional catalysts for chemical recycling by plastic hydrocracking: a single-source precursor approach', 'doi': '10.1098/rsos.211353', 'award': 'EP/R027129/1', 'ukch_affi': 'FALSE', 'search': '2022-03-15 to 2022-03-21', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1016/j.catcom.2021.106392
# Found  {'authors': 'Abbasi, Mohammad Reza, Galvanin, Federico, Blacker, Andrew John, Sorensen, Eva, Shi, Yiping, Dyer, Philip W., Gavriilidis, Asterios', 'year': '2022', 'title': 'Process-oriented approach towards catalyst design and optimisation', 'doi': '10.1016/j.catcom.2021.106392', 'award': 'EP/R026815/1', 'ukch_affi': 'FALSE', 'search': '2022-03-15 to 2022-03-21', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1016/j.fuel.2022.123420
# Found  {'authors': 'Sun, Shuzhuang, Sun, Hongman, Guan, Shaoliang, Xu, Shaojun, Wu, Chunfei', 'year': '2022', 'title': 'Integrated CO2 capture and methanation on Ru/CeO2-MgO combined materials: Morphology effect from CeO2 support', 'doi': '10.1016/j.fuel.2022.123420', 'award': 'EP/R026939/1', 'ukch_affi': 'FALSE', 'search': '2022-03-15 to 2022-03-21', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1021/acscatal.9b01820
# Found  {'authors': 'Minova, Ivalina B., Matam, Santhosh K., Greenaway, Alex, Catlow, C. Richard A., Frogley, Mark D., Cinque, Gianfelice, Wright, Paul A., Howe, Russell F.', 'year': '2019', 'title': 'Elementary Steps in the Formation of Hydrocarbons from Surface Methoxy Groups in HZSM-5 Seen by Synchrotron Infrared Microspectroscopy', 'doi': '10.1021/acscatal.9b01820', 'award': 'EP/K014714/1, EP/K014854/1, EP/M013219/1, EP/K014668/1', 'ukch_affi': 'TRUE', 'search': '2022-03-15 to 2022-03-21', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1021/acs.nanolett.9b01733
# Found  {'authors': 'Su, Yang, Prestat, Eric, Hu, Chengyi, Puthiyapura, Vinod Kumar, Neek-Amal, Mehdi, Xiao, Hui, Huang, Kun, Kravets, Vasyl G., Haigh, Sarah J., Hardacre, Christopher, Peeters, Francois M., Nair, Rahul R.', 'year': '2019', 'title': 'Self-Limiting Growth of Two-Dimensional Palladium between Graphene Oxide Layers', 'doi': '10.1021/acs.nanolett.9b01733', 'award': 'EP/K014668/1, EP/K014706/2, EP/K014854/1, EP/K014714/1', 'ukch_affi': 'FALSE', 'search': '2022-03-15 to 2022-03-21', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1021/acs.jpcc.9b09050
# Found  {'authors': 'Omori, Naomi, Greenaway, Alex G., Sarwar, Misbah, Collier, Paul, Valentini, Gianluca, Beale, Andrew M., Candeo, Alessia', 'year': '2019', 'title': 'Understanding the Dynamics of Fluorescence Emission during Zeolite Detemplation Using Time Resolved Photoluminescence Spectroscopy', 'doi': '10.1021/acs.jpcc.9b09050', 'award': 'EP/K014714/1', 'ukch_affi': 'FALSE', 'search': '2022-03-22 to 2022-03-28', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1021/acscatal.9b00160
# Found  {'authors': 'Wolf, Moritz, Gibson, Emma K., Olivier, Ezra J., Neethling, Jan H., Catlow, C. Richard A., Fischer, Nico, Claeys, Michael', 'year': '2019', 'title': 'Water-Induced Formation of Cobalt-Support Compounds under Simulated High Conversion Fischer–Tropsch Environment', 'doi': '10.1021/acscatal.9b00160', 'award': '', 'ukch_affi': 'TRUE', 'search': '2022-03-15 to 2022-03-21', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1021/acs.jcim.8b00940
# Found  {'authors': 'Ranaghan, Kara E., Shchepanovska, Darya, Bennie, Simon J., Lawan, Narin, Macrae, Stephen J., Zurek, Jolanta, Manby, Frederick R., Mulholland, Adrian J.', 'year': '2019', 'title': 'Projector-Based Embedding Eliminates Density Functional Dependence for QM/MM Calculations of Reactions in Enzymes and Solution', 'doi': '10.1021/acs.jcim.8b00940', 'award': 'EP/M013219/1', 'ukch_affi': 'FALSE', 'search': '2022-03-15 to 2022-03-21', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1021/acs.iecr.9b04263
# Found  {'authors': 'Bin Jumah, Abdulrahman, Anbumuthu, Vanithasri, Tedstone, Aleksander A., Garforth, Arthur A.', 'year': '2019', 'title': 'Catalyzing the Hydrocracking of Low Density Polyethylene', 'doi': '10.1021/acs.iecr.9b04263', 'award': 'EP/R027129/1', 'ukch_affi': 'FALSE', 'search': '2022-03-22 to 2022-03-28', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1021/jacs.9b02731
# Found  {'authors': 'Bunzel, H. Adrian, Kries, Hajo, Marchetti, Luca, Zeymer, Cathleen, Mittl, Peer R. E., Mulholland, Adrian J., Hilvert, Donald', 'year': '2019', 'title': 'Emergence of a Negative Activation Heat Capacity during Evolution of a Designed Enzyme', 'doi': '10.1021/jacs.9b02731', 'award': 'EP/M013219/1', 'ukch_affi': 'FALSE', 'search': '2022-03-22 to 2022-03-28', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1021/acs.jpcc.9b05475
# Found  {'authors': 'Shen, Yanbin, Mamakhel, Aref, Liu, Xi, Hansen, Thomas W., Tabanelli, Tommaso, Bonincontro, Danilo, Iversen, Bo B., Prati, Laura, Li, Yongwang, Niemantsverdriet, J. W. Hans, Hutchings, Graham, Dimitratos, Nikolaos, Villa, Alberto, Su, Ren', 'year': '2019', 'title': 'Promotion Mechanisms of Au Supported on TiO<sub>2</sub> in Thermal- and Photocatalytic Glycerol Conversion', 'doi': '10.1021/acs.jpcc.9b05475', 'award': '', 'ukch_affi': 'TRUE', 'search': '2022-03-22 to 2022-03-28', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1021/acs.est.0c04279
# Found  {'authors': 'McNeice, Peter, Reid, Andrew, Imam, Hasan T., McDonagh, Carol, Walby, Joel D., Collins, Terrence J., Marr, Andrew C., Marr, Patricia C.', 'year': '2020', 'title': 'Designing Materials for Aqueous Catalysis: Ionic Liquid Gel and Silica Sphere Entrapped Iron-TAML Catalysts for Oxidative Degradation of Dyes', 'doi': '10.1021/acs.est.0c04279', 'award': 'EP/M013219/1, EP/R026645/1', 'ukch_affi': 'FALSE', 'search': '2022-03-22 to 2022-03-28', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1021/acscatal.0c05413
# Found  {'authors': 'Doble, Megan V., Obrecht, Lorenz, Joosten, Henk-Jan, Lee, Misun, Rozeboom, Henriette J., Branigan, Emma, Naismith, James. H., Janssen, Dick B., Jarvis, Amanda G., Kamer, Paul C. J.', 'year': '2021', 'title': 'Engineering Thermostability in Artificial Metalloenzymes to Increase Catalytic Activity', 'doi': '10.1021/acscatal.0c05413', 'award': 'EP/K014668/1, EP/K014706/2, EP/K014714/1, EP/K014854/1, EP/M013219/1', 'ukch_affi': 'FALSE', 'search': '2022-03-22 to 2022-03-28', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1021/acs.inorgchem.1c00327
# Found  {'authors': 'Arnold, Polly L., Halliday, Connor J. V., Puig-Urrea, Laura, Nichol, Gary S.', 'year': '2021', 'title': 'Instantaneous and Phosphine-Catalyzed Arene Binding and Reduction by U(III) Complexes', 'doi': '10.1021/acs.inorgchem.1c00327', 'award': 'EP/K014714/1', 'ukch_affi': 'FALSE', 'search': '2022-03-22 to 2022-03-28', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1021/acs.jpcc.1c10180
# Found  {'authors': 'Silveri, Fabrizio, Quesne, Matthew G., Viñes, Francesc, Illas, Francesc, Catlow, C. Richard A., de Leeuw, Nora H.', 'year': '2022', 'title': 'Catalytic Reduction of Carbon Dioxide on the (001), (011), and (111) Surfaces of TiC and ZrC: A Computational Study', 'doi': '10.1021/acs.jpcc.1c10180', 'award': '', 'ukch_affi': 'TRUE', 'search': '2022-03-22 to 2022-03-28', 'occurrence': 1, 'alt_doi': ''}
# **********************************************
# checking  pub_search_crossref\cr_archive_lookup.csv
# Found:  pub_search_crossref\cr_archive_lookup.csv  entries:  309
# adding 186 10.1002/ange.201602930
# adding 187 10.1002/ange.201609557
# reviewing: 10.1002/ange.201701745
# Found  {'authors': 'Myers, Dominic, White, Andrew J. P., Forsyth, Craig M., Bown, Mark, Williams, Charlotte K.', 'year': '2017', 'title': 'Phosphasalen Indium Complexes Showing High Rates and Isoselectivities in <i>rac</i>\n-Lactide Polymerizations', 'doi': '10.1002/ange.201701745', 'award': 'EP/K014668/1', 'ukch_affi': 'False', 'search': '2021-06-25 to 2021-07-01', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1002/ange.201703550
# Found  {'authors': 'Gibson, Emma K, Stere, Cristina E, Curran-McAteer, Bronagh, Jones, Wilm, Cibin, Giannantonio, Gianolio, Diego, Goguet, Alexandre, Wells, Peter P., Catlow, C. Richard A., Collier, Paul, Hinde, Peter, Hardacre, Christopher', 'year': '2017', 'title': 'Probing the Role of a Non-Thermal Plasma (NTP) in the Hybrid NTP Catalytic Oxidation of Methane', 'doi': '10.1002/ange.201703550', 'award': 'EP/K014706/2, EP/K014668/1, EP/K014854/1, EP/K014714/1', 'ukch_affi': 'True', 'search': '2021-06-25 to 2021-07-01', 'occurrence': 1, 'alt_doi': ''}
# adding 188 10.1002/ange.201705753
# reviewing: 10.1002/ange.201713115
# Found  {'authors': 'Falkowska, Marta, Bowron, Daniel T., Manyar, Haresh, Youngs, Tristan G. A., Hardacre, Christopher', 'year': '2018', 'title': 'Confinement Effects on the Benzene Orientational Structure', 'doi': '10.1002/anie.201713115', 'award': 'EP/K014668/1, EP/K014854/1, EP/K014714/1, EP/M013219/1', 'ukch_affi': 'False', 'search': '2021-10-08 to 2021-10-14', 'occurrence': 2, 'alt_doi': '10.1002/anie.201713115'}
# reviewing: 10.1002/ange.201801400
# Found  {'authors': 'Stößer, Tim, Williams, Charlotte K.', 'year': '2018', 'title': 'Selektive Katalyse für Polymerisationen mit Monomermischungen: Verwendung eines kommerziellen Cr‐Salen‐Katalysators zur Herstellung von ABA‐Blockpolyestern', 'doi': '10.1002/ange.201801400', 'award': 'EP/K014668/1', 'ukch_affi': 'False', 'search': '2021-06-11 to 2021-06-17', 'occurrence': 2, 'alt_doi': '10.1002/ange.201801400'}
# reviewing: 10.1002/ange.201810245
# Found  {'authors': 'Stößer, Tim, Mulryan, Daniel, Williams, Charlotte K.', 'year': '2018', 'title': 'Schaltbare Katalyse zur Herstellung von Multiblock‐Polyestern aus einer Mischung von Propylenoxid, Lactid und Phthalsäureanhydrid', 'doi': '10.1002/ange.201810245', 'award': 'EP/K014668/1', 'ukch_affi': 'False', 'search': '2021-06-25 to 2021-07-01', 'occurrence': 1, 'alt_doi': ''}
# adding 189 10.1002/ange.201810709
# adding 190 10.1002/ange.201812058
# adding 191 10.1002/ange.201814320
# adding 192 10.1002/ange.201814381
# reviewing: 10.1002/ange.201901592
# Found  {'authors': 'Lim, Jason Y. C., Yuntawattana, Nattawut, Beer, Paul D., Williams, Charlotte K.', 'year': '2019', 'title': 'Isoselective Lactide Ring Opening Polymerisation using [2]Rotaxane Catalysts', 'doi': '10.1002/ange.201901592', 'award': 'EP/K014668/1', 'ukch_affi': 'False', 'search': '2021-06-25 to 2021-07-01', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1002/ange.201902857
# Found  {'authors': "Clément, Pierrick, Xu, Xinzhao, Stoppiello, Craig T., Rance, Graham A., Attanzio, Antonio, O'Shea, James N., Temperton, Robert H., Khlobystov, Andrei N., Lovelock, Kevin R. J., Seymour, Jake M., Fogarty, Richard M., Baker, Alastair, Bourne, Richard A., Hall, Brendan, Chamberlain, Thomas W., Palma, Matteo", 'year': '2019', 'title': 'Direct Synthesis of Multiplexed Metal‐Nanowire‐Based Devices by Using Carbon Nanotubes as Vector Templates', 'doi': '10.1002/ange.201902857', 'award': 'EP/K014714/1', 'ukch_affi': 'False', 'search': '2021-06-25 to 2021-07-01', 'occurrence': 2, 'alt_doi': '10.1002/ange.201902857'}
# reviewing: 10.1002/ange.202006807
# Found  {'authors': 'Chen, Thomas T. D., Carrodeguas, Leticia Peña, Sulley, Gregory S., Gregory, Georgina L., Williams, Charlotte K.', 'year': '2020', 'title': 'Bio‐based and Degradable Block Polyester Pressure‐Sensitive Adhesives', 'doi': '10.1002/ange.202006807', 'award': 'EP/K014668/1', 'ukch_affi': 'False', 'search': '2021-01-22 to 2021-01-28', 'occurrence': 2, 'alt_doi': '10.1002/ange.202006807'}
# reviewing: 10.1002/ange.202011839
# Found  {'authors': 'Protchenko, Andrey V., Vasko, Petra, Fuentes, M. Ángeles, Hicks, Jamie, Vidovic, Dragoslav, Aldridge, Simon', 'year': '2020', 'title': 'Approaching a “Naked” Boryl Anion: Amide Metathesis as a Route to Calcium, Strontium, and Potassium Boryl Complexes', 'doi': '10.1002/ange.202011839', 'award': 'EP/K014714/1', 'ukch_affi': 'False', 'search': '2021-07-02 to 2021-07-08', 'occurrence': 2, 'alt_doi': '10.1002/ange.202011839'}
# reviewing: 10.1002/anie.201602930
# Found  {'authors': 'Thevenon, , Arnaud, Romain, Charles, Bennington, Michael S., White, Andrew J. P., Davidson, Hannah J., Brooker, Sally, Williams, Charlotte K.', 'year': '2016', 'title': 'Dizinc Lactide Polymerization Catalysts: Hyperactivity by Control of Ligand Conformation and Metallic Cooperativity', 'doi': '10.1002/ange.201602930', 'award': 'EP/K014668/1, EP/L017393/1, EP/K014070/1, EP/K035274/1', 'ukch_affi': 'FALSE', 'search': 'archive before 2021-01', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1002/anie.201609557
# Found  {'authors': 'Demiray, , Melodi, Tang, Xiaoping, Wirth, Thomas, Faraldos, Juan A., Allemann, Rudolf K.', 'year': '2017', 'title': 'Effiziente chemoenzymatische Synthese von Dihydroartemisinaldehyd', 'doi': '10.1002/ange.201609557', 'award': 'BB/H01683X/1, BB/N012526/1, BB/M022463/1, EP/M013219/1', 'ukch_affi': 'FALSE', 'search': 'archive before 2021-02', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1002/anie.201701745
# Found  {'authors': 'Myers, Dominic, White, Andrew J. P., Forsyth, Craig M., Bown, Mark, Williams, Charlotte K.', 'year': '2017', 'title': 'Phosphasalen Indium Complexes Showing High Rates and Isoselectivities in <i>rac</i>\n-Lactide Polymerizations', 'doi': '10.1002/ange.201701745', 'award': 'EP/K014668/1', 'ukch_affi': 'False', 'search': '2021-06-25 to 2021-07-01', 'occurrence': 2, 'alt_doi': '10.1002/anie.201701745'}
# reviewing: 10.1002/anie.201703550
# Found  {'authors': 'Gibson, Emma K, Stere, Cristina E, Curran-McAteer, Bronagh, Jones, Wilm, Cibin, Giannantonio, Gianolio, Diego, Goguet, Alexandre, Wells, Peter P., Catlow, C. Richard A., Collier, Paul, Hinde, Peter, Hardacre, Christopher', 'year': '2017', 'title': 'Probing the Role of a Non-Thermal Plasma (NTP) in the Hybrid NTP Catalytic Oxidation of Methane', 'doi': '10.1002/ange.201703550', 'award': 'EP/K014706/2, EP/K014668/1, EP/K014854/1, EP/K014714/1', 'ukch_affi': 'True', 'search': '2021-06-25 to 2021-07-01', 'occurrence': 2, 'alt_doi': '10.1002/anie.201703550'}
# reviewing: 10.1002/anie.201705753
# Found  {'authors': 'Jarvis, , Amanda G., Obrecht, Lorenz, Deuss, Peter J., Laan, Wouter, Gibson, Emma K., Wells, Peter P., Kamer, Paul C. J.', 'year': '2017', 'title': 'Enzyme Activity by Design: An Artificial Rhodium Hydroformylase for Linear Aldehydes', 'doi': '10.1002/ange.201705753', 'award': 'H2020-MSCA-IF-2014-657755, EP/K014854/1, EP/J018139/1, FP6-2003-NEST-B3 15471, MEXT-2004-014320', 'ukch_affi': 'TRUE', 'search': 'archive before 2021-05', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1002/anie.201713115
# Found  {'authors': 'Falkowska, Marta, Bowron, Daniel T., Manyar, Haresh, Youngs, Tristan G. A., Hardacre, Christopher', 'year': '2018', 'title': 'Confinement Effects on the Benzene Orientational Structure', 'doi': '10.1002/anie.201713115', 'award': 'EP/K014668/1, EP/K014854/1, EP/K014714/1, EP/M013219/1', 'ukch_affi': 'False', 'search': '2021-10-08 to 2021-10-14', 'occurrence': 3, 'alt_doi': '10.1002/anie.201713115'}
# reviewing: 10.1002/anie.201801400
# Found  {'authors': 'Stößer, Tim, Williams, Charlotte K.', 'year': '2018', 'title': 'Selektive Katalyse für Polymerisationen mit Monomermischungen: Verwendung eines kommerziellen Cr‐Salen‐Katalysators zur Herstellung von ABA‐Blockpolyestern', 'doi': '10.1002/ange.201801400', 'award': 'EP/K014668/1', 'ukch_affi': 'False', 'search': '2021-06-11 to 2021-06-17', 'occurrence': 3, 'alt_doi': '10.1002/anie.201801400'}
# reviewing: 10.1002/anie.201810245
# Found  {'authors': 'Stößer, Tim, Mulryan, Daniel, Williams, Charlotte K.', 'year': '2018', 'title': 'Schaltbare Katalyse zur Herstellung von Multiblock‐Polyestern aus einer Mischung von Propylenoxid, Lactid und Phthalsäureanhydrid', 'doi': '10.1002/ange.201810245', 'award': 'EP/K014668/1', 'ukch_affi': 'False', 'search': '2021-06-25 to 2021-07-01', 'occurrence': 2, 'alt_doi': '10.1002/anie.201810245'}
# reviewing: 10.1002/anie.201810709
# Found  {'authors': 'Loh, , Ying Kai, Ángeles\u2005Fuentes, M., Vasko, Petra, Aldridge, Simon', 'year': '2018', 'title': 'Successive Protonation of an N-Heterocyclic Imine Derived Carbonyl: Superelectrophilic Dication Versus Masked Acylium Ion', 'doi': '10.1002/ange.201810709', 'award': 'EP/K014714/1', 'ukch_affi': 'FALSE', 'search': 'archive before 2021-09', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1002/anie.201812058
# Found  {'authors': 'Loh, , Ying Kai, Ying, Lu, Ángeles\u2005Fuentes, M., Do, Dinh Cao Huan, Aldridge, Simon', 'year': '2019', 'title': 'An N‐Heterocyclic Boryloxy Ligand Isoelectronic with N‐Heterocyclic Imines: Access to an Acyclic Dioxysilylene and its Heavier Congeners', 'doi': '10.1002/ange.201812058', 'award': 'EP/K014714/1', 'ukch_affi': 'FALSE', 'search': 'archive before 2021-10', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1002/anie.201814320
# Found  {'authors': 'Zhu, , Yunqing, Poma, Alessandro, Rizzello, Loris, Gouveia, Virginia M., Ruiz‐Perez, Lorena, Battaglia, Giuseppe, Williams, Charlotte K.', 'year': '2019', 'title': 'Metabolically Active, Fully Hydrolysable Polymersomes', 'doi': '10.1002/ange.201814320', 'award': 'EP/K014668/1, EP/L017393/1, EP/N026322/1, EnCO2re, ERC # 278793', 'ukch_affi': 'FALSE', 'search': 'archive before 2021-11', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1002/anie.201814381
# Found  {'authors': 'Jones, , Benjamin A., Balan, Tudor, Jolliffe, John D., Campbell, Craig D., Smith, Martin D.', 'year': '2019', 'title': 'Practical and Scalable Kinetic Resolution of BINOLs Mediated by a Chiral Counterion', 'doi': '10.1002/ange.201814381', 'award': 'EP/K014668/1, DTP, EP/ L015838/1', 'ukch_affi': 'FALSE', 'search': 'archive before 2021-12', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1002/anie.201901592
# Found  {'authors': 'Lim, Jason Y. C., Yuntawattana, Nattawut, Beer, Paul D., Williams, Charlotte K.', 'year': '2019', 'title': 'Isoselective Lactide Ring Opening Polymerisation using [2]Rotaxane Catalysts', 'doi': '10.1002/ange.201901592', 'award': 'EP/K014668/1', 'ukch_affi': 'False', 'search': '2021-06-25 to 2021-07-01', 'occurrence': 2, 'alt_doi': '10.1002/anie.201901592'}
# reviewing: 10.1002/anie.201902857
# Found  {'authors': "Clément, Pierrick, Xu, Xinzhao, Stoppiello, Craig T., Rance, Graham A., Attanzio, Antonio, O'Shea, James N., Temperton, Robert H., Khlobystov, Andrei N., Lovelock, Kevin R. J., Seymour, Jake M., Fogarty, Richard M., Baker, Alastair, Bourne, Richard A., Hall, Brendan, Chamberlain, Thomas W., Palma, Matteo", 'year': '2019', 'title': 'Direct Synthesis of Multiplexed Metal‐Nanowire‐Based Devices by Using Carbon Nanotubes as Vector Templates', 'doi': '10.1002/ange.201902857', 'award': 'EP/K014714/1', 'ukch_affi': 'False', 'search': '2021-06-25 to 2021-07-01', 'occurrence': 3, 'alt_doi': '10.1002/anie.201902857'}
# reviewing: 10.1002/anie.202006807
# Found  {'authors': 'Chen, Thomas T. D., Carrodeguas, Leticia Peña, Sulley, Gregory S., Gregory, Georgina L., Williams, Charlotte K.', 'year': '2020', 'title': 'Bio‐based and Degradable Block Polyester Pressure‐Sensitive Adhesives', 'doi': '10.1002/ange.202006807', 'award': 'EP/K014668/1', 'ukch_affi': 'False', 'search': '2021-01-22 to 2021-01-28', 'occurrence': 3, 'alt_doi': '10.1002/anie.202006807'}
# reviewing: 10.1002/anie.202011839
# Found  {'authors': 'Protchenko, Andrey V., Vasko, Petra, Fuentes, M. Ángeles, Hicks, Jamie, Vidovic, Dragoslav, Aldridge, Simon', 'year': '2020', 'title': 'Approaching a “Naked” Boryl Anion: Amide Metathesis as a Route to Calcium, Strontium, and Potassium Boryl Complexes', 'doi': '10.1002/ange.202011839', 'award': 'EP/K014714/1', 'ukch_affi': 'False', 'search': '2021-07-02 to 2021-07-08', 'occurrence': 3, 'alt_doi': '10.1002/anie.202011839'}
# reviewing: 10.1002/cctc.201500545
# Found  {'authors': 'Hammond, Ceri, Padovan, Daniele, Al-Nayili, Abbas, Wells, Peter. P., Gibson, Emma K., Dimitratos, Nikolaos', 'year': '2015', 'title': 'Identification of Active and Spectator Sn Sites in Sn-β Following Solid-State Stannation, and Consequences for Lewis Acid Catalysis', 'doi': '10.1002/cctc.201500545', 'award': 'EP/K014714/1', 'ukch_affi': 'True', 'search': '2021-07-02 to 2021-07-08', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1002/cctc.201600729
# Found  {'authors': 'Erigoni, Andrea, Newland, Stephanie H., Paul, Geo, Marchese, Leonardo, Raja, Robert, Gianotti, Enrica', 'year': '2016', 'title': 'Creating Accessible Active Sites in Hierarchical MFI Zeolites for Low-Temperature Acid Catalysis', 'doi': '10.1002/cctc.201600729', 'award': 'EP/K014668/1, EP/K014854/1, EP/K014714/1, EP/M013219/1', 'ukch_affi': 'False', 'search': '2021-07-02 to 2021-07-08', 'occurrence': 1, 'alt_doi': ''}
# adding 193 10.1002/cctc.201700516
# adding 194 10.1002/cctc.201801067
# adding 195 10.1002/cctc.201801299
# adding 196 10.1002/cctc.201900401
# adding 197 10.1002/cctc.201900658
# adding 198 10.1002/cctc.201900795
# adding 199 10.1002/cctc.201901166
# adding 200 10.1002/cctc.201901955
# reviewing: 10.1002/cctc.201902135
# Found  {'authors': 'Valikhani, Donya, Srivastava, Prabhakar Lal, Allemann, Rudolf K., Wirth, Thomas', 'year': '2020', 'title': 'Immobilised Enzymes for Sesquiterpene Synthesis in Batch and Flow Systems', 'doi': '10.1002/cctc.201902135', 'award': 'EP/M013219/1', 'ukch_affi': 'False', 'search': '2021-07-02 to 2021-07-08', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1002/celc.201800052
# Found  {'authors': 'Gobaille-Shaw, Gael. P. A., Celorrio, Veronica, Calvillo, Laura, Morris, Louis J., Granozzi, Gaetano, Fermín, David. J.', 'year': '2018', 'title': 'Effect of Ba Content on the Activity of La<sub>1-<i>x</i>\n                        </sub>\nBa<sub>\n                            <i>x</i>\n                        </sub>\nMnO<sub>3</sub>\n Towards the Oxygen Reduction Reaction', 'doi': '10.1002/celc.201800052', 'award': 'EP/K014714/1', 'ukch_affi': 'True', 'search': '2021-07-02 to 2021-07-08', 'occurrence': 2, 'alt_doi': ''}
# reviewing: 10.1002/celc.201800478
# Found  {'authors': 'Chen, Chang-Hui, Brennan, Colin, Lai, Stanley C. S., Fermin, David J., Unwin, Patrick R., Rodriguez, Paramaconi', 'year': '2018', 'title': 'Adsorption and Electrochemical Oxidation of Small Sulfur−Containing Anions on Pt Electrodes in Organic Media', 'doi': '10.1002/celc.201800478', 'award': 'EP/K014706/2, EP/K014668/1, EP/K014854/1, EP/K014714/1, EP/M013219/1', 'ukch_affi': 'False', 'search': '2021-07-02 to 2021-07-08', 'occurrence': 1, 'alt_doi': ''}
# adding 201 10.1002/celc.201800729
# reviewing: 10.1002/celc.201902005
# Found  {'authors': 'Freeman, Emma, Kumar, Santosh, Thomas, Sophie R., Pickering, Hayley, Fermin, David J., Eslava, Salvador', 'year': '2020', 'title': 'PrFeO\n            <sub>3</sub>\n            Photocathodes Prepared Through Spray Pyrolysis', 'doi': '10.1002/celc.201902005', 'award': 'EP/K014714/1', 'ukch_affi': 'False', 'search': '2021-04-09 to 2021-04-15', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1002/chem.201701013
# Found  {'authors': 'Romain, Charles, Garden, Jennifer A., Trott, Gemma, Buchard, Antoine, White, Andrew J. P., Williams, Charlotte K.', 'year': '2017', 'title': 'Di-Zinc-Aryl Complexes: CO<sub>2</sub>Insertions and Applications in Polymerisation Catalysis', 'doi': '10.1002/chem.201701013', 'award': 'EP/K014668/1', 'ukch_affi': 'False', 'search': '2021-07-02 to 2021-07-08', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1002/chem.201801871
# Found  {'authors': 'Vasko, Petra, Zulkifly, Ili A., Fuentes, M. Ángeles, Mo, Zhenbo, Hicks, Jamie, Kamer, Paul C. J., Aldridge, Simon', 'year': '2018', 'title': 'Reversible C−H Activation, Facile C−B/B−H Metathesis and Apparent Hydroboration Catalysis by a Dimethylxanthene-Based Frustrated Lewis Pair', 'doi': '10.1002/chem.201801871', 'award': 'EP/K014714/1', 'ukch_affi': 'False', 'search': '2021-07-02 to 2021-07-08', 'occurrence': 1, 'alt_doi': ''}
# adding 202 10.1002/chem.201804808
# reviewing: 10.1002/chem.201805250
# Found  {'authors': 'Limb, Michael A. L., Suardíaz, Reynier, Grant, Ian M., Mulholland, Adrian J.', 'year': '2018', 'title': 'Quantum Mechanics/Molecular Mechanics Simulations Show Saccharide Distortion is Required for Reaction in Hen Egg‐White Lysozyme', 'doi': '10.1002/chem.201805250', 'award': 'EP/M013219/1', 'ukch_affi': 'False', 'search': '2021-07-02 to 2021-07-08', 'occurrence': 2, 'alt_doi': ''}
# adding 203 10.1002/chem.201901188
# reviewing: 10.1002/chem.202004408
# Found  {'authors': 'Caise, Alexa, Hicks, Jamie, Ángeles Fuentes, M., Goicoechea, Jose M., Aldridge, Simon', 'year': '2020', 'title': 'Partnering a Three‐Coordinate Gallium Cation with a Hydroborate Counter‐Ion for the Catalytic Hydrosilylation of CO\n            <sub>2</sub>', 'doi': '10.1002/chem.202004408', 'award': 'EP/K014714/1', 'ukch_affi': 'False', 'search': '2021-01-22 to 2021-01-28', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1002/cphc.201600149
# Found  {'authors': 'Falkowska, Marta, Bowron, Daniel T., Manyar, Haresh G., Hardacre, Christopher, Youngs, Tristan G. A.', 'year': '2016', 'title': 'Neutron Scattering of Aromatic and Aliphatic Liquids', 'doi': '10.1002/cphc.201600149', 'award': 'EP/K014668/1, EP/K014854/1, EP/K014714/1, EP/M013219/1', 'ukch_affi': 'False', 'search': '2021-07-02 to 2021-07-08', 'occurrence': 1, 'alt_doi': ''}
# adding 204 10.1002/cphc.201800721
# adding 205 10.1002/cphc.201801054
# reviewing: 10.1002/cplu.201500195
# Found  {'authors': 'Hinde, Christopher S., Gill, Arran M., Wells, Peter P., Hor, T. S. Andy, Raja, Robert', 'year': '2015', 'title': 'Utilizing Benign Oxidants for Selective Aerobic Oxidations Using Heterogenized Platinum Nanoparticle Catalysts', 'doi': '10.1002/cplu.201500195', 'award': 'EP/K014668/1, EP/K014854/1, EP/K014714/1', 'ukch_affi': 'False', 'search': '2021-02-12 to 2021-02-18', 'occurrence': 1, 'alt_doi': ''}
# adding 206 10.1002/cptc.201700210
# reviewing: 10.1002/cssc.201501264
# Found  {'authors': 'Gill, Arran M., Hinde, Christopher S., Leary, Rowan K., Potter, Matthew E., Jouve, Andrea, Wells, Peter P., Midgley, Paul A., Thomas, John M., Raja, Robert', 'year': '2016', 'title': 'Design of Highly Selective Platinum Nanoparticle Catalysts for the Aerobic Oxidation of KA-Oil using Continuous-Flow Chemistry', 'doi': '10.1002/cssc.201501264', 'award': 'EP/K014668/1, EP/K014854/1, EP/K014714/1', 'ukch_affi': 'True', 'search': '2021-07-02 to 2021-07-08', 'occurrence': 1, 'alt_doi': ''}
# adding 207 10.1002/cssc.201600245
# reviewing: 10.1002/cssc.201600246
# Found  {'authors': 'Gill, Arran M., Hinde, Christopher S., Leary, Rowan K., Potter, Matthew E., Jouve, Andrea, Wells, Peter P., Midgley, Paul A., Thomas, John M., Raja, Robert', 'year': '2016', 'title': 'Design of Highly Selective Platinum Nanoparticle Catalysts for the Aerobic Oxidation of KA-Oil using Continuous-Flow Chemistry', 'doi': '10.1002/cssc.201600246', 'award': 'EP/K014714/1', 'ukch_affi': 'True', 'search': '2021-07-02 to 2021-07-08', 'occurrence': 1, 'alt_doi': ''}
# adding 208 10.1002/cssc.201902340
# adding 209 10.1002/ejoc.201601388
# reviewing: 10.1002/jctb.4662
# Found  {'authors': 'Ciddor, Lachlan, Bennett, James A, Hunns, James A, Wilson, Karen, Lee, Adam F', 'year': '2015', 'title': 'Catalytic upgrading of bio-oils by esterification', 'doi': '10.1002/jctb.4662', 'award': 'EP/K014714/1', 'ukch_affi': 'False', 'search': '2021-07-02 to 2021-07-08', 'occurrence': 1, 'alt_doi': ''}
# adding 210 10.1007/s10562-016-1742-5
# adding 211 10.1007/s10562-019-02876-7
# reviewing: 10.1007/s11244-020-01245-8
# Found  {'authors': 'Wangkawong, Kanlayawat, Phanichphant, Sukon, Inceesungvorn, Burapat, Stere, Cristina E., Chansai, Sarayute, Hardacre, Christopher, Goguet, Alexandre', 'year': '2020', 'title': 'Kinetics of Water Gas Shift Reaction on Au/CeZrO4: A Comparison Between Conventional Heating and Dielectric Barrier Discharge (DBD) Plasma Activation', 'doi': '10.1007/s11244-020-01245-8', 'award': 'EP/K014706/2, EP/K014668/1, EP/K014854/1, EP/K014714/1', 'ukch_affi': 'False', 'search': '2021-02-26 to 2021-03-04', 'occurrence': 1, 'alt_doi': ''}
# adding 212 10.1016/j.apcata.2015.10.023
# adding 213 10.1016/j.apcata.2017.03.039
# reviewing: 10.1016/j.apcata.2018.10.010
# Found  {'authors': 'Zachariou, Andrea, Hawkins, Alexander, Lennon, David, Parker, Stewart F., Suwardiyanto, Matam, Santhosh K., Catlow, C. Richard A., Collier, Paul, Hameed, Ali, McGregor, James, Howe, Russell F.', 'year': '2019', 'title': 'Investigation of ZSM-5 catalysts for dimethylether conversion using inelastic neutron scattering', 'doi': '10.1016/j.apcata.2018.10.010', 'award': 'EP/K014668/1, EP/K014714/1, EP/M013219/1, EP/K014854/1', 'ukch_affi': 'False', 'search': '2021-01-15 to 2021-01-21', 'occurrence': 1, 'alt_doi': ''}
# adding 214 10.1016/j.apcatb.2017.01.042
# adding 215 10.1016/j.apcatb.2018.07.008
# adding 216 10.1016/j.apcatb.2018.07.072
# adding 217 10.1016/j.apcatb.2020.118752
# adding 218 10.1016/j.bmc.2014.07.002
# adding 219 10.1016/j.bmc.2017.03.068
# adding 220 10.1016/j.carbon.2016.07.045
# adding 221 10.1016/j.cattod.2016.06.017
# adding 222 10.1016/j.cattod.2018.03.046
# adding 223 10.1016/j.cattod.2018.06.033
# adding 224 10.1016/j.cattod.2018.07.014
# adding 225 10.1016/j.cattod.2020.05.030
# adding 226 10.1016/j.cej.2019.123176
# adding 227 10.1016/j.electacta.2018.07.025
# adding 228 10.1016/j.est.2018.06.016
# adding 229 10.1016/j.ijhydene.2016.06.132
# adding 230 10.1016/j.ijhydene.2016.08.081
# adding 231 10.1016/j.ijhydene.2016.08.192
# adding 232 10.1016/j.jcat.2016.03.017
# adding 233 10.1016/j.jcat.2019.03.037
# adding 234 10.1016/j.jclepro.2016.11.159
# adding 235 10.1016/j.jelechem.2018.03.015
# adding 236 10.1016/j.joule.2020.07.024
# adding 237 10.1016/j.jphotochem.2018.01.031
# adding 238 10.1016/j.jpowsour.2018.02.022
# adding 239 10.1016/j.micromeso.2017.02.048
# adding 240 10.1016/j.sbi.2020.06.001
# adding 241 10.1016/j.ssi.2018.03.016
# adding 242 10.1016/j.susc.2015.11.010
# adding 243 10.1016/j.susc.2015.12.024
# adding 244 10.1016/j.susc.2016.01.001
# adding 245 10.1016/j.susc.2016.05.002
# adding 246 10.1016/j.tetasy.2015.02.002
# adding 247 10.1016/s1872-2067(19)63350-4
# reviewing: 10.1021/acs.biochem.8b00169
# Found  {'authors': 'Messiha, Hanan L., Ahmed, Syed T., Karuppiah, Vijaykumar, Suardíaz, Reynier, Ascue Avalos, Gabriel A., Fey, Natalie, Yeates, Stephen, Toogood, Helen S., Mulholland, Adrian J., Scrutton, Nigel S.', 'year': '2018', 'title': 'Biocatalytic Routes to Lactone Monomers for Polymer Production', 'doi': '10.1021/acs.biochem.8b00169', 'award': 'EP/K014668/1, EP/M013219/1, EP/K014714/1, EP/K014854/1', 'ukch_affi': 'False', 'search': '2021-08-20 to 2021-08-26', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1021/acs.chemmater.5b00866
# Found  {'authors': 'Gibson, Emma K., Beale, Andrew M., Catlow, C. Richard A., Chutia, Arunabhiram, Gianolio, Diego, Gould, Anna, Kroner, Anna, Mohammed, Khaled M. H., Perdjon, Michal, Rogers, Scott M., Wells, Peter P.', 'year': '2015', 'title': 'Restructuring of AuPd Nanoparticles Studied by a Combined XAFS/DRIFTS Approach', 'doi': '10.1021/acs.chemmater.5b00866', 'award': 'EP/K014668/1, EP/K014714/1, EP/K014854/1', 'ukch_affi': 'False', 'search': '2021-08-13 to 2021-08-19', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1021/acs.chemmater.7b02552
# Found  {'authors': 'Dann, Ellie K., Gibson, Emma K., Catlow, Richard A., Collier, Paul, Eralp Erden, Tugce, Gianolio, Diego, Hardacre, Christopher, Kroner, Anna, Raj, Agnes, Goguet, Alexandre, Wells, Peter P.', 'year': '2017', 'title': 'Combined In Situ XAFS/DRIFTS Studies of the Evolution of Nanoparticle Structures from Molecular Precursors', 'doi': '10.1021/acs.chemmater.7b02552', 'award': 'EP/K014668/1, EP/K014714/1, EP/K014854/1', 'ukch_affi': 'False', 'search': '2021-08-27 to 2021-09-02', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1021/acs.chemrev.9b00662
# Found  {'authors': 'Sankar, Meenakshisundaram, He, Qian, Engel, Rebecca V., Sainna, Mala A., Logsdail, Andrew J., Roldan, Alberto, Willock, David J., Agarwal, Nishtha, Kiely, Christopher J., Hutchings, Graham J.', 'year': '2020', 'title': 'Role of the Support in Gold-Containing Nanoparticles as Heterogeneous Catalysts', 'doi': '10.1021/acs.chemrev.9b00662', 'award': 'EP/R026645/1, EP/R026815/1, EP/R026939/1, EP/R027129/1', 'ukch_affi': 'False', 'search': '2021-08-20 to 2021-08-26', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1021/acs.est.0c04279
# Found  {'authors': 'McNeice, Peter, Reid, Andrew, Imam, Hasan T., McDonagh, Carol, Walby, Joel D., Collins, Terrence J., Marr, Andrew C., Marr, Patricia C.', 'year': '2020', 'title': 'Designing Materials for Aqueous Catalysis: Ionic Liquid Gel and Silica Sphere Entrapped Iron-TAML Catalysts for Oxidative Degradation of Dyes', 'doi': '10.1021/acs.est.0c04279', 'award': 'EP/M013219/1, EP/R026645/1', 'ukch_affi': 'FALSE', 'search': '2022-03-22 to 2022-03-28', 'occurrence': 2, 'alt_doi': ''}
# reviewing: 10.1021/acs.iecr.8b00230
# Found  {'authors': 'Bahruji, Hasliza, Armstrong, Robert D., Ruiz Esquius, Jonathan, Jones, Wilm, Bowker, Michael, Hutchings, Graham J.', 'year': '2018', 'title': 'Hydrogenation of CO<sub>2</sub> to Dimethyl Ether over Brønsted Acidic PdZn Catalysts', 'doi': '10.1021/acs.iecr.8b00230', 'award': 'EP/K014668/1, EP/K014714/1, EP/M013219/1, EP/K014854/1', 'ukch_affi': 'True', 'search': '2021-08-20 to 2021-08-26', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1021/acs.iecr.9b04263
# Found  {'authors': 'Bin Jumah, Abdulrahman, Anbumuthu, Vanithasri, Tedstone, Aleksander A., Garforth, Arthur A.', 'year': '2019', 'title': 'Catalyzing the Hydrocracking of Low Density Polyethylene', 'doi': '10.1021/acs.iecr.9b04263', 'award': 'EP/R027129/1', 'ukch_affi': 'FALSE', 'search': '2022-03-22 to 2022-03-28', 'occurrence': 2, 'alt_doi': ''}
# reviewing: 10.1021/acs.inorgchem.8b02923
# ...
# reviewing: 10.1021/acsomega.9b03351
# Found  {'authors': 'Zachariou, Andrea, Hawkins, Alexander P., Collier, Paul, Howe, Russell F., Lennon, David, Parker, Stewart F.', 'year': '2020', 'title': 'The Methyl Torsion in Unsaturated Compounds', 'doi': '10.1021/acsomega.9b03351', 'award': 'EP/M013219/1, EP/R026645/1, EP/R026815/1, EP/R026939/1, EP/R027129/1', 'ukch_affi': 'True', 'search': '2021-08-27 to 2021-09-02', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1021/acsomega.9b03503
# Found  {'authors': 'Hawkins, Alexander P., Zachariou, Andrea, Parker, Stewart F., Collier, Paul, Silverwood, Ian P., Howe, Russell F., Lennon, David', 'year': '2020', 'title': 'Onset of Propene Oligomerization Reactivity in ZSM-5 Studied by Inelastic Neutron Scattering Spectroscopy', 'doi': '10.1021/acsomega.9b03503', 'award': '', 'ukch_affi': 'True', 'search': '2021-08-13 to 2021-08-19', 'occurrence': 1, 'alt_doi': ''}
# adding 251 10.1021/acssuschemeng.5b00894
# reviewing: 10.1021/acssuschemeng.8b03568
# Found  {'authors': 'Doble, Megan V., Jarvis, Amanda G., Ward, Andrew C. C., Colburn, Jonathan D., Götze, Jan P., Bühl, Michael, Kamer, Paul C. J.', 'year': '2018', 'title': 'Artificial Metalloenzymes as Catalysts for Oxidative Lignin Degradation', 'doi': '10.1021/acssuschemeng.8b03568', 'award': 'EP/K014668/1, EP/K014854/1, EP/M013219/1, EP/K014714/1, EP/K014706/2', 'ukch_affi': 'False', 'search': '2021-08-13 to 2021-08-19', 'occurrence': 1, 'alt_doi': ''}
# adding 252 10.1021/acssuschemeng.8b04073
# adding 253 10.1021/cm503433q
# adding 254 10.1021/cs400683e
# reviewing: 10.1021/jacs.0c07980
# Found  {'authors': 'Deacy, Arron C., Moreby, Emma, Phanopoulos, Andreas, Williams, Charlotte K.', 'year': '2020', 'title': 'Co(III)/Alkali-Metal(I) Heterodinuclear Catalysts for the Ring-Opening Copolymerization of CO<sub>2</sub> and Propylene Oxide', 'doi': '10.1021/jacs.0c07980', 'award': 'EP/R027129/1', 'ukch_affi': 'False', 'search': '2021-08-13 to 2021-08-19', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1021/jacs.5b08614
# Found  {'authors': 'Mo, Zhenbo, Kolychev, Eugene L., Rit, Arnab, Campos, Jesús, Niu, Haoyu, Aldridge, Simon', 'year': '2015', 'title': 'Facile Reversibility by Design: Tuning Small Molecule Capture and Activation by Single Component Frustrated Lewis Pairs', 'doi': '10.1021/jacs.5b08614', 'award': 'EP/K014714/1', 'ukch_affi': 'False', 'search': '2021-08-20 to 2021-08-26', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1021/jacs.5b13070
# Found  {'authors': 'Romain, Charles, Zhu, Yunqing, Dingwall, Paul, Paul, Shyeni, Rzepa, Henry S., Buchard, Antoine, Williams, Charlotte K.', 'year': '2016', 'title': 'Chemoselective Polymerizations from Mixtures of Epoxide, Lactone, Anhydride, and Carbon Dioxide', 'doi': '10.1021/jacs.5b13070', 'award': 'EP/K014668/1', 'ukch_affi': 'False', 'search': '2021-08-06 to 2021-08-12', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1021/jacs.6b00710
# Found  {'authors': 'Protchenko, Andrey V., Bates, Joshua I., Saleh, Liban M. A., Blake, Matthew P., Schwarz, Andrew D., Kolychev, Eugene L., Thompson, Amber L., Jones, Cameron, Mountford, Philip, Aldridge, Simon', 'year': '2016', 'title': 'Enabling and Probing Oxidative Addition and Reductive Elimination at a Group 14 Metal Center: Cleavage and Functionalization of E–H Bonds by a Bis(boryl)stannylene', 'doi': '10.1021/jacs.6b00710', 'award': 'EP/K014714/1', 'ukch_affi': 'False', 'search': '2021-08-20 to 2021-08-26', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1021/jacs.6b01170
# Found  {'authors': 'Mo, Zhenbo, Rit, Arnab, Campos, Jesús, Kolychev, Eugene L., Aldridge, Simon', 'year': '2016', 'title': 'Catalytic B–N Dehydrogenation Using Frustrated Lewis Pairs: Evidence for a Chain-Growth Coupling Mechanism', 'doi': '10.1021/jacs.6b01170', 'award': 'EP/K014714/1', 'ukch_affi': 'False', 'search': '2021-08-13 to 2021-08-19', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1021/jacs.8b01920
# Found  {'authors': 'Thevenon, Arnaud, Cyriac, Anish, Myers, Dominic, White, Andrew J. P., Durr, Christopher B., Williams, Charlotte K.', 'year': '2018', 'title': 'Indium Catalysts for Low-Pressure CO<sub>2</sub>/Epoxide Ring-Opening Copolymerization: Evidence for a Mononuclear Mechanism?', 'doi': '10.1021/jacs.8b01920', 'award': 'EP/K014668/1', 'ukch_affi': 'False', 'search': '2021-08-27 to 2021-09-02', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1021/jacs.9b02731
# Found  {'authors': 'Bunzel, H. Adrian, Kries, Hajo, Marchetti, Luca, Zeymer, Cathleen, Mittl, Peer R. E., Mulholland, Adrian J., Hilvert, Donald', 'year': '2019', 'title': 'Emergence of a Negative Activation Heat Capacity during Evolution of a Designed Enzyme', 'doi': '10.1021/jacs.9b02731', 'award': 'EP/M013219/1', 'ukch_affi': 'FALSE', 'search': '2022-03-22 to 2022-03-28', 'occurrence': 2, 'alt_doi': ''}
# reviewing: 10.1021/jacs.9b13106
# Found  {'authors': 'Sulley, Gregory S., Gregory, Georgina L., Chen, Thomas T. D., Peña Carrodeguas, Leticia, Trott, Gemma, Santmarti, Alba, Lee, Koon-Yang, Terrill, Nicholas J., Williams, Charlotte K.', 'year': '2020', 'title': 'Switchable Catalysis Improves the Properties of CO<sub>2</sub>-Derived Polymers: Poly(cyclohexene carbonate-<i>b</i>-ε-decalactone-<i>b</i>-cyclohexene carbonate) Adhesives, Elastomers, and Toughened Plastics', 'doi': '10.1021/jacs.9b13106', 'award': 'EP/K014668/1', 'ukch_affi': 'False', 'search': '2021-08-20 to 2021-08-26', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1021/jp5081753
# Found  {'authors': 'Brookes, Catherine, Wells, Peter P., Dimitratos, Nikolaos, Jones, Wilm, Gibson, Emma K., Morgan, David J., Cibin, Giannantonio, Nicklin, Chris, Mora-Fonz, David, Scanlon, David O., Catlow, C. R. A., Bowker, Mike', 'year': '2014', 'title': 'The Nature of the Molybdenum Surface in Iron Molybdate. The Active Phase in Selective Methanol Oxidation', 'doi': '10.1021/jp5081753', 'award': 'EP/K014714/1', 'ukch_affi': 'False', 'search': '2021-08-20 to 2021-08-26', 'occurrence': 1, 'alt_doi': ''}
# adding 255 10.1021/nn500963m
# reviewing: 10.1021/om5008055
# Found  {'authors': 'Czauderna, Christine F., Jarvis, Amanda G., Heutz, Frank J. L., Cordes, David B., Slawin, Alexandra M. Z., van der Vlugt, Jarl Ivar, Kamer, Paul C. J.', 'year': '2015', 'title': 'Chiral Wide-Bite-Angle Diphosphine Ligands: Synthesis, Coordination Chemistry, and Application in Pd-Catalyzed Allylic Alkylation', 'doi': '10.1021/om5008055', 'award': 'EP/K014668/1, EP/K014714/1, EP/K014854/1', 'ukch_affi': 'False', 'search': '2021-08-13 to 2021-08-19', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1038/s41467-019-10481-w
# Found  {'authors': 'Stößer, Tim, Sulley, Gregory S., Gregory, Georgina L., Williams, Charlotte K.', 'year': '2019', 'title': 'Easy access to oxygenated block polymers via switchable catalysis', 'doi': '10.1038/s41467-019-10481-w', 'award': 'EP/K014668/1', 'ukch_affi': 'False', 'search': '2021-11-26 to 2021-12-02', 'occurrence': 1, 'alt_doi': ''}
# adding 256 10.1039/c4cp04488f
# adding 257 10.1039/c4cp04693e
# adding 258 10.1039/c4cy01246a
# adding 259 10.1039/c4dt01309c
# adding 260 10.1039/c4sc00545g
# adding 261 10.1039/c5cc03208c
# adding 262 10.1039/c5cc06118k
# adding 263 10.1039/c5cc08223d
# adding 264 10.1039/c5cc08956e
# adding 265 10.1039/c5cs00108k
# adding 266 10.1039/c5cy01175b
# adding 267 10.1039/c5cy01650a
# adding 268 10.1039/c5fd00153f
# adding 269 10.1039/c5fd00225g
# adding 270 10.1039/c5ra19197a
# adding 271 10.1039/c5sc03494a
# adding 272 10.1039/c5ta01592h
# adding 273 10.1039/c5ta10283a
# adding 274 10.1039/c6cc02169g
# adding 275 10.1039/c6cc90049f
# adding 276 10.1039/c6cp00957c
# adding 277 10.1039/c6cp01151a
# adding 278 10.1039/c6cp01160h
# adding 279 10.1039/c6cp01209d
# adding 280 10.1039/c6cp01311b
# adding 281 10.1039/c6cp01494a
# adding 282 10.1039/c6cp90150f
# adding 283 10.1039/c6cy01105e
# adding 284 10.1039/c6fd00010j
# adding 285 10.1039/c6fd00189k
# adding 286 10.1039/c6fd00195e
# adding 287 10.1039/c6me00061d
# adding 288 10.1039/c6nr00053c
# adding 289 10.1039/c6re00140h
# adding 290 10.1039/c6sc04130b
# adding 291 10.1039/c6tb01774f
# adding 292 10.1039/c7cc05982e
# adding 293 10.1039/c7cp04144f
# adding 294 10.1039/c7cy00965h
# adding 295 10.1039/c7dt01022b
# adding 296 10.1039/c7dt03395h
# adding 297 10.1039/c7dt04805j
# adding 298 10.1039/c7fd00210f
# adding 299 10.1039/c7fd00216e
# adding 300 10.1039/c7fd00221a
# adding 301 10.1039/c7ta10892c
# adding 302 10.1039/c8cc01880d
# adding 303 10.1039/c8cc07444e
# adding 304 10.1039/c8cp01022f
# adding 305 10.1039/c8cp02381f
# adding 306 10.1039/c8cp04216k
# adding 307 10.1039/c8cp06736h
# adding 308 10.1039/c8cy00422f
# adding 309 10.1039/c8cy90033g
# adding 310 10.1039/c8dt05051a
# adding 311 10.1039/c8fd00002f
# adding 312 10.1039/c8fd00005k
# adding 313 10.1039/c8nj03632b
# adding 314 10.1039/c8ra10509j
# adding 315 10.1039/c8sc03312a
# adding 316 10.1039/c8ta12263f
# adding 317 10.1039/c9cc02088h
# adding 318 10.1039/c9cc02459j
# adding 319 10.1039/c9cp00826h
# reviewing: 10.1039/c9cp02968k
# Found  {'authors': 'Zeinalipour-Yazdi, Constantinos D., Catlow, C. Richard A.', 'year': '2019', 'title': 'An experimental and computational IR and hybrid DFT-D3 study of the conformations of<scp>l</scp>-lactic and acrylic acid: new insight into the dehydration mechanism of lactic acid to acrylic acid', 'doi': '10.1039/c9cp02968k', 'award': '', 'ukch_affi': 'True', 'search': '2021-01-15 to 2021-01-21', 'occurrence': 1, 'alt_doi': ''}
# adding 320 10.1039/c9cp03934a
# adding 321 10.1039/c9cp05476f
# adding 322 10.1039/c9cy01679a
# adding 323 10.1039/c9cy02371b
# adding 324 10.1039/c9cy02473e
# adding 325 10.1039/c9dt00228f
# adding 326 10.1039/c9dt00535h
# adding 327 10.1039/c9dt00595a
# adding 328 10.1039/c9dt01634a
# adding 329 10.1039/c9dt02918d
# adding 330 10.1039/c9dt03590g
# adding 331 10.1039/c9na00159j
# adding 332 10.1039/c9nr04553h
# adding 333 10.1039/c9ra03568k
# adding 334 10.1039/c9sc00385a
# adding 335 10.1039/c9sc04905c
# adding 336 10.1039/c9se01103j
# adding 337 10.1039/d0cc02520h
# adding 338 10.1039/d0cc04036c
# adding 339 10.1039/d0cp00032a
# adding 340 10.1039/d0cp00704h
# adding 341 10.1039/d0cp00793e
# adding 342 10.1039/d0cp01192d
# adding 343 10.1039/d0cp01196g
# adding 344 10.1039/d0cp01227k
# adding 345 10.1039/d0cp90186e
# adding 346 10.1039/d0cy00036a
# adding 347 10.1039/d0cy00555j
# adding 348 10.1039/d0cy01484b
# adding 349 10.1039/d0cy01608j
# adding 350 10.1039/d0dt00007h
# adding 351 10.1039/d0dt00754d
# adding 352 10.1039/d0dt01447h
# adding 353 10.1039/d0dt01960g
# adding 354 10.1039/d0gc01312a
# adding 355 10.1039/d0gc02295k
# adding 356 10.1039/d0ra03871g
# adding 357 10.1039/d0sc01924k
# adding 358 10.1039/d0sc02152k
# adding 359 10.1039/d0sc03113e
# adding 360 10.1039/d0ta01398f
# adding 361 10.1039/d0ta08351h
# adding 362 10.1063/1.4885217
# adding 363 10.1063/1.4941825
# adding 364 10.1080/2055074x.2017.1278870
# adding 365 10.1080/2055074x.2017.1278890
# adding 366 10.1093/bioinformatics/btaa643
# reviewing: 10.1098/rspa.2016.0054
# Found  {'authors': 'Caravaca, A., Jones, W., Hardacre, C., Bowker, M.', 'year': '2016', 'title': 'H\n            <sub>2</sub>\n            production by the photocatalytic reforming of cellulose and raw biomass using Ni, Pd, Pt and Au on titania', 'doi': '10.1098/rspa.2016.0054', 'award': '', 'ukch_affi': 'True', 'search': '2021-02-12 to 2021-02-18', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1098/rspa.2016.0078
# Found  {'authors': 'Fehl, Charlie, Davis, Benjamin G.', 'year': '2016', 'title': 'Proteins as templates for complex synthetic metalloclusters: towards biologically programmed heterogeneous catalysis', 'doi': '10.1098/rspa.2016.0078', 'award': 'EP/K014668/1', 'ukch_affi': 'False', 'search': '2021-02-12 to 2021-02-18', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1098/rspa.2016.0095
# Found  {'authors': 'Newland, Stephanie H., Sinkler, Wharton, Mezza, Thomas, Bare, Simon R., Raja, Robert', 'year': '2016', 'title': 'Influence of dopant substitution mechanism on catalytic properties within hierarchical architectures', 'doi': '10.1098/rspa.2016.0095', 'award': 'EP/K014714/1', 'ukch_affi': 'False', 'search': '2021-02-12 to 2021-02-18', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1098/rspa.2016.0126
# Found  {'authors': 'Callear, Samantha K., Silverwood, Ian P., Chutia, Arunabhiram, Catlow, C. Richard A., Parker, Stewart F.', 'year': '2016', 'title': 'The reaction of formic acid with Raney\n            <sup>TM</sup>\n            copper', 'doi': '10.1098/rspa.2016.0126', 'award': 'EP/K014668/1, EP/K014714/1, EP/K014854/1, EP/M013219/1', 'ukch_affi': 'True', 'search': '2021-02-12 to 2021-02-18', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1098/rsta.2020.0056
# Found  {'authors': 'Morteo-Flores, Fabian, Engel, Julien, Roldan, Alberto', 'year': '2020', 'title': 'Biomass hydrodeoxygenation catalysts innovation from atomistic activity predictors', 'doi': '10.1098/rsta.2020.0056', 'award': 'EP/K014668/1, EP/K014714/1, EP/K014854/1, EP/M013219/1', 'ukch_affi': 'False', 'search': '2021-02-12 to 2021-02-18', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1098/rsta.2020.0058
# Found  {'authors': 'Bowker, M., Jones, W.', 'year': '2020', 'title': 'Methanol photo-reforming with water on pure titania for hydrogen production', 'doi': '10.1098/rsta.2020.0058', 'award': '', 'ukch_affi': 'True', 'search': '2021-02-12 to 2021-02-18', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1098/rsta.2020.0063
# Found  {'authors': "O'Malley, Alexander J., García Sakai, Victoria, Dimitratos, Nikolaos, Jones, Wilm, Catlow, C.\xa0Richard\xa0A., Parker, Stewart F.", 'year': '2020', 'title': 'Octane isomer dynamics in H-ZSM-5 as a function of Si/Al ratio: a quasi-elastic neutron scattering study', 'doi': '10.1098/rsta.2020.0063', 'award': '', 'ukch_affi': 'True', 'search': '2021-02-12 to 2021-02-18', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1107/s1600576720013576
# Found  {'authors': 'Vamvakeros, A., Coelho, A. A., Matras, D., Dong, H., Odarchenko, Y., Price, S. W. T., Butler, K. T., Gutowski, O., Dippel, A.-C., Zimmermann, M., Martens, I., Drnec, J., Beale, A. M., Jacques, S. D. M.', 'year': '2020', 'title': 'DLSR: a solution to the parallax artefact in X-ray diffraction computed tomography data', 'doi': '10.1107/s1600576720013576', 'award': 'EP/R026815/1', 'ukch_affi': 'False', 'search': '2022-02-11 to 2022-02-17', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1126/science.aal3439
# Found  {'authors': 'Malta, Grazia, Kondrat, Simon A., Freakley, Simon J., Davies, Catherine J., Lu, Li, Dawson, Simon, Thetford, Adam, Gibson, Emma K., Morgan, David J., Jones, Wilm, Wells, Peter P., Johnston, Peter, Catlow, C. Richard A., Kiely, Christopher J., Hutchings, Graham J.', 'year': '2017', 'title': 'Identification of single-site gold catalysis in acetylene hydrochlorination', 'doi': '10.1126/science.aal3439', 'award': 'EP/K014854/1', 'ukch_affi': 'True', 'search': '2022-01-07 to 2022-01-13', 'occurrence': 1, 'alt_doi': ''}
# reviewing: 10.1128/aac.00564-19
# Found  {'authors': 'Tooke, Catherine L., Hinchliffe, Philip, Lang, Pauline A., Mulholland, Adrian J., Brem, Jürgen, Schofield, Christopher J., Spencer, James', 'year': '2019', 'title': 'Molecular Basis of Class A β-Lactamase Inhibition by Relebactam', 'doi': '10.1128/aac.00564-19', 'award': 'EP/M013219/1', 'ukch_affi': 'False', 'search': '2022-02-18 to 2022-02-24', 'occurrence': 1, 'alt_doi': ''}
# adding 367 10.1142/9781786341228_0001
# adding 368 10.1142/9781786341228_0008
# adding 369 10.1179/2055075814y.0000000005
# adding 370 10.1179/2055075814y.0000000006
# adding 371 10.1179/2055075815y.0000000001
# adding 372 10.1179/2055075815y.0000000002
# adding 373 10.1179/2055075815y.0000000008
# adding 374 10.1557/mrc.2017.22
# adding 375 10.3390/catal10091067
# adding 376 10.3390/catal6070092
# adding 377 10.7717/peerj-pchem.8

# %%
# CR search results
base_dir = './WebOfScience'
in_file_name = "cr_check_wos_2023b.csv"
out_file_name = "cr_check_wos_2023c.csv"

# open DB
db_name = 'production'

# 1 currend app DB
ukchapp_db = "db_files/" + db_name + ".sqlite3"

out_file = Path(base_dir, out_file_name)
in_file = Path(base_dir, in_file_name)

csv_data, csv_headings = csv_rw.get_csv_data(in_file)

# get publication data from the ukch app
app_pubs = pr_fns.get_pub_data(ukchapp_db)

for collected_id in csv_data:
    a_doi = csv_data[collected_id]['doi']
    alt_doi = "";
    if ("/anie." in a_doi):
        alt_doi = a_doi.replace("/anie.","/ange.")
    elif ("/ange." in a_doi):
        alt_doi = a_doi.replace("/ange.","/anie.")
    found_in_db = False
    for a_pub in app_pubs:
        pub_id = a_pub[0]
        pub_title = a_pub[1]
        pub_doi = a_pub[2]
        pub_url = a_pub[3]
        pub_pdf = a_pub[4]
        if a_doi == pub_doi or \
            alt_doi == pub_doi:
            found_in_db = True
    csv_data[collected_id]['in_db'] = found_in_db

# %%
# WRITE TO FILE
if len(csv_data) > 0:
    csv_rw.write_csv_data(csv_data, out_file)

# %%
## Run the first cell and then run this one
base_dir = './WebOfScience'
out_file_name = "cr_check_wos_2023c.csv"

out_file = Path(base_dir, out_file_name)

csv_data, csv_headings = csv_rw.get_csv_data(out_file)

for an_id in csv_data:
    if (csv_data[an_id]['ask']==''):#and csv_data[an_id]['Reason']!= 'one or more authors with UKCH affiliation'):
        print (csv_data[an_id])
        print ("https://doi.org/"+csv_data[an_id]['doi'])
        print("ask if should be added")
        should_ask = input()
        csv_data[an_id]['ask']=should_ask
        print("reason for asking")
        reason_to_ask = input()
        csv_data[an_id]['Reason']=reason_to_ask
# Out:
# {'authors': 'Brookes, Catherine, Bowker, Michael, Gibson, Emma K., Gianolio, Diego, Mohammed, Khaled M. H., Parry, Stephen, Rogers, Scott M., Silverwood, Ian P., Wells, Peter P.', 'year': '2018', 'title': 'Correction: <i>In situ</i> spectroscopic investigations of MoO<sub>x</sub>/Fe<sub>2</sub>O<sub>3</sub> catalysts for the selective oxidation of methanol', 'doi': '10.1039/c8cy90033g', 'awards': '', 'mcc': '0', 'ukch': '0', 'ukch_affiliation': '1', 'found_by_cr_search': '0', 'in_DB': 'No', 'ask': '', 'acknowledgement': '', 'Reason': 'one or more authors with UKCH affiliation', 'in_db': 'FALSE', 'award_in_ack': '', 'error': 'one or more'}
# https://doi.org/10.1039/c8cy90033g
# ask if should be added
# no
# reason for asking
# correction to article
# {'authors': 'Jabłońska, Magdalena, Arán, Miren Agote, Beale, Andrew M., Góra-Marek, Kinga, Delahay, Gérard, Petitto, Carolina, Pacultová, Kateřina, Palkovits, Regina', 'year': '2019', 'title': 'Catalytic decomposition of N<sub>2</sub>O over Cu–Al–O<sub>x</sub> mixed metal oxides', 'doi': '10.1039/c8ra10509j', 'awards': '', 'mcc': '0', 'ukch': '0', 'ukch_affiliation': '1', 'found_by_cr_search': '0', 'in_DB': 'No', 'ask': '', 'acknowledgement': '', 'Reason': 'one or more authors with UKCH affiliation', 'in_db': 'FALSE', 'award_in_ack': '', 'error': 'one or more'}
# https://doi.org/10.1039/c8ra10509j
# ask if should be added
# yes
# reason for asking
# affiliation, andy
# {'authors': 'Catlow, C. Richard A., Wells, Peter, Gianolio, Diego', 'year': '2020', 'title': 'Synchrotron radiation techniques in catalytic science', 'doi': '10.1039/d0cp90186e', 'awards': '', 'mcc': '0', 'ukch': '0', 'ukch_affiliation': '1', 'found_by_cr_search': '0', 'in_DB': 'No', 'ask': '', 'acknowledgement': '', 'Reason': 'one or more authors with UKCH affiliation', 'in_db': 'FALSE', 'award_in_ack': '', 'error': 'one or more'}
# https://doi.org/10.1039/d0cp90186e
# ask if should be added
# no
# reason for asking
# abstract
# {'authors': 'Nastase, Stefan A. F., Logsdail, Andrew J., Catlow, C. Richard A.', 'year': '2021', 'title': 'QM/MM study of the reactivity of zeolite bound methoxy and carbene groups', 'doi': '10.1039/d1cp02535j', 'awards': 'EP/R029431', 'mcc': '1', 'ukch': '0', 'ukch_affiliation': '1', 'found_by_cr_search': '0', 'in_DB': 'No', 'ask': '', 'acknowledgement': '', 'Reason': 'one or more authors with UKCH affiliation', 'in_db': 'FALSE', 'award_in_ack': '', 'error': 'one or more'}
# https://doi.org/10.1039/d1cp02535j
# ask if should be added
# yes
# reason for asking
# affiliation, Richard
# {'authors': 'Kowalec, Igor, Kabalan, Lara, Catlow, C. Richard A., Logsdail, Andrew J.', 'year': '2022', 'title': 'A computational study of direct CO<sub>2</sub> hydrogenation to methanol on Pd surfaces', 'doi': '10.1039/d2cp01019d', 'awards': '', 'mcc': '0', 'ukch': '0', 'ukch_affiliation': '1', 'found_by_cr_search': '0', 'in_DB': 'No', 'ask': '', 'acknowledgement': '', 'Reason': 'one or more authors with UKCH affiliation', 'in_db': 'FALSE', 'award_in_ack': '', 'error': 'one or more'}
# https://doi.org/10.1039/d2cp01019d
# ask if should be added
# yes
# reason for asking
# affiliation, Richard
# {'authors': 'Nyathi, Thulani M., Fadlalla, Mohamed I., Fischer, Nico, York, Andrew P. E., Olivier, Ezra J., Gibson, Emma K., Wells, Peter P., Claeys, Michael', 'year': '2023', 'title': 'Co<sub>3</sub>O<sub>4</sub>/TiO<sub>2</sub> catalysts studied <i>in situ</i> during the preferential oxidation of carbon monoxide: the effect of different TiO<sub>2</sub> polymorphs', 'doi': '10.1039/d2cy01699k', 'awards': '', 'mcc': '0', 'ukch': '0', 'ukch_affiliation': '1', 'found_by_cr_search': '0', 'in_DB': 'No', 'ask': '', 'acknowledgement': '', 'Reason': 'one or more authors with UKCH affiliation', 'in_db': 'FALSE', 'award_in_ack': '', 'error': 'one or more'}
# https://doi.org/10.1039/d2cy01699k
# ask if should be added
# yes
# reason for asking
#  M. Panchal (University College London and UK Catalysis Hub) and Dr. N. Ramanan (Diamond Light Source) are thanked for assisting with the XAS measurements on beamline B18 at Diamond Light Source (sessions: SP19850-3, SP19850-4, and SP19850-5).
# {'authors': 'Navar, Ricardo, Tarantino, Giulia, Beynon, Owain T., Padovan, Daniele, Botti, Luca, Gibson, Emma K., Wells, Peter P., Owens, Alun, Kondrat, Simon A., Logsdail, Andrew J., Hammond, Ceri', 'year': '2022', 'title': 'Tracking the solid-state incorporation of Sn into the framework of dealuminated zeolite beta, and consequences for catalyst design', 'doi': '10.1039/d2ta03837d', 'awards': 'EP/R029431', 'mcc': '1', 'ukch': '0', 'ukch_affiliation': '1', 'found_by_cr_search': '0', 'in_DB': 'No', 'ask': '', 'acknowledgement': '', 'Reason': 'one or more authors with UKCH affiliation', 'in_db': 'FALSE', 'award_in_ack': '', 'error': 'one or more'}
# https://doi.org/10.1039/d2ta03837d
# ask if should be added
# yes
# reason for asking
# Affiliation, Emma Gibson
# {'authors': 'Li, Lili, Kang, Xinchen, He, Meng, Sheveleva, Alena, Hu, Kui, Xu, Shaojun, Zhou, Yiqi, Chen, Jin, Sapchenko, Sergei, Whitehead, George, Vitorica-Yrezabal, Iñigo J., Lopez-Odriozola, Laura, Natrajan, Louise S., McInnes, Eric J. L., Schröder, Martin, Yang, Sihai, Tuna, Floriana', 'year': '2022', 'title': 'Evolution of bismuth-based metal–organic frameworks for efficient electroreduction of CO<sub>2</sub>', 'doi': '10.1039/d2ta04485d', 'awards': '', 'mcc': '0', 'ukch': '0', 'ukch_affiliation': '1', 'found_by_cr_search': '0', 'in_DB': 'No', 'ask': '', 'acknowledgement': '', 'Reason': 'one or more authors with UKCH affiliation', 'in_db': 'FALSE', 'award_in_ack': '', 'error': 'one or more'}
# https://doi.org/10.1039/d2ta04485d
# ask if should be added
# yes
# reason for asking
# affiliation, Shaojun
# {'authors': 'Catlow, C. Richard A., Chutia, Arunabhiram, Quesne, Matthew G.', 'year': '2023', 'title': 'Computational modelling in catalytic science', 'doi': '10.1039/d3cp90127k', 'awards': '', 'mcc': '0', 'ukch': '0', 'ukch_affiliation': '1', 'found_by_cr_search': '0', 'in_DB': 'No', 'ask': '', 'acknowledgement': '', 'Reason': 'one or more authors with UKCH affiliation', 'in_db': 'FALSE', 'award_in_ack': '', 'error': 'one or more'}
# https://doi.org/10.1039/d3cp90127k
# ask if should be added
# yes
# reason for asking
# affiliations, Richard Matthew
# {'authors': 'Dempsey, Seán D., Ryan, Ailbhe A., Smyth, Megan, Moody, Thomas S., Wharry, Scott, Fahey, Karen, Beale, Andrew M., Mediavilla Madrigal, Sofia, Dingwall, Paul, Rooney, David W., Knipe, Peter C., Muldoon, Mark J., Thompson, Jillian M.', 'year': '2023', 'title': 'Continuous-flow transfer hydrogenation of benzonitrile using formate as a safe and sustainable source of hydrogen', 'doi': '10.1039/d3re00195d', 'awards': '', 'mcc': '0', 'ukch': '0', 'ukch_affiliation': '1', 'found_by_cr_search': '0', 'in_DB': 'No', 'ask': '', 'acknowledgement': '', 'Reason': 'one or more authors with UKCH affiliation', 'in_db': 'FALSE', 'award_in_ack': '', 'error': 'one or more'}
# https://doi.org/10.1039/d3re00195d
# ask if should be added
# yes
# reason for asking
# affiliation, Sofia, Andy
# {'authors': 'Parker, Stewart F., Carias, Celine, Tomkinson, John', 'year': '2017', 'title': 'Vibrational spectra of buta-1,3-diene iron tricarbonyl: comparison to surface species', 'doi': '10.1080/2055074x.2017.1278870', 'awards': '', 'mcc': '0', 'ukch': '0', 'ukch_affiliation': '1', 'found_by_cr_search': '0', 'in_DB': 'No', 'ask': '', 'acknowledgement': '', 'Reason': 'one or more authors with UKCH affiliation', 'in_db': 'FALSE', 'award_in_ack': '', 'error': 'one or more'}
# https://doi.org/10.1080/2055074x.2017.1278870
# ask if should be added
# yes
# reason for asking
# affiliation Stewart
# {'authors': 'Khan, Alveena Z., Alitt, Jacob, Germaney, Rhiannon, Hamada, Ikutaro, Wells, Peter P., Dimitratos, Nikolaos, Catlow, C. Richard A., Villa, Alberto, Chutia, Arunabhiram', 'year': '2022', 'title': 'A comparative study on the stability of the furfural molecule on the low index Ni, Pd and Pt surfaces', 'doi': '10.1098/rsos.211516', 'awards': 'EP/R029431', 'mcc': '1', 'ukch': '0', 'ukch_affiliation': '1', 'found_by_cr_search': '0', 'in_DB': 'No', 'ask': '', 'acknowledgement': '', 'Reason': 'one or more authors with UKCH affiliation', 'in_db': 'FALSE', 'award_in_ack': '', 'error': 'one or more'}
# https://doi.org/10.1098/rsos.211516
# ask if should be added
# yes
# reason for asking
# affiliation, Peter and Richard
# {'authors': 'Ortiz-Roldan, Jose M., Balestra, Salvador R. G., Bueno-Perez, Rocio, Calero, Sofía, Garcia-Perez, Elena, Catlow, C. Richard A., Ruiz-Salvador, A. Rabdel, Hamad, Said', 'year': '2022', 'title': 'Understanding the stability and structural properties of ordered nanoporous metals towards their rational synthesis', 'doi': '10.1098/rspa.2022.0201', 'awards': '', 'mcc': '0', 'ukch': '0', 'ukch_affiliation': '1', 'found_by_cr_search': '0', 'in_DB': 'No', 'ask': '', 'acknowledgement': '', 'Reason': 'one or more authors with UKCH affiliation', 'in_db': 'FALSE', 'award_in_ack': '', 'error': 'one or more'}
# https://doi.org/10.1098/rspa.2022.0201
# ask if should be added
# yes
# reason for asking
# affiliation, Richard
# {'authors': 'Wilding, Martin C., Benmore, Chris, Headen, Thomas F., Di Mino, Camilla, Miller, Thomas S., Suter, Theo M., Corà, Furio, Clancy, Adam J., Sella, Andrea, McMillan, Paul, Howard, Christopher A.', 'year': '2023', 'title': 'The local ordering of polar solvents around crystalline carbon nitride nanosheets in solution', 'doi': '10.1098/rsta.2022.0337', 'awards': '', 'mcc': '0', 'ukch': '0', 'ukch_affiliation': '1', 'found_by_cr_search': '0', 'in_DB': 'No', 'ask': '', 'acknowledgement': '', 'Reason': 'one or more authors with UKCH affiliation', 'in_db': 'FALSE', 'award_in_ack': '', 'error': 'one or more'}
# https://doi.org/10.1098/rsta.2022.0337
# ask if should be added
# yes
# reason for asking
# affiliation, Martin
# {'authors': 'Weidendorfer, Daniel, Hess, Kai-Uwe, Ruhekenya, Ruben M., Schawe, Jürgen E. K., Wilding, Martin C., Dingwell, Donald B.', 'year': '2023', 'title': 'Effect of water on the glass transition of a potassium-magnesium carbonate melt', 'doi': '10.1098/rsta.2022.0355', 'awards': '', 'mcc': '0', 'ukch': '0', 'ukch_affiliation': '1', 'found_by_cr_search': '0', 'in_DB': 'No', 'ask': '', 'acknowledgement': '', 'Reason': 'one or more authors with UKCH affiliation', 'in_db': 'FALSE', 'award_in_ack': '', 'error': 'one or more'}
# https://doi.org/10.1098/rsta.2022.0355
# ask if should be added
# yes
# reason for asking
# affiliation, Martin
# {'authors': 'Wilding, Martin C., Sella, Andrea, Howard, Christopher A., Sobrido, Ana Jorge, Catlow, C. R. A.', 'year': '2023', 'title': 'Exploring the length scales, timescales and chemistry of challenging materials (Part 2)', 'doi': '10.1098/rsta.2023.0175', 'awards': '', 'mcc': '0', 'ukch': '0', 'ukch_affiliation': '1', 'found_by_cr_search': '0', 'in_DB': 'No', 'ask': '', 'acknowledgement': '', 'Reason': 'one or more authors with UKCH affiliation', 'in_db': 'FALSE', 'award_in_ack': '', 'error': 'one or more'}
# https://doi.org/10.1098/rsta.2023.0175
# ask if should be added
# Yes
# reason for asking
# affiliation, Martin and Richard
# {'authors': 'Wells, P. P., Crabb, E. M., King, C. R., Fiddy, S., Amieiro-Fonseca, A., Thompsett, D., Russell, A. E.', 'year': '2015', 'title': 'Reduction properties of Ce in CeO<sub>x</sub>/Pt/Al<sub>2</sub>O<sub>3</sub> catalysts', 'doi': '10.1179/2055075815y.0000000001', 'awards': '', 'mcc': '0', 'ukch': '0', 'ukch_affiliation': '1', 'found_by_cr_search': '0', 'in_DB': 'No', 'ask': '', 'acknowledgement': '', 'Reason': 'one or more authors with UKCH affiliation', 'in_db': 'FALSE', 'award_in_ack': '', 'error': 'one or more'}
# https://doi.org/10.1179/2055075815y.0000000001
# ask if should be added
# yes
# reason for asking
# Affiliation. Peter
# {'authors': 'Bowker, Michael, Sharpe, Ryan', 'year': '2015', 'title': 'Pd deposition on TiO<sub>2</sub>(110) and nanoparticle encapsulation', 'doi': '10.1179/2055075815y.0000000008', 'awards': '', 'mcc': '0', 'ukch': '0', 'ukch_affiliation': '1', 'found_by_cr_search': '0', 'in_DB': 'No', 'ask': '', 'acknowledgement': '', 'Reason': 'one or more authors with UKCH affiliation', 'in_db': 'FALSE', 'award_in_ack': '', 'error': 'one or more'}
# https://doi.org/10.1179/2055075815y.0000000008
# ask if should be added
# yes
# reason for asking
# Affiliation Michael
# {'authors': 'Dingwell, Donald B., Hess, Kai-Uwe, Wilding, Martin C., Brooker, Richard A., Di Genova, Danilo, Drewitt, James W.E., Wilson, Mark, Weidendorfer, Daniel', 'year': '2022', 'title': 'The glass transition and the non-Arrhenian viscosity of carbonate melts', 'doi': '10.2138/am-2021-7752', 'awards': '', 'mcc': '0', 'ukch': '0', 'ukch_affiliation': '1', 'found_by_cr_search': '0', 'in_DB': 'No', 'ask': '', 'acknowledgement': '', 'Reason': 'one or more authors with UKCH affiliation', 'in_db': 'FALSE', 'award_in_ack': '', 'error': 'one or more'}
# https://doi.org/10.2138/am-2021-7752
# ask if should be added
# yes
# reason for asking
# Affiliation, Martin
# {'authors': 'Benmore, Chris J., Wilding, Martin C.', 'year': '2021', 'title': 'Probing the Structure of Melts, Glasses, and Amorphous Materials', 'doi': '10.2138/gselements.17.3.175', 'awards': '', 'mcc': '0', 'ukch': '0', 'ukch_affiliation': '1', 'found_by_cr_search': '0', 'in_DB': 'No', 'ask': '', 'acknowledgement': '', 'Reason': 'one or more authors with UKCH affiliation', 'in_db': 'FALSE', 'award_in_ack': '', 'error': 'one or more'}
# https://doi.org/10.2138/gselements.17.3.175
# ask if should be added
# yes
# reason for asking
# Affiliation, Martin

# %%
# WRITE TO FILE
if len(csv_data) > 0:
    csv_rw.write_csv_data(csv_data, out_file)

# %%
ukch_awards = ['EP/R026939/1', 'EP/R026815/1', 'EP/R026645/1', 'EP/R027129/1', 'EP/M013219/1',
               'EP/K014706/2', 'EP/K014668/1', 'EP/K014854/1', 'EP/K014714/1',]

for an_id in csv_data:
    if (csv_data[an_id]['Reason']!='' ):
        awards_list = []
        for an_aw in ukch_awards:
            if an_aw in csv_data[an_id]['Reason']:
                awards_list.append(an_aw)
        if awards_list != []:
            csv_data[an_id]['award_in_ack'] = str(awards_list)

# WRITE TO FILE
if len(csv_data) > 0:
    csv_rw.write_csv_data(csv_data, out_file)

# %%
csv_data
# Out:
# {1: {'authors': 'Wang, Mei, Papaioannou, Evangelos I., Metcalfe, Ian S., Naden, Aaron, Savaniu, Cristian D., Irvine, John T. S.',
#   'year': '2023',
#   'title': 'The Exsolution of Cu Particles from Doped Barium Cerate Zirconate via Barium Cuprate Intermediate Phases',
#   'doi': '10.1002/adfm.202302102',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': 'No',
#   'ask': 'yes',
#   'acknowledgement': ' the China Scholarship Commission (MW) received financial support from the UK Catalysis Hub funded by EPSRC Grant reference EP/R027129/1.',
#   'Reason': 'crossref does not include the UKCH grant number',
#   'in_db': 'FALSE'},
#  2: {'authors': 'Pi, Yutong, Ma, Yanfu, Wang, Xinyao, Price, Cameron‐Alexander Hurd, Li, Haitao, Liu, Qinglong, Wang, Liwei, Chen, Hongyu, Hou, Guangjin, Su, Bao‐Lian, Liu, Jian',
#   'year': '2022',
#   'title': 'Multilevel Hollow Phenolic Resin Nanoreactors with Precise Metal Nanoparticles Spatial Location toward Promising Heterogeneous Hydrogenations',
#   'doi': '10.1002/adma.202205153',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '1',
#   'found_by_cr_search': '0',
#   'in_DB': 'No',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'one or more authors with UKCH affiliation',
#   'in_db': 'FALSE'},
#  3: {'authors': 'Li, Xinyuan, Xu, Yikai, Greer, Adam J., Yue, Mingjian, Ye, Ziwei, McNeill, Aaron, Li, Chunchun, Mills, Andrew, Hu, Peijun, Hardacre, Christopher, Bell, Steven E. J.',
#   'year': '2021',
#   'title': 'A Simple and Ligand‐Free Synthesis of Light and Durable Metal‐TiO<sub>2</sub> Polymer Films with Enhanced Photocatalytic Properties',
#   'doi': '10.1002/admi.202101241',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': 'C.H. and A.G. acknowledge support from the UK Catalysis Hub, funded by EPSRC grant EP/R027129/1',
#   'Reason': '',
#   'in_db': 'FALSE'},
#  4: {'authors': 'Qu, Jie, Elgendy, Amr, Cai, Rongsheng, Buckingham, Mark A., Papaderakis, Athanasios A., de Latour, Hugo, Hazeldine, Kerry, Whitehead, George F. S., Alam, Firoz, Smith, Charles T., Binks, David J., Walton, Alex, Skelton, Jonathan M., Dryfe, Robert A. W., Haigh, Sarah J., Lewis, David J.',
#   'year': '2023',
#   'title': 'A Low‐Temperature Synthetic Route Toward a High‐Entropy 2D Hexernary Transition Metal Dichalcogenide for Hydrogen Evolution Electrocatalysis',
#   'doi': '10.1002/advs.202204488',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': ' R.C. and S.J.H. thank the UK Catalysis Hub for resources and support provided via membership of the UK Catalysis Hub Consortium (UK Engineering and Physical Sciences Research Council, EP/R027129/1)',
#   'Reason': '',
#   'in_db': 'FALSE'},
#  5: {'authors': 'Ye, Guanghua, Wang, Haizhi, Duan, Xuezhi, Sui, Zhijun, Zhou, Xinggui, Coppens, Marc‐Olivier, Yuan, Weikang',
#   'year': '2018',
#   'title': 'Pore network modeling of catalyst deactivation by coking, from single site to particle, during propane dehydrogenation',
#   'doi': '10.1002/aic.16410',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': 'M.-O.C. is supported by the EPSRC “Frontier Engineering” Centre for Nature Inspired Engineering (EP/K038656/1) and the UK Catalysis Hub (EP/K014706/1).',
#   'Reason': '',
#   'in_db': 'FALSE'},
#  6: {'authors': 'Price, Stephen W. T., Geraki, Kalotina, Ignatyev, Konstantin, Witte, Peter T., Beale, Andrew M., Mosselmans, J. Fred W.',
#   'year': '2015',
#   'title': 'In Situ Microfocus Chemical Computed Tomography of the Composition of a Single Catalyst Particle During Hydrogenation of Nitrobenzene in the Liquid Phase',
#   'doi': '10.1002/anie.201504227',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'Andrew M. Beale, UK Catalysis Hub, Research Complex at Harwell, Harwell Science and Innovation Campus, Harwell, Didcot, Oxon, OX11 0FA (UK)',
#   'in_db': 'FALSE'},
#  7: {'authors': 'Guo, Zhongyuan, Li, Xin, Hu, Shen, Ye, Guanghua, Zhou, Xinggui, Coppens, Marc‐Olivier',
#   'year': '2019',
#   'title': 'Understanding the Role of Internal Diffusion Barriers in Pt/Beta Zeolite Catalyzed Isomerization of <i>n</i>‐Heptane',
#   'doi': '10.1002/anie.201913660',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': 'M.-O.C is supported by the EPSRC “Frontier Engineering” Centre for Nature Inspired Engineering (EP/K038656/1) and the UK Catalysis Hub (EP/K014706/1).',
#   'Reason': '',
#   'in_db': 'FALSE'},
#  8: {'authors': 'Mattey, Ashley P., Ford, Grayson J., Citoler, Joan, Baldwin, Christopher, Marshall, James R., Palmer, Ryan B., Thompson, Matthew, Turner, Nicholas J., Cosgrove, Sebastian C., Flitsch, Sabine L.',
#   'year': '2021',
#   'title': 'Development of Continuous Flow Systems to Access Secondary Amines Through Previously Incompatible Biocatalytic Cascades**',
#   'doi': '10.1002/anie.202103805',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': 'S.C.C. acknowledges the UK Catalysis Hub and Keele University for funding.',
#   'Reason': '',
#   'in_db': 'FALSE'},
#  9: {'authors': 'Radley, Emily, Davidson, John, Foster, Jake, Obexer, Richard, Bell, Elizabeth L., Green, Anthony P.',
#   'year': '2023',
#   'title': 'Engineering Enzymes for Environmental Sustainability',
#   'doi': '10.1002/anie.202309305',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': 'the UK Catalysis Hub (funded through EP/RKLPMIN/I, EP/KKIXQKP/L, EP/KKIXPPM/I, EP/KKIXMNX/I, EP/KKIXQIX/I, and EP/MKIJLIY/I)',
#   'Reason': '',
#   'in_db': 'FALSE'},
#  10: {'authors': 'Potter, Matthew E., Mediavilla Madrigal, Sofia, Campbell, Emma, Allen, Lisa J., Vyas, Urvashi, Parry, Stephen, García‐Zaragova, Adrián, Martínez‐Prieto, Luis M., Oña‐Burgos, Pascual, Lützen, Mads, Damsgaard, Christian D., Rodríguez‐Castellón, Enrique, Schiaroli, Nicola, Fornasari, Giuseppe, Benito, Patricia, Beale, Andrew M.',
#   'year': '2023',
#   'title': 'A High Pressure <i>Operando</i> Spectroscopy Examination of Bimetal Interactions in ‘Metal Efficient’ Palladium/In<sub>2</sub>O<sub>3</sub>/Al<sub>2</sub>O<sub>3</sub> Catalysts for CO<sub>2</sub> Hydrogenation',
#   'doi': '10.1002/anie.202312645',
#   'awards': 'EP/R026939/1, EP/R026815/1',
#   'mcc': '0',
#   'ukch': '1',
#   'ukch_affiliation': '1',
#   'found_by_cr_search': '1',
#   'in_DB': 'No',
#   'ask': 'maybe',
#   'acknowledgement': '',
#   'Reason': 'already in CR search',
#   'in_db': 'FALSE'},
#  11: {'authors': 'Hammond, Ceri, Hermans, Ive, Dimitratos, Nikolaos',
#   'year': '2014',
#   'title': 'Biomimetic Oxidation with Fe‐ZSM‐5 and H<sub>2</sub>O<sub>2</sub>? Identification of an Active, Extra‐Framework Binuclear Core and an Fe<sup>III</sup>\uf8ffOOH Intermediate with Resonance‐Enhanced Raman Spectroscopy',
#   'doi': '10.1002/cctc.201402642',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': 'C.H. and N.D. appreciate the support of the UK Catalysis Hub and the EPSRC (EP/K014714/1)',
#   'Reason': '',
#   'in_db': 'FALSE'},
#  12: {'authors': 'Ruiz Esquius, Jonathan, Bahruji, Hasliza, Taylor, Stuart H., Bowker, Michael, Hutchings, Graham J.',
#   'year': '2020',
#   'title': 'CO<sub>2</sub> Hydrogenation to CH<sub>3</sub>OH over PdZn Catalysts, with Reduced CH<sub>4</sub> Production',
#   'doi': '10.1002/cctc.202000974',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '1',
#   'found_by_cr_search': '0',
#   'in_DB': 'No',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'one or more authors with UKCH affiliation',
#   'in_db': 'FALSE'},
#  13: {'authors': 'Wingad, Richard L., Birch, Laurence, Farndon, Joshua, Lee, Jason, Pellow, Katy J., Wass, Duncan F.',
#   'year': '2023',
#   'title': 'Control in Advanced Biofuels Synthesis via Alcohol Upgrading: Catalyst Selectivity to <i>n</i>‐Butanol, <i>sec</i>‐Butanol or Isobutanol',
#   'doi': '10.1002/cctc.202201410',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': 'The EPSRC Bristol Chemical Synthesis Centre for Doctoral Training (KJP), EPSRC UK Catalysis Hub (RLW) and bp (RLW and JL) are thanked for funding.',
#   'Reason': '',
#   'in_db': 'FALSE'},
#  14: {'authors': 'Costley‐Wood, Lucy G, Mohammed, Khaled, Carravetta, Marina, Decarolis, Donato, Goguet, Alexandre, Kordatos, Apostolos, Vakili, Reza, Manyar, Haresh, McPake, Erin, Skylaris, Chris‐Kriton, Thompson, Paul, Gibson, Emma K, Wells, Peter P.',
#   'year': '2023',
#   'title': 'Towards the Operational Window for Nitridic and Carbidic Palladium Nanoparticles for Directed Catalysis',
#   'doi': '10.1002/cctc.202300870',
#   'awards': 'EP/R026815/1, EP/R026939/1, EP/R026645/1, EP/R027129/1',
#   'mcc': '0',
#   'ukch': '1',
#   'ukch_affiliation': '1',
#   'found_by_cr_search': '1',
#   'in_DB': 'No',
#   'ask': 'maybe',
#   'acknowledgement': '',
#   'Reason': 'already in CR search',
#   'in_db': 'FALSE'},
#  15: {'authors': 'Miletto, Ivana, Paul, Geo, Chapman, Stephanie, Gatti, Giorgio, Marchese, Leonardo, Raja, Robert, Gianotti, Enrica',
#   'year': '2017',
#   'title': 'Mesoporous Silica Scaffolds as Precursor to Drive the Formation of Hierarchical SAPO‐34 with Tunable Acid Properties',
#   'doi': '10.1002/chem.201701978',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': 'The Engineering and Physical Sciences Research Council (EPSRC, UK) is gratefully acknowledged for resources and support provided through our membership of the UK Catalysis Hub Consortium (EP/K014706/1).',
#   'Reason': '',
#   'in_db': 'FALSE'},
#  16: {'authors': 'Kondrat, Simon A., Miedziak, Peter J., Douthwaite, Mark, Brett, Gemma L., Davies, Thomas E., Morgan, David J., Edwards, Jennifer K., Knight, David W., Kiely, Christopher J., Taylor, Stuart H., Hutchings, Graham J.',
#   'year': '2013',
#   'title': 'Base‐Free Oxidation of Glycerol Using Titania‐Supported Trimetallic Au–Pd–Pt Nanoparticles',
#   'doi': '10.1002/cssc.201300834',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': 'Also we would like to acknowledge the UK catalysis hub. TEM data was acquired at the Research Complex at Harwell (UK Catalysis Hub) by Catherine Brooks and Wilm Jones.',
#   'Reason': '',
#   'in_db': 'FALSE'},
#  17: {'authors': 'Newton, Mark A., Di Michiel, Marco, Ferri, Davide, Fernàndez-Garcia, Marcos, Beale, Andrew M., Jacques, Simon D. M., Chupas, Peter J., Chapman, Karena W.',
#   'year': '2014',
#   'title': 'Catalytic Adventures in Space and Time Using High Energy X-rays',
#   'doi': '10.1007/s10563-014-9173-z',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'Affiliation Andrew M. Beale  UK Catalysis Hub, Research Complex at Harwell, Rutherford Appleton Laboratory, Harwell, Didcot, Oxfordshire, OX11 0FA, UK',
#   'in_db': 'FALSE'},
#  18: {'authors': 'Bahruji, Hasliza, Esquius, Jonathan Ruiz, Bowker, Michael, Hutchings, Graham, Armstrong, Robert D., Jones, Wilm',
#   'year': '2018',
#   'title': 'Correction to: Solvent Free Synthesis of PdZn/TiO2 Catalysts for the Hydrogenation of CO2 to Methanol',
#   'doi': '10.1007/s11244-018-1081-4',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'No',
#   'acknowledgement': '',
#   'Reason': 'Correction to article 10.1007/s11244-018-0885-6, The UK Catalysis Hub, Research Complex at Harwell, Harwell, Oxon, OX11 0FA, UK  Michael Bowker & Wilm Jones',
#   'in_db': 'FALSE'},
#  19: {'authors': 'Lin, Longfei, Mei, Qingqing, Han, Xue, Parker, Stewart F., Yang, Sihai',
#   'year': '2020',
#   'title': 'Investigations of Hydrocarbon Species on Solid Catalysts by Inelastic Neutron Scattering',
#   'doi': '10.1007/s11244-020-01389-7',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'AffiliationStewart F. Parker      ISIS Facility, STFC Rutherford Appleton Laboratory, Chilton, OX11 0QX, Oxfordshire, UK     UK Catalysis Hub, Research Complex at Harwell, Harwell Science and Innovation Campus, Didcot, OX11 0FA, Oxfordshire, UK',
#   'in_db': 'FALSE'},
#  20: {'authors': 'Hernandez-Tamargo, Carlos, Silverwood, Ian P., O’Malley, Alexander J., Leeuw, Nora H. de',
#   'year': '2020',
#   'title': 'Quasielastic Neutron Scattering and Molecular Dynamics Simulation Study on the Molecular Behaviour of Catechol in Zeolite Beta',
#   'doi': '10.1007/s11244-020-01400-1',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'Affiliation UK Catalysis Hub, Research Complex at Harwell, Rutherford Appleton Laboratory, Harwell Science and Innovation Campus, Oxon, OX11 0FA, UK  Alexander J. O’Malley',
#   'in_db': 'FALSE'},
#  21: {'authors': 'Dimitratos, Nikolaos, Villa, Alberto, Prati, Laura, Hammond, Ceri, Chan-Thaw, Carine E., Cookson, James, Bishop, Peter T.',
#   'year': '2016',
#   'title': 'Effect of the preparation method of supported Au nanoparticles in the liquid phase oxidation of glycerol',
#   'doi': '10.1016/j.apcata.2015.12.031',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'Affiliation, Nikolaos and Ceri, UK Catalysis Hub, Research Complex at Harwell (RCaH), Rutherford Appleton Laboratory, Harwell, Oxon, OX11 0FA, UK',
#   'in_db': 'FALSE'},
#  22: {'authors': 'Islam, Mohammed J., Granollers Mesa, Marta, Osatiashtiani, Amin, Taylor, Martin J., Manayil, Jinesh C., Parlett, Christopher M.A., Isaacs, Mark A., Kyriakou, Georgios',
#   'year': '2020',
#   'title': 'The effect of metal precursor on copper phase dispersion and nanoparticle formation for the catalytic transformations of furfural',
#   'doi': '10.1016/j.apcatb.2020.119062',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': 'The authors wish to acknowledge the Diamond Light Source and the UK Catalysis Hub for provision of beamtime (proposal number SP19850-1).',
#   'Reason': '',
#   'in_db': 'FALSE'},
#  23: {'authors': 'Islam, Mohammed J., Granollers Mesa, Marta, Osatiashtiani, Amin, Manayil, Jinesh C., Isaacs, Mark A., Taylor, Martin J., Tsatsos, Sotirios, Kyriakou, Georgios',
#   'year': '2021',
#   'title': 'PdCu single atom alloys supported on alumina for the selective hydrogenation of furfural',
#   'doi': '10.1016/j.apcatb.2021.120652',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': 'The authors wish to acknowledge the Diamond Light Source and the UK Catalysis Hub for provision of beamtime (proposal number SP19850-5 and SP19850-6)',
#   'Reason': '',
#   'in_db': 'FALSE'},
#  24: {'authors': 'Hoekstra, Jacco, Beale, Andrew M., Soulimani, Fouad, Versluijs-Helder, Marjan, van de Kleut, Dirk, Koelewijn, Jacobus M., Geus, John W., Jenneskens, Leonardus W.',
#   'year': '2016',
#   'title': 'The effect of iron catalyzed graphitization on the textural properties of carbonized cellulose: Magnetically separable graphitic carbon bodies for catalysis and remediation',
#   'doi': '10.1016/j.carbon.2016.05.065',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'Affiliation, Andy Beale UK Catalysis Hub, Research Complex at Harwell, Rutherford Appleton Laboratory, Harwell, Didcot, Oxfordshire, OX11 0FA, UK',
#   'in_db': 'FALSE'},
#  25: {'authors': 'Qiu, Chengwu, Meng, Qingwei, Panchal, Monik, Li, Changzhi, Wu, Baoshan',
#   'year': '2020',
#   'title': 'Enhanced Fischer-Tropsch activity in ammonium nitrate pretreated cobalt-silica catalyst',
#   'doi': '10.1016/j.catcom.2020.106149',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'Affiliation, Monik Panchal Department of Chemistry, University College London, 20 Gordon Street, London WC1H 0AJ, United Kingdom UK Catalysis Hub, Research Complex at Harwell, Rutherford Appleton Laboratory, Didcot OX11 0FA, United Kingdom',
#   'in_db': 'FALSE'},
#  26: {'authors': 'Campisi, Sebastiano, Capelli, Sofia, Ferri, Michele, Villa, Alberto, Dann, Ellie, Wade, Austin, Wells, Peter P., Dimitratos, Nikolaos',
#   'year': '2021',
#   'title': 'On the role of bismuth as modifier in AuPdBi catalysts: Effects on liquid-phase oxidation and hydrogenation reactions',
#   'doi': '10.1016/j.catcom.2021.106340',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'Affiliation, Peter P. Wells View in Scopus School of Chemistry, University of Southampton, Southampton SO17 1BJ, UK UK Catalysis Hub, Research Complex at Harwell, Rutherford Appleton Laboratory, Harwell Oxon, Didcot OX11 0FA, UK Diamond Light Source Ltd., Harwell Science and Innovation Campus, Chilton, Didcot OX11 0DE, UK',
#   'in_db': 'FALSE'},
#  27: {'authors': "Woodward, Claire-Louise M., Porter, Alexander J., Morton, Katie S.C., O'Malley, Alexander J.",
#   'year': '2022',
#   'title': 'Methanol diffusion in H-ZSM-5 catalysts as a function of loading and Si/Al ratio: A classical molecular dynamics study',
#   'doi': '10.1016/j.catcom.2022.106415',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'Affiliation, Katie and Alex     Centre for Sustainable and Circular Technologies, Department of Chemistry, University of Bath, BA2 7AY, UK  b     UK Catalysis Hub, Research Complex at Harwell, Science and Technology Facilities Council, Rutherford Appleton Laboratory, Oxford OX11 0FA, UK',
#   'in_db': 'FALSE'},
#  28: {'authors': 'Hayward, James, Esquius, Jonathan Ruiz, Richards, Nia, Jones, Wilm, Hewes, Daniel, Bowker, Michael',
#   'year': '2023',
#   'title': 'Delaminated hydrotalcite precursors for green methanol synthesis',
#   'doi': '10.1016/j.catcom.2023.106694',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'Catalysis Hub grants, EPSRC grants EP/R026939/1 and EP/R026815/1. and affiliations',
#   'in_db': 'FALSE',
#   'award_in_ack': "['EP/R026939/1', 'EP/R026815/1']"},
#  29: {'authors': 'Beale, Andrew M., Newton, Mark A., Nachtegaal, Maarten, Ferri, Davide',
#   'year': '2014',
#   'title': 'Advances in the use of X-rays for the characterization of functional catalytic materials',
#   'doi': '10.1016/j.cattod.2014.03.001',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'Affiliation, Andy Beale, UK Catalysis Hub, Research Complex at Harwell, Rutherford Appleton Laboratory, Harwell Oxford, Didcot, Oxfordshire OX11 0FA, UK. It is a preface for a special edition',
#   'in_db': 'FALSE'},
#  30: {'authors': 'Sun, Shuzhuang, Lv, Zongze, Qiao, Yuanting, Qin, Changlei, Xu, Shaojun, Wu, Chunfei',
#   'year': '2021',
#   'title': 'Integrated CO2 capture and utilization with CaO-alone for high purity syngas production',
#   'doi': '10.1016/j.ccst.2021.100001',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'Affiliation, Shaojun K Catalysis Hub, Research Complex at Harwell; Didcot, OX11 0FA, UK',
#   'in_db': 'FALSE'},
#  31: {'authors': 'Skountzos, Epameinondas, Price, Cameron A., Alsalem, Mustafa M., Booth, Samuel G., Pollastri, Simone, Cussen, Serena A., Parlett, Christopher M.A., Sedransk Campbell, Kyra L.',
#   'year': '2023',
#   'title': 'Use of copper carbonate as corrosion inhibitor for carbon steel in post combustion carbon capture',
#   'doi': '10.1016/j.ccst.2022.100095',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'Affiliation, Chris and Cameron UK Catalysis Hub, Research Complex at Harwell, Rutherford Appleton Laboratory, Harwell, OX11 0FA, UK',
#   'in_db': 'FALSE'},
#  32: {'authors': 'Sun, Hongman, Zhang, Yu, Wang, Chunfen, Isaacs, Mark A., Osman, Ahmed I., Wang, Yehong, Rooney, David, Wang, Youhe, Yan, Zifeng, Parlett, Christopher M.A., Wang, Feng, Wu, Chunfei',
#   'year': '2022',
#   'title': 'Integrated carbon capture and utilization: Synergistic catalysis between highly dispersed Ni clusters and ceria oxygen vacancies',
#   'doi': '10.1016/j.cej.2022.135394',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'The authors wish to acknowledge the Diamond Light Source for provision of beamtime (UK Catalysis Hub SP19850), and affiliation of Chris',
#   'in_db': 'FALSE'},
#  33: {'authors': 'Chen, Huanhao, Mu, Yibing, Xu, Shanshan, Xu, Shaojun, Hardacre, Christopher, Fan, Xiaolei',
#   'year': '2020',
#   'title': 'Recent advances in non-thermal plasma (NTP) catalysis towards C1 chemistry',
#   'doi': '10.1016/j.cjche.2020.05.027',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'Affiliation, Shaojun     UK Catalysis Hub, Research Complex at Harwell, Rutherford Appleton Laboratory, Harwell, Oxon OX11 0FA, United Kingdom',
#   'in_db': 'FALSE'},
#  34: {'authors': 'Ismaila, Ammaru, Chen, Huanhao, Shao, Yan, Xu, Shaojun, Jiao, Yilai, Chen, Xueli, Gao, Xin, Fan, Xiaolei',
#   'year': '2020',
#   'title': 'Renewable hydrogen production from steam reforming of glycerol (SRG) over ceria-modified γ-alumina supported Ni catalyst',
#   'doi': '10.1016/j.cjche.2020.06.025',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'Affiliation, Shaojun     UK Catalysis Hub, Research Complex at Harwell, Rutherford Appleton Laboratory, Harwell, Oxon OX11 0FA, United Kingdom',
#   'in_db': 'FALSE'},
#  35: {'authors': 'Logsdail, Andrew J., Downing, Christopher A., Catlow, C. Richard A., Sokol, Alexey A.',
#   'year': '2017',
#   'title': 'Magnetic coupling constants for MnO as calculated using hybrid density functional theory',
#   'doi': '10.1016/j.cplett.2017.10.027',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'Affiliation, Richard UK Catalysis Hub, Research Complex at Harwell, Rutherford Appleton Laboratory, Harwell, Oxon OX11 0FA, United Kingdom',
#   'in_db': 'FALSE'},
#  36: {'authors': 'Huang, Haoliang, Blackman, Oliver F., Celorrio, Veronica, Russell, Andrea E.',
#   'year': '2021',
#   'title': 'Isolating the contributions of surface Sn atoms in the bifunctional behaviour of PtSn CO oxidation electrocatalysts',
#   'doi': '10.1016/j.electacta.2021.138811',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'he XAS data were collected at Diamond on B18 as part of the UK Catalysis Hub BAG allocation (SP19850–4, SP19850–5 and SP19850–6).',
#   'in_db': 'FALSE'},
#  37: {'authors': 'Kamran, Muhammad, Davidson, Matthew G., Tsanaktsis, Vasilios, van Berkel, Stefan, de Vos, Sicco',
#   'year': '2022',
#   'title': 'Structure-property insights of semi-aromatic polyamides based on renewable furanic monomer and aliphatic diamines',
#   'doi': '10.1016/j.eurpolymj.2022.111496',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'UK Catalysis Hub is kindly thanked for resources and support provided via our membership of the UK Catalysis Hub Consortium and funded by EPSRC grant EP/R027129/1.',
#   'in_db': 'FALSE',
#   'award_in_ack': "['EP/R027129/1']"},
#  38: {'authors': 'Sun, Hongman, Wang, Yehong, Xu, Shaojun, Osman, Ahmed I., Stenning, Gavin, Han, Jianyu, Sun, Shuzhuang, Rooney, David, Williams, Paul T., Wang, Feng, Wu, Chunfei',
#   'year': '2021',
#   'title': 'Understanding the interaction between active sites and sorbents during the integrated carbon capture and utilization process',
#   'doi': '10.1016/j.fuel.2020.119308',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'Affiliation, Shaojun     UK Catalysis Hub, Research Complex at Harwell, Rutherford Appleton Laboratory, Harwell, Oxon OX11 0FA, United Kingdom',
#   'in_db': 'FALSE'},
#  39: {'authors': 'Bahruji, Hasliza, Bowker, Michael, Davies, Philip R., Kennedy, Julia, Morgan, David J.',
#   'year': '2015',
#   'title': 'The importance of metal reducibility for the photo-reforming of methanol on transition metal-TiO2 photocatalysts and the use of non-precious metals',
#   'doi': '10.1016/j.ijhydene.2014.11.097',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'Affiliation, Michael UK Catalysis Hub, Research Complex at Harwell, Rutherford Appleton Laboratory, Harwell, Oxon OX11 0FA, United Kingdom',
#   'in_db': 'FALSE'},
#  40: {'authors': 'Yilmaz, Meltem, Handoko, Albertus Denny, Parkin, Ivan P., Sankar, Gopinathan',
#   'year': '2020',
#   'title': 'Probing the electronic and geometric structures of photoactive electrodeposited Cu2O films by X-ray absorption spectroscopy',
#   'doi': '10.1016/j.jcat.2020.06.021',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': ' for assistance with XAS data collection, and Dr Stephen Price at the UK Catalysis Hub, Harwell',
#   'in_db': 'FALSE'},
#  41: {'authors': 'Xu, Ruoyu, Kang, Liqun, Papanikolaou, Konstantinos G., Wang, Bolun, Marlow, Sushila, He, Qian, Zhang, Peng, Wang, Jianfang, Brett, Dan J.L., Stamatakis, Michail, Wang, Feng Ryan',
#   'year': '2022',
#   'title': 'Improving the ORR performance by enhancing the Pt oxidation resistance',
#   'doi': '10.1016/j.jcat.2022.10.025',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'The UK Catalysis Hub is kindly thanked for resources and support provided via our membership of the UK Catalysis Hub Consortium and funded by EPSRC (grants EP/K014706/2, EP/K014668/1, EP/K014854/1, EP/K014714/1 and EP/M013219/1).',
#   'in_db': 'FALSE',
#   'award_in_ack': "['EP/M013219/1', 'EP/K014706/2', 'EP/K014668/1', 'EP/K014854/1', 'EP/K014714/1']"},
#  42: {'authors': 'Wang, Hu, Wang, Caiyun, Wang, Xiaoxia, Chen, Qian, Liu, Shuai, Cai, Rongsheng, Haigh, Sarah J., Sun, Yuanyuan, Yang, Dongjiang',
#   'year': '2023',
#   'title': 'Cobalt atom sites anchored on sulfhydryl decorated UiO-66 to activate peroxymonosulfate for norfloxacin degradation',
#   'doi': '10.1016/j.jece.2022.108972',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'S.J.H. would further like to thank the UK Catalysis Hub for resources and support provided via the membership of the UK Catalysis Hub Consortium and funded by EPSRC grant: P/R027129/1.',
#   'in_db': 'FALSE'},
#  43: {'authors': 'Arrigo, Rosa, Sasaki, Takeo, Callison, June, Gianolio, Diego, Schuster, Manfred Erwin',
#   'year': '2022',
#   'title': 'Corrigendum to “Monitoring dynamics of defects and single Fe atoms in N-functionalized few-layer graphene by in situ temperature programmed scanning transmission electron microscopy” [JECHEM 64 (2022) 520-530]',
#   'doi': '10.1016/j.jechem.2021.08.003',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'affiliation, June UK Catalysis Hub, Research Complex at Harwell (RCaH), Rutherford Appleton Laboratory, Harwell Oxon OX11 0FA, UK',
#   'in_db': 'FALSE'},
#  44: {'authors': 'Hernandez-Tamargo, Carlos, Kwakye-Awuah, Bright, O’Malley, Alexander J., de Leeuw, Nora H.',
#   'year': '2021',
#   'title': 'Mercury exchange in zeolites Na-A and Na-Y studied by classical molecular dynamics simulations and ion exchange experiments',
#   'doi': '10.1016/j.micromeso.2021.110903',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'Affiliation, Alex UK Catalysis Hub, Research Complex at Harwell, Science and Technology Facilities Council Rutherford Appleton Laboratory, Harwell Science and Innovation Campus, Oxon, OX11 0QX, United Kingdom',
#   'in_db': 'FALSE'},
#  45: {'authors': 'Jumah, Abdulrahman bin, Tedstone, Aleksander A., Garforth, Arthur A.',
#   'year': '2021',
#   'title': 'Hydrocracking of virgin and post-consumer polymers',
#   'doi': '10.1016/j.micromeso.2021.110912',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'the UK Catalysis Hub for resources and support for Dr Tedstone via our membership of the UK Catalysis Hub Consortium and funding through EPSRC grant EP/R027129/1. ',
#   'in_db': 'FALSE',
#   'award_in_ack': "['EP/R027129/1']"},
#  46: {'authors': 'Parlett, Christopher M.A., Arandiyan, Hamidreza, Durndell, Lee J., Isaacs, Mark A., Lopez, Antonio Torres, Wong, Roong J., Wilson, Karen, Lee, Adam F.',
#   'year': '2022',
#   'title': 'Continuous-flow synthesis of mesoporous SBA-15',
#   'doi': '10.1016/j.micromeso.2021.111535',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'The authors would like to thank the Research Complex at Harwell and the UK Catalysis Hub for access and support to these facilities.',
#   'in_db': 'FALSE'},
#  47: {'authors': "Porter, A.J., McHugh, S.L., Omojola, T., Silverwood, I.P., O'Malley, A.J.",
#   'year': '2023',
#   'title': 'The effect of Si/Al ratio on local and nanoscale water diffusion in H-ZSM-5: A quasielastic neutron scattering and molecular dynamics simulation study',
#   'doi': '10.1016/j.micromeso.2022.112391',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'affiliation, Ian Silverwood UK Catalysis Hub, Research Complex at Harwell, Science and Technology Facilities Council, Rutherford Appleton Laboratory, Oxford, OX11 0FA, UK',
#   'in_db': 'FALSE'},
#  48: {'authors': 'Burnett, Joseph W.H., Howe, Russell F., Wang, Xiaodong',
#   'year': '2020',
#   'title': 'Cofactor NAD(P)H Regeneration: How Selective Are the Reactions?',
#   'doi': '10.1016/j.trechm.2020.03.002',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'No',
#   'acknowledgement': '',
#   'Reason': 'Cannot confirm affiliation or acknowledgement',
#   'in_db': 'FALSE'},
#  49: {'authors': 'Hellier, Pip, Wells, Peter P., Bowker, Michael',
#   'year': '2019',
#   'title': 'Methanol oxidation over shell-core MO /Fe2O3 (M = Mo, V, Nb) catalysts',
#   'doi': '10.1016/s1872-2067(19)63350-4',
#   'awards': 'EP/K014854/1, EP/K014714/1',
#   'mcc': '0',
#   'ukch': '1',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': 'yes',
#   'ask': 'no',
#   'acknowledgement': '',
#   'Reason': 'already in db',
#   'in_db': 'TRUE'},
#  50: {'authors': 'Crawley, James W. M., Gow, Isla E., Lawes, Naomi, Kowalec, Igor, Kabalan, Lara, Catlow, C. Richard A., Logsdail, Andrew J., Taylor, Stuart H., Dummer, Nicholas F., Hutchings, Graham J.',
#   'year': '2022',
#   'title': 'Heterogeneous Trimetallic Nanoparticles as Catalysts',
#   'doi': '10.1021/acs.chemrev.1c00493',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '1',
#   'found_by_cr_search': '0',
#   'in_DB': 'No',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'one or more authors with UKCH affiliation',
#   'in_db': 'FALSE'},
#  51: {'authors': 'Shi, Da, Liu, Jianfang, Ji, Shengfu',
#   'year': '2017',
#   'title': 'Correction to “Preparation of Au/TiO<sub>2</sub> Catalyst and the Performance of Liquid Methanol Catalytic Oxidation to Formic Acid”',
#   'doi': '10.1021/acs.iecr.7b04697',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'This is a correction of acknowledgement for paper https://doi.org/10.1021/acs.iecr.7b02506. In the correction the authors include: . The Research Complex at Harwell, Oxford isacknowledged for use of its facilities and support of their staff.UK Catalysis Hub is kindly thanked for resources and supportprovided.',
#   'in_db': 'FALSE'},
#  52: {'authors': 'Lu, You, Farrow, Matthew R., Fayon, Pierre, Logsdail, Andrew J., Sokol, Alexey A., Catlow, C. Richard A., Sherwood, Paul, Keal, Thomas W.',
#   'year': '2018',
#   'title': 'Open-Source, Python-Based Redevelopment of the ChemShell Multiscale QM/MM Environment',
#   'doi': '10.1021/acs.jctc.8b01036',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '1',
#   'found_by_cr_search': '0',
#   'in_DB': 'No',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'one or more authors with UKCH affiliation',
#   'in_db': 'FALSE'},
#  53: {'authors': 'Morton, Katie S. C., Elena, Alin M., Armstrong, Jeff, O’Malley, Alexander J.',
#   'year': '2023',
#   'title': 'Experimental and Modeling Studies of Local and Nanoscale <i>para</i>-Cresol Behavior: A Comparison of Classical Force Fields',
#   'doi': '10.1021/acs.jpca.2c08022',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '1',
#   'found_by_cr_search': '0',
#   'in_DB': 'No',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'one or more authors with UKCH affiliation',
#   'in_db': 'FALSE'},
#  54: {'authors': 'Britto, Sylvia, Parlett, Christopher M. A., Bartlett, Stuart, Elliott, Joshua D., Ignatyev, Konstantin, Schroeder, Sven L. M.',
#   'year': '2023',
#   'title': 'Intermediates during the Nucleation of Platinum Nanoparticles by a Reaction with Ethylene Glycol: Operando X-ray Absorption Spectroscopy Studies with a Microfluidic Cell',
#   'doi': '10.1021/acs.jpcc.2c08749',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '1',
#   'found_by_cr_search': '0',
#   'in_DB': 'No',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'one or more authors with UKCH affiliation',
#   'in_db': 'FALSE'},
#  55: {'authors': 'Gould, Anna L., Logsdail, Andrew J., Catlow, C. Richard A.',
#   'year': '2015',
#   'title': 'Influence of Composition and Chemical Arrangement on the Kinetic Stability of 147-Atom Au–Ag Bimetallic Nanoclusters',
#   'doi': '10.1021/acs.jpcc.5b03577',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '1',
#   'found_by_cr_search': '0',
#   'in_DB': 'No',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'one or more authors with UKCH affiliation',
#   'in_db': 'FALSE'},
#  56: {'authors': 'Lezcano-Gonzalez, Ines, Wragg, David S., Slawinski, Wojciech A., Hemelsoet, Karen, Van Yperen-De Deyne, Andy, Waroquier, Michel, Van Speybroeck, Veronique, Beale, Andrew M.',
#   'year': '2015',
#   'title': 'Determination of the Nature of the Cu Coordination Complexes Formed in the Presence of NO and NH<sub>3</sub> within SSZ-13',
#   'doi': '10.1021/acs.jpcc.5b06875',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '1',
#   'found_by_cr_search': '0',
#   'in_DB': 'No',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'one or more authors with UKCH affiliation',
#   'in_db': 'FALSE'},
#  57: {'authors': 'Gould, Anna L., Kadkhodazadeh, Shima, Wagner, Jakob B., Catlow, C. Richard A., Logsdail, Andrew J., Di Vece, Marcel',
#   'year': '2015',
#   'title': 'Understanding the Thermal Stability of Silver Nanoparticles Embedded in a-Si',
#   'doi': '10.1021/acs.jpcc.5b07324',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '1',
#   'found_by_cr_search': '0',
#   'in_DB': 'No',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'one or more authors with UKCH affiliation',
#   'in_db': 'FALSE'},
#  58: {'authors': 'Logsdail, Andrew J., Downing, Christopher A., Keal, Thomas W., Sherwood, Paul, Sokol, Alexey A., Catlow, C. Richard A.',
#   'year': '2018',
#   'title': 'Hybrid-DFT Modeling of Lattice and Surface Vacancies in MnO',
#   'doi': '10.1021/acs.jpcc.8b07846',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '1',
#   'found_by_cr_search': '0',
#   'in_DB': 'No',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'one or more authors with UKCH affiliation',
#   'in_db': 'FALSE'},
#  59: {'authors': 'Bowker, M., Grillo, F., Archard, D.',
#   'year': '2018',
#   'title': 'CO and O<sub>2</sub> Adsorption on K/Pt(111)',
#   'doi': '10.1021/acs.jpcc.8b08461',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '1',
#   'found_by_cr_search': '0',
#   'in_DB': 'No',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'one or more authors with UKCH affiliation',
#   'in_db': 'FALSE'},
#  60: {'authors': 'Gould, Anna L., Rossi, Kevin, Catlow, C. Richard A., Baletto, Francesca, Logsdail, Andrew J.',
#   'year': '2016',
#   'title': 'Controlling Structural Transitions in AuAg Nanoparticles through Precise Compositional Design',
#   'doi': '10.1021/acs.jpclett.6b02181',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '1',
#   'found_by_cr_search': '0',
#   'in_DB': 'No',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'one or more authors with UKCH affiliation',
#   'in_db': 'FALSE'},
#  61: {'authors': 'Finnigan, William, Citoler, Joan, Cosgrove, Sebastian C., Turner, Nicholas J.',
#   'year': '2020',
#   'title': 'Rapid Model-Based Optimization of a Two-Enzyme System for Continuous Reductive Amination in Flow',
#   'doi': '10.1021/acs.oprd.0c00075',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'W.F. acknowledges the UK Catalysis Hub for funding. S.C.C. acknowledges the UK Catalysis Hub and the EPSRC/BBSRC Future Biomanufacturing Research Hub (EP/S01778X/1) for funding.',
#   'in_db': 'FALSE'},
#  62: {'authors': 'Di Carmine, Graziano, Leonardi, Costanza, Forster, Luke, Hu, Min, Lee, Daniel, Parlett, Christopher M. A., Bortolini, Olga, Isaacs, Mark A., Massi, Alessandro, D’Agostino, Carmine',
#   'year': '2023',
#   'title': 'Humin Formation on SBA-15-pr-SO<sub>3</sub>H Catalysts during the Alcoholysis of Furfuryl Alcohol to Ethyl Levulinate: Effect of Pore Size on Catalyst Stability, Transport, and Adsorption',
#   'doi': '10.1021/acsami.3c04613',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '1',
#   'found_by_cr_search': '0',
#   'in_DB': 'No',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'one or more authors with UKCH affiliation',
#   'in_db': 'FALSE'},
#  63: {'authors': 'Ledendecker, Marc, Pizzutilo, Enrico, Malta, Grazia, Fortunato, Guilherme V., Mayrhofer, Karl J. J., Hutchings, Graham J., Freakley, Simon J.',
#   'year': '2020',
#   'title': 'Isolated Pd Sites as Selective Catalysts for Electrochemical and Direct Hydrogen Peroxide Synthesis',
#   'doi': '10.1021/acscatal.0c01305',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': ' The authors thank the UK Catalysis Hub for allocating beamtime through the UK Catalysis Hub BAG for X-ray acquisition of the absorption spectroscopic data at the Diamond synchrotron facility (SP15151).',
#   'in_db': 'FALSE'},
#  64: {'authors': 'Luo, Hui, Yukuhiro, Victor Y., Fernández, Pablo S., Feng, Jingyu, Thompson, Paul, Rao, Reshma R., Cai, Rongsheng, Favero, Silvia, Haigh, Sarah J., Durrant, James R., Stephens, Ifan E. L., Titirici, Maria-Magdalena',
#   'year': '2022',
#   'title': 'Role of Ni in PtNi Bimetallic Electrocatalysts for Hydrogen and Value-Added Chemicals Coproduction via Glycerol Electrooxidation',
#   'doi': '10.1021/acscatal.2c03907',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': ' R.C. and S.J.H. would like to thank the UK Catalysis Hub for resources and support provided via the membership of the UK Catalysis Hub Consortium and funded by EPSRC grant: EP/R027129/1.',
#   'in_db': 'FALSE',
#   'award_in_ack': "['EP/R027129/1']"},
#  65: {'authors': 'Khasu, Motlokoa, Marquart, Wijnand, Kooyman, Patricia J., Drivas, Charalampos, Isaacs, Mark A., Mayer, Alexander J., Dann, Sandie E., Kondrat, Simon A., Claeys, Michael, Fischer, Nico',
#   'year': '2023',
#   'title': 'Empowering Catalyst Supports: A New Concept for Catalyst Design Demonstrated in the Fischer–Tropsch Synthesis',
#   'doi': '10.1021/acscatal.3c00924',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': ' UK Catalysis Hub Block Allocation Group at the B18 beamline of the Diamond Light Source, ',
#   'in_db': 'FALSE'},
#  66: {'authors': 'Jin, Dongliang, Ye, Guanghua, Zheng, Jingwei, Yang, Weimin, Zhu, Kake, Coppens, Marc-Olivier, Zhou, Xinggui',
#   'year': '2017',
#   'title': 'Hierarchical Silicoaluminophosphate Catalysts with Enhanced Hydroisomerization Selectivity by Directing the Orientated Assembly of Premanufactured Building Blocks',
#   'doi': '10.1021/acscatal.7b01646',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'UK Catalysis Hub (No. EP/K014706/1).',
#   'in_db': 'FALSE'},
#  67: {'authors': 'Currin, Andrew, Dunstan, Mark S., Johannissen, Linus O., Hollywood, Katherine A., Vinaixa, Maria, Jervis, Adrian J., Swainston, Neil, Rattray, Nicholas J. W., Gardiner, John M., Kell, Douglas B., Takano, Eriko, Toogood, Helen S., Scrutton, Nigel S.',
#   'year': '2018',
#   'title': 'Engineering the “Missing Link” in Biosynthetic (−)-Menthol Production: Bacterial Isopulegone Isomerase',
#   'doi': '10.1021/acscatal.7b04115',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'The UK Catalysis Hub (http://www.ukcatalysishub.co.uk) is kindly thanked for resources and support.',
#   'in_db': 'FALSE'},
#  68: {'authors': 'Cosgrove, Sebastian C., Mattey, Ashley P., Riese, Michel, Chapman, Michael R., Birmingham, William R., Blacker, A. John, Kapur, Nikil, Turner, Nicholas J., Flitsch, Sabine L.',
#   'year': '2019',
#   'title': 'Biocatalytic Oxidation in Continuous Flow for the Generation of Carbohydrate Dialdehydes',
#   'doi': '10.1021/acscatal.9b04819',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': ' S.C.C acknowledges the UK Catalysis Hub and the Engineering and Physical Sciences Research Council (EPSRC) (Future BRH grant) for funding.',
#   'in_db': 'FALSE'},
#  69: {'authors': 'Yin, Xia, Yang, Jing, Zhang, Mengji, Wang, Xinyao, Xu, Wei, Price, Cameron-Alexander H., Huang, Lin, Liu, Wanshan, Su, Haiyang, Wang, Wenjing, Chen, Hongyu, Hou, Guangjin, Walker, Mark, Zhou, Ying, Shen, Zhen, Liu, Jian, Qian, Kun, Di, Wen',
#   'year': '2022',
#   'title': 'Serum Metabolic Fingerprints on Bowl-Shaped Submicroreactor Chip for Chemotherapy Monitoring',
#   'doi': '10.1021/acsnano.1c09864',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '1',
#   'found_by_cr_search': '0',
#   'in_DB': 'No',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'one or more authors with UKCH affiliation',
#   'in_db': 'FALSE'},
#  70: {'authors': 'Swallow, Jack E. N., Jones, Elizabeth S., Head, Ashley R., Gibson, Joshua S., David, Roey Ben, Fraser, Michael W., van Spronsen, Matthijs A., Xu, Shaojun, Held, Georg, Eren, Baran, Weatherup, Robert S.',
#   'year': '2023',
#   'title': 'Revealing the Role of CO during CO<sub>2</sub> Hydrogenation on Cu Surfaces with <i>In Situ</i> Soft X-Ray Spectroscopy',
#   'doi': '10.1021/jacs.2c12728',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '1',
#   'found_by_cr_search': '0',
#   'in_DB': 'No',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'one or more authors with UKCH affiliation',
#   'in_db': 'FALSE'},
#  71: {'authors': 'Ruiz Esquius, Jonathan, Morgan, David J., Algara Siller, Gerardo, Gianolio, Diego, Aramini, Matteo, Lahn, Leopold, Kasian, Olga, Kondrat, Simon A., Schlögl, Robert, Hutchings, Graham J., Arrigo, Rosa, Freakley, Simon J.',
#   'year': '2023',
#   'title': 'Lithium-Directed Transformation of Amorphous Iridium (Oxy)hydroxides To Produce Active Water Oxidation Catalysts',
#   'doi': '10.1021/jacs.2c13567',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'We acknowledge Diamond Light Source for time on Beamline B18 under Proposal SP18701-1 and the UK Catalysis Hub for allowing access through Bulk Allocation Group SP15151-10.',
#   'in_db': 'FALSE'},
#  72: {'authors': 'Ma, Yujie, Han, Xue, Xu, Shaojun, Li, Zhe, Lu, Wanpeng, An, Bing, Lee, Daniel, Chansai, Sarayute, Sheveleva, Alena M., Wang, Zi, Chen, Yinlin, Li, Jiangnan, Li, Weiyao, Cai, Rongsheng, da Silva, Ivan, Cheng, Yongqiang, Daemen, Luke L., Tuna, Floriana, McInnes, Eric J. L., Hughes, Lewis, Manuel, Pascal, Ramirez-Cuesta, Anibal J., Haigh, Sarah J., Hardacre, Christopher, Schröder, Martin, Yang, Sihai',
#   'year': '2023',
#   'title': 'Direct Conversion of Methane to Ethylene and Acetylene over an Iron-Based Metal–Organic Framework',
#   'doi': '10.1021/jacs.3c03935',
#   'awards': 'EP/M013219/1, EP/R026645/1, EP/R026815/1, EP/R026939/1, EP/R027129/1',
#   'mcc': '0',
#   'ukch': '1',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '1',
#   'in_DB': 'No',
#   'ask': 'maybe',
#   'acknowledgement': '',
#   'Reason': 'already in CR search',
#   'in_db': 'FALSE'},
#  73: {'authors': 'Luo, Wenhao, Sankar, Meenakshisundaram, Beale, Andrew M., He, Qian, Kiely, Christopher J., Bruijnincx, Pieter C. A., Weckhuysen, Bert M.',
#   'year': '2015',
#   'title': 'High performing and stable supported nano-alloys for the catalytic hydrogenation of levulinic acid to γ-valerolactone',
#   'doi': '10.1038/ncomms7540',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
# ...
#   'awards': 'EP/K014714/1, EP/K014854/1',
#   'mcc': '0',
#   'ukch': '1',
#   'ukch_affiliation': '1',
#   'found_by_cr_search': '0',
#   'in_DB': 'yes',
#   'ask': 'no',
#   'acknowledgement': '',
#   'Reason': 'already in db',
#   'in_db': 'TRUE'},
#  104: {'authors': 'Panchal, Monik, Callison, June, Skukauskas, Vainius, Gianolio, Diego, Cibin, Giannantonio, York, Andrew P E, Schuster, Manfred E, Hyde, Timothy I, Collier, Paul, Catlow, C Richard A, Gibson, Emma K',
#   'year': '2021',
#   'title': 'Operando XAFS investigation on the effect of ash deposition on three-way catalyst used in gasoline particulate filters and the effect of the manufacturing process on the catalytic activity',
#   'doi': '10.1088/1361-648x/abfe16',
#   'awards': 'EP/R026815/1',
#   'mcc': '0',
#   'ukch': '1',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': 'yes',
#   'ask': 'no',
#   'acknowledgement': '',
#   'Reason': 'already in db',
#   'in_db': 'TRUE'},
#  105: {'authors': 'Leach, A S, Hack, J, Amboage, M, Diaz-Moreno, S, Huang, H, Cullen, P L, Wilding, M, Magliocca, E, Miller, T S, Howard, C A, Brett, D J L, Shearing, P R, McMillan, P F, Russell, A E, Jervis, R',
#   'year': '2021',
#   'title': 'A novel fuel cell design for operando energy-dispersive x-ray absorption measurements',
#   'doi': '10.1088/1361-648x/ac0476',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'Affiliation, Martin Wilding',
#   'in_db': 'FALSE'},
#  106: {'authors': 'McMillan, Paul F, Wilding, Martin C, Catlow, C Richard A, Bras, Wim',
#   'year': '2021',
#   'title': 'Preface to the JPCM special issue on intense radiation sources in condensed matter and materials physics',
#   'doi': '10.1088/1361-648x/ac1301',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': 'yes',
#   'ask': 'no',
#   'acknowledgement': '',
#   'Reason': 'already in db',
#   'in_db': 'TRUE'},
#  107: {'authors': 'Kabalan, Lara, Kowalec, Igor, Rigamonti, Santiago, Troppenz, Maria, Draxl, Claudia, Catlow, C Richard A, Logsdail, Andrew J',
#   'year': '2023',
#   'title': 'Investigation of the Pd<sub>(1−x)</sub>Zn<sub>x</sub> alloy phase diagram using ab initio modelling approaches',
#   'doi': '10.1088/1361-648x/ace01a',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'Affiliation, Richard',
#   'in_db': 'FALSE'},
#  108: {'authors': 'Khan, Alveena Z., Alitt, Jacob, Germaney, Rhiannon, Hamada, Ikutaro, Wells, Peter P., Dimitratos, Nikolaos, Catlow, C. Richard A., Villa, Alberto, Chutia, Arunabhiram',
#   'year': '2022',
#   'title': 'A comparative study on the stability of the furfural molecule on the low index Ni, Pd and Pt surfaces',
#   'doi': '10.1098/rsos.211516',
#   'awards': 'EP/R029431',
#   'mcc': '1',
#   'ukch': '0',
#   'ukch_affiliation': '1',
#   'found_by_cr_search': '0',
#   'in_DB': 'No',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'one or more authors with UKCH affiliation',
#   'in_db': 'FALSE'},
#  109: {'authors': 'Ortiz-Roldan, Jose M., Balestra, Salvador R. G., Bueno-Perez, Rocio, Calero, Sofía, Garcia-Perez, Elena, Catlow, C. Richard A., Ruiz-Salvador, A. Rabdel, Hamad, Said',
#   'year': '2022',
#   'title': 'Understanding the stability and structural properties of ordered nanoporous metals towards their rational synthesis',
#   'doi': '10.1098/rspa.2022.0201',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '1',
#   'found_by_cr_search': '0',
#   'in_DB': 'No',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'one or more authors with UKCH affiliation',
#   'in_db': 'FALSE'},
#  110: {'authors': "Matam, Santhosh K., Silverwood, Ian P., Boudjema, Lotfi, O'Malley, Alexander J., Catlow, C. Richard A.",
#   'year': '2023',
#   'title': 'Methanol diffusion and dynamics in zeolite H-ZSM-5 probed by quasi-elastic neutron scattering and classical molecular dynamics simulations',
#   'doi': '10.1098/rsta.2022.0335',
#   'awards': 'EP/R026645/1, EP/R026939/1, EP/R027129/1',
#   'mcc': '0',
#   'ukch': '1',
#   'ukch_affiliation': '1',
#   'found_by_cr_search': '1',
#   'in_DB': 'No',
#   'ask': 'maybe',
#   'acknowledgement': '',
#   'Reason': 'already in CR search',
#   'in_db': 'FALSE'},
#  111: {'authors': 'Wilding, Martin C., Benmore, Chris, Headen, Thomas F., Di Mino, Camilla, Miller, Thomas S., Suter, Theo M., Corà, Furio, Clancy, Adam J., Sella, Andrea, McMillan, Paul, Howard, Christopher A.',
#   'year': '2023',
#   'title': 'The local ordering of polar solvents around crystalline carbon nitride nanosheets in solution',
#   'doi': '10.1098/rsta.2022.0337',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '1',
#   'found_by_cr_search': '0',
#   'in_DB': 'No',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'one or more authors with UKCH affiliation',
#   'in_db': 'FALSE'},
#  112: {'authors': 'Weidendorfer, Daniel, Hess, Kai-Uwe, Ruhekenya, Ruben M., Schawe, Jürgen E. K., Wilding, Martin C., Dingwell, Donald B.',
#   'year': '2023',
#   'title': 'Effect of water on the glass transition of a potassium-magnesium carbonate melt',
#   'doi': '10.1098/rsta.2022.0355',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '1',
#   'found_by_cr_search': '0',
#   'in_DB': 'No',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'one or more authors with UKCH affiliation',
#   'in_db': 'FALSE'},
#  113: {'authors': 'Wilding, Martin C., Sella, Andrea, Howard, Christopher A., Sobrido, Ana Jorge, Catlow, C. R. A.',
#   'year': '2023',
#   'title': 'Exploring the length scales, timescales and chemistry of challenging materials (Part 2)',
#   'doi': '10.1098/rsta.2023.0175',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '1',
#   'found_by_cr_search': '0',
#   'in_DB': 'No',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'one or more authors with UKCH affiliation',
#   'in_db': 'FALSE'},
#  114: {'authors': 'Vamvakeros, Antonios, Jacques, Simon D. M., Di Michiel, Marco, Middelkoop, Vesna, Egan, Christopher K., Cernik, Robert J., Beale, Andrew M.',
#   'year': '2015',
#   'title': 'Removing multiple outliers and single-crystal artefacts from X-ray diffraction computed tomography data',
#   'doi': '10.1107/s1600576715020701',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'Affiliation, Simon and Andy',
#   'in_db': 'FALSE'},
#  115: {'authors': 'Qu, Liu, Papaioannou, Evangelos I.',
#   'year': '2023',
#   'title': 'Study of CO<sub>2</sub> permeation in Zn<sup>2+</sup>‐modified Al<sub>2</sub>O<sub>3</sub>‐carbonate membrane',
#   'doi': '10.1111/jace.19216',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'the UK Catalysis Hub funded by EPSRC Grant reference EP/R027129/1',
#   'in_db': 'FALSE',
#   'award_in_ack': "['EP/R027129/1']"},
#  116: {'authors': 'Mollner, Tim A., Giltrap, Andrew M., Zeng, Yibo, Demyanenko, Yana, Buchanan, Charles, Oehlrich, Daniel, Baldwin, Andrew J., Anthony, Daniel C., Mohammed, Shabaz, Davis, Benjamin G.',
#   'year': '2022',
#   'title': 'Reductive site-selective atypical  <i>C</i> , <i>Z</i>  -type/N2-C2 cleavage allows C-terminal protein amidation',
#   'doi': '10.1126/sciadv.abl8675',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'The EPSRC UK Catalysis Hub (EP/R026815/1 and EP/R026939/1, to Y.Z. and B.G.D.)',
#   'in_db': 'FALSE',
#   'award_in_ack': "['EP/R026939/1', 'EP/R026815/1']"},
#  117: {'authors': "Xie, Jinxin, Coker, Victoria S., O'Driscoll, Brian, Cai, Rongsheng, Haigh, Sarah J., Lloyd, Jonathan R.",
#   'year': '2023',
#   'title': 'Microbial Reduction of Antimony(V)-Bearing Ferrihydrite by Geobacter sulfurreducens',
#   'doi': '10.1128/aem.02175-22',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'R.C. and S.J.H. would further like to thank the UK Catalysis Hub for resources and support provided via the membership of the UK Catalysis Hub Consortium and funded by EPSRC grant P/R027129/1.',
#   'in_db': 'FALSE'},
#  118: {'authors': 'Gould, Anna L., Catlow, C. Richard A., Logsdail, Andrew J.',
#   'year': '2018',
#   'title': 'Computational investigation of CO adsorbed on Aux, Agx  and (AuAg)x nanoclusters (x = 1 − 5, 147) and monometallic  Au and Ag low-energy surfaces',
#   'doi': '10.1140/epjb/e2017-80280-7',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'Affiliation, Anna and Richard',
#   'in_db': 'FALSE'},
#  119: {'authors': 'Lahiri, Abhishek, Chutia, Arunabhiram, Carstens, Timo, Endres, Frank',
#   'year': '2020',
#   'title': 'Surface-Oxygen Induced Electrochemical Self-Assembly of Mesoporous Conducting Polymers for Electrocatalysis',
#   'doi': '10.1149/1945-7111/ab9e3c',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'Affiliation, Arunabhiram Chutia',
#   'in_db': 'FALSE'},
#  120: {'authors': 'de la Hidalga, Abraham Nieva, Decarolis, Donato, Xu, Shaojun, Matam, Santhosh, Enciso, Willinton Yesid Hernández, Goodall, Josephine, Matthews, Brian, Catlow, C. Richard A.',
#   'year': '2022',
#   'title': 'A Workflow Demonstrator for Processing Catalysis Research Data',
#   'doi': '10.1162/dint_a_00143',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '1',
#   'found_by_cr_search': '0',
#   'in_DB': 'yes',
#   'ask': 'no',
#   'acknowledgement': '',
#   'Reason': 'already in db',
#   'in_db': 'TRUE'},
#  121: {'authors': 'Beale, Andrew M., Lezcano-Gonzalez, Ines, Maunula, Teuvo, Palgrave, Robert G.',
#   'year': '2014',
#   'title': 'Development and characterization of thermally stable supported V–W–TiO<sub>2</sub> catalysts for mobile NH<sub>3</sub>–SCR applications',
#   'doi': '10.1179/2055075814y.0000000005',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '1',
#   'found_by_cr_search': '0',
#   'in_DB': 'yes',
#   'ask': 'no',
#   'acknowledgement': '',
#   'Reason': 'already in db',
#   'in_db': 'TRUE'},
#  122: {'authors': 'Kennedy, Julia, Jones, Wilm, Morgan, David J., Bowker, Michael, Lu, Li, Kiely, Christopher J., Wells, Peter P., Dimitratos, Nikolaos',
#   'year': '2014',
#   'title': 'Photocatalytic hydrogen production by reforming of methanol using Au/TiO<sub>2</sub>, Ag/TiO<sub>2</sub> and Au-Ag/TiO<sub>2</sub> catalysts',
#   'doi': '10.1179/2055075814y.0000000006',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '1',
#   'found_by_cr_search': '0',
#   'in_DB': 'yes',
#   'ask': 'no',
#   'acknowledgement': '',
#   'Reason': 'already in db',
#   'in_db': 'TRUE'},
#  123: {'authors': 'Wells, P. P., Crabb, E. M., King, C. R., Fiddy, S., Amieiro-Fonseca, A., Thompsett, D., Russell, A. E.',
#   'year': '2015',
#   'title': 'Reduction properties of Ce in CeO<sub>x</sub>/Pt/Al<sub>2</sub>O<sub>3</sub> catalysts',
#   'doi': '10.1179/2055075815y.0000000001',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '1',
#   'found_by_cr_search': '0',
#   'in_DB': 'No',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'one or more authors with UKCH affiliation',
#   'in_db': 'FALSE'},
#  124: {'authors': 'Bowker, Michael, House, Matthew, Alshehri, Abdulmohsen, Brookes, Catherine, Gibson, Emma K., Wells, Peter P.',
#   'year': '2015',
#   'title': 'Selectivity determinants for dual function catalysts: applied to methanol selective oxidation on iron molybdate',
#   'doi': '10.1179/2055075815y.0000000002',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '1',
#   'found_by_cr_search': '0',
#   'in_DB': 'yes',
#   'ask': 'no',
#   'acknowledgement': '',
#   'Reason': 'already in db',
#   'in_db': 'TRUE'},
#  125: {'authors': 'Bowker, Michael, Sharpe, Ryan',
#   'year': '2015',
#   'title': 'Pd deposition on TiO<sub>2</sub>(110) and nanoparticle encapsulation',
#   'doi': '10.1179/2055075815y.0000000008',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '1',
#   'found_by_cr_search': '0',
#   'in_DB': 'No',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'one or more authors with UKCH affiliation',
#   'in_db': 'FALSE'},
#  126: {'authors': 'Parker, Stewart F., Collier, Paul',
#   'year': '2016',
#   'title': 'Applications of Neutron Scattering in Catalysis',
#   'doi': '10.1595/205651316x691230',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': 'yes',
#   'ask': 'no',
#   'acknowledgement': '',
#   'Reason': 'already in db',
#   'in_db': 'TRUE'},
#  127: {'authors': 'Dingwell, Donald B., Hess, Kai-Uwe, Wilding, Martin C., Brooker, Richard A., Di Genova, Danilo, Drewitt, James W.E., Wilson, Mark, Weidendorfer, Daniel',
#   'year': '2022',
#   'title': 'The glass transition and the non-Arrhenian viscosity of carbonate melts',
#   'doi': '10.2138/am-2021-7752',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '1',
#   'found_by_cr_search': '0',
#   'in_DB': 'No',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'one or more authors with UKCH affiliation',
#   'in_db': 'FALSE'},
#  128: {'authors': 'Benmore, Chris J., Wilding, Martin C.',
#   'year': '2021',
#   'title': 'Probing the Structure of Melts, Glasses, and Amorphous Materials',
#   'doi': '10.2138/gselements.17.3.175',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '1',
#   'found_by_cr_search': '0',
#   'in_DB': 'No',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'one or more authors with UKCH affiliation',
#   'in_db': 'FALSE'},
#  129: {'authors': 'Charalambous, Christina, Xu, Shanshan, Ding, Shengzhe, Chansai, Sarayute, Asuquo, Edidiong, Torres Lopez, Antonio, Parlett, Christopher M. A., Gilmour, Jamie D., Garforth, Arthur, Hardacre, Christopher',
#   'year': '2022',
#   'title': 'Non-thermal plasma activated CO2 hydrogenation over K- and La- promoted layered-double hydroxide supported Ni catalysts',
#   'doi': '10.3389/fceng.2022.1027167',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': '. UK Catalysis Hub is kindly thanked for resources and support provided via our membership of the UK Catalysis Hub Consortium and funded by EPSRC Grants: EP/R026939/1, EP/R026815/1, EP/R026645/1, and EP/R027129/1.',
#   'in_db': 'FALSE',
#   'award_in_ack': "['EP/R026939/1', 'EP/R026815/1', 'EP/R026645/1', 'EP/R027129/1']"},
#  130: {'authors': 'Alijani, Shahram, Capelli, Sofia, Cattaneo, Stefano, Schiavoni, Marco, Evangelisti, Claudio, Mohammed, Khaled M. H., Wells, Peter P., Tessore, Francesca, Villa, Alberto',
#   'year': '2019',
#   'title': 'Capping Agent Effect on Pd-Supported Nanoparticles in the Hydrogenation of Furfural',
#   'doi': '10.3390/catal10010011',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'Affiliation, Peter Wells',
#   'in_db': 'FALSE'},
#  131: {'authors': 'Jones, Matthew P., Storm, Malte, York, Andrew P. E., Hyde, Timothy I., Hatton, Gareth D., Greenaway, Alex G., Haigh, Sarah J., Eastwood, David S.',
#   'year': '2020',
#   'title': '4D In-Situ Microscopy of Aerosol Filtration in a Wall Flow Filter',
#   'doi': '10.3390/ma13245676',
#   'awards': '',
#   'mcc': '0',
#   'ukch': '0',
#   'ukch_affiliation': '0',
#   'found_by_cr_search': '0',
#   'in_DB': '',
#   'ask': 'yes',
#   'acknowledgement': '',
#   'Reason': 'We would like to acknowledge the UK Catalysis Hub and the University of Manchester at Harwell (UoMaH) for facility support given to this project',
#   'in_db': 'FALSE'}}
