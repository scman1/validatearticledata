# %% [markdown]
# # Get data references from html pages
#
# A list of publications is obtainded from the app database. This list will contain a titles, IDs and DOIs which need to be explored to look for asociated data (suplementary data, raw data, processed data).
#
# The steps of the process are:
#
# 1. get a Title, DOI, and URL for each publication
# 2. get the DOI landing page and see if it contains references to data
# 3. add a new dataset entry each time a new ds is found
# 4. link the dataset to the publication

# %%
# Connecting to the db
import lib.handle_db as dbh

# read and write csv files
import lib.handle_csv as csv_rw

# Parsing html 
from bs4 import BeautifulSoup

# http requests 
import requests

# url parser
from urllib.parse import urlparse  # python 3.x

# add aprogress bar
from tqdm import tqdm_notebook 

# library for using regular expressions
import re

# values for metadata class names to exclude
exclude_metadata = {'nature':['viewport', 'msapplication-TileColor', 'msapplication-config', 'theme-color', 
                    'application-name', 'robots', 'access', 'WT.cg_s', 'WT.z_bandiera_abtest', 'WT.page_categorisation',
                    'WT.template', 'WT.z_cg_type', 'WT.cg_n', 'dc.rights', 'prism.issn'],'springer':['viewport', 'msapplication-TileColor', 'msapplication-config',  'theme-color', 
                    'application-name', 'robots', 'access', 'WT.cg_s', 'WT.z_bandiera_abtest', 'WT.page_categorisation',
                    'WT.template', 'WT.z_cg_type', 'WT.cg_n', 'dc.rights', 'prism.issn'],"wiley":[],'rsc':['viewport',
                    'format-detection', 'msapplication-TileColor', 'theme-color', 'dc.domain', 'twitter:card',
                    'twitter:site'], "acs":['pbContext','viewport','robots','twitter:description','pb-robots-disabled',
                    'twitter:card','twitter:site','twitter:image','twitter:title','google-site-verification']}

# values for section labels which may contain references to data
section_labels = {'nature':{'aria-labelledby':'data-availability'},'springer':{'aria-labelledby':'data-availability'}}

# values for div which may contain references to data
div_filters = {'nature':{'class':'c-article-supplementary__item'}, 'springer':{'class':"c-article-supplementary__item"}}

#  Custom functions to get references to datasets
# returns beautifulsoup object from given url
def get_content(url):
    html_soup = None
    try:
        req_head = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 \
                    (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36'}
        response = requests.get(url, headers = req_head)
        redirected_to = response.url
        html_soup = BeautifulSoup(response.text,'html.parser')       
    except Exception as e:
        print(e)
    return html_soup, redirected_to

# get metadata
def get_metadata(soup, journal):
    result=[]
    try:
        metadata = soup.find_all('meta')
        ignore_these = []
        if journal in exclude_metadata:
            ignore_these = exclude_metadata[journal] 
        else:
            print('new journal')
        for md_item in metadata:
            if md_item.has_attr("name") and not md_item["name"] in ignore_these :
                result.append(md_item)
    except Exception as e:
        print(e)
    return result

# get data ref from metadata
def get_data_from_metadata(soup, journal = 'nature', data_refs = []):
    data_refs = []
    res = get_metadata(soup, journal)
    # check if metadata references supporting data or supplementary data
    for md_item in res:
        if 'data' in str(md_item["name"]).lower():
            #print(md_item["name"], md_item["content"])
            ret_data = md_item["content"]
            data_refs.append({'type':"metadata", "name":md_item["name"], 'data_url':md_item["content"]})
    # get author(s) data from metadata
    #for md_item in res:
    #    if 'author' in str(md_item["name"]).lower():
    #        print(md_item["name"], md_item["content"])    
    return data_refs

def get_data_from_section(soup, journal = 'nature', data_refs = [], base_url=""):
    inspect_these = {}
    if journal in section_labels:
        inspect_these = section_labels[journal]
    for sec_filter in inspect_these:
        sections = soup.find_all('section', {sec_filter:inspect_these[sec_filter]})
        for section in sections:
            pars = section.find_all('p')
            for par in pars:
                references = par.find_all('a')
                if len(references) == 0:
                   data_refs.append({'type':inspect_these[sec_filter], "name":par.contents[0], 'data_url':None}) 
                for a_ref in references:
                    content_text = a_ref.contents[0]
                    data_url = a_ref['href']
                    if data_url[0] == '/' and base_url != "":
                        data_url = base_url + data_url
                    data_refs.append({'type':inspect_these[sec_filter], "name":a_ref.contents[0], 'data_url':data_url})
    return data_refs

def get_data_from_divs(soup, journal = 'nature', data_refs = [], base_url=""):
    inspect_these = {}
    if journal in div_filters:
        inspect_these = div_filters[journal]
    for div_filter in inspect_these:
        divs = soup.find_all('div',{div_filter:inspect_these[div_filter]})
        for div in divs:
            a_ref =  div.find('a')
            content_text = a_ref.contents[0]
            data_url = a_ref['href']
            if data_url[0] == '/' and base_url != "":
                data_url = base_url + data_url
            data_refs.append({'type':"supplementary", "name":a_ref.contents[0], 'data_url':data_url})
    return data_refs


# Wiley online stores supplementary in tables on the article page. 
table_filters={'wiley':{"class":"support-info__table"}}
def get_data_from_tables(soup, journal = 'wiley', data_refs = [], base_url=""):
    inspect_these = {}
    if journal in table_filters:
        inspect_these = table_filters[journal]
    for tbl_filter in inspect_these:
        tables = soup.find_all('table',{tbl_filter:inspect_these[tbl_filter]})
        for table in tables:
            # find rows
            trs = table.find_all('tr')
            # get the type and link from each row
            for tr in trs:
                td_link = tr.find('td',{"headers":"article-filename"})
                td_desc = tr.find('td',{"headers":"article-description"})
                data_link = td_link.find('a')
                data_url = data_link['href']
                if data_url[0] == '/' and base_url != "":
                    data_url = base_url + data_url
                data_refs.append({'type':td_desc.contents[0], "name":data_link.contents[0], 'data_url':data_url})
    return data_refs

# extract from anchor in text publications
a_filters={'rsc':{"class":"list__item-link"}, 'acs':{"class":"suppl-anchor"}}
def get_data_from_anchor(soup, journal = 'rsc', data_refs = [], base_url=""):
    # find line for supplementary
    if journal in a_filters:
        inspect_these = a_filters[journal]
    for a_filter in inspect_these:
        supp_h2_line = -1
        inspect_heads = soup.find_all("h2")
        for a_head in inspect_heads:
            for content in a_head.contents:
                if content != None and "supplementary" in str(content).lower() :
                    supp_h2_line = a_head.sourceline

        # Use the position of "header line" as offset to look for data links
        links = soup.find_all("a", {a_filter:inspect_these[a_filter]})
        for link in links:
            dt_type = dt_link = dt_name = ""
            if link.sourceline > supp_h2_line:
                #print(link, "\nLine: ", link.sourceline)
                if journal == 'rsc':
                    l_spans = link.find_all("span",{"class":"list__item-label"})
                    for a_span in l_spans:
                        for contnt in a_span.contents:
                            if 'supplementary' in str(contnt).lower():
                                dt_link = link['href']
                                dt_name = str(contnt).strip()
                                #print('supplementary', link['href'], str(contnt).strip())
                            if str(type(contnt)) == "<class 'bs4.element.Tag'>":
                                #print(contnt.contents[0])
                                dt_name += contnt.contents[0]
                            #print(str(type(contnt)), str(contnt).strip())
                elif journal == 'acs':
                    dt_link = link['href']
                    dt_name = str(link.contents[0]).strip()
            if dt_link != "" and dt_name != "":
                if dt_link[0] == '/' and base_url != "":
                    dt_link = base_url + dt_link
                data_refs.append({'type':'supplementary',"name":dt_name, 'data_url':dt_link})
    return data_refs

# get full doc from rsc landig page
def get_full_html_doc(soup):
    # check if full html text is available
    more_soup = anoter_url = None
    metadata = soup.find_all("meta",{"name":"citation_fulltext_html_url"})
    if len(metadata)> 0:
        more_soup, anoter_url = get_content(metadata[0]['content'])
    return more_soup, anoter_url

# verify if statement refers to supporting data
def is_data_stmt(statement=""):
    support_keys = ["data", "underpin", "support", "result", "found", "find", "obtain", "doi","raw", "information"
                    "provide", "availabe", "online"]
    count = 0
    for a_word in support_keys:
        if a_word in statement:
            count += 1
    if count > 2:
        return True
    return False

# get data references from full html doc
def get_data_from_html_doc(soup, journal = 'rsc', data_refs = [], base_url=""):
    if journal == 'rsc':
        # rsc lists the link to full html document in metadata
        more_soup, another_url  = get_full_html_doc(soup)
        if more_soup != None and another_url != None:
            base_url = get_base_url(another_url)
            soup = more_soup
    tag_targets = ['p', 'span']
    for tag_name in tag_targets:
        paras = soup.find_all(tag_name)
        for para in paras:
            for cont_para in para.contents:
                content = str(cont_para).lower()
                if 'data' in content:
                    intresting = ""
                    if 'data' in content[content.rfind(".")+2:]:
                        intresting = content[content.rfind(".")+2:]
                    else:
                        intresting = content[:content.rfind(".")]
                    anchor_refs = para.find_all('a')
                    if len(anchor_refs)>0 and is_data_stmt(intresting):
                        for a_ref in anchor_refs:
                            dt_link = a_ref['href']
                            dt_name = str(a_ref.contents[0])
                            if dt_link != "" and dt_name != "" and dt_link[0] != "#":
                                if dt_link[0] == '/' and base_url != "":
                                    dt_link = base_url + dt_link 
                                data_refs.append({'type':'supporting',"name":dt_name, 'data_url':dt_link})
    return data_refs

# get a list of ids, titles, dois, links, pdf_file and 
# html_file names from the app database
def get_pub_app_data(db_name = "app_db.sqlite3"):
    db_conn = dbh.DataBaseAdapter(db_name)
    search_in = 'articles'
    fields_required = "id, title, doi, link, pdf_file, html_file"
    filter_str = "status = 'Added'"
    db_titles = db_conn.get_values(search_in, fields_required, filter_str)
    db_conn.close()
    return db_titles

def get_base_url(response_url):
    parsed_uri = urlparse(response_url)  # returns six components
    base_url = parsed_uri.scheme + "://" + parsed_uri.netloc
    return base_url

# use regular expression to check if a given string
# is a valid DOI, using pattern from CR
def valid_doi(cr_doi):
    # CR DOIS: https://www.crossref.org/blog/dois-and-matching-regular-expressions/
    # CR DOIs re1
    # /^10.\d{4,9}/[-._;()/:A-Z0-9]+$/i
    if cr_doi == None:
        return False
    cr_re_01 = '^10.\d{4,9}/[-._;()/:A-Z0-9]+'
    compare = re.match(cr_re_01, cr_doi, re.IGNORECASE)
    if compare != None and cr_doi == compare.group():
        return True
    else:
        return False

# %%
# get the publications list from the app database
ukchapp_db = "db_files/app_db.sqlite3"
db_pubs = get_pub_app_data(ukchapp_db)

# get the list of dois already mined for data 
input_file = 'pub_data_all.csv'
id_field = 'num'
processed, headings = csv_rw.get_csv_data(input_file, id_field)
for id_num in processed:
    current_title = processed[id_num]['doi']
processed[1]['num']

processed_dois = []
for entry in processed:
    if not processed[entry]['doi'] in processed_dois:
        processed_dois.append( processed[entry]['doi'])

data_records = {}
ref_count = 1
for a_pub in tqdm_notebook(db_pubs):
    pub_id = a_pub[0]
    pub_title = a_pub[1]
    pub_doi = a_pub[2]
    pub_url = a_pub[3]
    pub_pdf = a_pub[4]
    pub_html = a_pub[5]
    publishers = ['acs', "wiley", "springer", "rsc", 'nature','elsevier']
    if not pub_doi in processed_dois and valid_doi(pub_doi):
        # use doi reference to get landing page
        url = "http://dx.doi.org/" + pub_doi
        doc_content, response_url = get_content(url)
        base_url = get_base_url(response_url)
        publisher = 'another_pub'
        for pb_name in publishers:
            if pb_name in base_url:
                publisher = pb_name
        print("Title: ", pub_title, " look up: ", base_url, " publisher:", publisher)
        res = []
        if publisher in ['springer', 'nature']:
            res = get_data_from_metadata(doc_content, publisher, res)
            res = get_data_from_section(doc_content, publisher, res, base_url)
            res = get_data_from_divs(doc_content, publisher, res, base_url)
        if publisher in ['wiley']:
            res = get_data_from_tables(doc_content, publisher, res, base_url)
        if publisher in ['rsc','acs']:
            res = get_data_from_anchor(doc_content, publisher, res, base_url)
            res = get_data_from_html_doc(doc_content, publisher, res, base_url)
        if res != []:
            for data_ref in res:
                #print(data_ref)
                data_record = {'id':pub_id, 'doi':pub_doi}    
                data_record.update(data_ref)
                data_records[ref_count] = data_record
                ref_count += 1
# Out:
# C:\Users\scman1\Anaconda3\envs\python36\lib\site-packages\ipykernel_launcher.py:20: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=342.0), HTML(value='')))
# Title:  Simplified lipid II-binding antimicrobial peptides: Design, synthesis and antimicrobial activity of bioconjugates of nisin rings A and B with pore-forming peptides  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Concise synthesis of artemisinin from a farnesyl diphosphate analogue  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Discovery, Characterization, Engineering, and Applications of Ene-Reductases for Industrial Biocatalysis  look up:  https://pubs.acs.org  publisher: acs
# Title:  Investigation of ZSM-5 catalysts for dimethylether conversion using inelastic neutron scattering  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Operando HERFD-XANES/XES studies reveal differences in the activity of Fe-species in MFI and CHA structures for the standard selective catalytic reduction of NO with NH3  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Directed aqueous-phase reforming of glycerol through tailored platinum nanoparticles  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  The effects of MTG catalysis on methanol mobility in ZSM-5  look up:  https://pubs.rsc.org  publisher: rsc
# Title:  QENS study of methane diffusion in Mo/H-ZSM-5 used for the methane dehydroaromatisation reaction  look up:  https://aip.scitation.org  publisher: another_pub
# Title:  Structural investigations in pure-silica and Al-ZSM-12 with MTEA or TEA cations  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Hydrogen generation by photocatalytic reforming of potential biofuels: Polyols, cyclic alcohols, and saccharides  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Electrochemical characterization and regeneration of sulfur poisoned Pt catalysts in aqueous media  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  'Switch' catalysis: from monomer mixtures to sequence-controlled block copolymers  look up:  https://royalsocietypublishing.org  publisher: another_pub
# Title:  Influence of TiO2 structural properties on photocatalytic hydrogen gas production  look up:  https://link.springer.com  publisher: springer
# Title:  Simultaneous removal of NOx and soot particulate from diesel exhaust by in-situ catalytic generation and utilisation of N2O  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  The deposition of metal nanoparticles on carbon surfaces: the role of specific functional groups  look up:  https://pubs.rsc.org  publisher: rsc
# Title:  Hybrid Catalysts for Other C-C and C-X Bond Formation Reactions  look up:  https://onlinelibrary.wiley.com  publisher: wiley
# Title:  Catalytic applications of small bite-angle diphosphorus ligands with single-atom linkers  look up:  https://pubs.rsc.org  publisher: rsc
# Title:  Development of Interatomic Potentials for Supported Nanoparticles: The Cu/ZnO Case  look up:  https://pubs.acs.org  publisher: acs
# Title:  Nanosilicalites as Support for β-Glucosidases Covalent Immobilization  look up:  https://link.springer.com  publisher: springer
# Title:  Optimised hydrogen production by aqueous phase reforming of glycerol on Pt/Al2O3  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Neutron spectroscopy as a tool in catalytic science  look up:  https://pubs.rsc.org  publisher: rsc
# Title:  Identification of single-site gold catalysis in acetylene hydrochlorination  look up:  https://science.sciencemag.org  publisher: another_pub
# Title:  An assessment of hydrocarbon species in the methanol-to-hydrocarbon reaction over a ZSM-5 catalyst  look up:  https://pubs.rsc.org  publisher: rsc
# Title:  Heterostructures of GaN with SiC and ZnO enhance carrier stability and separation in framework semiconductors  look up:  https://onlinelibrary.wiley.com  publisher: wiley
# Title:  Understanding the role of promoters in catalysis: operando XAFS/DRIFTS study of CeOx/Pt/Al2O3 during CO oxidation  look up:  https://www.tandfonline.com  publisher: another_pub
# Title:  On the synthesis and performance of hierarchical nanoporous TS-1 catalysts  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  The adsorbed state of a thiol on palladium nanoparticles  look up:  https://pubs.rsc.org  publisher: rsc
# Title:  Towards microfluidic reactors for in situ synchrotron infrared studies  look up:  https://aip.scitation.org  publisher: another_pub
# Title:  Methanol oxidation on Fe2O3 catalysts and the effects of surface Mo  look up:  https://pubs.rsc.org  publisher: rsc
# Title:  The reaction of formic acid with Raney  TM copper  look up:  https://royalsocietypublishing.org  publisher: another_pub
# Title:  Methanol diffusion in zeolite HY: a combined quasielastic neutron scattering and molecular dynamics simulation study  look up:  https://pubs.rsc.org  publisher: rsc
# Title:  Neutron scattering in catalysis and energy materials  look up:  https://pubs.rsc.org  publisher: rsc
# Title:  Ammonia mobility in chabazite: insight into the diffusion component of the NH3-SCR process  look up:  https://pubs.rsc.org  publisher: rsc
# Title:  Adsorption of formate species on Cu(h,k,l) low index surfaces  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Design and stabilisation of a high area iron molybdate surface for the selective oxidation of methanol to formaldehyde  look up:  https://pubs.rsc.org  publisher: rsc
# Title:  Application of Inelastic Neutron Scattering to the Methanol-to-Gasoline Reaction Over a ZSM-5 Catalyst  look up:  https://link.springer.com  publisher: springer
# Title:  Applications of Neutron Scattering in Catalysis  look up:  https://www.ingentaconnect.com  publisher: another_pub
# Title:  Influence of dopant substitution mechanism on catalytic properties within hierarchical architectures  look up:  https://royalsocietypublishing.org  publisher: another_pub
# Title:  Modelling metal centres, acid sites and reaction mechanisms in microporous catalysts  look up:  https://pubs.rsc.org  publisher: rsc
# Title:  Photocatalytic hydrogen production by reforming of methanol using Au/TiO2, Ag/TiO2and Au-Ag/TiO2catalysts  look up:  https://www.tandfonline.com  publisher: another_pub
# Title:  Selectivity determinants for dual function catalysts: applied to methanol selective oxidation on iron molybdate  look up:  https://www.tandfonline.com  publisher: another_pub
# Title:  Optimizing spatial pore-size and porosity distributions of adsorbents for enhanced adsorption and desorption performance  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Hydrogen production by photoreforming of biofuels using Au, Pd and Au–Pd/TiO2 photocatalysts  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Chemical imaging of the sulfur-induced deactivation of Cu/ZnO catalyst bodies  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Comparison of Au and TiO2 based catalysts for the synthesis of chalcogenide nanowires  look up:  https://aip.scitation.org  publisher: another_pub
# Title:  Progress towards five dimensional diffraction imaging of functional materials under process conditions  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Molecular dynamics simulations of longer n-alkanes in silicalite: a comparison of framework and hydrocarbon models  look up:  https://pubs.rsc.org  publisher: rsc
# Title:  Deactivation study of the hydrodeoxygenation of p -methylguaiacol over silica supported rhodium and platinum catalysts  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Nb2O5/SBA-15 catalyzed propanoic acid esterification  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Tellurium-doped lanthanum manganite as catalysts for the oxygen reduction reaction  look up:  https://www.cambridge.org  publisher: another_pub
# Title:  Photoelectrochemical properties of BiOCl microplatelets  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  YFeO 3 Photocathodes for Hydrogen Evolution  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Pd segregation to the surface of Au on Pd(111) and on Pd/TiO 2 (110)  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Life cycle assessment of a polymer electrolyte membrane fuel cell system for passenger vehicles  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Heterogeneously Catalyzed Hydrothermal Processing of C5–C6 Sugars  look up:  https://pubs.acs.org  publisher: acs
# Title:  Enhanced MFC power production and struvite recovery by the addition of sea salts to urine  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Palladium–nickel materials as cathode electrocatalysts for alkaline fuel cells  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Nanoporous carbon/WO3 anodes for an enhanced water photooxidation  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Methanol tolerant Pt 2 CrCo catalysts supported on ordered mesoporous carbon for the cathode of DMFC  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Evolution and Enabling Capabilities of Spatially Resolved Techniques for the Characterization of Heterogeneously Catalyzed Reactions  look up:  https://pubs.acs.org  publisher: acs
# Title:  H2 production by the photocatalytic reforming of cellulose and raw biomass using Ni, Pd, Pt and Au on titania  look up:  https://royalsocietypublishing.org  publisher: another_pub
# Title:  Catalytic applications of waste derived materials  look up:  https://pubs.rsc.org  publisher: rsc
# Title:  Synthetic strategies to nanostructured photocatalysts for CO2reduction to solar fuels and chemicals  look up:  https://pubs.rsc.org  publisher: rsc
# Title:  Preliminary Investigation on the Electrochemical Activity of Butanol Isomers as Potential Fuel for Direct Alcohol Fuel Cell  look up:  https://iopscience.iop.org  publisher: another_pub
# Title:  Base-free glucose oxidation using air with supported gold catalysts  look up:  https://pubs.rsc.org  publisher: rsc
# Title:  Graphitic Carbon Nitride Supported Catalysts for Polymer Electrolyte Fuel Cells  look up:  https://pubs.acs.org  publisher: acs
# Title:  Hydrogen Oxidation on PdIr/C Catalysts in Alkaline Media  look up:  https://iopscience.iop.org  publisher: another_pub
# Title:  Sustainable polymers from renewable resources  look up:  https://www.nature.com  publisher: nature
# Title:  Catalysts for CO2/epoxide ring-opening copolymerization  look up:  https://royalsocietypublishing.org  publisher: another_pub
# Title:  Proteins as templates for complex synthetic metalloclusters: towards biologically programmed heterogeneous catalysis  look up:  https://royalsocietypublishing.org  publisher: another_pub
# Title:  The Effects of Secondary Oxides on Copper‐Based Catalysts for Green Methanol Synthesis  look up:  https://chemistry-europe.onlinelibrary.wiley.com  publisher: wiley
# Title:  On the Role of Water in Heterogeneous Catalysis: A Tribute to Professor M. Wyn Roberts  look up:  https://link.springer.com  publisher: springer
# Title:  XPS and STM studies of the oxidation of hydrogen chloride at Cu(100) surfaces  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  The role of precursor states in adsorption, surface reactions and catalysis  look up:  https://link.springer.com  publisher: springer
# Title:  The surface of iron molybdate catalysts used for the selective oxidation of methanol  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Pd/ZnO catalysts for direct CO2 hydrogenation to methanol  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  From surface science to catalysis: The importance of methoxy and formate species on Cu single crystals and industrial catalysts  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Exploring the mechanisms of metal co-catalysts in photocatalytic reduction reactions: Is Ag a good candidate?  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Robust synthesis of epoxy resin-filled microcapsules for application to self-healing materials  look up:  https://royalsocietypublishing.org  publisher: another_pub
# Title:  The preparation of large surface area lanthanum based perovskite supports for AuPt nanoparticles: tuning the glycerol oxidation reaction pathway by switching the perovskite B site  look up:  https://pubs.rsc.org  publisher: rsc
# Title:  Oxidation of Aliphatic Alcohols by Using Precious Metals Supported on Hydrotalcite under Solvent- and Base-Free Conditions  look up:  https://chemistry-europe.onlinelibrary.wiley.com  publisher: wiley
# Title:  Using real particulate matter to evaluate combustion catalysts for direct regeneration of diesel soot filters  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Selective Oxidation ofn-Butanol Using Gold-Palladium Supported Nanoparticles Under Base-Free Conditions  look up:  https://chemistry-europe.onlinelibrary.wiley.com  publisher: wiley
# Title:  Mechanochemical synthesis of copper manganese oxide for the ambient temperature oxidation of carbon monoxide  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Catalyst design in oxidation chemistry  from KMnO4 to artificial metalloenzymes  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Supercritical antisolvent precipitation of TiO2 with tailored anatase/rutile composition for applications in redox catalysis and photocatalysis  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  An Investigation of the Effect of the Addition of Tin to 5\u2009%Pd/TiO2for the Hydrogenation of Furfuryl Alcohol  look up:  https://chemistry-europe.onlinelibrary.wiley.com  publisher: wiley
# Title:  Molecular Basis of Class A β-Lactamase Inhibition by Relebactam  look up:  https://aac.asm.org  publisher: another_pub
# Title:  Chemo-enzymatic routes towards the synthesis of bio-based monomers and polymers  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  The influence of porosity on nanoparticle formation in hierarchical aluminophosphates  look up:  https://www.beilstein-journals.org  publisher: another_pub
# Title:  Methanol oxidation over shell-core MO /Fe2O3 (M = Mo, V, Nb) catalysts  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Methanol Synthesis from CO2 Hydrogenation  look up:  https://chemistry-europe.onlinelibrary.wiley.com  publisher: wiley
# Title:  Electrochemical Behavior of Pt–Ru Catalysts Supported on Graphitized Ordered Mesoporous Carbons toward CO and Methanol Oxidation  look up:  https://www.mdpi.com  publisher: another_pub
# Title:  SCILLs as selective catalysts for the oxidation of aromatic alcohols  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  In-depth characterisation of metal-support compounds in spent Co/SiO2 Fischer-Tropsch model catalysts  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Integration of supercapacitors into printed circuit boards  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  New insights into the electrochemical behaviour of porous carbon electrodes for supercapacitors  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Electrochemical reduction of carbon dioxide on copper-based nanocatalysts using the rotating ring-disc electrode  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Preface for the Issue of Topics in Catalysis Dedicated to the Memory of Professor Frank S. Stone  look up:  https://link.springer.com  publisher: springer
# Title:  Highlights from Faraday Discussion: Designing New Heterogeneous Catalysts, London, UK, April 2016  look up:  https://pubs.rsc.org  publisher: rsc
# Title:  Mechanistic Aspects of Hydrodeoxygenation of p-Methylguaiacol over Rh/Silica and Pt/Silica  look up:  https://pubs.acs.org  publisher: acs
# Title:  Solvent Free Synthesis of PdZn/TiO2 Catalysts for the Hydrogenation of CO2 to Methanol  look up:  https://link.springer.com  publisher: springer
# Title:  Combined spatially resolved operando spectroscopy: New insights into kinetic oscillations of CO oxidation on Pd/γ-Al2O3  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Catalysts for the Selective Oxidation of Methanol  look up:  https://www.mdpi.com  publisher: another_pub
# Title:  Development and characterization of thermally stable supported V–W–TiO2 catalysts for mobile NH3–SCR applications  look up:  https://www.tandfonline.com  publisher: another_pub
# Title:  The integration of experiment and computational modelling in heterogeneously catalysed ammonia synthesis over metal nitrides  look up:  https://pubs.rsc.org  publisher: rsc
# Title:  Preparation of bifunctional Au-Pd/TiO2 catalysts and research on methanol liquid phase one-step oxidation to methyl formate  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Rutile TiO2–Pd Photocatalysts for Hydrogen Gas Production from Methanol Reforming  look up:  https://link.springer.com  publisher: springer
# Title:  A Perspective on Counting Catalytic Active Sites and Rates of Reaction Using X-Ray Spectroscopy  look up:  https://link.springer.com  publisher: springer
# Title:  Reactions of Dimethylether in Single Crystals of the Silicoaluminophosphate STA-7 Studied via Operando Synchrotron Infrared Microspectroscopy  look up:  https://link.springer.com  publisher: springer
# Title:  Evolution of palladium sulfide phases during thermal treatments and consequences for acetylene hydrogenation  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Highly active Pt3Rh/C nanoparticles towards ethanol electrooxidation. Influence of the catalyst structure  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  In situ determination of the nanostructure effects on the activity, stability and selectivity of Pt-Sn ethanol oxidation catalysts  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Solution Processing Route to Multifunctional Titania Thin Films: Highly Conductive and Photcatalytically Active Nb:TiO2  look up:  https://onlinelibrary.wiley.com  publisher: wiley
# Title:  An experimental and computational IR and hybrid DFT-D3 study of the conformations of l-lactic and acrylic acid: new insight into the dehydration mechanism of lactic acid to acrylic acid  look up:  https://pubs.rsc.org  publisher: rsc
# Title:  Synchrotron Radiation and Catalytic Science  look up:  https://www.tandfonline.com  publisher: another_pub
# Title:  Mechanism of CO2 conversion to methanol over Cu(110) and Cu(100) surfaces  look up:  https://pubs.rsc.org  publisher: rsc
# Title:  In Situ Spatially Resolved Techniques for the Investigation of Packed Bed Catalytic Reactors: Current Status and Future Outlook of Spaci-FB  look up:  https://linkinghub.elsevier.com  publisher: elsevier
# Title:  Synchrotron radiation techniques in catalytic science  look up:  https://pubs.rsc.org  publisher: rsc
# Title:  Modern Developments in Catalysis  look up:  https://www.worldscientific.com  publisher: another_pub
# Title:  Shining light on the solid–liquid interface: in situ/operando monitoring of surface catalysis  look up:  https://pubs.rsc.org  publisher: rsc
# Title:  Science to enable the circular economy  look up:  https://royalsocietypublishing.org  publisher: another_pub

# %%
len(processed_dois)
# Out:
# 217

# %%
if len(data_records) > 0:
    csv_rw.write_csv_data(data_records, 'pub_data.csv')

# %%
missing_pubs = []
for a_pub in db_pubs:
    pub_id = a_pub[0]
    pub_title = a_pub[1]
    pub_doi = a_pub[2]
    pub_url = a_pub[3]
    pub_pdf = a_pub[4]
    pub_html = a_pub[5]
    if "acs" in str(pub_url).lower():
        data_found = False
        for dr in data_records:
            if pub_id == data_records[dr]['id']:
                data_found = True
                break
        if not data_found:
            url = "http://dx.doi.org/" + pub_doi
            print("missing: ", pub_id, pub_doi, url)
            missing_pubs.append(a_pub)
len(missing_pubs)
# Out:
# missing:  2 10.1021/acscatal.9b00685 http://dx.doi.org/10.1021/acscatal.9b00685
# missing:  6 10.1021/acssuschemeng.8b03568 http://dx.doi.org/10.1021/acssuschemeng.8b03568
# missing:  10 10.1021/acs.biochem.8b00169 http://dx.doi.org/10.1021/acs.biochem.8b00169
# missing:  11 10.1021/acscatal.8b00389 http://dx.doi.org/10.1021/acscatal.8b00389
# missing:  12 10.1021/acscatal.8b00624 http://dx.doi.org/10.1021/acscatal.8b00624
# missing:  13 10.1021/jacs.7b12621 http://dx.doi.org/10.1021/jacs.7b12621
# missing:  14 10.1021/acscatal.8b03169 http://dx.doi.org/10.1021/acscatal.8b03169
# missing:  15 10.1021/acscatal.9b01820 http://dx.doi.org/10.1021/acscatal.9b01820
# missing:  20 10.1021/acs.jpcc.8b08420 http://dx.doi.org/10.1021/acs.jpcc.8b08420
# missing:  23 10.1021/acscatal.8b02232 http://dx.doi.org/10.1021/acscatal.8b02232
# missing:  33 10.1021/acsaem.8b00873 http://dx.doi.org/10.1021/acsaem.8b00873
# missing:  49 10.1021/jacs.8b01920 http://dx.doi.org/10.1021/jacs.8b01920
# missing:  60 10.1021/acs.iecr.8b00230 http://dx.doi.org/10.1021/acs.iecr.8b00230
# missing:  65 10.1021/acs.organomet.8b00063 http://dx.doi.org/10.1021/acs.organomet.8b00063
# missing:  74 10.1021/acs.jpcc.7b04502 http://dx.doi.org/10.1021/acs.jpcc.7b04502
# missing:  87 10.1021/acs.jctc.6b01131 http://dx.doi.org/10.1021/acs.jctc.6b01131
# missing:  94 10.1021/acs.chemmater.7b02552 http://dx.doi.org/10.1021/acs.chemmater.7b02552
# missing:  96 10.1021/acscatal.6b03190 http://dx.doi.org/10.1021/acscatal.6b03190
# missing:  99 10.1021/acscatal.6b03641 http://dx.doi.org/10.1021/acscatal.6b03641
# missing:  129 10.1021/acs.chemmater.5b00866 http://dx.doi.org/10.1021/acs.chemmater.5b00866
# missing:  131 10.1021/cm503433q http://dx.doi.org/10.1021/cm503433q
# missing:  136 10.1021/acscatal.5b00480 http://dx.doi.org/10.1021/acscatal.5b00480
# missing:  137 10.1021/acscatal.5b00481 http://dx.doi.org/10.1021/acscatal.5b00481
# missing:  138 10.1021/acscatal.5b00754 http://dx.doi.org/10.1021/acscatal.5b00754
# missing:  147 10.1021/jp5081753 http://dx.doi.org/10.1021/jp5081753
# missing:  156 10.1021/acscatal.6b03237 http://dx.doi.org/10.1021/acscatal.6b03237
# missing:  164 10.1021/acs.chemrev.6b00311 http://dx.doi.org/10.1021/acs.chemrev.6b00311
# missing:  165 10.1021/acscatal.6b02369 http://dx.doi.org/10.1021/acscatal.6b02369
# missing:  169 10.1021/acsami.6b02863 http://dx.doi.org/10.1021/acsami.6b02863
# missing:  176 10.1021/acs.jpcc.6b04781 http://dx.doi.org/10.1021/acs.jpcc.6b04781
# missing:  177 10.1021/acscatal.5b02602 http://dx.doi.org/10.1021/acscatal.5b02602
# missing:  193 10.1021/jp412501j http://dx.doi.org/10.1021/jp412501j
# missing:  200 10.1021/jacs.5b13070 http://dx.doi.org/10.1021/jacs.5b13070
# missing:  202 10.1021/jacs.6b00710 http://dx.doi.org/10.1021/jacs.6b00710
# missing:  211 10.1021/jacs.5b09913 http://dx.doi.org/10.1021/jacs.5b09913
# missing:  212 10.1021/cs502038y http://dx.doi.org/10.1021/cs502038y
# missing:  213 10.1021/acs.inorgchem.5b02038 http://dx.doi.org/10.1021/acs.inorgchem.5b02038
# missing:  214 10.1021/acs.macromol.5b01293 http://dx.doi.org/10.1021/acs.macromol.5b01293
# missing:  215 10.1021/acs.inorgchem.5b02233 http://dx.doi.org/10.1021/acs.inorgchem.5b02233
# missing:  216 10.1021/acs.macromol.5b00225 http://dx.doi.org/10.1021/acs.macromol.5b00225
# missing:  217 10.1021/acscatal.5b01327 http://dx.doi.org/10.1021/acscatal.5b01327
# missing:  218 10.1021/om501252m http://dx.doi.org/10.1021/om501252m
# missing:  220 10.1021/ja5062467 http://dx.doi.org/10.1021/ja5062467
# missing:  245 10.1021/acscatal.5b00625 http://dx.doi.org/10.1021/acscatal.5b00625
# missing:  249 10.1021/om5008055 http://dx.doi.org/10.1021/om5008055
# missing:  256 10.1021/nn500963m http://dx.doi.org/10.1021/nn500963m
# missing:  257 10.1021/acs.iecr.9b04263 http://dx.doi.org/10.1021/acs.iecr.9b04263
# missing:  258 10.1021/acscatal.8b04564 http://dx.doi.org/10.1021/acscatal.8b04564
# missing:  260 10.1021/jacs.9b02731 http://dx.doi.org/10.1021/jacs.9b02731
# missing:  261 10.1021/acs.jcim.8b00940 http://dx.doi.org/10.1021/acs.jcim.8b00940
# missing:  278 10.1021/acs.nanolett.9b01733 http://dx.doi.org/10.1021/acs.nanolett.9b01733
# missing:  281 10.1021/acsnano.8b09399 http://dx.doi.org/10.1021/acsnano.8b09399
# missing:  283 10.1021/acscatal.9b00160 http://dx.doi.org/10.1021/acscatal.9b00160
# missing:  327 10.1021/acs.oprd.8b00211 http://dx.doi.org/10.1021/acs.oprd.8b00211
# missing:  358 10.1021/cs400683e http://dx.doi.org/10.1021/cs400683e
# missing:  366 10.1021/acscatal.8b01509 http://dx.doi.org/10.1021/acscatal.8b01509
# missing:  501 10.1021/acs.jpcc.6b11186 http://dx.doi.org/10.1021/acs.jpcc.6b11186
# missing:  509 10.1021/acscatal.6b00982 http://dx.doi.org/10.1021/acscatal.6b00982
# missing:  525 10.1021/ja512868a http://dx.doi.org/10.1021/ja512868a
# missing:  560 10.1021/acscatal.7b03805 http://dx.doi.org/10.1021/acscatal.7b03805
# missing:  566 10.1021/acscatal.6b00589 http://dx.doi.org/10.1021/acscatal.6b00589
# missing:  568 10.1021/acscatal.5b01936 http://dx.doi.org/10.1021/acscatal.5b01936
# missing:  587 10.1021/acsomega.9b03351 http://dx.doi.org/10.1021/acsomega.9b03351
# missing:  593 10.1021/acscatal.9b05129 http://dx.doi.org/10.1021/acscatal.9b05129
# missing:  595 10.1021/acsomega.9b03503 http://dx.doi.org/10.1021/acsomega.9b03503
# missing:  609 10.1021/acscatal.0c00596 http://dx.doi.org/10.1021/acscatal.0c00596
# missing:  612 10.1021/acscatal.0c00414 http://dx.doi.org/10.1021/acscatal.0c00414
# missing:  615 10.1021/acs.jpcc.9b05475 http://dx.doi.org/10.1021/acs.jpcc.9b05475
# 68

# %%
url = 'https://doi.org/10.1016/j.apcata.2018.10.010'
req_head = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36'}
response = requests.get(url, headers = req_head)

response = requests.get(response.url, headers = req_head)
print(response)
print(response.url)
redirected_to = response.url
parsed_uri = urlparse(redirected_to)  # returns six components
print(parsed_uri)
domain = parsed_uri.netloc
result = domain.replace('www.', '')  # as per your case
print(domain)
base_url = parsed_uri.scheme + "://" + parsed_uri.netloc

print(base_url)
soup = BeautifulSoup(response.text,'html.parser')

# check if full html text is available
metadata = soup.find_all("meta")#,{"name":"citation_fulltext_html_url"})
for meta in metadata:
  print(meta)
#more_soup = None
#if len(metadata)> 0:
#    print(metadata[0]['content'])
#    more_soup, _ = get_content(metadata[0]['content'])
    
#paras = more_soup.find_all('p')
#for para in paras:
#    anchor_ref = para.find_all('a')
#    if len(anchor_ref)>0:
#        print (para)
# Out:
# <Response [200]>
# https://linkinghub.elsevier.com/retrieve/pii/S0926860X18305003
# ParseResult(scheme='https', netloc='linkinghub.elsevier.com', path='/retrieve/pii/S0926860X18305003', params='', query='', fragment='')
# linkinghub.elsevier.com
# https://linkinghub.elsevier.com
# <meta charset="utf-8"/>
# <meta content="text/html" http-equiv="Content-Type"/>
# <meta content="2; url='/retrieve/articleSelectSinglePerm?Redirect=https%3A%2F%2Fwww.sciencedirect.com%2Fscience%2Farticle%2Fpii%2FS0926860X18305003%3Fvia%253Dihub&amp;key=b2d4819c47da207b2b55574a898c9b7ee7dabbdf'" http-equiv="REFRESH">
# <script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={licenseKey:"ee15051b1b",applicationID:"81847441"};window.NREUM||(NREUM={}),__nr_require=function(e,t,n){function r(n){if(!t[n]){var i=t[n]={exports:{}};e[n][0].call(i.exports,function(t){var i=e[n][1][t];return r(i||t)},i,i.exports)}return t[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(e,t,n){function r(){}function i(e,t,n){return function(){return o(e,[u.now()].concat(c(arguments)),t?null:this,n),t?void 0:this}}var o=e("handle"),a=e(6),c=e(7),f=e("ee").get("tracer"),u=e("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var d=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],p="api-",l=p+"ixn-";a(d,function(e,t){s[t]=i(p+t,!0,"api")}),s.addPageAction=i(p+"addPageAction",!0),s.setCurrentRouteName=i(p+"routeName",!0),t.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(e,t){var n={},r=this,i="function"==typeof t;return o(l+"tracer",[u.now(),e,n],r),function(){if(f.emit((i?"":"no-")+"fn-start",[u.now(),r,i],n),i)try{return t.apply(this,arguments)}catch(e){throw f.emit("fn-err",[arguments,this,e],n),e}finally{f.emit("fn-end",[u.now()],n)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(e,t){m[t]=i(l+t)}),newrelic.noticeError=function(e,t){"string"==typeof e&&(e=new Error(e)),o("err",[e,u.now(),!1,t])}},{}],2:[function(e,t,n){function r(){return c.exists&&performance.now?Math.round(performance.now()):(o=Math.max((new Date).getTime(),o))-a}function i(){return o}var o=(new Date).getTime(),a=o,c=e(8);t.exports=r,t.exports.offset=a,t.exports.getLastTimestamp=i},{}],3:[function(e,t,n){function r(e,t){var n=e.getEntries();n.forEach(function(e){"first-paint"===e.name?d("timing",["fp",Math.floor(e.startTime)]):"first-contentful-paint"===e.name&&d("timing",["fcp",Math.floor(e.startTime)])})}function i(e,t){var n=e.getEntries();n.length>0&&d("lcp",[n[n.length-1]])}function o(e){e.getEntries().forEach(function(e){e.hadRecentInput||d("cls",[e])})}function a(e){if(e instanceof m&&!g){var t=Math.round(e.timeStamp),n={type:e.type};t<=p.now()?n.fid=p.now()-t:t>p.offset&&t<=Date.now()?(t-=p.offset,n.fid=p.now()-t):t=p.now(),g=!0,d("timing",["fi",t,n])}}function c(e){d("pageHide",[p.now(),e])}if(!("init"in NREUM&&"page_view_timing"in NREUM.init&&"enabled"in NREUM.init.page_view_timing&&NREUM.init.page_view_timing.enabled===!1)){var f,u,s,d=e("handle"),p=e("loader"),l=e(5),m=NREUM.o.EV;if("PerformanceObserver"in window&&"function"==typeof window.PerformanceObserver){f=new PerformanceObserver(r);try{f.observe({entryTypes:["paint"]})}catch(v){}u=new PerformanceObserver(i);try{u.observe({entryTypes:["largest-contentful-paint"]})}catch(v){}s=new PerformanceObserver(o);try{s.observe({type:"layout-shift",buffered:!0})}catch(v){}}if("addEventListener"in document){var g=!1,y=["click","keydown","mousedown","pointerdown","touchstart"];y.forEach(function(e){document.addEventListener(e,a,!1)})}l(c)}},{}],4:[function(e,t,n){function r(e,t){if(!i)return!1;if(e!==i)return!1;if(!t)return!0;if(!o)return!1;for(var n=o.split("."),r=t.split("."),a=0;a<r.length;a++)if(r[a]!==n[a])return!1;return!0}var i=null,o=null,a=/Version\/(\S+)\s+Safari/;if(navigator.userAgent){var c=navigator.userAgent,f=c.match(a);f&&c.indexOf("Chrome")===-1&&c.indexOf("Chromium")===-1&&(i="Safari",o=f[1])}t.exports={agent:i,version:o,match:r}},{}],5:[function(e,t,n){function r(e){function t(){e(a&&document[a]?document[a]:document[i]?"hidden":"visible")}"addEventListener"in document&&o&&document.addEventListener(o,t,!1)}t.exports=r;var i,o,a;"undefined"!=typeof document.hidden?(i="hidden",o="visibilitychange",a="visibilityState"):"undefined"!=typeof document.msHidden?(i="msHidden",o="msvisibilitychange"):"undefined"!=typeof document.webkitHidden&&(i="webkitHidden",o="webkitv ...
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.10.1/jquery.min.js" type="text/JavaScript"></script>
# <script src="https://assets.adobedtm.com/4a848ae9611a/519188bfaff2/launch-d9c9ae460653.min.js"></script>
# <title>Redirecting</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="/retrieve/static/css/articleLocatorNew.css" rel="stylesheet" title="Default Styles"/>
# <link href="/retrieve/static/css/updateForm.css" rel="stylesheet" title="Default Styles"/>
# <script language="JavaScript" type="text/javascript">
# var timerStart = Date.now();
# var pageName = "";
#
# if (pageName == "") {
# 	pageName = "Auto Article Locator";
# }
# 	function autoRedirectToURL() {
# 		var url = '/retrieve/'+document.getElementById('resultName').value+'?Redirect='+document.getElementById('redirectURL').value+'&key='+document.getElementById('key').value
# 		try{siteCatalyst.clickEventTrack(document.getElementById('id').value);}catch(e){}
# 		window.location = url;
# 	}
# </script>
# </meta>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>

# %%
len(metadata)
# Out:
# 4

# %%
exclude_metadata = {'nature':['viewport', 'msapplication-TileColor', 'msapplication-config',  'theme-color', 
                    'application-name', 'robots', 'access', 'WT.cg_s', 'WT.z_bandiera_abtest', 'WT.page_categorisation',
                    'WT.template', 'WT.z_cg_type', 'WT.cg_n', 'dc.rights', 'prism.issn'],'springer':['viewport', 
                    'msapplication-TileColor', 'msapplication-config',  'theme-color', 
                    'application-name', 'robots', 'access', 'WT.cg_s', 'WT.z_bandiera_abtest', 'WT.page_categorisation',
                    'WT.template', 'WT.z_cg_type', 'WT.cg_n', 'dc.rights', 'prism.issn'],"wiley":[], 'rsc':['viewport',
                    'format-detection', 'msapplication-TileColor', 'theme-color', 'dc.domain','twitter:card',
                    'twitter:site'],"acs":['pbContext','viewport','robots','twitter:description','pb-robots-disabled',
                    'twitter:card','twitter:site','twitter:image','twitter:title','google-site-verification'],'elsevier':
                    []}
metadata = soup.find_all("meta",{"name":True})

publisher = 'elsevier'
for md in metadata:
    if not md['name'] in exclude_metadata[publisher]:
        print("X:", md['name'])
        print(md)
