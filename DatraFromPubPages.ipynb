# %%
# Connecting to the db
import lib.handle_db as dbh

# read and write csv files
import lib.handle_csv as csv_rw

# Parsing html 
from bs4 import BeautifulSoup

# http requests 
import requests

# url parser
from urllib.parse import urlparse  # python 3.x

# values for metadata class names to exclude
exclude_metadata = {'nature':['viewport', 'msapplication-TileColor', 'msapplication-config',  'theme-color', 
                    'application-name', 'robots', 'access', 'WT.cg_s', 'WT.z_bandiera_abtest', 'WT.page_categorisation',
                    'WT.template', 'WT.z_cg_type', 'WT.cg_n', 'dc.rights', 'prism.issn'],'springer':['viewport', 'msapplication-TileColor', 'msapplication-config',  'theme-color', 
                    'application-name', 'robots', 'access', 'WT.cg_s', 'WT.z_bandiera_abtest', 'WT.page_categorisation',
                    'WT.template', 'WT.z_cg_type', 'WT.cg_n', 'dc.rights', 'prism.issn'],"wiley":[]}

# values for section labels which may contain references to data
section_labels = {'nature':{'aria-labelledby':'data-availability'},'springer':{'aria-labelledby':'data-availability'}}

# values for div which may contain references to data
div_filters = {'nature':{'class':'c-article-supplementary__item'}, 'springer':{'class':"c-article-supplementary__item"}}

#  Custom functions to get references to datasets
# returns beautifulsoup object from given url
def get_content(url):
    html_soup = None
    try:
        req_head = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 \
                    (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36'}
        response = requests.get(url, headers = req_head)
        redirected_to = response.url
        html_soup = BeautifulSoup(response.text,'html.parser')       
    except Exception as e:
        print(e)
    return html_soup, redirected_to

# get metadata
def get_metadata(soup, journal):
    result=[]
    try:
        metadata = soup.find_all('meta')
        ignore_these = []
        if journal in exclude_metadata:
            ignore_these = exclude_metadata[journal] 
        else:
            print('new journal')
        for md_item in metadata:
            if md_item.has_attr("name") and not md_item["name"] in ignore_these :
                result.append(md_item)
    except Exception as e:
        print(e)
    return result

# get data ref from metadata
def get_data_from_metadata(soup, journal = 'nature', data_refs = []):
    data_refs = []
    res = get_metadata(soup, journal)
    # check if metadata references supporting data or supplementary data
    for md_item in res:
        if 'data' in str(md_item["name"]).lower():
            #print(md_item["name"], md_item["content"])
            ret_data = md_item["content"]
            data_refs.append({'type':"metadata", "name":md_item["name"], 'data_url':md_item["content"]})
    # get author(s) data from metadata
    #for md_item in res:
    #    if 'author' in str(md_item["name"]).lower():
    #        print(md_item["name"], md_item["content"])    
    return data_refs

def get_data_from_section(soup, journal = 'nature', data_refs = [], base_url=""):
    inspect_these = {}
    if journal in section_labels:
        inspect_these = section_labels[journal]
    for sec_filter in inspect_these:
        sections = soup.find_all('section', {sec_filter:inspect_these[sec_filter]})
        for section in sections:
            pars = section.find_all('p')
            for par in pars:
                references = par.find_all('a')
                if len(references) == 0:
                   data_refs.append({'type':inspect_these[sec_filter], "name":par.contents[0], 'data_url':None}) 
                for a_ref in references:
                    content_text = a_ref.contents[0]
                    data_url = a_ref['href']
                    if data_url[0] == '/' and base_url != "":
                        data_url = base_url + data_url
                    data_refs.append({'type':inspect_these[sec_filter], "name":a_ref.contents[0], 'data_url':data_url})
    return data_refs

def get_data_from_divs(soup, journal = 'nature', data_refs = [], base_url=""):
    inspect_these = {}
    if journal in div_filters:
        inspect_these = div_filters[journal]
    for div_filter in inspect_these:
        divs = soup.find_all('div',{div_filter:inspect_these[div_filter]})
        for div in divs:
            a_ref =  div.find('a')
            content_text = a_ref.contents[0]
            data_url = a_ref['href']
            if data_url[0] == '/' and base_url != "":
                data_url = base_url + data_url
            data_refs.append({'type':"supplementary", "name":a_ref.contents[0], 'data_url':data_url})
    return data_refs


# Wiley online stores supplementary in tables on the article page. 
table_filters={'wiley':{"class":"support-info__table"}}
def get_data_from_tables(soup, journal = 'wiley', data_refs = [], base_url=""):
    inspect_these = {}
    if journal in table_filters:
        inspect_these = table_filters[journal]
    for tbl_filter in inspect_these:
        tables = soup.find_all('table',{tbl_filter:inspect_these[tbl_filter]})
        for table in tables:
            # find rows
            trs = table.find_all('tr')
            # get the type and link from each row
            for tr in trs:
                td_link = tr.find('td',{"headers":"article-filename"})
                td_desc = tr.find('td',{"headers":"article-description"})
                data_link = td_link.find('a')
                data_url = data_link['href']
                if data_url[0] == '/' and base_url != "":
                    data_url = base_url + data_url
                data_refs.append({'type':td_desc.contents[0], "name":data_link.contents[0], 'data_url':data_url})
    return data_refs

# get a list of ids, titles, dois, links, pdf_file and 
# html_file names from the app database
def get_pub_app_data(db_name = "app_db.sqlite3"):
    db_conn = dbh.DataBaseAdapter(db_name)
    search_in = 'articles'
    fields_required = "id, title, doi, link, pdf_file, html_file"
    filter_str = "status = 'Added'"
    db_titles = db_conn.get_values(search_in, fields_required, filter_str)
    db_conn.close()
    return db_titles

def get_base_url(response_url):
    parsed_uri = urlparse(response_url)  # returns six components
    base_url = parsed_uri.scheme + "://" + parsed_uri.netloc
    return base_url

# %%
ukchapp_db = "db_files/app_db.sqlite3"
db_pubs = get_pub_app_data(ukchapp_db)
data_records = {}
ref_count = 1
for a_pub in db_pubs:
    pub_id = a_pub[0]
    pub_title = a_pub[1]
    pub_doi = a_pub[2]
    pub_url = a_pub[3]
    pub_pdf = a_pub[4]
    pub_html = a_pub[5]
    publisher = "wiley"# "springet"
    if publisher in str(pub_url).lower():
        #print(pub_title) 
        # use doi reference to get landing page
        url = "http://dx.doi.org/" + pub_doi
        #print("Title: ", pub_title, " look up: ", url)
        doc_content, response_url = get_content(url)
        base_url = get_base_url(response_url)
        res = []
        if publisher in ['springer', 'nature']:
            res = get_data_from_metadata(doc_content, publisher, res)
            res = get_data_from_section(doc_content, publisher, res, base_url)
            res = get_data_from_divs(doc_content, publisher, res, base_url)
        if publisher in ['wiley']:
            res = get_data_from_tables(doc_content, publisher, res, base_url)
        if res != []:
            for data_ref in res:
                #print(data_ref)
                data_record = {'id':pub_id, 'doi':pub_doi}    
                data_record.update(data_ref)
                data_records[ref_count] = data_record
                ref_count += 1
# Out:
# Supplementary /action/downloadSupplement?doi=10.1002%2Fcctc.201901268&file=cctc201901268-sup-0001-misc_information.pdf cctc201901268-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fchem.201805250&file=chem201805250-sup-0001-misc_information.pdf chem201805250-sup-0001-misc_information.pdf
# Supporting Information /action/downloadSupplement?doi=10.1002%2Fejoc.201800799&file=ejoc201800799-sup-0001-SupMat.pdf ejoc201800799-sup-0001-SupMat.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fcctc.201801299&file=cctc201801299-sup-0001-misc_information.pdf cctc201801299-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fcelc.201800729&file=celc201800729-sup-0001-misc_information.pdf celc201800729-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fcelc.201800052&file=celc201800052-sup-0001-misc_information.pdf celc201800052-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fcptc.201700210&file=cptc201700210-sup-0001-misc_information.pdf cptc201700210-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fanie.201713115&file=anie201713115-sup-0001-misc_information.pdf anie201713115-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fcelc.201800770&file=celc201800770-sup-0001-misc_information.pdf celc201800770-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fcelc.201800770&file=celc201800770-sup-0001-Movie_S2-Surface_current.avi celc201800770-sup-0001-Movie_S2-Surface_current.avi
# Supplementary /action/downloadSupplement?doi=10.1002%2Fanie.201801400&file=anie201801400-sup-0001-misc_information.pdf anie201801400-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fcelc.201800478&file=celc201800478-sup-0001-misc_information.pdf celc201800478-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fanie.201710091&file=anie201710091-sup-0001-misc_information.pdf anie201710091-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fcctc.201900795&file=cctc201900795-sup-0001-misc_information.pdf cctc201900795-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fcctc.201900100&file=cctc201900100-sup-0001-misc_information.pdf cctc201900100-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fchem.201704151&file=chem201704151-sup-0001-misc_information.pdf chem201704151-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fcctc.201701946&file=cctc201701946-sup-0001-misc_information.pdf cctc201701946-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fanie.201705753&file=anie201705753-sup-0001-misc_information.pdf anie201705753-sup-0001-misc_information.pdf
# Supporting Information /action/downloadSupplement?doi=10.1002%2Fejoc.201601388&file=ejoc201601388-sup-0001-SupMat.pdf ejoc201601388-sup-0001-SupMat.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fanie.201609557&file=anie201609557-sup-0001-misc_information.pdf anie201609557-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fange.201703550&file=ange201703550-sup-0001-misc_information.pdf ange201703550-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fcctc.201700516&file=cctc201700516-sup-0001-misc_information.pdf cctc201700516-sup-0001-misc_information.pdf
#
#  /action/downloadSupplement?doi=10.1002%2Faic.15095&file=aic15095-sup-0001-suppinfo01.doc aic15095-sup-0001-suppinfo01.doc
#
#  /action/downloadSupplement?doi=10.1002%2Faic.15415&file=aic15415-sup-0001-suppinfo01.doc aic15415-sup-0001-suppinfo01.doc
# Supplementary /action/downloadSupplement?doi=10.1002%2Fcctc.201600729&file=cctc201600729-sup-0001-misc_information.pdf cctc201600729-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fcctc.201500545&file=cctc201500545-sup-0001-misc_information.pdf cctc201500545-sup-0001-misc_information.pdf
# miscellaneous_information /action/downloadSupplement?doi=10.1002%2Fcplu.201500195&file=cplu_201500195_sm_miscellaneous_information.pdf cplu_201500195_sm_miscellaneous_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fanie.201612370&file=anie201612370-sup-0001-misc_information.pdf anie201612370-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fchem.201703567&file=chem201703567-sup-0001-misc_information.pdf chem201703567-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fcphc.201600149&file=cphc201600149-sup-0001-misc_information.pdf cphc201600149-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fcctc.201501260&file=cctc201501260-sup-0001-misc_information.pdf cctc201501260-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fchem.201701013&file=chem201701013-sup-0001-misc_information.pdf chem201701013-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fchem.201605690&file=chem201605690-sup-0001-misc_information.pdf chem201605690-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fanie.201602930&file=anie201602930-sup-0001-misc_information.pdf anie201602930-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fcssc.201501225&file=cssc201501225-sup-0001-misc_information.pdf cssc201501225-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fcctc.201600925&file=cctc201600925-sup-0001-misc_information.pdf cctc201600925-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fcctc.201601603&file=cctc201601603-sup-0001-misc_information.pdf cctc201601603-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fcctc.201600775&file=cctc201600775-sup-0001-misc_information.pdf cctc201600775-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fcctc.201900658&file=cctc201900658-sup-0001-misc_information.pdf cctc201900658-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fcbic.201800606&file=cbic201800606-sup-0001-misc_information.pdf cbic201800606-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fchem.201901188&file=chem201901188-sup-0001-misc_information.pdf chem201901188-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fcctc.201801067&file=cctc201801067-sup-0001-misc_information.pdf cctc201801067-sup-0001-misc_information.pdf
# <p><b>Figure S1</b> Mechanisms of catalyst deactivation by coke at the particle level. (a) Site coverage, (b) pore narrowing, and (c) pore blockage.</p> /action/downloadSupplement?doi=10.1002%2Faic.16687&file=aic16687-sup-0001-FigureS1.doc aic16687-sup-0001-FigureS1.doc
# Supplementary /action/downloadSupplement?doi=10.1002%2Fcssc.201501264&file=cssc201501264-sup-0001-misc_information.pdf cssc201501264-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fcctc.201701840&file=cctc201701840-sup-0001-misc_information.pdf cctc201701840-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fchem.201700496&file=chem201700496-sup-0001-misc_information.pdf chem201700496-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fcctc.201901955&file=cctc201901955-sup-0001-misc_information.pdf cctc201901955-sup-0001-misc_information.pdf
# Supplementary /action/downloadSupplement?doi=10.1002%2Fcctc.201901166&file=cctc201901166-sup-0001-misc_information.pdf cctc201901166-sup-0001-misc_information.pdf

# %%
data_records
# Out:
# {1: {'id': 3,
#   'doi': '10.1002/cctc.201901268',
#   'type': 'Supplementary',
#   'name': 'cctc201901268-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fcctc.201901268&file=cctc201901268-sup-0001-misc_information.pdf'},
#  2: {'id': 4,
#   'doi': '10.1002/chem.201805250',
#   'type': 'Supplementary',
#   'name': 'chem201805250-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fchem.201805250&file=chem201805250-sup-0001-misc_information.pdf'},
#  3: {'id': 7,
#   'doi': '10.1002/ejoc.201800799',
#   'type': 'Supporting Information',
#   'name': 'ejoc201800799-sup-0001-SupMat.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fejoc.201800799&file=ejoc201800799-sup-0001-SupMat.pdf'},
#  4: {'id': 28,
#   'doi': '10.1002/cctc.201801299',
#   'type': 'Supplementary',
#   'name': 'cctc201801299-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fcctc.201801299&file=cctc201801299-sup-0001-misc_information.pdf'},
#  5: {'id': 34,
#   'doi': '10.1002/celc.201800729',
#   'type': 'Supplementary',
#   'name': 'celc201800729-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fcelc.201800729&file=celc201800729-sup-0001-misc_information.pdf'},
#  6: {'id': 36,
#   'doi': '10.1002/celc.201800052',
#   'type': 'Supplementary',
#   'name': 'celc201800052-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fcelc.201800052&file=celc201800052-sup-0001-misc_information.pdf'},
#  7: {'id': 43,
#   'doi': '10.1002/cptc.201700210',
#   'type': 'Supplementary',
#   'name': 'cptc201700210-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fcptc.201700210&file=cptc201700210-sup-0001-misc_information.pdf'},
#  8: {'id': 45,
#   'doi': '10.1002/anie.201713115',
#   'type': 'Supplementary',
#   'name': 'anie201713115-sup-0001-misc_information.pdf',
#   'data_url': 'https://onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fanie.201713115&file=anie201713115-sup-0001-misc_information.pdf'},
#  9: {'id': 48,
#   'doi': '10.1002/celc.201800770',
#   'type': 'Supplementary',
#   'name': 'celc201800770-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fcelc.201800770&file=celc201800770-sup-0001-misc_information.pdf'},
#  10: {'id': 48,
#   'doi': '10.1002/celc.201800770',
#   'type': 'Supplementary',
#   'name': 'celc201800770-sup-0001-Movie_S2-Surface_current.avi',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fcelc.201800770&file=celc201800770-sup-0001-Movie_S2-Surface_current.avi'},
#  11: {'id': 51,
#   'doi': '10.1002/anie.201801400',
#   'type': 'Supplementary',
#   'name': 'anie201801400-sup-0001-misc_information.pdf',
#   'data_url': 'https://onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fanie.201801400&file=anie201801400-sup-0001-misc_information.pdf'},
#  12: {'id': 52,
#   'doi': '10.1002/celc.201800478',
#   'type': 'Supplementary',
#   'name': 'celc201800478-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fcelc.201800478&file=celc201800478-sup-0001-misc_information.pdf'},
#  13: {'id': 53,
#   'doi': '10.1002/anie.201710091',
#   'type': 'Supplementary',
#   'name': 'anie201710091-sup-0001-misc_information.pdf',
#   'data_url': 'https://onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fanie.201710091&file=anie201710091-sup-0001-misc_information.pdf'},
#  14: {'id': 55,
#   'doi': '10.1002/cctc.201900795',
#   'type': 'Supplementary',
#   'name': 'cctc201900795-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fcctc.201900795&file=cctc201900795-sup-0001-misc_information.pdf'},
#  15: {'id': 57,
#   'doi': '10.1002/cctc.201900100',
#   'type': 'Supplementary',
#   'name': 'cctc201900100-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fcctc.201900100&file=cctc201900100-sup-0001-misc_information.pdf'},
#  16: {'id': 63,
#   'doi': '10.1002/chem.201704151',
#   'type': 'Supplementary',
#   'name': 'chem201704151-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fchem.201704151&file=chem201704151-sup-0001-misc_information.pdf'},
#  17: {'id': 66,
#   'doi': '10.1002/cctc.201701946',
#   'type': 'Supplementary',
#   'name': 'cctc201701946-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fcctc.201701946&file=cctc201701946-sup-0001-misc_information.pdf'},
#  18: {'id': 83,
#   'doi': '10.1002/anie.201705753',
#   'type': 'Supplementary',
#   'name': 'anie201705753-sup-0001-misc_information.pdf',
#   'data_url': 'https://onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fanie.201705753&file=anie201705753-sup-0001-misc_information.pdf'},
#  19: {'id': 84,
#   'doi': '10.1002/ejoc.201601388',
#   'type': 'Supporting Information',
#   'name': 'ejoc201601388-sup-0001-SupMat.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fejoc.201601388&file=ejoc201601388-sup-0001-SupMat.pdf'},
#  20: {'id': 85,
#   'doi': '10.1002/anie.201609557',
#   'type': 'Supplementary',
#   'name': 'anie201609557-sup-0001-misc_information.pdf',
#   'data_url': 'https://onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fanie.201609557&file=anie201609557-sup-0001-misc_information.pdf'},
#  21: {'id': 93,
#   'doi': '10.1002/ange.201703550',
#   'type': 'Supplementary',
#   'name': 'ange201703550-sup-0001-misc_information.pdf',
#   'data_url': 'https://onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fange.201703550&file=ange201703550-sup-0001-misc_information.pdf'},
#  22: {'id': 98,
#   'doi': '10.1002/cctc.201700516',
#   'type': 'Supplementary',
#   'name': 'cctc201700516-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fcctc.201700516&file=cctc201700516-sup-0001-misc_information.pdf'},
#  23: {'id': 124,
#   'doi': '10.1002/aic.15095',
#   'type': '\n',
#   'name': 'aic15095-sup-0001-suppinfo01.doc',
#   'data_url': 'https://aiche.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Faic.15095&file=aic15095-sup-0001-suppinfo01.doc'},
#  24: {'id': 125,
#   'doi': '10.1002/aic.15415',
#   'type': '\n',
#   'name': 'aic15415-sup-0001-suppinfo01.doc',
#   'data_url': 'https://aiche.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Faic.15415&file=aic15415-sup-0001-suppinfo01.doc'},
#  25: {'id': 126,
#   'doi': '10.1002/cctc.201600729',
#   'type': 'Supplementary',
#   'name': 'cctc201600729-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fcctc.201600729&file=cctc201600729-sup-0001-misc_information.pdf'},
#  26: {'id': 134,
#   'doi': '10.1002/cctc.201500545',
#   'type': 'Supplementary',
#   'name': 'cctc201500545-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fcctc.201500545&file=cctc201500545-sup-0001-misc_information.pdf'},
#  27: {'id': 135,
#   'doi': '10.1002/cplu.201500195',
#   'type': 'miscellaneous_information',
#   'name': 'cplu_201500195_sm_miscellaneous_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fcplu.201500195&file=cplu_201500195_sm_miscellaneous_information.pdf'},
#  28: {'id': 152,
#   'doi': '10.1002/anie.201612370',
#   'type': 'Supplementary',
#   'name': 'anie201612370-sup-0001-misc_information.pdf',
#   'data_url': 'https://onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fanie.201612370&file=anie201612370-sup-0001-misc_information.pdf'},
#  29: {'id': 159,
#   'doi': '10.1002/chem.201703567',
#   'type': 'Supplementary',
#   'name': 'chem201703567-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fchem.201703567&file=chem201703567-sup-0001-misc_information.pdf'},
#  30: {'id': 168,
#   'doi': '10.1002/cphc.201600149',
#   'type': 'Supplementary',
#   'name': 'cphc201600149-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fcphc.201600149&file=cphc201600149-sup-0001-misc_information.pdf'},
#  31: {'id': 170,
#   'doi': '10.1002/cctc.201501260',
#   'type': 'Supplementary',
#   'name': 'cctc201501260-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fcctc.201501260&file=cctc201501260-sup-0001-misc_information.pdf'},
#  32: {'id': 197,
#   'doi': '10.1002/chem.201701013',
#   'type': 'Supplementary',
#   'name': 'chem201701013-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fchem.201701013&file=chem201701013-sup-0001-misc_information.pdf'},
#  33: {'id': 198,
#   'doi': '10.1002/chem.201605690',
#   'type': 'Supplementary',
#   'name': 'chem201605690-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fchem.201605690&file=chem201605690-sup-0001-misc_information.pdf'},
#  34: {'id': 201,
#   'doi': '10.1002/anie.201602930',
#   'type': 'Supplementary',
#   'name': 'anie201602930-sup-0001-misc_information.pdf',
#   'data_url': 'https://onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fanie.201602930&file=anie201602930-sup-0001-misc_information.pdf'},
#  35: {'id': 210,
#   'doi': '10.1002/cssc.201501225',
#   'type': 'Supplementary',
#   'name': 'cssc201501225-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fcssc.201501225&file=cssc201501225-sup-0001-misc_information.pdf'},
#  36: {'id': 225,
#   'doi': '10.1002/cctc.201600925',
#   'type': 'Supplementary',
#   'name': 'cctc201600925-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fcctc.201600925&file=cctc201600925-sup-0001-misc_information.pdf'},
#  37: {'id': 226,
#   'doi': '10.1002/cctc.201601603',
#   'type': 'Supplementary',
#   'name': 'cctc201601603-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fcctc.201601603&file=cctc201601603-sup-0001-misc_information.pdf'},
#  38: {'id': 244,
#   'doi': '10.1002/cctc.201600775',
#   'type': 'Supplementary',
#   'name': 'cctc201600775-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fcctc.201600775&file=cctc201600775-sup-0001-misc_information.pdf'},
#  39: {'id': 262,
#   'doi': '10.1002/cctc.201900658',
#   'type': 'Supplementary',
#   'name': 'cctc201900658-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fcctc.201900658&file=cctc201900658-sup-0001-misc_information.pdf'},
#  40: {'id': 264,
#   'doi': '10.1002/cbic.201800606',
#   'type': 'Supplementary',
#   'name': 'cbic201800606-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fcbic.201800606&file=cbic201800606-sup-0001-misc_information.pdf'},
#  41: {'id': 272,
#   'doi': '10.1002/chem.201901188',
#   'type': 'Supplementary',
#   'name': 'chem201901188-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fchem.201901188&file=chem201901188-sup-0001-misc_information.pdf'},
#  42: {'id': 313,
#   'doi': '10.1002/cctc.201801067',
#   'type': 'Supplementary',
#   'name': 'cctc201801067-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fcctc.201801067&file=cctc201801067-sup-0001-misc_information.pdf'},
#  43: {'id': 494,
#   'doi': '10.1002/aic.16687',
#   'type': <p><b>Figure S1</b> Mechanisms of catalyst deactivation by coke at the particle level. (a) Site coverage, (b) pore narrowing, and (c) pore blockage.</p>,
#   'name': 'aic16687-sup-0001-FigureS1.doc',
#   'data_url': 'https://aiche.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Faic.16687&file=aic16687-sup-0001-FigureS1.doc'},
#  44: {'id': 559,
#   'doi': '10.1002/cssc.201501264',
#   'type': 'Supplementary',
#   'name': 'cssc201501264-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fcssc.201501264&file=cssc201501264-sup-0001-misc_information.pdf'},
#  45: {'id': 564,
#   'doi': '10.1002/cctc.201701840',
#   'type': 'Supplementary',
#   'name': 'cctc201701840-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fcctc.201701840&file=cctc201701840-sup-0001-misc_information.pdf'},
#  46: {'id': 567,
#   'doi': '10.1002/chem.201700496',
#   'type': 'Supplementary',
#   'name': 'chem201700496-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fchem.201700496&file=chem201700496-sup-0001-misc_information.pdf'},
#  47: {'id': 583,
#   'doi': '10.1002/cctc.201901955',
#   'type': 'Supplementary',
#   'name': 'cctc201901955-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fcctc.201901955&file=cctc201901955-sup-0001-misc_information.pdf'},
#  48: {'id': 596,
#   'doi': '10.1002/cctc.201901166',
#   'type': 'Supplementary',
#   'name': 'cctc201901166-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fcctc.201901166&file=cctc201901166-sup-0001-misc_information.pdf'}}

# %%
csv_rw.write_csv_data(data_records, 'pub_data.csv')

# %%
missing_pubs = []
for a_pub in db_pubs:
    pub_id = a_pub[0]
    pub_title = a_pub[1]
    pub_doi = a_pub[2]
    pub_url = a_pub[3]
    pub_pdf = a_pub[4]
    pub_html = a_pub[5]
    if "wiley" in str(pub_url).lower():
        data_found = False
        for dr in data_records:
            if pub_id == data_records[dr]['id']:
                data_found = True
                break
        if not data_found:
            url = "http://dx.doi.org/" + pub_doi
            print("missing: ", pub_id, pub_doi, url)
            missing_pubs.append(a_pub)
missing_pubs
# Out:
# missing:  64 10.1002/9783527804085.ch10 http://dx.doi.org/10.1002/9783527804085.ch10
# missing:  97 10.1002/pssa.201600440 http://dx.doi.org/10.1002/pssa.201600440
# missing:  227 10.1002/cctc.201601692 http://dx.doi.org/10.1002/cctc.201601692
# missing:  241 10.1002/cssc.201500503 http://dx.doi.org/10.1002/cssc.201500503
# missing:  248 10.1002/cssc.201403190 http://dx.doi.org/10.1002/cssc.201403190
# missing:  255 10.1002/cctc.201500242 http://dx.doi.org/10.1002/cctc.201500242
# missing:  274 10.1002/cctc.201900401 http://dx.doi.org/10.1002/cctc.201900401
# missing:  569 10.1002/adfm.201400338 http://dx.doi.org/10.1002/adfm.201400338
# [(64,
#   'Hybrid Catalysts for Other C-C and C-X Bond Formation Reactions',
#   '10.1002/9783527804085.ch10',
#   'https://api.wiley.com/onlinelibrary/tdm/v1/articles/10.1002%2F9783527804085.ch10',
#   'None',
#   None),
#  (97,
#   'Heterostructures of GaN with SiC and ZnO enhance carrier stability and separation in framework semiconductors',
#   '10.1002/pssa.201600440',
#   'https://api.wiley.com/onlinelibrary/tdm/v1/articles/10.1002%2Fpssa.201600440',
#   'pssa.201600440.pdf',
#   None),
#  (227,
#   'The Effects of Secondary Oxides on Copper‐Based Catalysts for Green Methanol Synthesis',
#   '10.1002/cctc.201601692',
#   'https://api.wiley.com/onlinelibrary/tdm/v1/articles/10.1002%2Fcctc.201601692',
#   'cctc.201601692.pdf',
#   None),
#  (241,
#   'Oxidation of Aliphatic Alcohols by Using Precious Metals Supported on Hydrotalcite under Solvent- and Base-Free Conditions',
#   '10.1002/cssc.201500503',
#   'https://api.wiley.com/onlinelibrary/tdm/v1/articles/10.1002%2Fcssc.201500503',
#   'cssc.201500503.pdf',
#   None),
#  (248,
#   'Selective Oxidation ofn-Butanol Using Gold-Palladium Supported Nanoparticles Under Base-Free Conditions',
#   '10.1002/cssc.201403190',
#   'https://api.wiley.com/onlinelibrary/tdm/v1/articles/10.1002%2Fcssc.201403190',
#   'cssc.201403190.pdf',
#   None),
#  (255,
#   'An Investigation of the Effect of the Addition of Tin to 5\\u2009%Pd/TiO2for the Hydrogenation of Furfuryl Alcohol',
#   '10.1002/cctc.201500242',
#   'https://api.wiley.com/onlinelibrary/tdm/v1/articles/10.1002%2Fcctc.201500242',
#   'cctc.201500242.pdf',
#   None),
#  (274,
#   'Methanol Synthesis from CO2 Hydrogenation',
#   '10.1002/cctc.201900401',
#   'https://api.wiley.com/onlinelibrary/tdm/v1/articles/10.1002%2Fcctc.201900401',
#   'cctc.201900401.pdf',
#   None),
#  (569,
#   'Solution Processing Route to Multifunctional Titania Thin Films: Highly Conductive and Photcatalytically Active Nb:TiO2',
#   '10.1002/adfm.201400338',
#   'https://api.wiley.com/onlinelibrary/tdm/v1/articles/10.1002%2Fadfm.201400338',
#   'adfm.201400338.pdf',
#   None)]

# %%
data_refs = []
for sup_inf_div in sup_info_divs:
    s_i_d_r =  sup_inf_div.find('a')
    print (s_i_d_r.contents[0])
    print (s_i_d_r['href'])
    data_refs.append({'type':"supplementary", "name":s_i_d_r.contents[0], 'data_url':s_i_d_r['href']})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-de95408f515d> in <module>
#       1 data_refs = []
# ----> 2 for sup_inf_div in sup_info_divs:
#       3     s_i_d_r =  sup_inf_div.find('a')
#       4     print (s_i_d_r.contents[0])
#       5     print (s_i_d_r['href'])
#
# NameError: name 'sup_info_divs' is not defined

# %%
data_refs = get_data_from_divs(soup, 'nature catalysis', [])

# %%
data_refs
# Out:
# []

# %%
url = 'http://dx.doi.org/10.1002/cctc.201901268'
req_head = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36'}
response = requests.get(url, headers = req_head)
print(response)
print(response.url)
redirected_to = response.url
parsed_uri = urlparse(redirected_to)  # returns six components
print(parsed_uri)
domain = parsed_uri.netloc
result = domain.replace('www.', '')  # as per your case
print(domain)
base_url = parsed_uri.scheme + "://" + parsed_uri.netloc

print(base_url)
soup = BeautifulSoup(response.text,'html.parser')

sup_info_divs = soup.find_all("div", {"class": "c-article-supplementary__item"})
data_avl = soup.find_all('section', {'aria-labelledby':'data-availability'})
# Out:
# <Response [200]>
# https://chemistry-europe.onlinelibrary.wiley.com/doi/full/10.1002/cctc.201901268
# ParseResult(scheme='https', netloc='chemistry-europe.onlinelibrary.wiley.com', path='/doi/full/10.1002/cctc.201901268', params='', query='', fragment='')
# chemistry-europe.onlinelibrary.wiley.com
# https://chemistry-europe.onlinelibrary.wiley.com

# %%
tables = soup.find_all("table", {"class":"support-info__table"})
for table in tables:
    # find rows
    trs = table.find_all('tr')
    # get the type and link from each row
    for tr in trs:
        td_link = tr.find('td',{"headers":"article-filename"})
        td_desc = tr.find('td',{"headers":"article-description"})
        data_link = td_link.find('a')
        print(td_desc.contents[0], data_link['href'], data_link.contents[0])
# Out:
# Supplementary /action/downloadSupplement?doi=10.1002%2Fcctc.201901268&file=cctc201901268-sup-0001-misc_information.pdf cctc201901268-sup-0001-misc_information.pdf

# %%
get_data_from_table(soup, 'elsevier', [], base_url)
# Out:
# Supplementary /action/downloadSupplement?doi=10.1002%2Fcctc.201901268&file=cctc201901268-sup-0001-misc_information.pdf cctc201901268-sup-0001-misc_information.pdf
# [{'type': 'Supplementary',
#   'name': 'cctc201901268-sup-0001-misc_information.pdf',
#   'data_url': 'https://chemistry-europe.onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fcctc.201901268&file=cctc201901268-sup-0001-misc_information.pdf'}]
