# %%
# Connecting to the db
import lib.handle_db as dbh

# read and write csv files
import lib.handle_csv as csv_rw

# date functions
from datetime import datetime, date, timedelta

# use habanero to query crossref api
from habanero import Crossref
cr = Crossref()

# search for UKCH Awards in CR record
def award_in_crossref(aw):
    ukch_wks =[]
    not_revised = []
    for wk in aw:      
        awd_list = []
        if 'funder' in wk.keys():
            for fdr in wk['funder']:
                if 'award' in fdr.keys():
                   awds = 0
                   for awd in fdr['award']:
                        if awd in ['EP/R026939/1', 'EP/R026815/1', 'EP/R026645/1', 'EP/R027129/1', 'EP/M013219/1',
                                  'EP/K014706/2', 'EP/K014668/1', 'EP/K014854/1', 'EP/K014714/1']:
                            awd_list.append(awd)
        else:
            not_revised.append(wk)
        if len(awd_list) > 0:
            ukch_wks.append(wk)
    return ukch_wks, not_revised

# search for UKCH Affiliation in CR record
def affi_in_crossref(aw):
    ukch_wks = []
    for wk in aw:
        ukch_affiliation = False
        if 'author' in wk.keys():
            for autr in wk['author']:
                if 'affiliation' in autr.keys():
                    for affi in autr['affiliation']:
                        if "UK Catalysis Hub" in affi['name']:
                            ukch_affiliation = True
                            break
                    if ukch_affiliation:
                        ukch_wks.append(wk)
                        break
    return  ukch_wks

# %%
start_date = date(2021, 1, 1)
end_date = date(2021, 1, 1)

pubs_with_award = []
skiped_works =[]
while end_date < datetime.now().date():
    end_date = start_date + timedelta(days=9)
    print ("From:", str(start_date), "to",  str(end_date))
    cr_filter =  {'has_funder': True, 'from-pub-date':str(start_date), 'until-pub-date':str(end_date)}
    cr_filter =  {'has_funder': True, 'from-deposit-date':str(start_date), 'until-deposit-date':str(end_date)}
    result = cr.works(filter = cr_filter, cursor = "*", limit = 500)
    print(cr_filter)
    #print (result)
    for res_500 in result:
        print("Results:",len(res_500['message']['items']))
        pubs_found, wks_ignored = award_in_crossref(res_500['message']['items'])
        pubs_with_award += pubs_found
        skiped_works += wks_ignored
    start_date = end_date + timedelta(days=1)
# Out:
# From: 2021-01-01 to 2021-01-10
# {'has_funder': 'true', 'from-deposit-date': '2021-01-01', 'until-deposit-date': '2021-01-10'}
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# From: 2021-01-11 to 2021-01-20
# {'has_funder': 'true', 'from-deposit-date': '2021-01-11', 'until-deposit-date': '2021-01-20'}
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# From: 2021-01-21 to 2021-01-30
# {'has_funder': 'true', 'from-deposit-date': '2021-01-21', 'until-deposit-date': '2021-01-30'}
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# From: 2021-01-31 to 2021-02-09
# {'has_funder': 'true', 'from-deposit-date': '2021-01-31', 'until-deposit-date': '2021-02-09'}
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# From: 2021-02-10 to 2021-02-19
# {'has_funder': 'true', 'from-deposit-date': '2021-02-10', 'until-deposit-date': '2021-02-19'}
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# From: 2021-02-20 to 2021-03-01
# {'has_funder': 'true', 'from-deposit-date': '2021-02-20', 'until-deposit-date': '2021-03-01'}
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# From: 2021-03-02 to 2021-03-11
# {'has_funder': 'true', 'from-deposit-date': '2021-03-02', 'until-deposit-date': '2021-03-11'}
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# From: 2021-03-12 to 2021-03-21
# {'has_funder': 'true', 'from-deposit-date': '2021-03-12', 'until-deposit-date': '2021-03-21'}
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# From: 2021-03-22 to 2021-03-31
# {'has_funder': 'true', 'from-deposit-date': '2021-03-22', 'until-deposit-date': '2021-03-31'}
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# From: 2021-04-01 to 2021-04-10
# {'has_funder': 'true', 'from-deposit-date': '2021-04-01', 'until-deposit-date': '2021-04-10'}
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# From: 2021-04-11 to 2021-04-20
# {'has_funder': 'true', 'from-deposit-date': '2021-04-11', 'until-deposit-date': '2021-04-20'}
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# From: 2021-04-21 to 2021-04-30
# {'has_funder': 'true', 'from-deposit-date': '2021-04-21', 'until-deposit-date': '2021-04-30'}
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# From: 2021-05-01 to 2021-05-10
# {'has_funder': 'true', 'from-deposit-date': '2021-05-01', 'until-deposit-date': '2021-05-10'}
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# From: 2021-05-11 to 2021-05-20
# {'has_funder': 'true', 'from-deposit-date': '2021-05-11', 'until-deposit-date': '2021-05-20'}
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# From: 2021-05-21 to 2021-05-30
# {'has_funder': 'true', 'from-deposit-date': '2021-05-21', 'until-deposit-date': '2021-05-30'}
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# From: 2021-05-31 to 2021-06-09
# {'has_funder': 'true', 'from-deposit-date': '2021-05-31', 'until-deposit-date': '2021-06-09'}
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# From: 2021-06-10 to 2021-06-19
# {'has_funder': 'true', 'from-deposit-date': '2021-06-10', 'until-deposit-date': '2021-06-19'}
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# From: 2021-06-20 to 2021-06-29
# {'has_funder': 'true', 'from-deposit-date': '2021-06-20', 'until-deposit-date': '2021-06-29'}
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# From: 2021-06-30 to 2021-07-09
# {'has_funder': 'true', 'from-deposit-date': '2021-06-30', 'until-deposit-date': '2021-07-09'}
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# From: 2021-07-10 to 2021-07-19
# {'has_funder': 'true', 'from-deposit-date': '2021-07-10', 'until-deposit-date': '2021-07-19'}
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# From: 2021-07-20 to 2021-07-29
# {'has_funder': 'true', 'from-deposit-date': '2021-07-20', 'until-deposit-date': '2021-07-29'}
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# From: 2021-07-30 to 2021-08-08
# {'has_funder': 'true', 'from-deposit-date': '2021-07-30', 'until-deposit-date': '2021-08-08'}
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# From: 2021-08-09 to 2021-08-18
# {'has_funder': 'true', 'from-deposit-date': '2021-08-09', 'until-deposit-date': '2021-08-18'}
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# From: 2021-08-19 to 2021-08-28
# {'has_funder': 'true', 'from-deposit-date': '2021-08-19', 'until-deposit-date': '2021-08-28'}
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# From: 2021-08-29 to 2021-09-07
# {'has_funder': 'true', 'from-deposit-date': '2021-08-29', 'until-deposit-date': '2021-09-07'}
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# From: 2021-09-08 to 2021-09-17
# {'has_funder': 'true', 'from-deposit-date': '2021-09-08', 'until-deposit-date': '2021-09-17'}
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# From: 2021-09-18 to 2021-09-27
# {'has_funder': 'true', 'from-deposit-date': '2021-09-18', 'until-deposit-date': '2021-09-27'}
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# From: 2021-09-28 to 2021-10-07
# {'has_funder': 'true', 'from-deposit-date': '2021-09-28', 'until-deposit-date': '2021-10-07'}
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# From: 2021-10-08 to 2021-10-17
# {'has_funder': 'true', 'from-deposit-date': '2021-10-08', 'until-deposit-date': '2021-10-17'}
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# From: 2021-10-18 to 2021-10-27
# {'has_funder': 'true', 'from-deposit-date': '2021-10-18', 'until-deposit-date': '2021-10-27'}
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# From: 2021-10-28 to 2021-11-06
# {'has_funder': 'true', 'from-deposit-date': '2021-10-28', 'until-deposit-date': '2021-11-06'}
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# From: 2021-11-07 to 2021-11-16
# {'has_funder': 'true', 'from-deposit-date': '2021-11-07', 'until-deposit-date': '2021-11-16'}
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# Results: 500
# From: 2021-11-17 to 2021-11-26
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-0b92bc6149ee> in <module>
#       9     cr_filter =  {'has_funder': True, 'from-pub-date':str(start_date), 'until-pub-date':str(end_date)}
#      10     cr_filter =  {'has_funder': True, 'from-deposit-date':str(start_date), 'until-deposit-date':str(end_date)}
# ---> 11     result = cr.works(filter = cr_filter, cursor = "*", limit = 500)
#      12     print(cr_filter)
#      13     #print (result)
#
# C:\ProgramData\Anaconda3\lib\site-packages\habanero\crossref\crossref.py in works(self, ids, query, filter, offset, limit, sample, sort, order, facet, select, cursor, cursor_max, progress_bar, **kwargs)
#     361             )
#     362         else:
# --> 363             return Request(
#     364                 self.mailto,
#     365                 self.ua_string,
#
# C:\ProgramData\Anaconda3\lib\site-packages\habanero\request_class.py in do_request(self)
#      98         cu = js["message"].get("next-cursor")
#      99         max_avail = js["message"]["total-results"]
# --> 100         res = self._redo_req(js, payload, cu, max_avail)
#     101         return res
#     102
#
# C:\ProgramData\Anaconda3\lib\site-packages\habanero\request_class.py in _redo_req(self, js, payload, cu, max_avail)
#     127                 cu = out["message"].get("next-cursor")
#     128                 res.append(out)
# --> 129                 total = sum([len(z["message"]["items"]) for z in res])
#     130                 if self.progress_bar:
#     131                     pbar.update(1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\habanero\request_class.py in <listcomp>(.0)
#     127                 cu = out["message"].get("next-cursor")
#     128                 res.append(out)
# --> 129                 total = sum([len(z["message"]["items"]) for z in res])
#     130                 if self.progress_bar:
#     131                     pbar.update(1)
#
# KeyError: 'items'

# %%
foud_pubs = {}
for wk in pubs_with_award:
    art_authors = ""
    if 'author' in wk.keys() :
        for autr in wk['author']:
            if art_authors == "":
                art_authors = autr['family']+", " + (", "+ autr ['given'] if 'given' in autr.keys() else "" )
            else:
                art_authors += ", " + autr['family']+ (", "+ autr ['given'] if 'given' in autr.keys() else "" )
    fund_award = ""
    for fdr in wk['funder']:
        if 'award' in fdr.keys():
          for awd in fdr['award']:
               if awd in ['EP/R026939/1', 'EP/R026815/1', 'EP/R026645/1', 'EP/R027129/1', 'EP/M013219/1',
                          'EP/K014706/2', 'EP/K014668/1', 'EP/K014854/1', 'EP/K014714/1']:
                    if fund_award  == "":
                        fund_award = awd
                    else:
                        fund_award += ", " +awd
                    
    ol_year = 0
    pr_year = 0
    pub_year = 0
    if 'published-online' in wk.keys() and 'date-parts' in wk['published-online'].keys():
        ol_year = int(wk['published-online']['date-parts'][0][0])
    if 'published-print' in wk.keys() and 'date-parts' in wk['published-print'].keys():
        pr_year = int(wk['published-print']['date-parts'][0][0])
    if pr_year > 0 and ol_year > 0:
        if pr_year > ol_year:
            pub_year = ol_year
        else:
            pub_year = pr_year
    elif ol_year > 0:
        pub_year = ol_year
    elif pr_year > 0:
        pub_year = pr_year
        
    print(art_authors,"|",pub_year,"|",wk['title'][0],
          "|", wk['DOI'],"|", fund_award)     
    this_pub = {}
    this_pub['authors'] = art_authors
    this_pub['year'] = pub_year
    this_pub['title'] = wk['title'][0]
    this_pub['DOI'] = wk['DOI']
    if not wk['DOI'] in foud_pubs:
         foud_pubs[wk['DOI']]= this_pub

if len(foud_pubs) > 0:
    csv_rw.write_csv_data(foud_pubs, 'cr_check_202111x.csv') 
if len(skiped_works) > 0:
    print(skiped_works)
# Out:
# Hinde, , Christopher S., Gill, Arran M., Wells, Peter P., Hor, T. S. Andy, Raja, Robert | 2015 | Utilizing Benign Oxidants for Selective Aerobic Oxidations Using Heterogenized Platinum Nanoparticle Catalysts | 10.1002/cplu.201500195 | EP/K014668/1, EP/K014854/1, EP/K014714/1
# Lim, , Jason Y. C., Yuntawattana, Nattawut, Beer, Paul D., Williams, Charlotte K. | 2019 | Isoselective Lactide Ring Opening Polymerisation using [2]Rotaxane Catalysts | 10.1002/ange.201901592 | EP/K014668/1
# Malta, , G., Kondrat, S. A., Freakley, S. J., Davies, C. J., Dawson, S., Liu, X., Lu, L., Dymkowski, K., Fernandez-Alonso, F., Mukhopadhyay, S., Gibson, E. K., Wells, P. P., Parker, S. F., Kiely, C. J., Hutchings, G. J. | 2018 | Deactivation of a Single-Site Gold-on-Carbon Acetylene Hydrochlorination Catalyst: An X-ray Absorption and Inelastic Neutron Scattering Study | 10.1021/acscatal.8b02232 | EP/K014668/1, EP/K014714/1, EP/M013219/1, EP/K014854/1
# [{'indexed': {'date-parts': [[2021, 11, 2]], 'date-time': '2021-11-02T17:07:03Z', 'timestamp': 1635872823737}, 'publisher': 'James S. McDonnell Foundation', 'award-start': {'date-parts': [[2021, 2, 1]]}, 'award': '2020-1456', 'DOI': '10.37717/2020-1456', 'type': 'grant', 'created': {'date-parts': [[2021, 1, 8]], 'date-time': '2021-01-08T15:52:55Z', 'timestamp': 1610121175000}, 'source': 'Crossref', 'prefix': '10.37717', 'member': '24568', 'project': [{'project-title': [{'title': "In support of the postdoctoral fellow's salary, fringe benefits and research plan.", 'language': 'en'}], 'project-description': [{'description': "In support of the postdoctoral fellow's salary, fringe benefits and research plan.", 'language': 'en'}], 'lead-investigator': [{'given': 'Stefany', 'family': 'Moreno-Gámez', 'affiliation': [{'name': 'Massachusetts Institute of Technology'}]}], 'award-amount': {'amount': 200000.0, 'currency': 'USD'}, 'award-start': {'date-parts': [[2021, 2, 1]]}, 'award-end': {'date-parts': [[2023, 1, 31]]}, 'funding': [{'type': 'fellowship', 'scheme': 'Postdoctoral Fellowship Award', 'award-amount': {'amount': 200000.0, 'currency': 'USD', 'percentage': 100}, 'funder': {'name': 'James S. McDonnell Foundation', 'id': [{'id': '10.13039/100000913', 'id-type': 'DOI', 'asserted-by': 'publisher'}]}}]}], 'deposited': {'date-parts': [[2021, 1, 8]], 'date-time': '2021-01-08T15:52:56Z', 'timestamp': 1610121176000}, 'score': 0.0, 'issued': {'date-parts': [[2021, 2, 1]]}, 'URL': 'http://dx.doi.org/10.37717/2020-1456'}, {'indexed': {'date-parts': [[2021, 11, 9]], 'date-time': '2021-11-09T11:15:13Z', 'timestamp': 1636456513527}, 'publisher': 'Wellcome', 'award': '223024', 'DOI': '10.35802/223024', 'type': 'grant', 'created': {'date-parts': [[2021, 11, 8]], 'date-time': '2021-11-08T14:45:42Z', 'timestamp': 1636382742000}, 'source': 'Crossref', 'prefix': '10.35802', 'member': '13928', 'project': [{'project-title': [{'title': 'Deciphering the heterogeneity of early-onset type 2 diabetes using epidemiological and genetic approaches'}], 'project-description': [{'description': 'Background: Early-onset type 2 diabetes (diagnosed <40-years), is a severe presentation with excess risk of complications, cardiovascular events and early death, compared to later-onset disease. UK south Asian populations have an unexplained higher prevalence of this diagnosis. Studies of later-onset type 2 diabetes reveal heterogeneity in phenotype associating with complication risk, raising the possibility that targeting this variation with specific treatments could improve outcomes. These methods have not been extended to early-onset type 2 diabetes. Goal: I will decipher heterogeneity of early-onset type 2 diabetes in white and south Asian individuals using epidemiological and genetic approaches. Proposal: - Determine whether early-onset type 2 diabetes is enriched for sub-phenotypes contributing to higher risk, using analysis of large datasets to examine ethnic differences in presentation and progression by age-at-diagnosis with application of supervised and unsupervised statistical methods. - Determine if the higher risk of early-onset type 2 diabetes in south Asian individuals is driven by excess polygenic risk, by undertaking a cohort study with application of trans-ancestry polygenic scores compared to controls. Summary: This broad population-level study together with deep genotyping and phenotyping of affected individuals has the potential to produce new insights leading to better surveillance, earlier therapies, and fewer complications.', 'language': 'en'}, {'description': 'Background: Type 2 diabetes is typically diagnosed later in life but early-onset cases (before 40-years) are increasing, particularly in south Asian people. This is concerning as early-onset type 2 diabetes carries a higher risk of complications and early death. We don’t know what explains this higher risk or why some ethnicities are more affected. My approach: I will study early-onset type  ...

# %%
if len(skiped_works) > 0:
    print(skiped_works)
    print(len(skiped_works))
# Out:
# [{'indexed': {'date-parts': [[2021, 11, 2]], 'date-time': '2021-11-02T17:07:03Z', 'timestamp': 1635872823737}, 'publisher': 'James S. McDonnell Foundation', 'award-start': {'date-parts': [[2021, 2, 1]]}, 'award': '2020-1456', 'DOI': '10.37717/2020-1456', 'type': 'grant', 'created': {'date-parts': [[2021, 1, 8]], 'date-time': '2021-01-08T15:52:55Z', 'timestamp': 1610121175000}, 'source': 'Crossref', 'prefix': '10.37717', 'member': '24568', 'project': [{'project-title': [{'title': "In support of the postdoctoral fellow's salary, fringe benefits and research plan.", 'language': 'en'}], 'project-description': [{'description': "In support of the postdoctoral fellow's salary, fringe benefits and research plan.", 'language': 'en'}], 'lead-investigator': [{'given': 'Stefany', 'family': 'Moreno-Gámez', 'affiliation': [{'name': 'Massachusetts Institute of Technology'}]}], 'award-amount': {'amount': 200000.0, 'currency': 'USD'}, 'award-start': {'date-parts': [[2021, 2, 1]]}, 'award-end': {'date-parts': [[2023, 1, 31]]}, 'funding': [{'type': 'fellowship', 'scheme': 'Postdoctoral Fellowship Award', 'award-amount': {'amount': 200000.0, 'currency': 'USD', 'percentage': 100}, 'funder': {'name': 'James S. McDonnell Foundation', 'id': [{'id': '10.13039/100000913', 'id-type': 'DOI', 'asserted-by': 'publisher'}]}}]}], 'deposited': {'date-parts': [[2021, 1, 8]], 'date-time': '2021-01-08T15:52:56Z', 'timestamp': 1610121176000}, 'score': 0.0, 'issued': {'date-parts': [[2021, 2, 1]]}, 'URL': 'http://dx.doi.org/10.37717/2020-1456'}, {'indexed': {'date-parts': [[2021, 11, 9]], 'date-time': '2021-11-09T11:15:13Z', 'timestamp': 1636456513527}, 'publisher': 'Wellcome', 'award': '223024', 'DOI': '10.35802/223024', 'type': 'grant', 'created': {'date-parts': [[2021, 11, 8]], 'date-time': '2021-11-08T14:45:42Z', 'timestamp': 1636382742000}, 'source': 'Crossref', 'prefix': '10.35802', 'member': '13928', 'project': [{'project-title': [{'title': 'Deciphering the heterogeneity of early-onset type 2 diabetes using epidemiological and genetic approaches'}], 'project-description': [{'description': 'Background: Early-onset type 2 diabetes (diagnosed <40-years), is a severe presentation with excess risk of complications, cardiovascular events and early death, compared to later-onset disease. UK south Asian populations have an unexplained higher prevalence of this diagnosis. Studies of later-onset type 2 diabetes reveal heterogeneity in phenotype associating with complication risk, raising the possibility that targeting this variation with specific treatments could improve outcomes. These methods have not been extended to early-onset type 2 diabetes. Goal: I will decipher heterogeneity of early-onset type 2 diabetes in white and south Asian individuals using epidemiological and genetic approaches. Proposal: - Determine whether early-onset type 2 diabetes is enriched for sub-phenotypes contributing to higher risk, using analysis of large datasets to examine ethnic differences in presentation and progression by age-at-diagnosis with application of supervised and unsupervised statistical methods. - Determine if the higher risk of early-onset type 2 diabetes in south Asian individuals is driven by excess polygenic risk, by undertaking a cohort study with application of trans-ancestry polygenic scores compared to controls. Summary: This broad population-level study together with deep genotyping and phenotyping of affected individuals has the potential to produce new insights leading to better surveillance, earlier therapies, and fewer complications.', 'language': 'en'}, {'description': 'Background: Type 2 diabetes is typically diagnosed later in life but early-onset cases (before 40-years) are increasing, particularly in south Asian people. This is concerning as early-onset type 2 diabetes carries a higher risk of complications and early death. We don’t know what explains this higher risk or why some ethnicities are more affected. My approach: I will study early-onset type  ...
# 408

# %%
ukch_wks =[]
aw = result[6]['message']['items']
for wk in aw:      
    awd_list = []
    if 'funder' in wk.keys():
        for fdr in wk['funder']:
            if 'award' in wk.keys():
               awds = 0
               for awd in fdr['award']:
                    if awd in ['EP/R026939/1', 'EP/R026815/1', 'EP/R026645/1', 'EP/R027129/1', 'EP/M013219/1',
                              'EP/K014706/2', 'EP/K014668/1', 'EP/K014854/1', 'EP/K014714/1']:
                        awd_list.append(awd)
        if len(awd_list) > 0:
            ukch_wks.append(wk)
    else: 
        print(wk)
    
ukch_wks

# %%
{'indexed': {'date-parts': [[2021, 11, 2]], 
             'date-time': '2021-11-02T17:07:03Z', 'timestamp': 1635872823737}, 
 'publisher': 'James S. McDonnell Foundation', 
 'award-start': {'date-parts': [[2021, 2, 1]]}, 
 'award': '2020-1456', 'DOI': '10.37717/2020-1456', 'type': 'grant', 
 'created': {'date-parts': [[2021, 1, 8]], 'date-time': '2021-01-08T15:52:55Z', 'timestamp': 1610121175000},
 'source': 'Crossref',
 'prefix': '10.37717', 
 'member': '24568', 
 'project': [{'project-title': [{'title': "In support of the postdoctoral fellow's salary, fringe benefits and research plan.", 'language': 'en'}], 'project-description': [{'description': "In support of the postdoctoral fellow's salary, fringe benefits and research plan.", 'language': 'en'}], 
              'lead-investigator': [{'given': 'Stefany', 'family': 'Moreno-Gámez', 'affiliation': [{'name': 'Massachusetts Institute of Technology'}]}], 'award-amount': {'amount': 200000.0, 'currency': 'USD'}, 'award-start': {'date-parts': [[2021, 2, 1]]}, 'award-end': {'date-parts': [[2023, 1, 31]]}, 'funding': [{'type': 'fellowship', 'scheme': 'Postdoctoral Fellowship Award', 'award-amount': {'amount': 200000.0, 'currency': 'USD', 'percentage': 100}, 'funder': {'name': 'James S. McDonnell Foundation', 'id': [{'id': '10.13039/100000913', 'id-type': 'DOI', 'asserted-by': 'publisher'}]}}]}], 'deposited': {'date-parts': [[2021, 1, 8]], 
              'date-time': '2021-01-08T15:52:56Z', 'timestamp': 1610121176000}, 
 'score': 0.0, 
 'issued': {'date-parts': [[2021, 2, 1]]},
 'URL': 'http://dx.doi.org/10.37717/2020-1456'}
