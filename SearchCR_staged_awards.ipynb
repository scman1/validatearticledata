# %% [markdown]
# # Search publications using the Crossref API
#
# Use crossref restful API to get the works based on the award codes

# %%
# Connecting to the db
import lib.handle_db as dbh

# read and write csv files
import lib.handle_csv as csv_rw

# direct write to csv
import csv

# file management
from pathlib import Path

# date functions
from datetime import datetime, date, timedelta

# time delay
import time

#CR libraries
from crossref.restful import Works, Etiquette

# search for UKCH Awards in CR record
def award_in_crossref(aw, award_list):
    ukch_wks =[]
    not_revised = []
    for wk in aw:      
        awd_list = []
        if 'funder' in wk.keys():
            for fdr in wk['funder']:
                if 'award' in fdr.keys():
                   awds = 0
                   for awd in fdr['award']:
                        if awd in award_list:
                            awd_list.append(awd)
                            #print (fdr)
                            break
        else:
            not_revised.append(wk)
        if len(awd_list) > 0:
            ukch_wks.append(wk)
    return ukch_wks, not_revised

def collect_keys(aw, wk_keys):
    for wk in aw:
        these_keys = wk.keys()
        for a_key in these_keys:
            if a_key in wk_keys:
                wk_keys[a_key] += 1
            else:
                wk_keys[a_key] = 1
    return wk_keys

def collect_fdr_keys(aw, wk_keys):
    for wk in aw:
        if 'funder' in wk.keys():
            for fdr in wk['funder']:
                these_keys = fdr.keys()
                for a_key in these_keys:
                    if a_key in wk_keys:
                        wk_keys[a_key] += 1
                    else:
                        wk_keys[a_key] = 1
    return wk_keys

def collect_awds(aw, wk_keys):
    for wk in aw:
        if 'funder' in wk.keys():
            for fdr in wk['funder']:
                if 'award' in fdr.keys():
                   awds = 0
                   for awd in fdr['award']:
                        if awd in wk_keys:
                            wk_keys[awd] += 1
                        else:
                            wk_keys[awd] = 1
    return wk_keys

# search for UKCH Affiliation in CR record
def affi_in_crossref(aw):
    ukch_wks = []
    for wk in aw:
        ukch_affiliation = False
        if 'author' in wk.keys():
            for autr in wk['author']:
                if 'affiliation' in autr.keys():
                    for affi in autr['affiliation']:
                        if "UK Catalysis Hub" in affi['name']:
                            ukch_affiliation = True
                            break
                    if ukch_affiliation:
                        ukch_wks.append(wk)
                        break
    return  ukch_wks

# %% [markdown]
# Define the awards to look for. In this case we also look for partial matches because the sometimes the publications drop the last part (/1 or /2)

# %%
my_etiquette = Etiquette('UK Catalysis Hub - Catalysis Data Infrastructure', 
                         'Prototype 1', 
                         'https://ukcatalysishub.co.uk/core/', 
                         'nieva@rc-harwell.ac.uk')

ukch_awards = ['EP/R026939/1', 'EP/R026815/1', 'EP/R026645/1', 'EP/R027129/1', 'EP/M013219/1',
               'EP/K014706/2', 'EP/K014668/1', 'EP/K014854/1', 'EP/K014714/1',
               'EP/R026939', 'EP/R026815', 'EP/R026645', 'EP/R027129', 'EP/M013219',
               'EP/K014706', 'EP/K014668', 'EP/K014854', 'EP/K014714',
              ]

mcc_awards = ['EP/R029431/1', 'EP/P020194/1', 'EP/T022213/1', 'EP/D504872/1', 'EP/F067496/1','EP/X035859/1', 
              'EP/W032260/1', 'EP/L000202/1', 'EP/R029431','EP/P020194', 'EP/T022213', 'EP/D504872', 
              'EP/F067496','EP/X035859', 'EP/W032260', 'EP/L000202']

cplas_awards = ['EP/W017075/1','EP/W017075']

ukch_affi_synonyms = ["UK Catalysis Hub"]

award_list = cplas_awards#ukch_awards + mcc_awards

works = Works(etiquette=my_etiquette)

start_date = end_date = date(2025, 1, 1) #started 7,1
stop_date = date(2025, 7, 30)

out_dir = './pub_search_crossref/cr_results_202507/'

pubs_with_award = []
skiped_works =[]
wk_keys = {}
fd_keys = {}
awds_lst = {}
foud_pubs = {}
out_file_1 =  Path(out_dir,'cr_check_'+str(stop_date)+'a.csv')
while end_date < stop_date + timedelta(days=1):
    end_date = start_date + timedelta(days=1)
    print ("From:", str(start_date), "to",  str(end_date))
    # works with from_published_date and until_published_date 
    # next test with from_deposit_date and until_deposit_date
    # Valid filters for this route are: alternative_id, archive, article_number, assertion, assertion-group, 
    #    award.funder, award.number, category-name, clinical-trial-number, container-title, content-domain,
    #    directory, doi, from-accepted-date, from-created-date, from-deposit-date, from-event-end-date,
    #    from-event-start-date, from-index-date, from-issued-date, from-online-pub-date, from-posted-date,
    #    from-print-pub-date, from-pub-date, from-update-date, full-text.application, full-text.type, 
    #    full-text.version, funder, funder-doi-asserted-by, group-title, has-abstract, has-affiliation,
    #    has-archive, has-assertion, has-authenticated-orcid, has-award, has-clinical-trial-number,
    #    has-content-domain, has-domain-restriction, has-event, has-full-text, has-funder, has-funder-doi,
    #    has-license, has-orcid, has-references, has-relation, has-update, has-update-policy, is-update, 
    #    isbn, issn, license.delay, license.url, license.version, location, member, orcid, prefix,
    #    relation.object, relation.object-type, relation.type, type, type-name, until-accepted-date,
    #    until-created-date, until-deposit-date, until-event-end-date, until-event-start-date,
    #    until-index-date, until-issued-date, until-online-pub-date, until-posted-date,
    #    until-print-pub-date, until-pub-date, until-update-date, update-type, updates

    ukch_wks = []
    for this_aw in award_list:
        a_filter = works.filter(from_created_date=str(start_date)).filter(award__number=this_aw).url
        print(a_filter)
        time.sleep(5.0)
        try:
            pub_w_grant = works.filter(from_created_date=str(start_date)).filter(award__number=this_aw)
        except:
            print("error in the call")
            pub_w_grant =[]
        for wk in pub_w_grant:
            awd_list = [] 
            for fdr in wk['funder']:
                if 'award' in fdr.keys():
                   awds = 0
                   for awd in fdr['award']:
                       if awd in award_list:
                           awd_list.append(awd)
            if len(awd_list) > 0:
                ukch_wks.append(wk)

        foud_pubs = {}
        if len(ukch_wks) > 0:
            foud_pubs = {}
            for wk in ukch_wks:
                mcc_pub = ukch_pub = False
                art_authors = ""
                if 'author' in wk.keys() :
                    for autr in wk['author']:
                        if art_authors == "":
                            art_authors = autr['family'] + (", "+ autr ['given'] if 'given' in autr.keys() else "" )
                        else:
                            art_authors += ", " + autr['family']+ (", "+ autr ['given'] if 'given' in autr.keys() else "" )
                fund_award = ""
                for fdr in wk['funder']:
                    if 'award' in fdr.keys():
                      for awd in fdr['award']:
                           if awd in award_list:
                                if fund_award  == "":
                                    fund_award = awd
                                else:
                                    fund_award += ", " +awd
                                if awd in ukch_awards:
                                    ukch_pub = True
                                if awd in mcc_awards:
                                    mcc_pub = True
                ol_year = 0
                pr_year = 0
                pub_year = 0
                if 'published-online' in wk.keys() and 'date-parts' in wk['published-online'].keys():
                    ol_year = int(wk['published-online']['date-parts'][0][0])
                if 'published-print' in wk.keys() and 'date-parts' in wk['published-print'].keys():
                    pr_year = int(wk['published-print']['date-parts'][0][0])
                if pr_year > 0 and ol_year > 0:
                    if pr_year > ol_year:
                        pub_year = ol_year
                    else:
                        pub_year = pr_year
                elif ol_year > 0:
                    pub_year = ol_year
                elif pr_year > 0:
                    pub_year = pr_year

                #print(art_authors,"|",pub_year,"|",wk['title'][0],
                #      "|", wk['DOI'],"|", fund_award)     
                this_pub = {}
                this_pub['authors'] = art_authors
                this_pub['year'] = pub_year
                this_pub['title'] = wk['title'][0]
                this_pub['DOI'] = wk['DOI']
                this_pub['awards'] = fund_award

                this_pub['mcc'] = 1 if mcc_pub else 0
                this_pub['ukch'] = 1 if ukch_pub else 0
                if not wk['DOI'] in foud_pubs:
                    foud_pubs[wk['DOI']]= this_pub
                    #write as they are found instead of waiting until the end        
                    with open(out_file_1, 'a', newline='',encoding='utf8') as f:
                        writer = csv.writer(f)
                        writer.writerow(this_pub.values())
                    
    # WRITE TO FILE
    if len(foud_pubs) > 0:
        out_file =  Path(out_dir,'cr_check_'+str(end_date)+'b.csv')
        print ("writting to", out_file)
        csv_rw.write_csv_data(foud_pubs, out_file) 
        foud_pubs = {}
    start_date = end_date + timedelta(days=1)
# Out:
# From: 2025-01-01 to 2025-01-02
# https://api.crossref.org/works?filter=from-created-date%3A2025-01-01%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-01-01%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-01-02b.csv
# From: 2025-01-03 to 2025-01-04
# https://api.crossref.org/works?filter=from-created-date%3A2025-01-03%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-01-03%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-01-04b.csv
# From: 2025-01-05 to 2025-01-06
# https://api.crossref.org/works?filter=from-created-date%3A2025-01-05%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-01-05%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-01-06b.csv
# From: 2025-01-07 to 2025-01-08
# https://api.crossref.org/works?filter=from-created-date%3A2025-01-07%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-01-07%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-01-08b.csv
# From: 2025-01-09 to 2025-01-10
# https://api.crossref.org/works?filter=from-created-date%3A2025-01-09%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-01-09%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-01-10b.csv
# From: 2025-01-11 to 2025-01-12
# https://api.crossref.org/works?filter=from-created-date%3A2025-01-11%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-01-11%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-01-12b.csv
# From: 2025-01-13 to 2025-01-14
# https://api.crossref.org/works?filter=from-created-date%3A2025-01-13%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-01-13%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-01-14b.csv
# From: 2025-01-15 to 2025-01-16
# https://api.crossref.org/works?filter=from-created-date%3A2025-01-15%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-01-15%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-01-16b.csv
# From: 2025-01-17 to 2025-01-18
# https://api.crossref.org/works?filter=from-created-date%3A2025-01-17%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-01-17%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-01-18b.csv
# From: 2025-01-19 to 2025-01-20
# https://api.crossref.org/works?filter=from-created-date%3A2025-01-19%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-01-19%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-01-20b.csv
# From: 2025-01-21 to 2025-01-22
# https://api.crossref.org/works?filter=from-created-date%3A2025-01-21%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-01-21%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-01-22b.csv
# From: 2025-01-23 to 2025-01-24
# https://api.crossref.org/works?filter=from-created-date%3A2025-01-23%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-01-23%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-01-24b.csv
# From: 2025-01-25 to 2025-01-26
# https://api.crossref.org/works?filter=from-created-date%3A2025-01-25%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-01-25%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-01-26b.csv
# From: 2025-01-27 to 2025-01-28
# https://api.crossref.org/works?filter=from-created-date%3A2025-01-27%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-01-27%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-01-28b.csv
# From: 2025-01-29 to 2025-01-30
# https://api.crossref.org/works?filter=from-created-date%3A2025-01-29%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-01-29%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-01-30b.csv
# From: 2025-01-31 to 2025-02-01
# https://api.crossref.org/works?filter=from-created-date%3A2025-01-31%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-01-31%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-02-01b.csv
# From: 2025-02-02 to 2025-02-03
# https://api.crossref.org/works?filter=from-created-date%3A2025-02-02%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-02-02%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-02-03b.csv
# From: 2025-02-04 to 2025-02-05
# https://api.crossref.org/works?filter=from-created-date%3A2025-02-04%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-02-04%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-02-05b.csv
# From: 2025-02-06 to 2025-02-07
# https://api.crossref.org/works?filter=from-created-date%3A2025-02-06%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-02-06%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-02-07b.csv
# From: 2025-02-08 to 2025-02-09
# https://api.crossref.org/works?filter=from-created-date%3A2025-02-08%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-02-08%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-02-09b.csv
# From: 2025-02-10 to 2025-02-11
# https://api.crossref.org/works?filter=from-created-date%3A2025-02-10%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-02-10%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-02-11b.csv
# From: 2025-02-12 to 2025-02-13
# https://api.crossref.org/works?filter=from-created-date%3A2025-02-12%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-02-12%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-02-13b.csv
# From: 2025-02-14 to 2025-02-15
# https://api.crossref.org/works?filter=from-created-date%3A2025-02-14%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-02-14%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-02-15b.csv
# From: 2025-02-16 to 2025-02-17
# https://api.crossref.org/works?filter=from-created-date%3A2025-02-16%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-02-16%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-02-17b.csv
# From: 2025-02-18 to 2025-02-19
# https://api.crossref.org/works?filter=from-created-date%3A2025-02-18%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-02-18%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-02-19b.csv
# From: 2025-02-20 to 2025-02-21
# https://api.crossref.org/works?filter=from-created-date%3A2025-02-20%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-02-20%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-02-21b.csv
# From: 2025-02-22 to 2025-02-23
# https://api.crossref.org/works?filter=from-created-date%3A2025-02-22%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-02-22%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-02-23b.csv
# From: 2025-02-24 to 2025-02-25
# https://api.crossref.org/works?filter=from-created-date%3A2025-02-24%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-02-24%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-02-25b.csv
# From: 2025-02-26 to 2025-02-27
# https://api.crossref.org/works?filter=from-created-date%3A2025-02
# https://api.crossref.org/works?filter=from-created-date%3A2025-05-23%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-05-23%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-05-24b.csv
# From: 2025-05-25 to 2025-05-26
# https://api.crossref.org/works?filter=from-created-date%3A2025-05-25%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-05-25%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-05-26b.csv
# From: 2025-05-27 to 2025-05-28
# https://api.crossref.org/works?filter=from-created-date%3A2025-05-27%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-05-27%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-05-28b.csv
# From: 2025-05-29 to 2025-05-30
# https://api.crossref.org/works?filter=from-created-date%3A2025-05-29%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-05-29%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-05-30b.csv
# From: 2025-05-31 to 2025-06-01
# https://api.crossref.org/works?filter=from-created-date%3A2025-05-31%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-05-31%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-06-01b.csv
# From: 2025-06-02 to 2025-06-03
# https://api.crossref.org/works?filter=from-created-date%3A2025-06-02%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-06-02%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-06-03b.csv
# From: 2025-06-04 to 2025-06-05
# https://api.crossref.org/works?filter=from-created-date%3A2025-06-04%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-06-04%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-06-05b.csv
# From: 2025-06-06 to 2025-06-07
# https://api.crossref.org/works?filter=from-created-date%3A2025-06-06%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-06-06%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-06-07b.csv
# From: 2025-06-08 to 2025-06-09
# https://api.crossref.org/works?filter=from-created-date%3A2025-06-08%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-06-08%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-06-09b.csv
# From: 2025-06-10 to 2025-06-11
# https://api.crossref.org/works?filter=from-created-date%3A2025-06-10%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-06-10%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-06-11b.csv
# From: 2025-06-12 to 2025-06-13
# https://api.crossref.org/works?filter=from-created-date%3A2025-06-12%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-06-12%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-06-13b.csv
# From: 2025-06-14 to 2025-06-15
# https://api.crossref.org/works?filter=from-created-date%3A2025-06-14%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-06-14%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-06-15b.csv
# From: 2025-06-16 to 2025-06-17
# https://api.crossref.org/works?filter=from-created-date%3A2025-06-16%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-06-16%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-06-17b.csv
# From: 2025-06-18 to 2025-06-19
# https://api.crossref.org/works?filter=from-created-date%3A2025-06-18%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-06-18%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-06-19b.csv
# From: 2025-06-20 to 2025-06-21
# https://api.crossref.org/works?filter=from-created-date%3A2025-06-20%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-06-20%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-06-21b.csv
# From: 2025-06-22 to 2025-06-23
# https://api.crossref.org/works?filter=from-created-date%3A2025-06-22%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-06-22%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-06-23b.csv
# From: 2025-06-24 to 2025-06-25
# https://api.crossref.org/works?filter=from-created-date%3A2025-06-24%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-06-24%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-06-25b.csv
# From: 2025-06-26 to 2025-06-27
# https://api.crossref.org/works?filter=from-created-date%3A2025-06-26%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-06-26%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-06-27b.csv
# From: 2025-06-28 to 2025-06-29
# https://api.crossref.org/works?filter=from-created-date%3A2025-06-28%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-06-28%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-06-29b.csv
# From: 2025-06-30 to 2025-07-01
# https://api.crossref.org/works?filter=from-created-date%3A2025-06-30%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-06-30%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-07-01b.csv
# From: 2025-07-02 to 2025-07-03
# https://api.crossref.org/works?filter=from-created-date%3A2025-07-02%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-07-02%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-07-03b.csv
# From: 2025-07-04 to 2025-07-05
# https://api.crossref.org/works?filter=from-created-date%3A2025-07-04%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-07-04%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-07-05b.csv
# From: 2025-07-06 to 2025-07-07
# https://api.crossref.org/works?filter=from-created-date%3A2025-07-06%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-07-06%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-07-07b.csv
# From: 2025-07-08 to 2025-07-09
# https://api.crossref.org/works?filter=from-created-date%3A2025-07-08%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-07-08%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-07-09b.csv
# From: 2025-07-10 to 2025-07-11
# https://api.crossref.org/works?filter=from-created-date%3A2025-07-10%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-07-10%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-07-11b.csv
# From: 2025-07-12 to 2025-07-13
# https://api.crossref.org/works?filter=from-created-date%3A2025-07-12%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-07-12%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-07-13b.csv
# From: 2025-07-14 to 2025-07-15
# https://api.crossref.org/works?filter=from-created-date%3A2025-07-14%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-07-14%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-07-15b.csv
# From: 2025-07-16 to 2025-07-17
# https://api.crossref.org/works?filter=from-created-date%3A2025-07-16%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-07-16%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-07-17b.csv
# From: 2025-07-18 to 2025-07-19
# https://api.crossref.org/works?filter=from-created-date%3A2025-07-18%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-07-18%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-07-19b.csv
# From: 2025-07-20 to 2025-07-21
# https://api.crossref.org/works?filter=from-created-date%3A2025-07-20%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-07-20%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-07-21b.csv
# From: 2025-07-22 to 2025-07-23
# https://api.crossref.org/works?filter=from-created-date%3A2025-07-22%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-07-22%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-07-23b.csv
# From: 2025-07-24 to 2025-07-25
# https://api.crossref.org/works?filter=from-created-date%3A2025-07-24%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-07-24%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-07-25b.csv
# From: 2025-07-26 to 2025-07-27
# https://api.crossref.org/works?filter=from-created-date%3A2025-07-26%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-07-26%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-07-27b.csv
# From: 2025-07-28 to 2025-07-29
# https://api.crossref.org/works?filter=from-created-date%3A2025-07-28%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-07-28%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-07-29b.csv
# From: 2025-07-30 to 2025-07-31
# https://api.crossref.org/works?filter=from-created-date%3A2025-07-30%2Caward.number%3AEP%2FW017075%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2025-07-30%2Caward.number%3AEP%2FW017075
# writting to pub_search_crossref\cr_results_202507\cr_check_2025-07-31b.csv

# %%
if len(foud_pubs) > 0:
    csv_rw.write_csv_data(foud_pubs, out_dir+'cr_check_'+str(end_date)+'a.csv') 
start_date = end_date + timedelta(days=1)

# %%
start_date = end_date + timedelta(days=1)
start_date

# %%
foud_pubs

# %%
works.filter(from_created_date=str(start_date)).filter(until_created_date=str(end_date))%3A

# %%
works = Works(etiquette=my_etiquette)
works.filter("award.number%3AEP/K014706/2").url

# %%
foud_pubs
