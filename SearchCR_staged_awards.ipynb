# %% [markdown]
# # Search publications using the Crossref API
#
# Use crossref restful API to get the works based on the award codes

# %%
# Connecting to the db
import lib.handle_db as dbh

# read and write csv files
import lib.handle_csv as csv_rw

# file management
from pathlib import Path

# date functions
from datetime import datetime, date, timedelta

#CR libraries
from crossref.restful import Works, Etiquette

# search for UKCH Awards in CR record
def award_in_crossref(aw, award_list):
    ukch_wks =[]
    not_revised = []
    for wk in aw:      
        awd_list = []
        if 'funder' in wk.keys():
            for fdr in wk['funder']:
                if 'award' in fdr.keys():
                   awds = 0
                   for awd in fdr['award']:
                        if awd in award_list:
                            awd_list.append(awd)
                            #print (fdr)
                            break
        else:
            not_revised.append(wk)
        if len(awd_list) > 0:
            ukch_wks.append(wk)
    return ukch_wks, not_revised

def collect_keys(aw, wk_keys):
    for wk in aw:
        these_keys = wk.keys()
        for a_key in these_keys:
            if a_key in wk_keys:
                wk_keys[a_key] += 1
            else:
                wk_keys[a_key] = 1
    return wk_keys

def collect_fdr_keys(aw, wk_keys):
    for wk in aw:
        if 'funder' in wk.keys():
            for fdr in wk['funder']:
                these_keys = fdr.keys()
                for a_key in these_keys:
                    if a_key in wk_keys:
                        wk_keys[a_key] += 1
                    else:
                        wk_keys[a_key] = 1
    return wk_keys

def collect_awds(aw, wk_keys):
    for wk in aw:
        if 'funder' in wk.keys():
            for fdr in wk['funder']:
                if 'award' in fdr.keys():
                   awds = 0
                   for awd in fdr['award']:
                        if awd in wk_keys:
                            wk_keys[awd] += 1
                        else:
                            wk_keys[awd] = 1
    return wk_keys

# search for UKCH Affiliation in CR record
def affi_in_crossref(aw):
    ukch_wks = []
    for wk in aw:
        ukch_affiliation = False
        if 'author' in wk.keys():
            for autr in wk['author']:
                if 'affiliation' in autr.keys():
                    for affi in autr['affiliation']:
                        if "UK Catalysis Hub" in affi['name']:
                            ukch_affiliation = True
                            break
                    if ukch_affiliation:
                        ukch_wks.append(wk)
                        break
    return  ukch_wks

# %% [markdown]
# Define the awards to look for. In this case we also look for partial matches because the sometimes the publications drop the last part (/1 or /2)

# %%
my_etiquette = Etiquette('UK Catalysis Hub - Catalysis Data Infrastructure', 
                         'Prototype 1', 
                         'https://ukcatalysishub.co.uk/core/', 
                         'nieva@rc-harwell.ac.uk')

ukch_awards = ['EP/R026939/1', 'EP/R026815/1', 'EP/R026645/1', 'EP/R027129/1', 'EP/M013219/1',
               'EP/K014706/2', 'EP/K014668/1', 'EP/K014854/1', 'EP/K014714/1',
               'EP/R026939', 'EP/R026815', 'EP/R026645', 'EP/R027129', 'EP/M013219',
               'EP/K014706', 'EP/K014668', 'EP/K014854', 'EP/K014714',
              ]

mcc_awards = ['EP/R029431/1', 'EP/P020194/1', 'EP/T022213/1', 'EP/D504872/1', 'EP/F067496/1','EP/X035859/1', 
              'EP/W032260/1', 'EP/L000202/1', 'EP/R029431','EP/P020194', 'EP/T022213', 'EP/D504872', 
              'EP/F067496','EP/X035859', 'EP/W032260', 'EP/L000202']

ukch_affi_synonyms = ["UK Catalysis Hub"]

award_list = ukch_awards + mcc_awards

works = Works(etiquette=my_etiquette)

start_date = end_date = date(2024, 4, 30) #started 7,1
stop_date = date(2024, 6, 25)

out_dir = './pub_search_crossref/cr_results_202406/'

pubs_with_award = []
skiped_works =[]
wk_keys = {}
fd_keys = {}
awds_lst = {}
foud_pubs = {}
while end_date < stop_date + timedelta(days=1):
    end_date = start_date + timedelta(days=1)
    print ("From:", str(start_date), "to",  str(end_date))
    # works with from_published_date and until_published_date 
    # next test with from_deposit_date and until_deposit_date
    # Valid filters for this route are: alternative_id, archive, article_number, assertion, assertion-group, 
    #    award.funder, award.number, category-name, clinical-trial-number, container-title, content-domain,
    #    directory, doi, from-accepted-date, from-created-date, from-deposit-date, from-event-end-date,
    #    from-event-start-date, from-index-date, from-issued-date, from-online-pub-date, from-posted-date,
    #    from-print-pub-date, from-pub-date, from-update-date, full-text.application, full-text.type, 
    #    full-text.version, funder, funder-doi-asserted-by, group-title, has-abstract, has-affiliation,
    #    has-archive, has-assertion, has-authenticated-orcid, has-award, has-clinical-trial-number,
    #    has-content-domain, has-domain-restriction, has-event, has-full-text, has-funder, has-funder-doi,
    #    has-license, has-orcid, has-references, has-relation, has-update, has-update-policy, is-update, 
    #    isbn, issn, license.delay, license.url, license.version, location, member, orcid, prefix,
    #    relation.object, relation.object-type, relation.type, type, type-name, until-accepted-date,
    #    until-created-date, until-deposit-date, until-event-end-date, until-event-start-date,
    #    until-index-date, until-issued-date, until-online-pub-date, until-posted-date,
    #    until-print-pub-date, until-pub-date, until-update-date, update-type, updates

    ukch_wks = []
    for this_aw in award_list:
        a_filter = works.filter(from_created_date=str(start_date)).filter(award__number=this_aw).url
        print(a_filter)
        pub_w_grant = works.filter(from_created_date=str(start_date)).filter(award__number=this_aw)
        
        for wk in pub_w_grant:     
            awd_list = [] 
            for fdr in wk['funder']:
                if 'award' in fdr.keys():
                   awds = 0
                   for awd in fdr['award']:
                       if awd in award_list:
                           awd_list.append(awd)
            if len(awd_list) > 0:
                ukch_wks.append(wk)

        foud_pubs = {}
        if len(ukch_wks) > 0:
            foud_pubs = {}
            for wk in ukch_wks:
                mcc_pub = ukch_pub = False
                art_authors = ""
                if 'author' in wk.keys() :
                    for autr in wk['author']:
                        if art_authors == "":
                            art_authors = autr['family'] + (", "+ autr ['given'] if 'given' in autr.keys() else "" )
                        else:
                            art_authors += ", " + autr['family']+ (", "+ autr ['given'] if 'given' in autr.keys() else "" )
                fund_award = ""
                for fdr in wk['funder']:
                    if 'award' in fdr.keys():
                      for awd in fdr['award']:
                           if awd in award_list:
                                if fund_award  == "":
                                    fund_award = awd
                                else:
                                    fund_award += ", " +awd
                                if awd in ukch_awards:
                                    ukch_pub = True
                                if awd in mcc_awards:
                                    mcc_pub = True
                ol_year = 0
                pr_year = 0
                pub_year = 0
                if 'published-online' in wk.keys() and 'date-parts' in wk['published-online'].keys():
                    ol_year = int(wk['published-online']['date-parts'][0][0])
                if 'published-print' in wk.keys() and 'date-parts' in wk['published-print'].keys():
                    pr_year = int(wk['published-print']['date-parts'][0][0])
                if pr_year > 0 and ol_year > 0:
                    if pr_year > ol_year:
                        pub_year = ol_year
                    else:
                        pub_year = pr_year
                elif ol_year > 0:
                    pub_year = ol_year
                elif pr_year > 0:
                    pub_year = pr_year

                #print(art_authors,"|",pub_year,"|",wk['title'][0],
                #      "|", wk['DOI'],"|", fund_award)     
                this_pub = {}
                this_pub['authors'] = art_authors
                this_pub['year'] = pub_year
                this_pub['title'] = wk['title'][0]
                this_pub['DOI'] = wk['DOI']
                this_pub['awards'] = fund_award

                this_pub['mcc'] = 1 if mcc_pub else 0
                this_pub['ukch'] = 1 if ukch_pub else 0
                if not wk['DOI'] in foud_pubs:
                     foud_pubs[wk['DOI']]= this_pub
    # WRITE TO FILE
    if len(foud_pubs) > 0:
        out_file =  Path(out_dir,'cr_check_'+str(end_date)+'a.csv')
        print ("writting to", out_file)
        csv_rw.write_csv_data(foud_pubs, out_file) 
        foud_pubs = {}
    start_date = end_date + timedelta(days=1)
# Out:
# From: 2024-04-30 to 2024-05-01
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FR026939%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FR026815%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FR026645%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FR027129%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FM013219%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FK014706%2F2
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FK014668%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FK014854%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FK014714%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FR026939
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FR026815
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FR026645
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FR027129
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FM013219
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FK014706
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FK014668
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FK014854
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FK014714
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FR029431%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FP020194%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FT022213%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FD504872%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FF067496%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FX035859%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FW032260%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FL000202%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FR029431
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FP020194
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FT022213
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FD504872
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FF067496
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FX035859
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FW032260
# https://api.crossref.org/works?filter=from-created-date%3A2024-04-30%2Caward.number%3AEP%2FL000202
# writting to pub_search_crossref\cr_results_202406\cr_check_2024-05-01a.csv
# From: 2024-05-02 to 2024-05-03
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FR026939%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FR026815%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FR026645%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FR027129%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FM013219%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FK014706%2F2
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FK014668%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FK014854%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FK014714%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FR026939
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FR026815
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FR026645
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FR027129
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FM013219
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FK014706
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FK014668
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FK014854
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FK014714
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FR029431%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FP020194%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FT022213%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FD504872%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FF067496%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FX035859%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FW032260%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FL000202%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FR029431
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FP020194
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FT022213
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FD504872
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FF067496
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FX035859
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FW032260
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-02%2Caward.number%3AEP%2FL000202
# writting to pub_search_crossref\cr_results_202406\cr_check_2024-05-03a.csv
# From: 2024-05-04 to 2024-05-05
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FR026939%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FR026815%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FR026645%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FR027129%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FM013219%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FK014706%2F2
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FK014668%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FK014854%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FK014714%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FR026939
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FR026815
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FR026645
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FR027129
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FM013219
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FK014706
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FK014668
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FK014854
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FK014714
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FR029431%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FP020194%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FT022213%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FD504872%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FF067496%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FX035859%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FW032260%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FL000202%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FR029431
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FP020194
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FT022213
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FD504872
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FF067496
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FX035859
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FW032260
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-04%2Caward.number%3AEP%2FL000202
# writting to pub_search_crossref\cr_results_202406\cr_check_2024-05-05a.csv
# From: 2024-05-06 to 2024-05-07
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-06%2Caward.number%3AEP%2FR026939%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-06%2Caward.number%3AEP%2FR026815%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-06%2Caward.number%3AEP%2FR026645%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-06%2Caward.number%3AEP%2FR027129%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-06%2Caward.number%3AEP%2FM013219%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-06%2Caward.number%3AEP%2FK014706%2F2
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-06%2Caward.number%3AEP%2FK014668%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-06%2Caward.number%3AEP%2FK014854%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-06%2Caward.number%3AEP%2FK014714%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-06%2Caward.number%3AEP%2FR026939
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-06%2Caward.number%3AEP%2FR026815
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-06%2Caward.number%3AEP%2FR026645
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-06%2Caward.number%3AEP%2FR027129
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-06%2Caward.number%3AEP%2FM013219
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-06%2Caward.number%3AEP%2FK014706
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-06%2Caward.number%3AEP%2FK014668
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-06%2Caward.number%3AEP%2FK014854
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-06%2Caward.number%3AEP%2FK014714
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-06%2Caward.number%3AEP%2FR029431%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-06%2Caward.number%3AEP%2FP020194%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-06%2Caward.number%3AEP%2FT022213%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-06%2Caward.number%3AEP%2FD504872%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-06%2Caward.number%3AEP%2FF067496%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-06%2Caward.number%3AEP%2FX035859%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-06%2Caward.number%3AEP%2FW032260%2F1
# https://api.crossref.org/works?filter=from-created-date%3A2024-05-06%2Caward.number%3AEP%2FL000202%2F1
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\users\scman1\appdata\local\programs\python\python39\lib\site-packages\requests\models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\users\scman1\appdata\local\programs\python\python39\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File c:\users\scman1\appdata\local\programs\python\python39\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File c:\users\scman1\appdata\local\programs\python\python39\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[7], line 59
#      56 print(a_filter)
#      57 pub_w_grant = works.filter(from_created_date=str(start_date)).filter(award__number=this_aw)
# ---> 59 for wk in pub_w_grant:
#      60     awd_list = []
#      61     for fdr in wk['funder']:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\crossref\restful.py:292, in Endpoint.__iter__(self)
#     289 if result.status_code == 404:
#     290     raise StopIteration()
# --> 292 result = result.json()
#     294 if len(result['message']['items']) == 0:
#     295     return
#
# File c:\users\scman1\appdata\local\programs\python\python39\lib\site-packages\requests\models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
if len(foud_pubs) > 0:
    csv_rw.write_csv_data(foud_pubs, out_dir+'cr_check_'+str(end_date)+'a.csv') 
start_date = end_date + timedelta(days=1)

# %%
start_date = end_date + timedelta(days=1)
start_date

# %%
foud_pubs

# %%
works.filter(from_created_date=str(start_date)).filter(until_created_date=str(end_date))%3A

# %%
works = Works(etiquette=my_etiquette)
works.filter("award.number%3AEP/K014706/2").url

# %%
foud_pubs
# Out:
# {'10.1016/j.cattod.2024.114867': {'authors': 'Bowker, M.',
#   'year': 2024,
#   'title': 'The importance of Pd carbide formation for reactions with ethene and other organic molecules',
#   'DOI': '10.1016/j.cattod.2024.114867',
#   'awards': 'EP/R026939/1, EP/R026815/1',
#   'mcc': 0,
#   'ukch': 1},
#  '10.1021/acs.jpclett.4c00865': {'authors': 'Campbell, Emma, Sazanovich, Igor V., Towrie, Michael, Watson, Michael J., Lezcano-Gonzalez, Ines, Beale, Andrew M.',
#   'year': 2024,
#   'title': 'Methanol-to-Olefins Studied by UV Raman Spectroscopy as Compared to Visible Wavelength: Capitalization on Resonance Enhancement',
#   'DOI': '10.1021/acs.jpclett.4c00865',
#   'awards': 'EP/R026815/1',
#   'mcc': 0,
#   'ukch': 1},
#  '10.1039/d4ey00026a': {'authors': 'Belami, Debora, Lindley, Matthew, Jonnalagadda, Umesh S., Goncalves Bullock, Annie Mae, Fan, Qianwenhao, Liu, Wen, Haigh, Sarah J., Kwan, James, Regmi, Yagya N., King, Laurie A.',
#   'year': 2024,
#   'title': 'Active and highly durable supported catalysts for proton exchange membrane electrolysers',
#   'DOI': '10.1039/d4ey00026a',
#   'awards': 'EP/R026645/1',
#   'mcc': 0,
#   'ukch': 1},
#  '10.1016/j.mtsust.2024.100870': {'authors': 'Leishman, Claire, García-Vázquez, Miguel, Bekris, Leonidas, Alvarez Ruiz, Diana Talia, Doustdar, Omid, Zeraati Rezaei, Soheil, Martin Herreros, Jose, Tsolakis, Athanasios, Papaioannou, Evangelos I., Li, Kang, García-García, Francisco R.',
#   'year': 2024,
#   'title': 'Non-PGM hollow fibre-based after-treatment for emission control under real diesel engine exhaust gas conditions',
#   'DOI': '10.1016/j.mtsust.2024.100870',
#   'awards': 'EP/R027129/1',
#   'mcc': 0,
#   'ukch': 1},
#  '10.1021/acs.jpcb.4c00362': {'authors': 'Gousseva, Ekaterina, Towers Tompkins, Frances K., Seymour, Jake M., Parker, Lewis G., Clarke, Coby J., Palgrave, Robert G., Bennett, Roger A., Grau-Crespo, Ricardo, Lovelock, Kevin R. J.',
#   'year': 2024,
#   'title': 'Anion-Dependent Strength Scale of Interactions in Ionic Liquids from X-ray Photoelectron Spectroscopy, Ab Initio Molecular Dynamics, and Density Functional Theory',
#   'DOI': '10.1021/acs.jpcb.4c00362',
#   'awards': 'EP/R029431/1, EP/T022213/1',
#   'mcc': 1,
#   'ukch': 0},
#  '10.1039/d4nr01296h': {'authors': 'Moxon, Samuel, Symington, Adam R., Tse, Joshua S., Flitcroft, Joseph M., Skelton, Jonathan M., Gillie, Lisa J., Cooke, David J., Parker, Stephen C., Molinari, Marco',
#   'year': 2024,
#   'title': 'Composition-dependent morphologies of CeO<sub>2</sub> nanoparticles in the presence of Co-adsorbed H<sub>2</sub>O and CO<sub>2</sub>: a density functional theory study',
#   'DOI': '10.1039/d4nr01296h',
#   'awards': 'EP/L000202/1, EP/R029431/1, EP/X035859/1',
#   'mcc': 1,
#   'ukch': 0},
#  '10.1103/physrevlett.132.196201': {'authors': 'Stoodley, Matthew A., Rochford, Luke A., Lee, Tien-Lin, Klein, Benedikt P., Duncan, David A., Maurer, Reinhard J.',
#   'year': 2024,
#   'title': 'Structure of Graphene Grown on Cu(111): X-Ray Standing Wave Measurement and Density Functional Theory Prediction',
#   'DOI': '10.1103/physrevlett.132.196201',
#   'awards': 'EP/L000202/1, EP/R029431/1',
#   'mcc': 1,
#   'ukch': 0},
#  '10.3390/polym16101376': {'authors': 'Craig, Ben, Townsend, Peter, de Leon, Carlos Ponce, Skylaris, Chris-Kriton, Kramer, Denis',
#   'year': 2024,
#   'title': 'An Electronic Structure Investigation of PEDOT with AlCl4− Anions—A Promising Redox Combination for Energy Storage Applications',
#   'DOI': '10.3390/polym16101376',
#   'awards': 'EP/T022213/1, EP/W032260/1, EP/P020194/1',
#   'mcc': 1,
#   'ukch': 0},
#  '10.1103/physrevb.109.224102': {'authors': 'Anwar, Nabeel, Harker, Robert M., Storr, Mark T., Molinari, Marco, Skylaris, Chris-Kriton',
#   'year': 2024,
#   'title': 'Large-scale density functional theory simulations of defects and hydrogen incorporation in \n<mml:math xmlns:mml="http://www.w3.org/1998/Math/MathML"><mml:msub><mml:mrow><mml:mi>PuO</mml:mi></mml:mrow><mml:mn>2</mml:mn></mml:msub></mml:math>',
#   'DOI': '10.1103/physrevb.109.224102',
#   'awards': 'EP/X035859/1, EP/T022213/1, EP/W032260/1, EP/P020194/1',
#   'mcc': 1,
#   'ukch': 0},
#  '10.1021/acs.jpclett.4c01030': {'authors': 'O’Neill, Niamh, Shi, Benjamin X., Fong, Kara, Michaelides, Angelos, Schran, Christoph',
#   'year': 2024,
#   'title': 'To Pair or not to Pair? Machine-Learned Explicitly-Correlated Electronic Structure for NaCl in Water',
#   'DOI': '10.1021/acs.jpclett.4c01030',
#   'awards': 'EP/P020194/1, EP/T022213/1',
#   'mcc': 1,
#   'ukch': 0},
#  '10.1039/d3dd00234a': {'authors': 'Wu, Yifan, Walsh, Aron, Ganose, Alex M.',
#   'year': 2024,
#   'title': 'Race to the bottom: Bayesian optimisation for chemical problems',
#   'DOI': '10.1039/d3dd00234a',
#   'awards': 'EP/T022213/1, EP/W032260/1, EP/P020194/1',
#   'mcc': 1,
#   'ukch': 0},
#  '10.1016/j.comptc.2024.114720': {'authors': 'Pang, Siu-Kwong',
#   'year': 2024,
#   'title': 'Why high spin? Why sulphur? Comparative analysis of catalytic oxidation by Compound I of cytochrome P450, catalase, peroxidase, and selenocysteine-modified P450',
#   'DOI': '10.1016/j.comptc.2024.114720',
#   'awards': 'EP/T022213/1, EP/W032260/1, EP/P020194/1',
#   'mcc': 1,
#   'ukch': 0},
#  '10.1021/acsomega.4c03060': {'authors': 'Zhong, Zhiwen, Ulmschneider, Martin B., Lorenz, Christian D.',
#   'year': 2024,
#   'title': 'Unraveling the Molecular Dance: Insights into TREM2/DAP12 Complex Formation in Alzheimer’s Disease through Molecular Dynamics Simulations',
#   'DOI': '10.1021/acsomega.4c03060',
#   'awards': 'EP/P020194/1, EP/T022213/1, EP/W032260/1',
#   'mcc': 1,
#   'ukch': 0},
#  '10.26434/chemrxiv-2024-sdd5c': {'authors': 'Carman, Fionn, Ewen, James P., Bresme, Fernando, Wu, Billy, Dini, Daniele',
#   'year': 0,
#   'title': 'Molecular Simulations of Thermal Transport across Iron Oxide-Hydrocarbon Interfaces',
#   'DOI': '10.26434/chemrxiv-2024-sdd5c',
#   'awards': 'EP/W032260/1, EP/P020194/1',
#   'mcc': 1,
#   'ukch': 0},
#  '10.1016/j.joule.2024.05.004': {'authors': 'Wang, Xinwei, Kavanagh, Seán R., Scanlon, David O., Walsh, Aron',
#   'year': 2024,
#   'title': 'Upper efficiency limit of <mml:math xmlns:mml="http://www.w3.org/1998/Math/MathML" altimg="si1.gif"><mml:mrow><mml:msub><mml:mtext>Sb</mml:mtext><mml:mn>2</mml:mn></mml:msub><mml:msub><mml:mtext>Se</mml:mtext><mml:mn>3</mml:mn></mml:msub></mml:mrow></mml:math> solar cells',
#   'DOI': '10.1016/j.joule.2024.05.004',
#   'awards': 'EP/X035859/1',
#   'mcc': 1,
#   'ukch': 0},
#  '10.1039/d4cp00348a': {'authors': 'Jyoti, Shaswati, Vijay, Aditi, Terranova, Umberto, Gupta, Santosh K, Sudarshan, Kathi, Vaidya, Sonalika',
#   'year': 2024,
#   'title': 'Electrocatalytic OER behavior of the Bi–Fe–O system: an understanding from the perspective of the presence of oxygen vacancies',
#   'DOI': '10.1039/d4cp00348a',
#   'awards': 'EP/X035859/1, EP/R029431',
#   'mcc': 1,
#   'ukch': 0}}
