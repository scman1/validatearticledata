# %% [markdown]
# ## Required Libraries

# %%
# Libraries
# library containign functions that read and write to csv files
import lib.handle_csv as csvh
# library for getting data from crossref
import lib.crossref_api as cr_api
# library for mapping json data
import lib.handle_json as hjson
# library for connecting to the db
import lib.handle_db as dbh

# datetime parsing
from datetime import datetime
# clear the output after each loop cycle
from IPython.display import clear_output

# %% [markdown]
# ## Global variables

# %%
db_conn = dbh.DataBaseAdapter('./db_files/production.sqlite3')
#db_conn = dbh.DataBaseAdapter('../mcc_data/development.sqlite3')

# global lists of affiliation components
#institutions_list = []
#countries_list = []
#school_list = []
#department_list = []
#faculty_list = []
#group_list = []

#def refresh_lists():
db_conn = dbh.DataBaseAdapter('../mcc_data/development.sqlite3')
# get institutions list from affiliations table
print("Refreshing lists")
institutions_list = db_conn.get_value_list("affiliations", "institution")
# get coutries from affiliations table
countries_list = db_conn.get_value_list("affiliations","country")
# get school list from affiliations table
school_list = db_conn.get_value_list("Affiliations","school")
# get department list from affiliations table
department_list = db_conn.get_value_list("affiliations","department")
# get faculty list from affiliations table
faculty_list = db_conn.get_value_list("affiliations","faculty")
# get research group list from affiliations table
group_list = db_conn.get_value_list("affiliations", "work_group")

def refresh_lists(affi_values):
    if affi_values['institution'] != "" and not affi_values['institution'] in institutions_list:
        institutions_list.append (affi_values['institution'])
    if affi_values['department'] != "" and not affi_values['department'] in department_list:
        department_list.append(affi_values['department'])
    if affi_values['faculty'] != "" and not affi_values['faculty'] in faculty_list:
        faculty_list.append(affi_values['faculty'])
    if affi_values['work_group'] != "" and not affi_values['work_group'] in group_list:
        group_list.append(affi_values['work_group'])
    if affi_values['school'] != "" and not affi_values['school'] in  school_list:
        school_list.append( affi_values['school'])
    if affi_values['country'] != "" and not affi_values['country'] in countries_list:
        countries_list.append(affi_values['country'])
    
affi_keys = {'a':'institution', 'b':'country', 'c':'department','d':'faculty',
             'e':'work_group'}

country_synonyms = {"(UK)":"United Kingdom", "UK":"United Kingdom",
                    "U.K.":"United Kingdom", "U. K.":"United Kingdom",
                    "U.K":"United Kingdom", "PRC":"Peoples Republic of China",
                    "P.R.C.":"Peoples Republic of China", 
                    "P.R.China":"Peoples Republic of China",
                    "P. R. China":"Peoples Republic of China",
                    "P.R. China":"Peoples Republic of China","China":"Peoples Republic of China",
                    "United States":"United States of America",
                    "USA":"United States of America","U.S.A.":"United States of America",
                    "U. S. A.":"United States of America", "U.S.":"United States of America",
                    "U. S.":"United States of America","US":"United States of America",
                   }

institution_synonyms = {"Paul Scherrer Institut":"Paul Scherrer Institute",
                        "PSI":"Paul Scherrer Institute",
                        "Diamond Light source Ltd": "Diamond Light Source Ltd.",
                        "Diamond Light Source": "Diamond Light Source Ltd.",
                        "University of St Andrews": "University of St. Andrews",
                        "Queen’s University of Belfast":"Queen's University Belfast",
                        "STFC":"Science and Technology Facilities Council",
                        "University of Manchester": "The University of Manchester",
                        "Finden Limited": "Finden Ltd",
                        "The ISIS facility":"ISIS Neutron and Muon Source",
                        "ISIS Neutron and Muon Facility":"ISIS Neutron and Muon Source",
                        "ISIS Pulsed Neutron and Muon Facility":"ISIS Neutron and Muon Source",
                        "STFC":"Science and Technology Facilities Council",
                        "Oxford University":"University of Oxford",
                        "University of St Andrews":"University of St. Andrews",
                        "Diamond Light Source Ltd Harwell Science and Innovation Campus":"Diamond Light Source Ltd.",
                        "Diamond Light Source":"Diamond Light Source Ltd.",
                        "ISIS Facility":"ISIS Neutron and Muon Source",
                        "University College of London":"University College London",
                        "UCL":"University College London", "UOP LLC":"UOP LLC, A Honeywell Company",
                        "University of Manchester":"The University of Manchester",
                        "Johnson-Matthey Technology Centre":"Johnson Matthey Technology Centre",
                        "Research Complex at Harwell (RCaH)":"Research Complex at Harwell",
                        "RCaH":"Research Complex at Harwell",
                        "Queens University Belfast":"Queen's University Belfast",
                        "Queen’s University Belfast":"Queen's University Belfast",
                        "University of Edinburgh":"The University of Edinburgh",
                        "SynCat@Beijing, Synfuels China Technology Co. Ltd.":"SynCat@Beijing Synfuels China Company Limited",
                        "Synfuels China Compnay Limited":"SynCat@Beijing Synfuels China Company Limited",
                        "Finden Limited":"Finden Ltd",
                        "The UK Catalysis Hub":"UK Catalysis Hub",
                        "Univ. Pablo de Olavide":"Universidad Pablo de Olavide",
                        "Univ Rennes":"Université de Rennes",
                        "Université Rennes":"Université de Rennes",
                        "Institut Laue Langevin":"Institut Laue-Langevin",
                        "Esfera UAB":"Universitat Autònoma de Barcelona",
                        "Kings College London":"King's College London",
                       }  

country_exceptions = ["Denmark Hill", "UK Catalysis Hub", "Sasol Technology U.K.", "N. Ireland", 'Indian']
# Out:
# Refreshing lists

# %% [markdown]
# ## Custom Processing Functions

# %%
# process addresses which are a single string
def process_single_affi(cf_affi_id, art_aut_id, cr_affi_str):
    clear_output()
    print('*********************************************************')
    print("* Art. author", art_aut_id, "Affi:", cr_affi_str, "Affi ID:", cr_affi_id)
    # 1. split the single string using keywords list and synonyms tables
    affi_values = split_single(cr_affi_str)
    print("* Affi Values:", affi_values)
    affiliation_id = address_id = 0
    # determine if parsing needs help (institution found?)   
    if affi_values['institution'] in ["", None]:
        affi_values = custom_split(affi_values)
    if not affi_values['institution'] in ["", None]:
        affiliation_id, address_id = affiliation_exists(affi_values)
        if affiliation_id !=0 and address_id != 0:
            print("* Affiliation found in DB id:", affiliation_id, "Address:", address_id)
            print('* Add ')
        elif affiliation_id !=0 and address_id == 0:
            print("* Affiliation found in DB id:", affiliation_id, "Need to add address:", affi_values['address'])
            address_id = add_address(affi_values['address'], affiliation_id, affi_values['country'])
            print("* Added address:", affi_values['address'], "ID:", address_id)
        else:
            print("* Need to add affiliation and address")
            print ('* Try to add affi for', affi_values)
            address_string = affi_values['address']
            affiliation_id = add_affiliation(affi_values)
            # renew lists as new affi is added
            refresh_lists(affi_values)
            address_id = add_address(address_string, affiliation_id, affi_values['country'])
            print ('* Added affiliation and address', affiliation_id, address_id)
            
        if affiliation_id !=0 and address_id != 0:
            print("* Adding author affiliation record ")
            added_aut_affi_id = add_author_affiliation(art_aut_id, affiliation_id, address_id)
            print("* Added author affiliation record ID:", added_aut_affi_id)
            update_cr_affiliation(cf_affi_id, added_aut_affi_id)
            print("* Update cr affiliation", cf_affi_id)
    else: 
        print('could not process string:', cr_affi_str)
        print('results obtained:', affi_values)
    print('&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&')

# Check the if any of the values in the list is in the given string
def check_list(a_string, a_list):
    return_str = ""
    temp_str = ""
    for an_item in a_list:
        if an_item in a_string:
            if len(an_item) > len(temp_str):
                temp_str = an_item
    if len(temp_str)>0:
        a_string = a_string.replace(temp_str,"")
        return_str = temp_str
    return return_str, a_string

# verify if the string has some of the synomyms in the provided synonym table
def str_has_synonym(affi_str, synonym_dict):
    ret_str = ""
    temp_str = ""
    for a_key in synonym_dict.keys():
        if a_key in affi_str:
            if len(a_key) > len(temp_str):
                temp_str = a_key
    if len(temp_str) > 0:
        ret_str = synonym_dict[temp_str]
        affi_str = affi_str.replace(temp_str,'')
    return ret_str, affi_str

def custom_split(affiliation_values):
    # Look for institution name should be in the address element
    print ("Select how to parse ",  affiliation_values)
    option_how = 0
    while not option_how in [1,2,3,4]:
        print('options: ')
        print('1: get from address element')
        print('2: enter manually')
        print('3: manual parse')
        print('4: do nothing ')
        print('selection:')
        str_opt = input()
        if str_opt != '':
            option_how = int(str_opt)
        else:
            option_how = 4
    if option_how == 1:
        affiliation_values = get_from_address(affiliation_values, 'institution')
    elif option_how == 2:
        affiliation_values = institution_manual_entry(affiliation_values)
    elif option_how == 3:
        affiliation_values = manual_split_address(affiliation_values)
    return affiliation_values

def manual_split_address(affiliation_values):
    opt_end = False
    while (opt_end == False):
        print(affiliation_values)
        missing_vals = {}
        int_idx = 1
        for an_element in affiliation_values:
            if affiliation_values[an_element] == "":
                missing_vals[int_idx] = an_element
                int_idx += 1
        print('Which element to get from string:')
        for an_idx in missing_vals:
            print(" ", an_idx, missing_vals[an_idx])
        print (" ", len(missing_vals)+1, 'end')
        print('Selection')
        option_sel = int(input())
        if option_sel == len(missing_vals)+1:
            opt_end = True
        elif option_sel > 0 and option_sel <= len(missing_vals):
            print("Try to extract ", missing_vals[option_sel])
            affiliation_values[missing_vals[option_sel]], affiliation_values['address'] = \
            get_from_string(affiliation_values['address'], missing_vals[option_sel])
    return affiliation_values
        
def get_from_string(string_value, element):
    element_value = ""
    print("************ get",element,"*************************")
    print("split and add this: ", string_value)
    element_value = extract_custom(string_value)
    string_value = string_value.replace(element_value,'')
    string_value = remove_extra_commas(string_value)
    return element_value, string_value

def get_from_address(affiliation_values, element): 
    affiliation_values[element], affiliation_values['address'] = \
      get_from_string(affiliation_values['address'], element)
    return affiliation_values

def institution_manual_entry(affiliation_values):
    print("*********** enter institution ************************")
    print("Provide institution for:", affiliation_values)            
    ins_str = input()
    affiliation_values['institution'] = ins_str
    return affiliation_values

def extract_custom(split_this):
    print(split_this)
    decimal_str = ""
    for indx in range(0, len(split_this)):
        val = " "
        if (indx % 10 == 0): val = str(int(indx/10)) 
        decimal_str += val
    print(decimal_str)
    unit_str = ""
    for indx in range(0, len(split_this)):
        val = str(indx%10)
        if (indx % 10 == 0): val = "0" 
        unit_str += val
    print(unit_str)
    print("start")
    str_start = int(input())
    print("end")
    str_end = int(input())
    return split_this[str_start:str_end+1]
    
def remove_extra_commas(str_this):
    str_this = str_this.replace(", ,", "")
    str_this = str_this.replace("; ;", "")
    str_this = str_this.replace(" ;", ";")
    str_this = str_this.strip()
    if len(str_this) == 0:
        return ""
    if str_this[0] in (",",";") : str_this = str_this[1:] 
    if str_this[-1:] in (",",";") : str_this = str_this[:-1] 
    return str_this.strip()

def split_single(affiliation_str):
    inst_str = dept_str = faculty_str = group_str = ctry_str = school_str = ""

    splitting_this = affiliation_str
    # lookup using institution synonyms table
    inst_str, splitting_this = str_has_synonym(splitting_this, institution_synonyms)
    # Lookup using list of institutions 
    if inst_str == "":
        inst_str, splitting_this = check_list(splitting_this,institutions_list)

    #  lookup using Country Synonyms table
    ctry_str, splitting_this = str_has_synonym(splitting_this, country_synonyms)
    #  lookup using Countries list        
    if ctry_str == "":
        ctry_str, splitting_this = check_list(splitting_this, countries_list)

    # Lookup using department list
    dept_str, splitting_this = check_list(splitting_this, department_list)

    # Lookup using school list
    school_str, splitting_this = check_list(splitting_this, school_list)

    # Lookup using faculty list
    faculty_str, splitting_this = check_list(splitting_this, faculty_list)
    
    # Lookup using group list
    group_str, splitting_this = check_list(splitting_this, group_list)
    
    splitting_this = remove_extra_commas(splitting_this)
    
    return {'institution':inst_str, 'school': school_str, 
            'department': dept_str, 'faculty': faculty_str, 
            'work_group': group_str, 'country': ctry_str, 'address':  splitting_this}

def get_affi_address(affiliation_id):
    return_val = 0
    add_id = db_conn.get_value("addresses", "id", "affiliation_id", affiliation_id)
    if  add_id == None or add_id == []:
        return_val = 0
    else:
        return_val = add_id[0]
    return return_val

def make_author_affiliation(art_aut_id, affi_values, addr_values):
    # get smallest unit
    smallest_unit = "" 
    #id Institution> Faculty > School > Department > Work_group + address + Country
    if affi_values[4] != None and  len(affi_values[4]) > 0: #'work_group'
        smallest_unit = affi_values[4]
    elif affi_values[2] != None and len(affi_values[2]) > 0 and smallest_unit == "": #'department'
        smallest_unit = affi_values[2]
    elif affi_values[9] != None and  len(affi_values[9]) > 0 and smallest_unit == "": #'school'
        smallest_unit = affi_values[9]
    elif affi_values[3] != None and len(affi_values[3]) > 0 and smallest_unit == "": #'faculty'
        smallest_unit = affi_values[3]
       
    ret_parsed = {}
    ret_parsed['article_author_id'] = art_aut_id
    if len(smallest_unit) > 0:
        ret_parsed['name'] = smallest_unit + ", "+  affi_values[1] #'institution'
    else:
        ret_parsed['name'] = affi_values[1]
    ret_parsed['short_name'] = affi_values[1]
    add_01 = ""
    if affi_values[3] != None and affi_values[3]  != "" and affi_values[3] != smallest_unit:
        add_01 = affi_values[3] 
    if affi_values[9] != None and affi_values[9] != "" and affi_values[9] != smallest_unit:
        if add_01 != "":
               add_01 += ", "+ affi_values[9]
        else:
               add_01 += affi_values[9]
    if affi_values[2] != None and affi_values[2] != "" and affi_values[2] != smallest_unit:
        if add_01 != "":
               add_01 += ", "+ affi_values[2]
        else:
               add_01 += affi_values[2]
    if add_01 != "":
        ret_parsed['add_01'] = add_01
        ret_parsed['add_02'] = addr_values[1] 
        ret_parsed['add_03'] = addr_values[2]
        ret_parsed['add_04'] = addr_values[3]
        ret_parsed['add_05'] = addr_values[4]
    else:
        ret_parsed['add_01'] = addr_values[1]
        ret_parsed['add_02'] = addr_values[2] 
        ret_parsed['add_03'] = addr_values[3]
        ret_parsed['add_04'] = addr_values[4]
        
    ret_parsed['country'] = addr_values[5]
    ret_parsed['affiliation_id'] = affi_values[0]
    ret_parsed['created_at'] = datetime.today().strftime('%Y-%m-%d %H:%M:%S')
    ret_parsed['updated_at'] = ret_parsed['created_at'] 
    return ret_parsed


def add_author_affiliation(art_aut_id, affi_id, add_id):
    print("Arguments",art_aut_id, affi_id, add_id)
    affiliation_row = list(db_conn.get_row("affiliations", affi_id))[0]
    address_row = list(db_conn.get_row("addresses", add_id))[0]
    print("Affiliation values", affiliation_row)
    print("Address values", address_row )
    new_aut_affi = make_author_affiliation(art_aut_id, affiliation_row, address_row)
    new_aa_id = db_conn.put_values_table("author_affiliations", new_aut_affi.keys(), new_aut_affi.values())
    return new_aa_id

def add_address(addr_str, affi_id, ctry_str):
    add_update_time = datetime.today().strftime('%Y-%m-%d %H:%M:%S')
    affi_address = {'add_01':addr_str,"affiliation_id":affi_id,'country':ctry_str,
                    'created_at': add_update_time, 'updated_at':add_update_time}
    add_id = db_conn.put_values_table("addresses", affi_address.keys(), affi_address.values())
    return add_id

def add_affiliation(affi_values):
    add_update_time = datetime.today().strftime('%Y-%m-%d %H:%M:%S')
    affiliation_new = affi_values
    del affiliation_new['address']
    if 'address' in affiliation_new.keys():
        del affiliation_new['address']
    if 'num' in affiliation_new.keys():
        del affiliation_new['num']
    affiliation_new['created_at'] = add_update_time
    affiliation_new['updated_at'] = add_update_time
    affiliation_id = db_conn.put_values_table("affiliations", affiliation_new.keys(), affiliation_new.values())
    return affiliation_id
    
def affiliation_exists(affi_values):
    qry_where = ""
    affi_id = add_id = 0
    if affi_values['institution'] != "":
        qry_where += "institution = \"" + affi_values['institution'] + "\""
    if affi_values['department'] != "":
        qry_where += " AND department = '" + affi_values['department'] + "'"
    if affi_values['faculty'] != "":
        qry_where += " AND faculty = '" + affi_values['faculty'] + "'"
    if affi_values['work_group'] != "":
        qry_where += " AND work_group = '" + affi_values['work_group'] + "'"
    if affi_values['school'] != "":
        qry_where += " AND school = '" + affi_values['school'] + "'"
    if affi_values['country'] != "":
        qry_where += " AND country = '" + affi_values['country'] + "'"
    
    if (qry_where[0:4] == " AND"):
        qry_where= qry_where[4:]
    print("Query:", qry_where)    
    if qry_where == "":
        return 0,0
    
    result = db_conn.get_values("affiliations","id",qry_where)
    if result != []:
        affi_id = result[0][0]
        add_id = get_affi_address(affi_id)
    return affi_id, add_id

def update_cr_affiliation(cr_affi_id, aut_affi_id):
    db_conn.set_value_table('cr_affiliations', cr_affi_id, 'author_affiliation_id', aut_affi_id)


def get_flat_list(comp_list):
    flat_list = []
    for sublist in comp_list:
            for item in sublist:
                flat_list.append(item)
    return flat_list

def aut_ids_unmapped_cr_affiliations():
    aut_affi_ids = db_conn.get_values('cr_affiliations', 'article_author_id',
                                      'NOT author_affiliation_id is NULL GROUP BY article_author_id')# HAVING count() = 1')
    return get_flat_list(aut_affi_ids)

# %% [markdown]
# # process affiliations in single strings >>

# %%
#refresh_lists()
# this part runs OK on single affi strings
aut_affi_ids = db_conn.get_values('cr_affiliations', 'article_author_id',
                                  'author_affiliation_id is NULL')
flat_list = []
for sublist in aut_affi_ids:
    for item in sublist:
        flat_list.append(item)

i_idx = 0
aut_affi_ids = get_flat_list(aut_affi_ids)
for aut_afi_id in aut_affi_ids:
    non_parsed_affis = db_conn.get_values('cr_affiliations', 'name', 'article_author_id = '+ str(aut_afi_id) +\
                                          ' and author_affiliation_id is NULL')
    non_parsed_cr_affi_ids = db_conn.get_values('cr_affiliations', 'id', 'article_author_id = '+ str(aut_afi_id)+\
                                          ' and author_affiliation_id is NULL')
    if len(non_parsed_affis) == 1:
        cr_affi_id = non_parsed_cr_affi_ids[0][0]
        process_single_affi(cr_affi_id, aut_afi_id, non_parsed_affis[0][0].replace('\r',' '))

# %%
# add manually parsed affis >>

# %%
# add manually parsed affis
csv_affis = '../mcc_data/new_affis.csv'
affi_data, cols= csvh.get_csv_data(csv_affis, 'num')
for an_affi  in affi_data:
    print (affi_data[an_affi])
    affiliation_id, address_id = affiliation_exists(affi_data[an_affi])
    if affiliation_id !=0 and address_id != 0:
        print("* Affiliation found in DB id:", affiliation_id, "Address:", address_id)
        print('* Add ')
    elif affiliation_id !=0 and address_id == 0:
        print("* Affiliation found in DB id:", affiliation_id, "Need to add address:", affi_data[an_affi]['address'])
        address_id = add_address(affi_data[an_affi]['address'], affiliation_id, affi_data[an_affi]['country'])
        print("* Added address:", affi_data[an_affi]['address'], "ID:", address_id)
    else:
        print("* Need to add affiliation and address")
        print ('* Try to add affi for', affi_data[an_affi])
        address_string = affi_data[an_affi]['address']
        affiliation_id = add_affiliation(affi_data[an_affi])
        # renew lists as new affi is added
        #refresh_lists(affi_values)
        address_id = add_address(address_string, affiliation_id, affi_data[an_affi]['country'])
        #print ('* Added affiliation and address', affiliation_id, address_id)
# Out:
# {'num': '1', 'institution': 'Advanced Light Source', 'department': '', 'faculty': '', 'work_group': '', 'country': 'United States of America', 'sector': 'Research Facility', 'school': '', 'address': 'Lawrence Berkeley National Laboratory, Berkeley, California 94720'}
# Query: institution = "Advanced Light Source" AND country = 'United States of America'
# * Affiliation found in DB id: 564 Address: 191
# * Add
# {'num': '2', 'institution': 'Aix-Marseille Université CNRS', 'department': '', 'faculty': '', 'work_group': '', 'country': 'France', 'sector': 'Academia', 'school': '', 'address': 'IM2NP UMR 7334, 13397 Marseille'}
# Query: institution = "Aix-Marseille Université CNRS" AND country = 'France'
# * Affiliation found in DB id: 565 Address: 192
# * Add
# {'num': '3', 'institution': 'ALISTORE European Research Institute', 'department': '', 'faculty': '', 'work_group': '', 'country': 'France', 'sector': 'Research Facility', 'school': '', 'address': 'FR CNRS 3104, 80039 Cedex Amiens'}
# Query: institution = "ALISTORE European Research Institute" AND country = 'France'
# * Affiliation found in DB id: 367 Address: 193
# * Add
# {'num': '4', 'institution': 'American Museum of Natural History', 'department': 'Department of Mammalogy', 'faculty': '', 'work_group': '', 'country': 'United States of America', 'sector': 'Research Facility', 'school': '', 'address': 'New York'}
# Query: institution = "American Museum of Natural History" AND department = 'Department of Mammalogy' AND country = 'United States of America'
# * Affiliation found in DB id: 566 Address: 194
# * Add
# {'num': '5', 'institution': 'Applied Materials Inc.', 'department': '', 'faculty': '', 'work_group': '', 'country': 'United States of America', 'sector': 'Industry', 'school': '', 'address': '3225 Oakmead Village Drive, M/S 1240, P.O. Box 58039, Santa Clara, California 95052-8039'}
# Query: institution = "Applied Materials Inc." AND country = 'United States of America'
# * Affiliation found in DB id: 567 Address: 195
# * Add
# {'num': '6', 'institution': 'Luleå University of Technology', 'department': 'Department of Engineering Sciences and Mathematics', 'faculty': '', 'work_group': 'Division of Materials Science', 'country': 'Sweden', 'sector': 'Academia', 'school': '', 'address': 'Applied Physics, SE-971 87 Luleå'}
# Query: institution = "Luleå University of Technology" AND department = 'Department of Engineering Sciences and Mathematics' AND work_group = 'Division of Materials Science' AND country = 'Sweden'
# * Affiliation found in DB id: 568 Address: 196
# * Add
# {'num': '7', 'institution': 'Argonne National Laboratory', 'department': '', 'faculty': '', 'work_group': 'Chemical Science and Engineering Division', 'country': 'United States of America', 'sector': 'Research Facility', 'school': '', 'address': '9700 South Cass Avenue, Argonne, Illinois 60439'}
# Query: institution = "Argonne National Laboratory" AND work_group = 'Chemical Science and Engineering Division' AND country = 'United States of America'
# * Affiliation found in DB id: 569 Address: 197
# * Add
# {'num': '8', 'institution': 'Argonne National Laboratory', 'department': '', 'faculty': '', 'work_group': 'X-ray Science Division', 'country': 'United States of America', 'sector': 'Research Facility', 'school': '', 'address': '9700 South Cass Avenue, Argonne, Illinois 60439'}
# Query: institution = "Argonne National Laboratory" AND work_group = 'X-ray Science Division' AND country = 'United States of America'
# * Affiliation found in DB id: 570 Address: 198
# * Add
# {'num': '9', 'institution': 'Argonne National Laboratory', 'department': '', 'faculty': '', 'work_group': 'X-ray Science Division', 'country': 'United States of America', 'sector': 'Research Facility', 'school': '', 'address': 'Advanced Photon Source, Argonne, Illinois 60439'}
# Query: institution = "Argonne National Laboratory" AND work_group = 'X-ray Science Division' AND country = 'United States of America'
# * Affiliation found in DB id: 570 Address: 198
# * Add
# {'num': '10', 'institution': 'Arizona State University', 'department': '', 'faculty': '', 'work_group': 'Institute of Human Origins', 'country': 'United States of America', 'sector': 'Academia', 'school': '', 'address': 'SHESC, Tempe'}
# Query: institution = "Arizona State University" AND work_group = 'Institute of Human Origins' AND country = 'United States of America'
# * Affiliation found in DB id: 571 Address: 199
# * Add
# {'num': '11', 'institution': 'AWE Public Limited Company', 'department': '', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Industry', 'school': '', 'address': 'Aldermaston, Reading RG7 4PR'}
# Query: institution = "AWE Public Limited Company" AND country = 'United Kingdom'
# * Affiliation found in DB id: 1075 Address: 457
# * Add
# {'num': '12', 'institution': 'Bangor University', 'department': '', 'faculty': '', 'work_group': 'Molecular Ecology and Fisheries Genetics Laboratory', 'country': 'United Kingdom', 'sector': 'Academia', 'school': 'School of Biological Sciences', 'address': 'Bangor'}
# Query: institution = "Bangor University" AND work_group = 'Molecular Ecology and Fisheries Genetics Laboratory' AND school = 'School of Biological Sciences' AND country = 'United Kingdom'
# * Affiliation found in DB id: 573 Address: 201
# * Add
# {'num': '13', 'institution': 'Bauman Moscow State Technical University—Kaluga Branch', 'department': '', 'faculty': '', 'work_group': '', 'country': 'Russia', 'sector': 'Academia', 'school': '', 'address': '248000 Kaluga, Moscow obl.'}
# Query: institution = "Bauman Moscow State Technical University—Kaluga Branch" AND country = 'Russia'
# * Affiliation found in DB id: 574 Address: 202
# * Add
# {'num': '14', 'institution': 'Ben-Gurion University of the Negev', 'department': 'Department of Chemistry', 'faculty': '', 'work_group': '', 'country': 'Israel', 'sector': 'Academia', 'school': '', 'address': 'Beer Sheva'}
# Query: institution = "Ben-Gurion University of the Negev" AND department = 'Department of Chemistry' AND country = 'Israel'
# * Affiliation found in DB id: 575 Address: 203
# * Add
# {'num': '15', 'institution': 'Binghamton University', 'department': 'Department of Physics', 'faculty': '', 'work_group': 'Applied Physics and Astronomy', 'country': 'United States of America', 'sector': 'Academia', 'school': '', 'address': 'Binghamton, New York 13902'}
# Query: institution = "Binghamton University" AND department = 'Department of Physics' AND work_group = 'Applied Physics and Astronomy' AND country = 'United States of America'
# * Affiliation found in DB id: 576 Address: 204
# * Add
# {'num': '16', 'institution': 'Binghamton University', 'department': '', 'faculty': '', 'work_group': 'Materials Science & Engineering', 'country': 'United States of America', 'sector': 'Academia', 'school': '', 'address': 'Binghamton, New York 13902'}
# Query: institution = "Binghamton University" AND work_group = 'Materials Science & Engineering' AND country = 'United States of America'
# * Affiliation found in DB id: 577 Address: 205
# * Add
# {'num': '17', 'institution': 'Brazilian Nanotechnology National Laboratory (LNNano)/CNPEM', 'department': '', 'faculty': '', 'work_group': '', 'country': 'Brazil', 'sector': 'Research Facility', 'school': '', 'address': 'Campinas, São Paulo'}
# Query: institution = "Brazilian Nanotechnology National Laboratory (LNNano)/CNPEM" AND country = 'Brazil'
# * Affiliation found in DB id: 578 Address: 206
# * Add
# {'num': '18', 'institution': 'Cardiff University', 'department': '', 'faculty': '', 'work_group': 'Cardiff Catalysis Institute', 'country': 'United Kingdom', 'sector': 'Academia', 'school': 'School of Chemistry', 'address': 'Main Building, Park Place, Cardiff CF10 3AT'}
# Query: institution = "Cardiff University" AND work_group = 'Cardiff Catalysis Institute' AND school = 'School of Chemistry' AND country = 'United Kingdom'
# * Affiliation found in DB id: 5 Address: 207
# * Add
# {'num': '19', 'institution': 'Cardiff University', 'department': '', 'faculty': '', 'work_group': 'Cardiff Catalysis Institute', 'country': 'United Kingdom', 'sector': 'Academia', 'school': 'School of Chemistry', 'address': 'Main Building, Park Place Cardiff CF10 3AT UK'}
# Query: institution = "Cardiff University" AND work_group = 'Cardiff Catalysis Institute' AND school = 'School of Chemistry' AND country = 'United Kingdom'
# * Affiliation found in DB id: 5 Address: 207
# * Add
# {'num': '20', 'institution': 'Cardiff University', 'department': '', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Academia', 'school': 'School of Chemistry', 'address': 'Cardiff CF10 3AT'}
# Query: institution = "Cardiff University" AND school = 'School of Chemistry' AND country = 'United Kingdom'
# * Affiliation found in DB id: 5 Address: 207
# * Add
# {'num': '21', 'institution': 'Cardiff University', 'department': '', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Academia', 'school': 'School of Chemistry', 'address': 'Main Building, Park Place, Cardiff CF10 3AT'}
# Query: institution = "Cardiff University" AND school = 'School of Chemistry' AND country = 'United Kingdom'
# * Affiliation found in DB id: 5 Address: 207
# * Add
# {'num': '22', 'institution': 'Cardiff University', 'department': '', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Academia', 'school': 'School of Chemistry', 'address': 'Main Building, Park Place, Cardiff, CF10 3AT'}
# Query: institution = "Cardiff University" AND school = 'School of Chemistry' AND country = 'United Kingdom'
# * Affiliation found in DB id: 5 Address: 207
# * Add
# {'num': '23', 'institution': 'Cardiff University', 'department': '', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Academia', 'school': 'School of Chemistry', 'address': 'Cardiff CF10 3AT'}
# Query: institution = "Cardiff University" AND school = 'School of Chemistry' AND country = 'United Kingdom'
# * Affiliation found in DB id: 5 Address: 207
# * Add
# {'num': '24', 'institution': 'Cardiff University', 'department': '', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Academia', 'school': 'School of Chemistry', 'address': 'Main Building Park Place, Cardiff CF10 3AT'}
# Query: institution = "Cardiff University" AND school = 'School of Chemistry' AND country = 'United Kingdom'
# * Affiliation found in DB id: 5 Address: 207
# * Add
# {'num': '25', 'institution': 'Cardiff University', 'department': '', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Academia', 'school': 'School of Chemistry', 'address': 'Main Building, Park Place, Cardiff CF10 3AT'}
# Query: institution = "Cardiff University" AND school = 'School of Chemistry' AND country = 'United Kingdom'
# * Affiliation found in DB id: 5 Address: 207
# * Add
# {'num': '26', 'institution': 'Cardiff University', 'department': '', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Academia', 'school': 'School of Chemistry', 'address': 'Main Building, Park Place, Cardiff CF10 3AT'}
# Query: institution = "Cardiff University" AND school = 'School of Chemistry' AND country = 'United Kingdom'
# * Affiliation found in DB id: 5 Address: 207
# * Add
# {'num': '27', 'institution': 'Cardiff University', 'department': '', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Academia', 'school': 'School of Engineering', 'address': 'Cardiff CF24 3AA'}
# Query: institution = "Cardiff University" AND school = 'School of Engineering' AND country = 'United Kingdom'
# * Affiliation found in DB id: 579 Address: 208
# * Add
# {'num': '28', 'institution': 'Cardinal Stefan Wyszyński University', 'department': '', 'faculty': 'Faculty of Mathematics and Natural Sciences', 'work_group': '', 'country': 'Poland', 'sector': 'Academia', 'school': 'College of Science', 'address': 'Dewajtis 5, 01-815 Warsaw'}
# Query: institution = "Cardinal Stefan Wyszyński University" AND faculty = 'Faculty of Mathematics and Natural Sciences' AND school = 'College of Science' AND country = 'Poland'
# * Affiliation found in DB id: 580 Address: 209
# * Add
# {'num': '29', 'institution': 'Cardinal Stefan Wyszyński University', 'department': '', 'faculty': 'Faculty of Mathematics and Natural Sciences', 'work_group': '', 'country': 'Poland', 'sector': 'Academia', 'school': 'College of Science', 'address': 'Dewajtis 5, Warsaw 01-815'}
# Query: institution = "Cardinal Stefan Wyszyński University" AND faculty = 'Faculty of Mathematics and Natural Sciences' AND school = 'College of Science' AND country = 'Poland'
# * Affiliation found in DB id: 580 Address: 209
# * Add
# {'num': '30', 'institution': 'CAS Center for Excellence in Deep Earth Science', 'department': '', 'faculty': '', 'work_group': '', 'country': 'Peoples Republic of China', 'sector': 'Research Facility', 'school': '', 'address': 'Guangzhou, 510640'}
# Query: institution = "CAS Center for Excellence in Deep Earth Science" AND country = 'Peoples Republic of China'
# * Affiliation found in DB id: 1076 Address: 458
# * Add
# {'num': '31', 'institution': 'Catalonia Institute for Energy Research (IREC)', 'department': '', 'faculty': '', 'work_group': '', 'country': 'Spain', 'sector': 'Research Facility', 'school': '', 'address': 'Jardins de les Dones de Negre 1, 08930 Sant Adria de Besos'}
# Query: institution = "Catalonia Institute for Energy Research (IREC)" AND country = 'Spain'
# * Affiliation found in DB id: 582 Address: 211
# * Add
# {'num': '32', 'institution': 'Central South University', 'department': '', 'faculty': '', 'work_group': '', 'country': 'Peoples Republic of China', 'sector': 'Academia', 'school': 'College of Chemistry & Chemical Engineering', 'address': 'Changsha 410083'}
# Query: institution = "Central South University" AND school = 'College of Chemistry & Chemical Engineering' AND country = 'Peoples Republic of China'
# * Affiliation found in DB id: 583 Address: 212
# * Add
# {'num': '33', 'institution': 'Chalmers University of Technology', 'department': 'Department of Applied Physics', 'faculty': '', 'work_group': '', 'country': 'Sweden', 'sector': 'Academia', 'school': '', 'address': 'Göteborg, SE-41296'}
# Query: institution = "Chalmers University of Technology" AND department = 'Department of Applied Physics' AND country = 'Sweden'
# * Affiliation found in DB id: 584 Address: 213
# * Add
# {'num': '34', 'institution': 'Chalmers University of Technology', 'department': 'Department of Physics', 'faculty': '', 'work_group': '', 'country': 'Sweden', 'sector': 'Academia', 'school': '', 'address': 'SE 41296 Göteborg'}
# Query: institution = "Chalmers University of Technology" AND department = 'Department of Physics' AND country = 'Sweden'
# * Affiliation found in DB id: 585 Address: 214
# * Add
# {'num': '35', 'institution': 'Chiba University', 'department': '', 'faculty': '', 'work_group': '', 'country': 'Japan', 'sector': 'Academia', 'school': 'Graduate School of Science and Engineering', 'address': 'Chiba'}
# Query: institution = "Chiba University" AND school = 'Graduate School of Science and Engineering' AND country = 'Japan'
# * Affiliation found in DB id: 586 Address: 215
# * Add
# {'num': '36', 'institution': 'CNRS-Université Paris Est', 'department': '', 'faculty': '', 'work_group': 'Institut de Chimie et des Matériaux Paris-Est', 'country': 'France', 'sector': 'Academia', 'school': '', 'address': 'GESMAT, UMR 7182, 2 rue Henri Dunant, 94320 Thiais'}
# Query: institution = "CNRS-Université Paris Est" AND work_group = 'Institut de Chimie et des Matériaux Paris-Est' AND country = 'France'
# * Affiliation found in DB id: 587 Address: 216
# * Add
# {'num': '37', 'institution': 'Colorado State University', 'department': 'Department of Chemistry', 'faculty': '', 'work_group': '', 'country': 'United States of America', 'sector': 'Academia', 'school': '', 'address': 'Fort Collins, Colorado 80523-1872'}
# Query: institution = "Colorado State University" AND department = 'Department of Chemistry' AND country = 'United States of America'
# * Affiliation found in DB id: 588 Address: 217
# * Add
# {'num': '38', 'institution': 'Complutense University of Madrid', 'department': 'Department of Prehistory', 'faculty': '', 'work_group': '', 'country': 'Spain', 'sector': 'Academia', 'school': '', 'address': 'Madrid'}
# Query: institution = "Complutense University of Madrid" AND department = 'Department of Prehistory' AND country = 'Spain'
# * Affiliation found in DB id: 1077 Address: 459
# * Add
# {'num': '39', 'institution': 'Cornell University', 'department': '', 'faculty': '', 'work_group': 'Cornell High Energy Synchrotron Source (CHESS)', 'country': 'United States of America', 'sector': 'Academia', 'school': '', 'address': 'Wilson Laboratory, Ithaca, New York 14853'}
# Query: institution = "Cornell University" AND work_group = 'Cornell High Energy Synchrotron Source (CHESS)' AND country = 'United States of America'
# * Affiliation found in DB id: 590 Address: 219
# * Add
# {'num': '40', 'institution': 'Curtin University', 'department': 'Department of Chemistry', 'faculty': '', 'work_group': 'Curtin Institute for Computation', 'country': 'Australia', 'sector': 'Academia', 'school': '', 'address': 'The Institute for Geoscience Research (TIGeR), P.O. Box U1987, Perth, WA 6845'}
# Query: institution = "Curtin University" AND department = 'Department of Chemistry' AND work_group = 'Curtin Institute for Computation' AND country = 'Australia'
# * Affiliation found in DB id: 591 Address: 220
# * Add
# {'num': '41', 'institution': 'Dalhousie University', 'department': 'Department of Chemistry', 'faculty': '', 'work_group': '', 'country': 'Canada', 'sector': 'Academia', 'school': '', 'address': 'Halifax, Nova Scotia B3H 4R2'}
# Query: institution = "Dalhousie University" AND department = 'Department of Chemistry' AND country = 'Canada'
# * Affiliation found in DB id: 592 Address: 221
# * Add
# {'num': '42', 'institution': 'Daresbury Laboratory', 'department': '', 'faculty': '', 'work_group': 'Daresbury', 'country': 'United Kingdom', 'sector': 'Research Facility', 'school': '', 'address': 'Warrington, WA4 4AD'}
# Query: institution = "Daresbury Laboratory" AND work_group = 'Daresbury' AND country = 'United Kingdom'
# * Affiliation found in DB id: 1078 Address: 460
# * Add
# {'num': '43', 'institution': 'Diamond Light Source', 'department': '', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Research Facility', 'school': '', 'address': 'Harwell Science and Innovation Campus, Didcot OX11 0QX'}
# Query: institution = "Diamond Light Source" AND country = 'United Kingdom'
# * Affiliation found in DB id: 1079 Address: 461
# * Add
# {'num': '44', 'institution': 'East China Normal University', 'department': '', 'faculty': '', 'work_group': 'Key Laboratory of Polar Materials and Devices (MOE)', 'country': 'Peoples Republic of China', 'sector': 'Academia', 'school': '', 'address': 'Shanghai 200241 (China)'}
# Query: institution = "East China Normal University" AND work_group = 'Key Laboratory of Polar Materials and Devices (MOE)' AND country = 'Peoples Republic of China'
# * Affiliation found in DB id: 595 Address: 224
# * Add
# {'num': '45', 'institution': 'Ecole Polytechnique Federale de Lausanne', 'department': '', 'faculty': '', 'work_group': 'Laboratory of Computational Science and Modeling', 'country': 'Switzerland', 'sector': 'Academia', 'school': '', 'address': 'Institute des Materiaux CH-1015 Lausanne'}
# Query: institution = "Ecole Polytechnique Federale de Lausanne" AND work_group = 'Laboratory of Computational Science and Modeling' AND country = 'Switzerland'
# * Affiliation found in DB id: 596 Address: 225
# * Add
# {'num': '46', 'institution': 'Ecole Polytechnique Fédérale de Lausanne (EPFL)', 'department': '', 'faculty': '', 'work_group': 'Laboratory of Computational Science and Modeling (COSMO)', 'country': 'Switzerland', 'sector': 'Academia', 'school': '', 'address': 'Institute of Materials, Lausanne, 1015'}
# Query: institution = "Ecole Polytechnique Fédérale de Lausanne (EPFL)" AND work_group = 'Laboratory of Computational Science and Modeling (COSMO)' AND country = 'Switzerland'
# * Affiliation found in DB id: 1080 Address: 462
# * Add
# {'num': '47', 'institution': 'Elettra - Sincrotrone Trieste S.C.p.A.', 'department': '', 'faculty': '', 'work_group': '', 'country': 'Italy', 'sector': 'Research Facility', 'school': '', 'address': '34149 Trieste'}
# Query: institution = "Elettra - Sincrotrone Trieste S.C.p.A." AND country = 'Italy'
# * Affiliation found in DB id: 1081 Address: 463
# * Add
# {'num': '48', 'institution': 'Elettra-Sincrotrone Trieste S.C.p.A.', 'department': '', 'faculty': '', 'work_group': '', 'country': 'Italy', 'sector': 'Research Facility', 'school': '', 'address': 'Strada Statale 14 Km 163.5, 34149 Trieste'}
# Query: institution = "Elettra-Sincrotrone Trieste S.C.p.A." AND country = 'Italy'
# * Affiliation found in DB id: 598 Address: 227
# * Add
# {'num': '49', 'institution': 'Empa − Swiss Federal Laboratories for Materials Science and Technology', 'department': '', 'faculty': '', 'work_group': 'Laboratory for Thin Films and Photovoltaics', 'country': 'Switzerland', 'sector': 'Research Facility', 'school': '', 'address': 'Überlandstrasse 129, CH-8600 Dübendorf'}
# Query: institution = "Empa − Swiss Federal Laboratories for Materials Science and Technology" AND work_group = 'Laboratory for Thin Films and Photovoltaics' AND country = 'Switzerland'
# * Affiliation found in DB id: 1082 Address: 464
# * Add
# {'num': '50', 'institution': 'ETH Zürich', 'department': 'Department of Chemistry and Applied Biosciences', 'faculty': '', 'work_group': 'Institute of Inorganic Chemistry', 'country': 'Switzerland', 'sector': 'Academia', 'school': '', 'address': 'Vladimir Prelog Weg 1, CH-8093 Zürich'}
# Query: institution = "ETH Zürich" AND department = 'Department of Chemistry and Applied Biosciences' AND work_group = 'Institute of Inorganic Chemistry' AND country = 'Switzerland'
# * Affiliation found in DB id: 601 Address: 230
# * Add
# {'num': '51', 'institution': 'European Synchrotron Radiation Facility', 'department': '', 'faculty': '', 'work_group': '', 'country': 'France', 'sector': 'Research Facility', 'school': '', 'address': 'BP220, Grenoble F38043'}
# Query: institution = "European Synchrotron Radiation Facility" AND country = 'France'
# * Affiliation found in DB id: 337 Address: 465
# * Add
# {'num': '52', 'institution': 'ExxonMobil', 'department': '', 'faculty': '', 'work_group': '', 'country': 'United States of America', 'sector': 'Industry', 'school': '', 'address': 'Research & Engineering Company, 1545 Route 22 East Annandale New Jersey 08801'}
# Query: institution = "ExxonMobil" AND country = 'United States of America'
# * Affiliation found in DB id: 603 Address: 232
# * Add
# {'num': '53', 'institution': 'Friedrich-Alexander University Erlangen-Nürnberg', 'department': 'Department of Chemistry and Pharmacy', 'faculty': '', 'work_group': '', 'country': 'Germany', 'sector': 'Academia', 'school': '', 'address': 'Egerlandstrasse 1, 91058 Erlangen'}
# Query: institution = "Friedrich-Alexander University Erlangen-Nürnberg" AND department = 'Department of Chemistry and Pharmacy' AND country = 'Germany'
# * Affiliation found in DB id: 1083 Address: 466
# * Add
# {'num': '54', 'institution': 'Friedrich-Alexander-Universität Erlangen-Nürnberg', 'department': '', 'faculty': '', 'work_group': 'Interdisciplinary Center for Molecular Materials (ICMM) and Computer-Chemistry-Center (CCC)', 'country': 'Germany', 'sector': 'Academia', 'school': '', 'address': 'Nägelsbachstraße 25, 91052 Erlangen'}
# Query: institution = "Friedrich-Alexander-Universität Erlangen-Nürnberg" AND work_group = 'Interdisciplinary Center for Molecular Materials (ICMM) and Computer-Chemistry-Center (CCC)' AND country = 'Germany'
# * Affiliation found in DB id: 605 Address: 234
# * Add
# {'num': '55', 'institution': 'Fritz Haber Institute of the Max-Planck Society', 'department': '', 'faculty': '', 'work_group': '', 'country': 'Germany', 'sector': 'Academia', 'school': '', 'address': '14195 Berlin'}
# Query: institution = "Fritz Haber Institute of the Max-Planck Society" AND country = 'Germany'
# * Affiliation found in DB id: 1084 Address: 467
# * Add
# {'num': '56', 'institution': 'Fritz-Haber Institute of the Max-Planck Society', 'department': 'Department of Physical Chemistry', 'faculty': '', 'work_group': '', 'country': 'Germany', 'sector': 'Academia', 'school': '', 'address': 'Faradayweg 4-6, 14195 Berlin'}
# Query: institution = "Fritz-Haber Institute of the Max-Planck Society" AND department = 'Department of Physical Chemistry' AND country = 'Germany'
# * Affiliation found in DB id: 1085 Address: 468
# * Add
# {'num': '57', 'institution': 'Fritz-Haber Institute of the Max-Planck Society', 'department': 'Department of Physical Chemistry', 'faculty': '', 'work_group': '', 'country': 'Germany', 'sector': 'Academia', 'school': '', 'address': 'Faradayweg 4-6, Berlin 14195'}
# Query: institution = "Fritz-Haber Institute of the Max-Planck Society" AND department = 'Department of Physical Chemistry' AND country = 'Germany'
# * Affiliation found in DB id: 1085 Address: 468
# * Add
# {'num': '58', 'institution': 'Fritz-Haber Institute of the Max-Planck Society', 'department': 'Theory Department', 'faculty': '', 'work_group': '', 'country': 'Germany', 'sector': 'Academia', 'school': '', 'address': 'Faradayweg 4-6, 14195 Berlin'}
# Query: institution = "Fritz-Haber Institute of the Max-Planck Society" AND department = 'Theory Department' AND country = 'Germany'
# * Affiliation found in DB id: 1086 Address: 469
# * Add
# {'num': '59', 'institution': 'Fudan University', 'department': '', 'faculty': '', 'work_group': 'Key Laboratory for Computational Physical Sciences (MOE) and Surface Physics Laboratory', 'country': 'Peoples Republic of China', 'sector': 'Academia', 'school': '', 'address': 'Shanghai 200433 (China)'}
# Query: institution = "Fudan University" AND work_group = 'Key Laboratory for Computational Physical Sciences (MOE) and Surface Physics Laboratory' AND country = 'Peoples Republic of China'
# * Affiliation found in DB id: 608 Address: 237
# * Add
# {'num': '60', 'institution': 'Graz University of Technology', 'department': '', 'faculty': '', 'work_group': 'Institute of Experimental Physics', 'country': 'Austria', 'sector': 'Academia', 'school': '', 'address': 'Petersgasse 16, 8010 Graz'}
# Query: institution = "Graz University of Technology" AND work_group = 'Institute of Experimental Physics' AND country = 'Austria'
# * Affiliation found in DB id: 609 Address: 238
# * Add
# {'num': '61', 'institution': 'Graz University of Technology', 'department': '', 'faculty': '', 'work_group': 'Institute of Solid State Physics', 'country': 'Austria', 'sector': 'Academia', 'school': '', 'address': 'Petersgasse 16, 8010 Graz'}
# Query: institution = "Graz University of Technology" AND work_group = 'Institute of Solid State Physics' AND country = 'Austria'
# * Affiliation found in DB id: 610 Address: 239
# * Add
# {'num': '62', 'institution': 'Graz University of Technology', 'department': '', 'faculty': '', 'work_group': 'Institute of Solid State Physics–', 'country': 'Austria', 'sector': 'Academia', 'school': '', 'address': 'Petersgasse 16, 8010 Graz'}
# Query: institution = "Graz University of Technology" AND work_group = 'Institute of Solid State Physics–' AND country = 'Austria'
# * Affiliation found in DB id: 611 Address: 240
# * Add
# {'num': '63', 'institution': 'Guangdong Institute of Eco-environmental Science and Technology', 'department': '', 'faculty': '', 'work_group': 'Guangdong Key Laboratory of Integrated Agro-environmental Pollution Control and Management', 'country': 'Peoples Republic of China', 'sector': 'Academia', 'school': '', 'address': 'Guangzhou 510650'}
# Query: institution = "Guangdong Institute of Eco-environmental Science and Technology" AND work_group = 'Guangdong Key Laboratory of Integrated Agro-environmental Pollution Control and Management' AND country = 'Peoples Republic of China'
# * Affiliation found in DB id: 612 Address: 241
# * Add
# {'num': '64', 'institution': 'Guangzhou Institute of Geochemistry', 'department': '', 'faculty': '', 'work_group': 'CAS Key Laboratory of Mineralogy and Metallogeny/Guangdong Provincial Key Laboratory of Mineral Physics and Material Research and Development', 'country': 'Peoples Republic of China', 'sector': 'Academia', 'school': '', 'address': 'Chinese Academy of Sciences, Guangzhou 510640'}
# Query: institution = "Guangzhou Institute of Geochemistry" AND work_group = 'CAS Key Laboratory of Mineralogy and Metallogeny/Guangdong Provincial Key Laboratory of Mineral Physics and Material Research and Development' AND country = 'Peoples Republic of China'
# * Affiliation found in DB id: 613 Address: 242
# * Add
# {'num': '65', 'institution': 'Harbin Institute of Technology', 'department': 'Department of Physics', 'faculty': '', 'work_group': '', 'country': 'Peoples Republic of China', 'sector': 'Academia', 'school': '', 'address': 'Harbin 15000'}
# Query: institution = "Harbin Institute of Technology" AND department = 'Department of Physics' AND country = 'Peoples Republic of China'
# * Affiliation found in DB id: 502 Address: 100
# * Add
# {'num': '66', 'institution': 'HH Wills Physics Laboratory', 'department': '', 'faculty': '', 'work_group': 'Centre for Doctoral Training in Condensed Matter Physics', 'country': 'United Kingdom', 'sector': 'Academia', 'school': '', 'address': 'Tyndall Avenue, Bristol BS8 1TL'}
# Query: institution = "HH Wills Physics Laboratory" AND work_group = 'Centre for Doctoral Training in Condensed Matter Physics' AND country = 'United Kingdom'
# * Affiliation found in DB id: 614 Address: 243
# * Add
# {'num': '67', 'institution': 'Hokkaido University', 'department': '', 'faculty': '', 'work_group': '', 'country': 'Japan', 'sector': 'Academia', 'school': 'Graduate School of Engineering', 'address': 'N-13, W-8, Sapporo 060-8628'}
# Query: institution = "Hokkaido University" AND school = 'Graduate School of Engineering' AND country = 'Japan'
# * Affiliation found in DB id: 615 Address: 244
# * Add
# {'num': '68', 'institution': 'Hokkaido University', 'department': '', 'faculty': 'Faculty of Environmental Earth Science', 'work_group': '', 'country': 'Japan', 'sector': 'Academia', 'school': '', 'address': 'Nishi 5, Kita 10, Kita-ku, Sapporo 060-0810'}
# Query: institution = "Hokkaido University" AND faculty = 'Faculty of Environmental Earth Science' AND country = 'Japan'
# * Affiliation found in DB id: 616 Address: 245
# * Add
# {'num': '69', 'institution': 'Humboldt-Universität zu Berlin', 'department': 'Chemistry Department', 'faculty': '', 'work_group': '', 'country': 'Germany', 'sector': 'Academia', 'school': '', 'address': 'Brook-Taylor-Strasse 2, 12489 Berlin'}
# Query: institution = "Humboldt-Universität zu Berlin" AND department = 'Chemistry Department' AND country = 'Germany'
# * Affiliation found in DB id: 617 Address: 246
# * Add
# {'num': '70', 'institution': 'Hunan University', 'department': '', 'faculty': '', 'work_group': '', 'country': 'Peoples Republic of China', 'sector': 'Academia', 'school': 'School of Physics and Electronics', 'address': 'Changsha 410082'}
# Query: institution = "Hunan University" AND school = 'School of Physics and Electronics' AND country = 'Peoples Republic of China'
# * Affiliation found in DB id: 618 Address: 247
# * Add
# {'num': '71', 'institution': 'IBM Research-Zurich', 'department': '', 'faculty': '', 'work_group': '', 'country': 'Switzerland', 'sector': 'Industry', 'school': '', 'address': '8803 Rüschlikon'}
# Query: institution = "IBM Research-Zurich" AND country = 'Switzerland'
# * Affiliation found in DB id: 619 Address: 248
# * Add
# {'num': '72', 'institution': 'IKERBASQUE, Basque Foundation for Science', 'department': '', 'faculty': '', 'work_group': '', 'country': 'Spain', 'sector': 'Research Facility', 'school': '', 'address': 'Maria Diaz de Haro 3, 48013 Bilbao'}
# Query: institution = "IKERBASQUE, Basque Foundation for Science" AND country = 'Spain'
# * Affiliation found in DB id: 620 Address: 249
# * Add
# {'num': '73', 'institution': 'Imperial College London', 'department': 'Department of Materials', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Academia', 'school': '', 'address': 'London SW7 2AZ'}
# Query: institution = "Imperial College London" AND department = 'Department of Materials' AND country = 'United Kingdom'
# * Affiliation found in DB id: 12 Address: 81
# * Add
# {'num': '74', 'institution': 'Imperial College London', 'department': 'Department of Materials', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Academia', 'school': '', 'address': 'South Kensington, London SW7 2AB'}
# Query: institution = "Imperial College London" AND department = 'Department of Materials' AND country = 'United Kingdom'
# * Affiliation found in DB id: 12 Address: 81
# * Add
# {'num': '75', 'institution': 'Imperial College London', 'department': 'Department of Materials', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Academia', 'school': '', 'address': 'Exhibition Road, London SW7 2AZ'}
# Query: institution = "Imperial College London" AND department = 'Department of Materials' AND country = 'United Kingdom'
# * Affiliation found in DB id: 12 Address: 81
# * Add
# {'num': '76', 'institution': 'Imperial College London', 'department': 'Department of Materials', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Academia', 'school': '', 'address': 'London SW7 2AZ'}
# Query: institution = "Imperial College London" AND department = 'Department of Materials' AND country = 'United Kingdom'
# * Affiliation found in DB id: 12 Address: 81
# * Add
# {'num': '77', 'institution': 'Imperial College London', 'department': 'Department of Physics', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Academia', 'school': '', 'address': 'Exhibition Road, London SW7 2AZ'}
# Query: institution = "Imperial College London" AND department = 'Department of Physics' AND country = 'United Kingdom'
# * Affiliation found in DB id: 386 Address: 88
# * Add
# {'num': '78', 'institution': 'Indian Institute of Technology', 'department': 'Department of Chemistry', 'faculty': '', 'work_group': 'Environmental Materials & Analytical Chemistry Laboratory', 'country': 'India', 'sector': 'Academia', 'school': '', 'address': 'Kharagpur 721302'}
# Query: institution = "Indian Institute of Technology" AND department = 'Department of Chemistry' AND work_group = 'Environmental Materials & Analytical Chemistry Laboratory' AND country = 'India'
# * Affiliation found in DB id: 621 Address: 250
# * Add
# {'num': '79', 'institution': 'Indian Institute of Technology Bombay', 'department': 'Department of Chemistry', 'faculty': '', 'work_group': '', 'country': 'India', 'sector': 'Academia', 'school': '', 'address': 'Powai, Mumbai-400076'}
# Query: institution = "Indian Institute of Technology Bombay" AND department = 'Department of Chemistry' AND country = 'India'
# * Affiliation found in DB id: 622 Address: 251
# * Add
# {'num': '80', 'institution': 'Infineon Technologies', 'department': '', 'faculty': '', 'work_group': '', 'country': 'Austria', 'sector': 'Industry', 'school': '', 'address': 'Siemensstraße 2, 9500 Villach'}
# Query: institution = "Infineon Technologies" AND country = 'Austria'
# * Affiliation found in DB id: 623 Address: 252
# * Add
# {'num': '81', 'institution': 'Infineon Technologies Austria AG', 'department': '', 'faculty': '', 'work_group': '', 'country': 'Austria', 'sector': 'Industry', 'school': '', 'address': 'Siemensstraße 2, 9500 Villach'}
# Query: institution = "Infineon Technologies Austria AG" AND country = 'Austria'
# * Affiliation found in DB id: 624 Address: 253
# * Add
# {'num': '82', 'institution': 'Institució Catalana de Recerca i Estudis Avançats (ICREA)', 'department': '', 'faculty': '', 'work_group': '', 'country': 'Spain', 'sector': 'Research Facility', 'school': '', 'address': 'Barcelona'}
# Query: institution = "Institució Catalana de Recerca i Estudis Avançats (ICREA)" AND country = 'Spain'
# * Affiliation found in DB id: 329 Address: 254
# * Add
# {'num': '83', 'institution': 'Institut de Ciència de Materials de Barcelona (CSIC)', 'department': '', 'faculty': '', 'work_group': '', 'country': 'Spain', 'sector': 'Research Facility', 'school': '', 'address': 'Campus UAB, 08193 Bellaterra'}
# Query: institution = "Institut de Ciència de Materials de Barcelona (CSIC)" AND country = 'Spain'
# * Affiliation found in DB id: 625 Address: 255
# * Add
# {'num': '84', 'institution': 'Institute of Technical Physics and Materials Science', 'department': '', 'faculty': '', 'work_group': 'Centre for Energy Research', 'country': 'Hungary', 'sector': 'Research Facility', 'school': '', 'address': 'Konkoly-Thege út 29-33, 1121 Budapest'}
# Query: institution = "Institute of Technical Physics and Materials Science" AND work_group = 'Centre for Energy Research' AND country = 'Hungary'
# * Affiliation found in DB id: 626 Address: 256
# * Add
# {'num': '85', 'institution': 'Instituto de Física Fundamental', 'department': '', 'faculty': '', 'work_group': '', 'country': 'Spain', 'sector': 'Research Facility', 'school': '', 'address': 'Consejo Superior de Investigaciones Científicas, Serrano 123, E-28006 Madrid'}
# Query: institution = "Instituto de Física Fundamental" AND country = 'Spain'
# * Affiliation found in DB id: 627 Address: 257
# * Add
# {'num': '86', 'institution': 'Instituto Venezolano de Investigaciones Cientificas', 'department': '', 'faculty': '', 'work_group': 'Centro de Estudios Interdisciplinarios de la Fisica', 'country': 'Venezuela', 'sector': 'Research Facility', 'school': '', 'address': 'Caracas 1020A'}
# Query: institution = "Instituto Venezolano de Investigaciones Cientificas" AND work_group = 'Centro de Estudios Interdisciplinarios de la Fisica' AND country = 'Venezuela'
# * Affiliation found in DB id: 628 Address: 258
# * Add
# {'num': '87', 'institution': 'International Iberian Nanotechnology Laboratory', 'department': '', 'faculty': '', 'work_group': 'INL – Advanced (magnetic) Theranostic Nanostructures Lab', 'country': 'Spain', 'sector': 'Research Facility', 'school': '', 'address': ''}
# Query: institution = "International Iberian Nanotechnology Laboratory" AND work_group = 'INL – Advanced (magnetic) Theranostic Nanostructures Lab' AND country = 'Spain'
# * Affiliation found in DB id: 1087 Address: 470
# * Add
# {'num': '88', 'institution': 'IOM-CNR', 'department': '', 'faculty': '', 'work_group': 'Laboratorio TASC', 'country': 'Italy', 'sector': 'Research Facility', 'school': '', 'address': 'AREA Science Park, S.S. 14 Km 163.5, 34149 Trieste'}
# Query: institution = "IOM-CNR" AND work_group = 'Laboratorio TASC' AND country = 'Italy'
# * Affiliation found in DB id: 630 Address: 260
# * Add
# {'num': '89', 'institution': 'ISIS Facility', 'department': '', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Research Facility', 'school': '', 'address': 'Rutherford Appleton Laboratory, Didcot OX11 0QX'}
# Query: institution = "ISIS Facility" AND country = 'United Kingdom'
# * Affiliation found in DB id: 1088 Address: 471
# * Add
# {'num': '90', 'institution': 'JST-PRESTO', 'department': '', 'faculty': '', 'work_group': '', 'country': 'Japan', 'sector': 'Research Facility', 'school': '', 'address': '4-1-8 Honcho, Kawaguchi, Saitama 332-0012'}
# Query: institution = "JST-PRESTO" AND country = 'Japan'
# * Affiliation found in DB id: 632 Address: 262
# * Add
# {'num': '91', 'institution': 'KAI GmbH', 'department': '', 'faculty': '', 'work_group': '', 'country': 'Austria', 'sector': 'Research Facility', 'school': '', 'address': 'Europastraße 8, 9500 Villach'}
# Query: institution = "KAI GmbH" AND country = 'Austria'
# * Affiliation found in DB id: 633 Address: 263
# * Add
# {'num': '92', 'institution': 'Kanagawa University', 'department': 'Department of Material and Life Chemistry', 'faculty': 'Faculty of Engineering', 'work_group': '', 'country': 'Japan', 'sector': 'Academia', 'school': '', 'address': '3-27, Rokkakubashi, Kanagawa-ku, Yokohama 221-8686'}
# Query: institution = "Kanagawa University" AND department = 'Department of Material and Life Chemistry' AND faculty = 'Faculty of Engineering' AND country = 'Japan'
# * Affiliation found in DB id: 634 Address: 264
# * Add
# {'num': '93', 'institution': 'King’s College London', 'department': 'Department of Physics', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Academia', 'school': '', 'address': 'London WC2R 2LS'}
# Query: institution = "King’s College London" AND department = 'Department of Physics' AND country = 'United Kingdom'
# * Affiliation found in DB id: 1089 Address: 472
# * Add
# {'num': '94', 'institution': 'King’s College London', 'department': 'Physics Department', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Academia', 'school': '', 'address': 'Strand, WC2R 2LS'}
# Query: institution = "King’s College London" AND department = 'Physics Department' AND country = 'United Kingdom'
# * Affiliation found in DB id: 1090 Address: 473
# * Add
# {'num': '95', 'institution': 'KTH-Royal Institute of Technology', 'department': 'Department of Chemical Engineering and Technology', 'faculty': '', 'work_group': '', 'country': 'Sweden', 'sector': 'Research Facility', 'school': '', 'address': 'Teknikringen 42, 100 44 Stockholm'}
# Query: institution = "KTH-Royal Institute of Technology" AND department = 'Department of Chemical Engineering and Technology' AND country = 'Sweden'
# * Affiliation found in DB id: 635 Address: 265
# * Add
# {'num': '96', 'institution': 'Kyoto University', 'department': 'Department of Materials Science and Engineering', 'faculty': '', 'work_group': '', 'country': 'Japan', 'sector': 'Academia', 'school': '', 'address': 'Sakyo, Kyoto 606-8501'}
# Query: institution = "Kyoto University" AND department = 'Department of Materials Science and Engineering' AND country = 'Japan'
# * Affiliation found in DB id: 636 Address: 266
# * Add
# {'num': '97', 'institution': 'Kyoto University', 'department': '', 'faculty': '', 'work_group': 'Elements Strategy Initiative for Structural Materials', 'country': 'Japan', 'sector': 'Academia', 'school': '', 'address': 'Sakyo, Kyoto 606-8501'}
# Query: institution = "Kyoto University" AND work_group = 'Elements Strategy Initiative for Structural Materials' AND country = 'Japan'
# * Affiliation found in DB id: 637 Address: 267
# * Add
# {'num': '98', 'institution': 'Lancaster University', 'department': 'Department of Chemistry', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Academia', 'school': '', 'address': 'Bailrigg, Lancaster LA1 4YB'}
# Query: institution = "Lancaster University" AND department = 'Department of Chemistry' AND country = 'United Kingdom'
# * Affiliation found in DB id: 506 Address: 110
# * Add
# {'num': '99', 'institution': 'Lawrence Berkeley National Laboratory', 'department': 'Computational Research Division', 'faculty': '', 'work_group': '', 'country': 'United States of America', 'sector': 'Research Facility', 'school': '', 'address': 'Berkeley, California 94720'}
# Query: institution = "Lawrence Berkeley National Laboratory" AND department = 'Computational Research Division' AND country = 'United States of America'
# * Affiliation found in DB id: 638 Address: 268
# * Add
# {'num': '100', 'institution': 'Le Mans Université', 'department': '', 'faculty': '', 'work_group': 'Institut des Molécules et Matériaux du Mans (IMMM) – UMR 6283 CNRS', 'country': 'France', 'sector': 'Academia', 'school': '', 'address': ''}
# Query: institution = "Le Mans Université" AND work_group = 'Institut des Molécules et Matériaux du Mans (IMMM) – UMR 6283 CNRS' AND country = 'France'
# * Affiliation found in DB id: 639 Address: 269
# * Add
# {'num': '101', 'institution': 'Le Mans Université-CNRS', 'department': '', 'faculty': '', 'work_group': 'Institut des Molécules et Matériaux du Mans', 'country': 'France', 'sector': 'Academia', 'school': '', 'address': 'IMMM, UMR 6283, Avenue Olivier Messiaen, 72085 Le Mans, Cedex 9'}
# Query: institution = "Le Mans Université-CNRS" AND work_group = 'Institut des Molécules et Matériaux du Mans' AND country = 'France'
# * Affiliation found in DB id: 640 Address: 270
# * Add
# {'num': '102', 'institution': 'London Centre for Nanotechnology', 'department': '', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Research Facility', 'school': '', 'address': 'London SW7 2AZ'}
# Query: institution = "London Centre for Nanotechnology" AND country = 'United Kingdom'
# * Affiliation found in DB id: 392 Address: 271
# * Add
# {'num': '103', 'institution': 'London Centre for Nanotechnology', 'department': '', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Research Facility', 'school': '', 'address': '17-19 Gordon Street, London WC1H 0AH'}
# Query: institution = "London Centre for Nanotechnology" AND country = 'United Kingdom'
# * Affiliation found in DB id: 392 Address: 271
# * Add
# {'num': '104', 'institution': 'London Centre for Nanotechnology', 'department': '', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Research Facility', 'school': '', 'address': '17–19 Gordon Street, London WC1H 0AH'}
# Query: institution = "London Centre for Nanotechnology" AND country = 'United Kingdom'
# * Affiliation found in DB id: 392 Address: 271
# * Add
# {'num': '105', 'institution': 'Lund University', 'department': '', 'faculty': '', 'work_group': 'MAX IV Laboratory', 'country': 'Sweden', 'sector': 'Academia', 'school': '', 'address': '225 94 Lund'}
# Query: institution = "Lund University" AND work_group = 'MAX IV Laboratory' AND country = 'Sweden'
# * Affiliation found in DB id: 641 Address: 272
# * Add
# {'num': '106', 'institution': 'Luxembourg Institute of Science and Technology', 'department': 'Department of Materials Research and Technology', 'faculty': '', 'work_group': '', 'country': 'Luxembourg', 'sector': 'Academia', 'school': '', 'address': '5 Avenue des Hauts-Fourneaux, Esch-sur-Alzette, L-4362'}
# Query: institution = "Luxembourg Institute of Science and Technology" AND department = 'Department of Materials Research and Technology' AND country = 'Luxembourg'
# * Affiliation found in DB id: 642 Address: 273
# * Add
# {'num': '107', 'institution': 'Massachusetts Institute of Technology', 'department': 'Department of Chemical Engineering', 'faculty': '', 'work_group': '', 'country': 'United States of America', 'sector': 'Academia', 'school': '', 'address': 'Cambridge, Massachusetts 02139'}
# Query: institution = "Massachusetts Institute of Technology" AND department = 'Department of Chemical Engineering' AND country = 'United States of America'
# * Affiliation found in DB id: 643 Address: 274
# * Add
# {'num': '108', 'institution': 'Massachusetts Institute of Technology', 'department': 'Department of Chemistry', 'faculty': '', 'work_group': '', 'country': 'United States of America', 'sector': 'Academia', 'school': '', 'address': '77 Massachusetts Avenue, Cambridge, Massachusetts 02139'}
# Query: institution = "Massachusetts Institute of Technology" AND department = 'Department of Chemistry' AND country = 'United States of America'
# * Affiliation found in DB id: 644 Address: 275
# * Add
# {'num': '109', 'institution': 'Massachusetts Institute of Technology', 'department': 'Department of Chemistry', 'faculty': '', 'work_group': '', 'country': 'United States of America', 'sector': 'Academia', 'school': '', 'address': 'Cambridge, Massachusetts 02139'}
# Query: institution = "Massachusetts Institute of Technology" AND department = 'Department of Chemistry' AND country = 'United States of America'
# * Affiliation found in DB id: 644 Address: 275
# * Add
# {'num': '110', 'institution': 'Massachusetts Institute of Technology', 'department': 'Department of Chemistry', 'faculty': '', 'work_group': '', 'country': 'United States of America', 'sector': 'Academia', 'school': '', 'address': 'Cambridge, Massachusetts 02139'}
# Query: institution = "Massachusetts Institute of Technology" AND department = 'Department of Chemistry' AND country = 'United States of America'
# * Affiliation found in DB id: 644 Address: 275
# * Add
# ...
# Query: institution = "University of Leuven" AND department = 'Department of Physics and Astronomy' AND work_group = 'Laboratory of Semiconductor Physics' AND country = 'Belgium'
# * Affiliation found in DB id: 772 Address: 405
# * Add
# {'num': '276', 'institution': 'University of Limerick', 'department': 'Department of Physics and Energy', 'faculty': '', 'work_group': 'Materials and Surface Science Institute', 'country': 'Ireland', 'sector': 'Academia', 'school': '', 'address': 'Castletroy'}
# Query: institution = "University of Limerick" AND department = 'Department of Physics and Energy' AND work_group = 'Materials and Surface Science Institute' AND country = 'Ireland'
# * Affiliation found in DB id: 773 Address: 406
# * Add
# {'num': '277', 'institution': 'University of Lincoln', 'department': '', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Academia', 'school': 'School of Mathematics and Physics', 'address': 'Lincoln LN6 7TS'}
# Query: institution = "University of Lincoln" AND school = 'School of Mathematics and Physics' AND country = 'United Kingdom'
# * Affiliation found in DB id: 493 Address: 76
# * Add
# {'num': '278', 'institution': 'University of Liverpool', 'department': 'Department of Chemistry', 'faculty': '', 'work_group': 'Stephenson Institute for Renewable Energy', 'country': 'United Kingdom', 'sector': 'Academia', 'school': '', 'address': 'Crown Street, Liverpool L69 7ZD'}
# Query: institution = "University of Liverpool" AND department = 'Department of Chemistry' AND work_group = 'Stephenson Institute for Renewable Energy' AND country = 'United Kingdom'
# * Affiliation found in DB id: 774 Address: 407
# * Add
# {'num': '279', 'institution': 'University of Liverpool', 'department': 'Department of Chemistry', 'faculty': '', 'work_group': 'Surface Science Research Centre', 'country': 'United Kingdom', 'sector': 'Academia', 'school': '', 'address': 'Liverpool L69 3BX'}
# Query: institution = "University of Liverpool" AND department = 'Department of Chemistry' AND work_group = 'Surface Science Research Centre' AND country = 'United Kingdom'
# * Affiliation found in DB id: 775 Address: 408
# * Add
# {'num': '280', 'institution': 'University of Liverpool', 'department': 'Department of Chemistry', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Academia', 'school': '', 'address': 'Crown Street, Liverpool, L69 7ZD'}
# Query: institution = "University of Liverpool" AND department = 'Department of Chemistry' AND country = 'United Kingdom'
# * Affiliation found in DB id: 68 Address: 73
# * Add
# {'num': '281', 'institution': 'University of Liverpool', 'department': 'Department of Chemistry', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Academia', 'school': '', 'address': 'Crown Street, Liverpool L69 7ZD'}
# Query: institution = "University of Liverpool" AND department = 'Department of Chemistry' AND country = 'United Kingdom'
# * Affiliation found in DB id: 68 Address: 73
# * Add
# {'num': '282', 'institution': 'University of Liverpool', 'department': 'Department of Physics', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Academia', 'school': '', 'address': 'Oxford Street, Liverpool L69 7ZE'}
# Query: institution = "University of Liverpool" AND department = 'Department of Physics' AND country = 'United Kingdom'
# * Affiliation found in DB id: 115 Address: 409
# * Add
# {'num': '283', 'institution': 'University of Liverpool', 'department': '', 'faculty': '', 'work_group': 'Stephenson Institute for Renewable Energy', 'country': 'United Kingdom', 'sector': 'Academia', 'school': '', 'address': 'Crown Street, Liverpool, L69 7ZD'}
# Query: institution = "University of Liverpool" AND work_group = 'Stephenson Institute for Renewable Energy' AND country = 'United Kingdom'
# * Affiliation found in DB id: 66 Address: 410
# * Add
# {'num': '284', 'institution': 'University of Liverpool', 'department': '', 'faculty': '', 'work_group': 'Stephenson Institute for Renewable Energy', 'country': 'United Kingdom', 'sector': 'Academia', 'school': '', 'address': 'Peach Street, Liverpool L69 7ZF'}
# Query: institution = "University of Liverpool" AND work_group = 'Stephenson Institute for Renewable Energy' AND country = 'United Kingdom'
# * Affiliation found in DB id: 66 Address: 410
# * Add
# {'num': '285', 'institution': 'University of Manchester', 'department': '', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Academia', 'school': 'School of Materials', 'address': 'M13 9PL'}
# Query: institution = "University of Manchester" AND school = 'School of Materials' AND country = 'United Kingdom'
# * Affiliation found in DB id: 1104 Address: 487
# * Add
# {'num': '286', 'institution': 'University of Modena and Reggio Emilia', 'department': '', 'faculty': '', 'work_group': 'DISMI', 'country': 'Italy', 'sector': 'Academia', 'school': '', 'address': 'Via Amendola 2, 41122 Reggio Emilia (RE)'}
# Query: institution = "University of Modena and Reggio Emilia" AND work_group = 'DISMI' AND country = 'Italy'
# * Affiliation found in DB id: 777 Address: 412
# * Add
# {'num': '287', 'institution': 'University of Nottingham', 'department': '', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Academia', 'school': 'School of Physics & Astronomy', 'address': 'Nottingham NG7 2RD'}
# Query: institution = "University of Nottingham" AND school = 'School of Physics & Astronomy' AND country = 'United Kingdom'
# * Affiliation found in DB id: 778 Address: 413
# * Add
# {'num': '288', 'institution': 'University of Oxford', 'department': 'Department of Biochemistry', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Academia', 'school': '', 'address': 'Oxford OX1 3QU'}
# Query: institution = "University of Oxford" AND department = 'Department of Biochemistry' AND country = 'United Kingdom'
# * Affiliation found in DB id: 489 Address: 63
# * Add
# {'num': '289', 'institution': 'University of Pannonia', 'department': 'Department of Earth and Environmental Sciences', 'faculty': '', 'work_group': '', 'country': 'Hungary', 'sector': 'Academia', 'school': '', 'address': 'Egyetem út 10, 8200 Veszprém'}
# Query: institution = "University of Pannonia" AND department = 'Department of Earth and Environmental Sciences' AND country = 'Hungary'
# * Affiliation found in DB id: 779 Address: 414
# * Add
# {'num': '290', 'institution': 'University of Reading', 'department': 'Department of Chemistry', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Academia', 'school': '', 'address': 'Reading RG6 6AD'}
# Query: institution = "University of Reading" AND department = 'Department of Chemistry' AND country = 'United Kingdom'
# * Affiliation found in DB id: 93 Address: 115
# * Add
# {'num': '291', 'institution': 'University of Salzburg', 'department': 'Department of Chemistry and Physics of Materials', 'faculty': '', 'work_group': '', 'country': 'Austria', 'sector': 'Academia', 'school': '', 'address': 'Hellbrunner Straße 34/III, A-5020 Salzburg'}
# Query: institution = "University of Salzburg" AND department = 'Department of Chemistry and Physics of Materials' AND country = 'Austria'
# * Affiliation found in DB id: 780 Address: 415
# * Add
# {'num': '292', 'institution': 'University of Sofia', 'department': '', 'faculty': 'Faculty of Chemistry and Pharmacy', 'work_group': '', 'country': 'Bulgaria', 'sector': 'Academia', 'school': '', 'address': 'Sofia'}
# Query: institution = "University of Sofia" AND faculty = 'Faculty of Chemistry and Pharmacy' AND country = 'Bulgaria'
# * Affiliation found in DB id: 781 Address: 416
# * Add
# {'num': '293', 'institution': 'University of Southern California', 'department': 'Department of Chemistry', 'faculty': '', 'work_group': '', 'country': 'United States of America', 'sector': 'Academia', 'school': '', 'address': 'Los Angeles, California 90089'}
# Query: institution = "University of Southern California" AND department = 'Department of Chemistry' AND country = 'United States of America'
# * Affiliation found in DB id: 782 Address: 417
# * Add
# {'num': '294', 'institution': 'University of Surrey', 'department': 'Department of Chemistry', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Academia', 'school': '', 'address': 'Guildford GU2 7XH'}
# Query: institution = "University of Surrey" AND department = 'Department of Chemistry' AND country = 'United Kingdom'
# * Affiliation found in DB id: 783 Address: 418
# * Add
# {'num': '295', 'institution': 'University of Surrey', 'department': 'Department of Chemistry', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Academia', 'school': '', 'address': 'GU2 7XH Guildford'}
# Query: institution = "University of Surrey" AND department = 'Department of Chemistry' AND country = 'United Kingdom'
# * Affiliation found in DB id: 783 Address: 418
# * Add
# {'num': '296', 'institution': 'University of Sydney', 'department': '', 'faculty': '', 'work_group': '', 'country': 'Australia', 'sector': 'Academia', 'school': 'School of Chemistry', 'address': 'Sydney, NSW 2006'}
# Query: institution = "University of Sydney" AND school = 'School of Chemistry' AND country = 'Australia'
# * Affiliation found in DB id: 784 Address: 419
# * Add
# {'num': '297', 'institution': 'University of the Witwatersrand', 'department': '', 'faculty': '', 'work_group': 'Evolutionary Studies Institute', 'country': 'South Africa', 'sector': 'Academia', 'school': '', 'address': 'Braamfontein'}
# Query: institution = "University of the Witwatersrand" AND work_group = 'Evolutionary Studies Institute' AND country = 'South Africa'
# * Affiliation found in DB id: 785 Address: 420
# * Add
# {'num': '298', 'institution': 'University of Tokyo', 'department': '', 'faculty': '', 'work_group': 'Institute of Engineering Innovation', 'country': 'Japan', 'sector': 'Academia', 'school': '', 'address': '2-11-16, Yayoi, Bunkyo-ku, Tokyo 113-8656'}
# Query: institution = "University of Tokyo" AND work_group = 'Institute of Engineering Innovation' AND country = 'Japan'
# * Affiliation found in DB id: 786 Address: 421
# * Add
# {'num': '299', 'institution': 'University of Toronto', 'department': 'Department of Anthropology', 'faculty': '', 'work_group': '', 'country': 'Canada', 'sector': 'Academia', 'school': '', 'address': 'Toronto'}
# Query: institution = "University of Toronto" AND department = 'Department of Anthropology' AND country = 'Canada'
# * Affiliation found in DB id: 787 Address: 422
# * Add
# {'num': '300', 'institution': 'University of Toronto', 'department': 'Department of Chemistry', 'faculty': '', 'work_group': '', 'country': 'Canada', 'sector': 'Academia', 'school': '', 'address': 'Toronto, Ontario M5S 3H6'}
# Query: institution = "University of Toronto" AND department = 'Department of Chemistry' AND country = 'Canada'
# * Affiliation found in DB id: 788 Address: 423
# * Add
# {'num': '301', 'institution': 'University of Trieste', 'department': 'Physics Department', 'faculty': '', 'work_group': '', 'country': 'Italy', 'sector': 'Academia', 'school': '', 'address': 'Via Valerio 2, 34127 Trieste'}
# Query: institution = "University of Trieste" AND department = 'Physics Department' AND country = 'Italy'
# * Affiliation found in DB id: 1105 Address: 488
# * Add
# {'num': '302', 'institution': 'University of Vienna', 'department': '', 'faculty': 'Faculty of Physics', 'work_group': 'Vienna Center for Quantum Science and Technology', 'country': 'Austria', 'sector': 'Academia', 'school': '', 'address': 'Boltzmanngasse 5, A-1090 Vienna'}
# Query: institution = "University of Vienna" AND faculty = 'Faculty of Physics' AND work_group = 'Vienna Center for Quantum Science and Technology' AND country = 'Austria'
# * Affiliation found in DB id: 790 Address: 425
# * Add
# {'num': '303', 'institution': 'University of Warwick', 'department': 'Department of Chemistry', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Academia', 'school': '', 'address': 'Coventry CV4 7AL'}
# Query: institution = "University of Warwick" AND department = 'Department of Chemistry' AND country = 'United Kingdom'
# * Affiliation found in DB id: 87 Address: 96
# * Add
# {'num': '304', 'institution': 'University of Warwick', 'department': 'Department of Physics', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Academia', 'school': '', 'address': 'Gibbet Hill Road, Coventry CV4 7AL'}
# Query: institution = "University of Warwick" AND department = 'Department of Physics' AND country = 'United Kingdom'
# * Affiliation found in DB id: 472 Address: 41
# * Add
# {'num': '305', 'institution': 'University of York', 'department': 'Department of Chemistry', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Academia', 'school': '', 'address': 'York'}
# Query: institution = "University of York" AND department = 'Department of Chemistry' AND country = 'United Kingdom'
# * Affiliation found in DB id: 102 Address: 121
# * Add
# {'num': '306', 'institution': 'University of York', 'department': 'Department of Mathematics', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Academia', 'school': '', 'address': 'York'}
# Query: institution = "University of York" AND department = 'Department of Mathematics' AND country = 'United Kingdom'
# * Affiliation found in DB id: 791 Address: 426
# * Add
# {'num': '307', 'institution': 'University of York', 'department': 'Department of Physics', 'faculty': '', 'work_group': '', 'country': 'United Kingdom', 'sector': 'Academia', 'school': '', 'address': 'York, Heslington YO10 5DD'}
# Query: institution = "University of York" AND department = 'Department of Physics' AND country = 'United Kingdom'
# * Affiliation found in DB id: 389 Address: 65
# * Add
# {'num': '308', 'institution': 'University of York', 'department': '', 'faculty': '', 'work_group': 'Centre of Excellence in Mass Spectrometry', 'country': 'United States of America', 'sector': 'Academia', 'school': '', 'address': 'New York'}
# Query: institution = "University of York" AND work_group = 'Centre of Excellence in Mass Spectrometry' AND country = 'United States of America'
# * Affiliation found in DB id: 792 Address: 427
# * Add
# {'num': '309', 'institution': 'Vienna University of Technology', 'department': '', 'faculty': '', 'work_group': 'Institute for Microelectronics', 'country': 'Austria', 'sector': 'Academia', 'school': '', 'address': 'Gußhausstraße 27–29/E360, 1040 Wien'}
# Query: institution = "Vienna University of Technology" AND work_group = 'Institute for Microelectronics' AND country = 'Austria'
# * Affiliation found in DB id: 793 Address: 428
# * Add
# {'num': '310', 'institution': 'Wrocław University of Technology', 'department': '', 'faculty': 'Faculty of Fundamental Problems of Technology', 'work_group': 'Laboratory for Optical Spectroscopy of Nanostructures', 'country': 'Poland', 'sector': 'Academia', 'school': '', 'address': 'Wybrzeże Wyspiańskiego 27, Wrocław'}
# Query: institution = "Wrocław University of Technology" AND faculty = 'Faculty of Fundamental Problems of Technology' AND work_group = 'Laboratory for Optical Spectroscopy of Nanostructures' AND country = 'Poland'
# * Affiliation found in DB id: 1106 Address: 489
# * Add
# {'num': '311', 'institution': 'Wuhan University', 'department': '', 'faculty': '', 'work_group': '', 'country': 'Peoples Republic of China', 'sector': 'Academia', 'school': 'School of Physics and Technology', 'address': 'Wuhan 430072'}
# Query: institution = "Wuhan University" AND school = 'School of Physics and Technology' AND country = 'Peoples Republic of China'
# * Affiliation found in DB id: 795 Address: 430
# * Add
# {'num': '312', 'institution': 'Yonsei University', 'department': 'Department of Chemistry', 'faculty': '', 'work_group': '', 'country': 'Republic of Korea.', 'sector': 'Academia', 'school': '', 'address': '03722 Seoul'}
# Query: institution = "Yonsei University" AND department = 'Department of Chemistry' AND country = 'Republic of Korea.'
# * Affiliation found in DB id: 1107 Address: 490
# * Add

# %% [markdown]
# # UNDER DEVELOPMENT CODE >>>

# %%
# return a flat list from a complex list
def flatten_list(comp_list):
    flat_list = []
    for sublist in comp_list:
            for item in sublist:
                flat_list.append(item)
    return flat_list

# get lits of article_authors with unmapped crossref affiliations
def aut_ids_unmapped_cr_affiliations():
    aut_affi_ids = db_conn.get_values('cr_affiliations', 'article_author_id',
                                      'author_affiliation_id is NULL GROUP BY article_author_id')# HAVING count() = 1')
    return flatten_list(aut_affi_ids)

def cr_affiliation_ids_for_author(aut_affi_id):
    non_parsed_cr_affi_ids = db_conn.get_values('cr_affiliations', 'id', 'article_author_id = '+ str(aut_affi_id) +\
                                          ' and author_affiliation_id is NULL')
    return flatten_list(non_parsed_cr_affi_ids)

def get_cr_values(cr_ids):
    filter_str = str(tuple(cr_ids))
    if (filter_str[-2:-1]) == ",":
        filter_str = filter_str[:-2]+")"
    cr_values = db_conn.get_values('cr_affiliations', 'id,name', 'id in' + filter_str)
    return cr_values

def is_string_affi(affi_string):
    #affi string shoud include the institution else it is not an affi string
    affi_values = split_single(affi_string)
    non_empty_count = 0
    if affi_values['institution'] == "":
        return False
    for an_element in affi_values:
        if affi_values[an_element] != "" and an_element != 'address':
            non_empty_count += 1
    if non_empty_count > 1:
        print(affi_values)
        return True
    else:
        return False

def remove_blanks(affi_values):
    remove_keys = []
    for a_key in affi_values:
        if affi_values[a_key] == "":
            remove_keys.append(a_key)
    for a_key in remove_keys:
        del affi_values[a_key]
    return affi_values

def get_affi_vals(a_str):
    ret_vals = split_single(a_str.replace('\r',' '))
    # omit address vals too
    del ret_vals['address']
    return remove_blanks(ret_vals)
    
def one_affi(affi_hash):
    valid_keys = ["institution","work_group","department","faculty","country","school"]
    find_str = ""
    for item_key in affi_hash.keys():
        if affi_hash[item_key] != "" and item_key in valid_keys:
            find_str += item_key + " = '" + affi_hash[item_key].replace("'","''") + "' and "
    if find_str != "":
        find_str = find_str[:-5]
        print(find_str)
        found = db_conn.get_values('affiliations', 'id', find_str)
        if len(found) > 0 :
            return True
    return False
    
def manual_map_complex(affiliation_values, complex_vals):
    opt_end = False
    while (opt_end == False):
        print ("*** Manual Mapping ***")
        print("* Parsed:   ", affiliation_values)
        print("* Original: ", complex_vals)
        missing_vals = {}
        int_idx = 1
        for an_element in affiliation_values:
            if affiliation_values[an_element] == "":
                missing_vals[int_idx] = an_element
                int_idx += 1
        print('Which element to get from string:')
        for an_idx in missing_vals:
            print(" ", an_idx, missing_vals[an_idx])
        print (" ", len(missing_vals)+1, 'end')
        print('Selection')
        option_sel = int(input())
        if option_sel == len(missing_vals)+1:
            opt_end = True
        elif option_sel > 0 and option_sel <= len(missing_vals):
            print("Map: ", missing_vals[option_sel])
            affiliation_values[missing_vals[option_sel]] = \
                get_from_list(complex_vals, missing_vals[option_sel])
    return affiliation_values

def get_from_list(complex_vals, element):
    element_value = ""
    print("************ get",element,"*************************")
    print("split or map this: ", complex_vals)
    option_how = 0
    while not option_how in [1,2,3]:
        print('options: ')
        print('1: map complex element')
        print('2: enter manually')
        print('3: do nothing ')
        print('selection:')
        try:
            option_how = int(input())
        except:
            option_how = 0
    if option_how == 1:
        element_value = map_complex(complex_vals, element)
    elif option_how == 2:
        print('enter value')
        element_value = input()  
    return element_value

def map_complex(complex_vals, element):
    return_value = ""
    print('mapping')
    opt_end = False
    while (opt_end == False):
        print ("*** Manual Mapping ",element,"***")
        missing_vals = {}
        int_idx = 1
        for an_element in complex_vals:
            missing_vals[int_idx] = complex_vals[an_element]
            int_idx += 1
        print('Which value corresponds to ',element+':')
        for an_idx in missing_vals:
            print(" ", an_idx, missing_vals[an_idx])
        print (" ", len(missing_vals)+1, 'end')
        print('Selection')
        option_sel = int(input())
        if option_sel > 0 and option_sel <= len(missing_vals):
            return_value = missing_vals[option_sel]
            opt_end = True
        elif option_sel == len(missing_vals) + 1:
            opt_end = True
    return return_value

# %%
def merge_affi_vals(affi_val_1, affi_val_2):
    ret_affi_vals = affi_val_1
    for an_element in affi_val_2:
        if affi_val_2[an_element] != '': #and an_element != 'address':
            affi_val_1[an_element] = affi_val_2[an_element]           
    return affi_val_1

def process_complex_affi(complex_affi, art_aut_id):
    print ("process as complex affiliation in strings:", complex_affi )
    current_affi = {}
    test_affi={}
    temp_affi={}
    same_affi = True # one institution is found
    for cr_id in complex_affi:
        temp_split = split_single(complex_affi[cr_id])
        if temp_split!={}:
            if test_affi == {}:
                test_affi = temp_split
            else:
                temp_affi = merge_affi_vals(test_affi, temp_split)
                print("temp affi:", temp_affi)
                affi_id, add_id = affiliation_exists(temp_affi)
                if affi_id != 0 and temp_affi['institution']!="": # some affiliation exists, consistency
                    if current_affi == {}:
                        current_affi = temp_affi
                    elif (temp_affi['institution'] == current_affi['institution']):
                        current_affi = temp_affi
                    else:
                        same_affi = False
                        print ("* Institution changed", temp_affi)
                        print("save current")
    
    if 'institution' in temp_affi.keys() and temp_affi['institution']!="": # affi does not exist
        print ("new affi:", temp_affi,"\nAdd it?") 
        opt_sel = 0
        while (not opt_sel in [1,2]):
            print("1. Add" )
            print("2. Ingore" )
            try:
                opt_sel = int(input())
            except:
                opt_sel = 0
        if opt_sel == 1:
            current_affi = temp_affi

    if 'institution' in temp_affi.keys() and temp_affi['institution']=="":
        print ("not parsed correctLY? ", temp_affi, complex_affi)
        current_affi = manual_map_complex(temp_affi, complex_affi)
        
    if current_affi != {}:
        print("save current", current_affi)
        affiliation_id, address_id = affiliation_exists(current_affi)
        if affiliation_id !=0 and address_id != 0:
            print("* Affiliation found in DB id:", affiliation_id, "Address:", address_id)
            print('* Add ')
        elif affiliation_id !=0 and address_id == 0:
            print("* Affiliation found in DB id:", affiliation_id, "Need to add address:", current_affi['address'])
            address_id = add_address(current_affi['address'], affiliation_id, current_affi['country'])
            print("* Added address:", current_affi['address'], "ID:", address_id)
        else:
            print("* Need to add affiliation and address")
            print ('* Try to add affi for', current_affi)
            address_string = current_affi['address']
            affiliation_id = add_affiliation(current_affi)
            
            address_id = add_address(address_string, affiliation_id, current_affi['country'])
            print ('* Added affiliation and address', affiliation_id, address_id)
            
        if affiliation_id !=0 and address_id != 0:
            print("* Adding author affiliation record ")
            added_aut_affi_id = add_author_affiliation(art_aut_id, affiliation_id, address_id)
            print("* Added author affiliation record ID:", added_aut_affi_id)
            for cr_id in complex_affi:
                update_cr_affiliation(cr_id, added_aut_affi_id)
                print("* Update cr affiliation", cr_id)
        
# get lits of article author ids with unmapped crossref affiliations
art_aut_ids = aut_ids_unmapped_cr_affiliations()
for art_aut_id in art_aut_ids:
    print ('Art. author ID:', art_aut_id)
    # get cr ids for art. author
    non_parsed_cr_affi_ids = cr_affiliation_ids_for_author(art_aut_id)     
    cr_values = get_cr_values(non_parsed_cr_affi_ids)
    #print ("CrossRef values ", cr_values)
    complex_affi = {}
    for a_cr_val in cr_values:
        if is_string_affi(a_cr_val[1]): 
            print("process as single affiliation in string: ", a_cr_val[0], a_cr_val[1],"\n author:", art_aut_id)
            #process_single_affi(a_cr_val[0], aut_affi_id, a_cr_val[1])
            affi_values = split_single(a_cr_val[1])
            #print("processed as", affi_values)
        else:
            print("element: ", a_cr_val[1])
            complex_affi[a_cr_val[0]] = a_cr_val[1].replace('\r',' ')
    if len(complex_affi)>0:
        process_complex_affi(complex_affi, art_aut_id)

# %%
one_affi({'institution': 'East China University of Science and Technology', 'line_1': 'Shanghai 200237'})
# Out:
# institution = 'East China University of Science and Technology'
# True

# %% [markdown]
# # Incomplete code >>>

# %%
def merge_affi_vals(affi_val_1, affi_val_2):
    ret_affi_vals = affi_val_1
    for an_element in affi_val_2:
        if affi_val_2[an_element] != '' and an_element != 'address':
            affi_val_1[an_element] = affi_val_2[an_element]   
        # merge all unmatched strings into address
        #if affi_val_2['address'] != "" and affi_val_1['address'] != "":
        #    affi_val_1['address'] += ", "+ affi_val_2['address']
        #elif affi_val_2['address'] != "":
        #    affi_val_1['address'] = affi_val_2['address']
            
    return affi_val_1

def process_complex_affi(complex_affi, aut_affi_id):
    print ("process as complex affiliation in strings:", complex_affi )
    # take the first element
    # add it to affi_hash if affi_lines empty
    # in next element try to see if the string belongs to same affiliation
    # after first line try adding to affi_hash, if resulting in same affi, add, else start new affi_hash item
    #   - test if current affiliation is full (i.e. inst, dep, sch, fcty, wg, cty.)
    #     or already contains the elements just returned
    #     - not complete then test if it fits with current affiliation
    #       - if an affi is element already filled then mark current affi as
    #         - complete and create a new affi.
    #           - mark as complete requires looking for matches and missing minimal parts in affiliations table: i.e. inst, ctry,
    #           - if inst and ctry blank, use the same as last one (i.e. inst and ctry from previous)
    # currently there is no affiliation

    affi_hash = {}
    hash_indx = 0
    affi_hash[hash_indx] = None
    current_affi = {}
    test_affi={}
    for cr_id in complex_affi:
        temp_split = split_single(complex_affi[cr_id])
        if temp_split!={}:
            if test_affi == {}:
                test_affi = temp_split
            else:
                temp_affi = merge_affi_vals(test_affi, temp_split) 
                affi_id, add_id = affiliation_exists(temp_affi)
                if affi_id != 0:
                    print ("affi exists")
    print(test_affi)
       
# get lits of article_authors with unmapped crossref affiliations
aut_affi_ids = aut_ids_unmapped_cr_affiliations()
for aut_affi_id in aut_affi_ids:
    if aut_affi_id>2089:
        print ('Art. author ID:', aut_affi_id)
        # get cr ids for art. author
        non_parsed_cr_affi_ids = cr_affiliation_ids_for_author(aut_affi_id)     
        #print(aut_affi_id)
        #print(non_parsed_affis)
        #print(non_parsed_cr_affi_ids)
        # get values for cr_ids
        cr_values = get_cr_values(non_parsed_cr_affi_ids)
        #print ("CrossRef values ", cr_values)
        complex_affi = {}
        other_lines = 1
        affi_hash = {}
        hash_indx = 0
        affi_hash[hash_indx] = None
        for a_cr_val in cr_values:
            temp_split = get_affi_vals(a_cr_val[1])
            if temp_split == {}:
                temp_split["line_"+str(other_lines)] = a_cr_val[1]
                other_lines += 1
            print("TEMP split", temp_split)
            add_another = False      
            if affi_hash[hash_indx] == None:
                # if all elements are from same affi just add them
                if one_affi(temp_split):
                    affi_hash[hash_indx] = [temp_split,[a_cr_val[0]]]
            # add element if it belongs to same affi
            elif affi_hash[hash_indx] != None:
                current_pair = affi_hash[hash_indx]
                print("Current pair",current_pair)
                if set(current_pair[0].keys()).isdisjoint(set(temp_split.keys())):
                    temp_pair = [merge_affi_vals(current_pair[0], temp_split),current_pair[1].append(a_cr_val[0])]
                    print("TEMP PAIR", temp_pair, current_pair[1], a_cr_val[0])
                    if one_affi(temp_pair[0]):
                        affi_hash[hash_indx] = [temp_split,[a_cr_val[0]]]
                    else :
                        add_another = True
            if add_another:
                hash_indx+=1
                affi_hash[hash_indx] = [temp_split,[a_cr_val[0]]]
                add_another = False
        ####################################################        
            print (affi_hash)
            
            #if temps_split
            if is_string_affi(a_cr_val[1]): 
                print("process as single affiliation in string: ", a_cr_val[0], a_cr_val[1],"\n author:", aut_affi_id)
                #process_single_affi(a_cr_val[0], aut_affi_id, a_cr_val[1])
                affi_values = split_single(a_cr_val[1])
                #print("processed as", affi_values)
            else:
                print("element: ", a_cr_val[1])
                complex_affi[a_cr_val[0]] = a_cr_val[1].replace('\r',' ')
        if len(complex_affi)>0:
            process_complex_affi(complex_affi, aut_affi_id)
    #if aut_affi_id>150:
    #    break

# %%
non_parsed_affi = "Some string\rwith a return"
print (non_parsed_affi)
non_parsed_affi.replace('\r',' ')
print (non_parsed_affi.replace('\r',' '))
affi_vals = {'institution': '', 'school': 'Chemical Engineering', 'department': '', 'faculty': '', 'work_group': '', 'country': '', 'address': 'UNILAB, State Key Lab of , School of'}
print(affi_vals)
affi_vals = remove_blanks(affi_vals)
print(affi_vals)

# %%
# old version


# Split the affiliation
# if affiliatin is found in DB:
#    retrieve affiliation ID and address ID
# else:
#    add affiliation and address to the DB
#    get the IDs of affiliation and address
# return affiliation ID and address ID
def db_split(affiliation):
    affiliation_id = 0
    address_id = 0
    fields={'a':'institution', 'b':'country', 'c':'department','d':'faculty',
            'e':'work_group','f':'address', 'g':'school'}
    print (affiliation, len(affiliation))
    for indx in range(0, len(affiliation)):
        inst_str = dept_str = faculty_str = group_str = ctry_str = school_str = ""
        qry_where_str = ""
        addr_list=[]
        
        checking_this = affiliation[indx]['name']
        #print (affiliation[indx]['name'])
        for inst in institution_synonyms.keys():
            if inst in checking_this:
                inst_str = institution_synonyms[inst]
                checking_this = checking_this.replace(inst,'')
                break
        # Institution 
        if inst_str == "":
            inst_str, checking_this = check_list(checking_this,institutions_list)

        # Country Synonyms
        for ctry in country_synonyms.keys():
            if ctry in checking_this:
                ctry_str = country_synonyms[ctry]
                checking_this = checking_this.replace(ctry,'')
                break
        
        for ctry in countries_list:
            if ctry in checking_this:
                ctry_str = ctry
                checking_this = checking_this.replace(ctry,'')
                break
        
        # see if department in affiliation string
        dept_str, checking_this = check_list(checking_this, department_list)
            
        # find schools in affiliation string
        school_str, checking_this = check_list(checking_this, school_list)

                
        for fclty in faculty_list:
            if fclty in checking_this:
                faculty_str = fclty
                checking_this = checking_this.replace(fclty,'')
                break
        for grp in group_list:
            if grp in checking_this:
                group_str = grp
                checking_this = checking_this.replace(grp,'')
                break
        checking_this = checking_this.strip()
        checking_this = checking_this.replace("  ", " ")
        addr_list.append(checking_this)
        
        result=-1
        print ('Institution:', inst_str)
        print ('School:', school_str)
        print ('Department:', dept_str)
        print ('Faculty:', faculty_str)
        print ('Group:', group_str)
        print ('Country:', ctry_str)

        print ('Address',  addr_list)
        if inst_str != "":
            affiliation_id, address_id = find_or_add(inst_str, dept_str, faculty_str, group_str, ctry_str, school_str, addr_list)
        else:        
            print("***************** get institution **************************************")
            print("split and add this: ", checking_this)
            addr_list.pop(0)
            ins_str = extract_custom(checking_this)
            checking_this = checking_this.replace(ins_str,'')
            checking_this = checking_this.strip()
            checking_this = checking_this.replace("  ", " ")
            addr_list.append(checking_this)
            affiliation_id, address_id = find_or_add(ins_str, dept_str, faculty_str, group_str, ctry_str, school_str, addr_list)
    return affiliation_id, address_id

def add_affi_to_db(inst_str, dept_str, faculty_str, group_str, ctry_str, school_str, addr_list, qry_where):
    ret_parsed = {}
    ret_parsed['institution'] = inst_str
    ret_parsed['school'] = school_str
    ret_parsed['department'] = dept_str
    ret_parsed['faculty'] = faculty_str
    ret_parsed['work_group'] = group_str
    ret_parsed['country'] = ctry_str
    ret_parsed['created_at'] = datetime.today().strftime('%Y-%m-%d %H:%M:%S')
    ret_parsed['updated_at'] = ret_parsed['created_at'] 
    print("** Will Add:", ret_parsed, " with address ", addr_list)
    db_conn.put_values_table("affiliations", ret_parsed.keys(), ret_parsed.values())
    result = db_conn.get_values("affiliations","id",qry_where)
    affi_id = result[0][0]
    print("Added:", result, len(result))
    addr_str = "; ".join(addr_list)
    affi_address = {'add_01':addr_str,"affiliation_id":affi_id,'country':ctry_str,
                    'created_at':ret_parsed['created_at'], 'updated_at':ret_parsed['created_at']}
    db_conn.put_values_table("addresses", affi_address.keys(), affi_address.values())
    add_id = db_conn.get_value("addresses", "id", "affiliation_id", affi_id)[0]
    print('affiliation id:', affi_id, " address id: ", add_id)
    return affi_id, add_id

def build_aut_affi(inst_str, dept_str, faculty_str, group_str, ctry_str, school_str, addr_list, art_aut_id, affi_id, addr_str):
    # get smallest unit
    smallest_unit = "" 
    #id Institution> Faculty > School > Department > Work_group + address + Country
    if len(group_str) > 0:
        smallest_unit = group_str
    elif len(dept_str) > 0 and smallest_unit == "":
        smallest_unit = dept_str
    elif len(school_str) > 0 and smallest_unit == "":
        smallest_unit = school_str
    elif len(faculty_str) > 0 and smallest_unit == "":
        smallest_unit = faculty_str
       
    ret_parsed = {}
    ret_parsed['article_author_id'] = art_aut_id
    if len(smallest_unit) > 0:
        ret_parsed['name'] = smallest_unit + ", "+  inst_str
        ret_parsed['short_name'] = inst_str
    else:
        ret_parsed['name'] = inst_str
        ret_parsed['short_name'] = inst_str
    add_01 = ""
    if faculty_str != "" and faculty_str != smallest_unit:
        add_01 = faculty_str
    if school_str != "" and school_str != smallest_unit:
        if add_01 != "":
               add_01 += ", "+ school_str
        else:
               add_01 += school_str
    if dept_str != "" and dept_str != smallest_unit:
        if add_01 != "":
               add_01 += ", "+ dept_str
        else:
               add_01 += dept_str
    ret_parsed['add_01'] = add_01
    ret_parsed['add_02'] = addr_str
    ret_parsed['add_03'] = ctry_str
    ret_parsed['country'] = ctry_str
    ret_parsed['affiliation_id'] = affi_id
    ret_parsed['created_at'] = datetime.today().strftime('%Y-%m-%d %H:%M:%S')
    ret_parsed['updated_at'] = ret_parsed['created_at'] 
    return ret_parsed
                   

# add a new author affi record
def add_author_affi_to_db(inst_str, dept_str, faculty_str, group_str, ctry_str, school_str, addr_list, art_aut_id, affi_id, addr_str):  
    # build record for author affiliation    
    ret_parsed = build_aut_affi(inst_str, dept_str, faculty_str, group_str, ctry_str, school_str, addr_list, art_aut_id, affi_id, addr_str)
    print("** Will Add:", ret_parsed)
    aut_affi_id = db_conn.put_values_table("author_affiliations", ret_parsed.keys(), ret_parsed.values())
    return aut_affi_id;

def find_or_add(inst_str, dept_str, faculty_str, group_str, ctry_str, school_str, addr_list):
    qry_where = ""
    if inst_str != "":
        qry_where += "institution = '" + inst_str + "'"
        if dept_str != "":
            qry_where += " AND department = '" + dept_str + "'"
        if faculty_str != "":
            qry_where += " AND faculty = '" + faculty_str + "'"
        if group_str != "":
            qry_where += " AND work_group = '" + group_str + "'"
        if school_str != "":
            qry_where += " AND school = '" + school_str + "'"
        if ctry_str != "":
            qry_where += " AND country = '" + ctry_str + "'"
        print(qry_where)
        result = db_conn.get_values("affiliations","id",qry_where)
        if result != []:
            affi_id = result[0][0]
            print("Found:", affi_id, len(result))
            add_id = db_conn.get_value("addresses", "id", "affiliation_id", affi_id)[0]
            print('affiliation id:', affi_id, " address id: ", add_id)
            return affi_id, add_id
        # not found, add new institution record
        else:
            affi_id, add_id = add_affi_to_db(inst_str, dept_str, faculty_str, group_str, ctry_str, school_str, addr_list, qry_where)
            return affi_id, add_id
    return 0, 0

def extract_custom(split_this):
    print( split_this)
    decimal_str = ""
    for indx in range(0, len(split_this)):
        val = " "
        if (indx % 10 == 0): val = str(int(indx/10)) 
        decimal_str += val
    print(decimal_str)
    unit_str = ""
    for indx in range(0, len(split_this)):
        val = str(indx%10)
        if (indx % 10 == 0): val = "0" 
        unit_str += val
    print(unit_str)
    print("start")
    str_start = int(input())
    print("end")
    str_end = int(input())
    return split_this[str_start:str_end+1]

def is_address(affi_element):
    while True:
        print ("************************SELECT OPTION*************************")
        print (affi_element,": \n a) address \n n) new affi \n s) str affi")
        print ("selection:", end=" ")
        user_select = input().lower()
        if user_select == 'a':
            return 1
        elif user_select == 'n':
            return 0
        elif user_select == 's':
            return -1

def assing_keyword(affi_element):
    while True:
        print ("****************ASSIGN KEYWORD TO ELEMENT****************")
        print ("* Element:",affi_element)
        for opt in affi_keys:
            print (opt+")", affi_keys[opt])
        print ("x) None")
        print ("selection:", end=" ")
        user_select = input().lower()
        if user_select in affi_keys:
            return affi_keys[user_select]
        elif user_select == "x":
            return ""

def assign_not_mapped(list_affis, not_mapped):
    for element in not_mapped:
        print(element)
        print ("************************MAPPED AFFIS*************************")
        affi_keyword = assing_keyword(element)
        for i, affi in enumerate(list_affis):
            print (i, affi)
        while True:
            print ("******************ASSIGN NOT MAPPED TO AFFIS******************")
            print(element)
            print ("select number to assing to from above or 9 to assign to new affiliation")
            print ("selection:", end=" ")
            user_select = input()
            try:
                user_select = int(user_select)
                if user_select < len(list_affis):
                    if not affi_keyword in list_affis[user_select].keys():
                        list_affis[user_select][affi_keyword] = element
                        break;
                    else:
                        print ("cannot add")
                elif user_select == 9:
                    list_affis.append({affi_keyword:element})
                    break
            except:
                print("select a valid index")
        return list_affis
    
def get_keyword(affi_element):
    if affi_element in institutions_list:
        return "institution"
    elif affi_element in institution_synonyms:
        return "institution"
    elif affi_element in department_list:
        return "department"
    elif affi_element in faculty_list:
        return "faculty"
    elif affi_element in group_list: 
        return "work_group"
    elif affi_element in countries_list:
        return "country"
    elif affi_element in country_synonyms:
        return "country"
    else:
        return ""

# returns a list of dictionaries with affiliation values
def map_split_affi(affiliation):
    parsed_affi = { }
    affis_count = 0
    list_affis = []
    addr_list = []
    not_mapped = []
    for affi_element in affiliation:
        element_value = affi_element['name']
        element_key = get_keyword(element_value)
        if element_key == "":
            # Not found it could be a single string or an address element
            # ask if address or new affi
            is_addr = is_address(element_value)
            if is_addr == 1: # address part
                addr_list.append(element_value)
            elif is_addr == 0: # new affi part
                not_mapped.append(element_value)
            elif is_addr == -1: # new affi part
                print("not handled", element_value)
        else:
            if not element_key in parsed_affi:
                parsed_affi[element_key] = element_value
            else:
                # There is more than one affiliation
                parsed_affi['addr'] = addr_list
                list_affis.append(parsed_affi)
                parsed_affi = {}
                addr_list = []
                parsed_affi[element_key] = element_value
                affis_count += 1
        if affis_count > 0 and parsed_affi != {}:
            if addr_list != []:
                parsed_affi['addr'] = addr_list
            list_affis.append(parsed_affi)
    return list_affis, not_mapped

def get_afi_id(affiliation):
    print (affiliation, len(affiliation))
    inst_str = dept_str = faculty_str = group_str = ctry_str = ""
    qry_where_str = ""
    addr_list=[]
    for indx in range(0, len(affiliation)):
        checking_this = affiliation[indx]['name']
        #print (affiliation[indx]['name'])
        if checking_this in institutions_list:
            if inst_str == "":
                inst_str = checking_this
        elif checking_this in department_list:
            if inst_str == "":
                dept_str = checking_this
        elif checking_this in faculty_list:
            faculty_str = checking_this
        elif checking_this in group_list: 
            group_str = checking_this
        elif checking_this in countries_list:
            ctry_str = checking_this
        elif checking_this in country_synonyms:
            ctry_str = country_synonyms[checking_this]
        elif checking_this in institution_synonyms:
            inst_str = institution_synonyms[checking_this]
        else:
            addr_list.append(checking_this)
            
    qry_where_str += "institution = '" + inst_str + "'"        
    qry_where_str += " AND department = '" + dept_str + "'"
    qry_where_str += " AND faculty = '" + faculty_str + "'"
    qry_where_str += " AND work_group = '" + group_str + "'"
    qry_where_str += " AND country = '" + ctry_str + "'"

    print ('Institution:', inst_str)
    print ('Department:', dept_str)
    print ('Faculty:', faculty_str)
    print ('Group:', group_str)
    print ('Country:', ctry_str) 
    print ('Address',  addr_list)
    print (qry_where_str)
    result = db_conn.get_values("affiliations","id",qry_where_str)
    print("found",result)
    if result != []:
            affi_id = result[0][0]
            print("Found:", affi_id, len(result))
            add_id = db_conn.get_value("addresses", "id", "affiliation_id", affi_id)[0]
            print('affiliation id:', affi_id, " address id: ", add_id)
            addr_row = list(db_conn.get_row("addresses", add_id)[0])
            print(addr_row)
            another_affi=[]
            for indx in range(0, len(affiliation)):
                checking_this = affiliation[indx]['name']
                print(checking_this)
                if not checking_this in [inst_str, dept_str, faculty_str, group_str, ctry_str]:
                    if not(checking_this in country_synonyms.keys()):
                        skip = False
                        for add_itm in addr_row:
                            if str(add_itm) in checking_this:
                                skip = True
                                break;
                        if not skip:
                            another_affi.append({'name':checking_this})
                        
            if another_affi != []:
                get_afi_id(another_affi)
            return affi_id, add_id
    else:
        # add new affiliation
        affi_id, add_id = add_affi_to_db(inst_str, dept_str, faculty_str, group_str, ctry_str, addr_list,qry_where_str)
        return affi_id, add_id

# %%
def copy_author_affi(art_aut_id, affi_id):
    new_id = None
    values_list = db_conn.get_values("author_affiliations", "id", "affiliation_id = "+str(affi_id))
    
    row_values = []
    if len(values_list)>0:
        row_values = db_conn.get_row ("author_affiliations",values_list[0][0])

    if len(row_values) > 0: 
        # get the first element, ignoring the ID 
        row_values = list(row_values[0][1:])
        #replace art_aut_id 
        row_values[0] = art_aut_id
        row_values[10] = datetime.today().strftime('%Y-%m-%d %H:%M:%S')
        row_values[11] = datetime.today().strftime('%Y-%m-%d %H:%M:%S')
        row_keys = ['article_author_id','name', 'short_name', 'add_01', 
                    'add_02', 'add_03','add_04','add_05','country',
                    'affiliation_id','created_at','updated_at']
        new_id = db_conn.put_values_table("author_affiliations", row_keys, row_values)
    return new_id

# %%
aut_affi_ids = db_conn.get_values('cr_affiliations', 'article_author_id',
                                  'author_affiliation_id is NULL GROUP BY article_author_id HAVING count() = 1')
flat_list = []
for sublist in aut_affi_ids:
    for item in sublist:
        flat_list.append(item)

i_idx = 0
aut_affi_ids = list(set(flat_list))
for aai in aut_affi_ids:
    print("Art. author", aai)
    non_parsed_affis = db_conn.get_values('cr_affiliations', 'name', 'article_author_id = '+ str(aai))
    non_parsed_cr_affi_ids = db_conn.get_values('cr_affiliations', 'id', 'article_author_id = '+ str(aai))
    json_affis = []
    for sublist in non_parsed_affis:
        for item in sublist:
            json_affis.append({'name':item})
            
    print("PARSING", json_affis)
    list_affis, not_mapped = map_split_affi(json_affis)
    if not_mapped != []:
        print('****** There are some not mapped affis ******')
        print('* Not mapped: ', not_mapped)
        list_affis = assign_not_mapped(list_affis, not_mapped)
    print('* List mapped affis:', list_affis)
    print('*********************************************')
    if len(json_affis) == 1:
        affiliation_id, address_id = db_split(json_affis)
        print("Returned IDs:", affiliation_id, address_id, "for art. author", aai)
        # add author affiliation record
        aut_affi_id = copy_author_affi(aai, affiliation_id)
        print ("Inserted author affiliation:", aut_affi_id )
        #if there is only one then there is no problem for adding 
        if len(non_parsed_cr_affi_ids) == 1:
            db_conn.set_value_table('cr_affiliations', non_parsed_cr_affi_ids[0][0], 'author_affiliation_id', aut_affi_id)
            print("Updated CR affiliation:", non_parsed_cr_affi_ids[0][0])
    elif len(json_affis) > 1:
        break
        affiliation_id, address_id = db_split(json_affis)
        print("Returned IDs:", affiliation_id, address_id, "for art. author", aai)
    elif len(json_affis) > 5:
        get_afi_id(json_affis)
    if i_idx == 9:
        break
    i_idx+=1

# %%
# test str_has_synonym
test_str = "Beamline I22, Diamond Light Source, Harwell Science and Innovation Campus, Didcot OX11 0DE, U.K."
inst_str, parsed_str = str_has_synonym(test_str, institution_synonyms)

if inst_str != "Diamond Light Source Ltd.": 
    print ("str_has_synonym failed, returned\n\t", inst_str, "expected\n\t", "Diamond Light Source Ltd.")    
elif parsed_str != "Beamline I22, , Harwell Science and Innovation Campus, Didcot OX11 0DE, U.K.":
    print ("str_has_synonym failed, returned\n\t", parsed_str,"expected\n\t","Beamline I22, , Harwell Science and Innovation Campus, Didcot OX11 0DE, U.K." )
else:
    print ("str_has_synonym works")
    

test_str = "Beamline I22, Diamond Light Source, Harwell Science and Innovation Campus, Didcot OX11 0DE, U.K."
inst_str, parsed_str = str_has_synonym(test_str, country_synonyms)

if inst_str != "United Kingdom": 
    print ("str_has_synonym failed, returned\n\t", inst_str, "expected\n\t", "United Kingdom")    
elif parsed_str != "Beamline I22, Diamond Light Source, Harwell Science and Innovation Campus, Didcot OX11 0DE, ":
    print ("str_has_synonym failed, returned\n\t", parsed_str,"expected\n\t","Beamline I22, Diamond Light Source, Harwell Science and Innovation Campus, Didcot OX11 0DE, " )
else:
    print ("str_has_synonym works")

# %%
aut_affi = {'institution': '', 'school': '', 'department': '', 'faculty': '', 'group': 'Chemical Research Laboratory', 'country': 'United Kingdom', 'address': 'Oxford Chemistry   12 Mansfield Road Oxford OX1 3TA'}
print(aut_affi)
del aut_affi['address']
print(aut_affi)
del aut_affi['address']
print(aut_affi)

# %%
non_parsed_affi_ids = db_conn.get_values('cr_affiliations', 'id', 'article_author_id = '+ str(aai))

# %%
non_parsed_affi_ids[0][0]

# %%
str_this = ', , Nakhon Pathom, , , '
str_this = str_this.replace(", ,", "")
str_this = str_this.replace(" ,", ",")
str_this = str_this.strip()
if str_this[0] =="," : str_this = str_this[1:] 
if str_this[-1:] =="," : str_this = str_this[:-1] 
str_this
#str_this[0] =="," then

# %%
str_this[:-1]

# %%
affiliation_values = {'institution': '', 'school': 'School of Chemistry and Chemical Engineering', 
                      'department': '',  'faculty': '', 'work_group': '', 'country': 'United Kingdom', 
                       'address': 'Queen’s University of Belfast, University Road, Belfast BT9 5AG, Northern Ireland'}
affiliation_values = {'institution': '', 'school': '', 'department': '', 'faculty': '', 'work_group': '',
                      'country': 'United Kingdom',
                      'address': 'School of Biological and Chemical SciencesMaterials Research InstituteQueen Mary University of London London E1 4NS'}

# %%
opt_end = False
while (opt_end == False):
    print(affiliation_values)
    missing_vals = {}
    int_idx = 1
    for an_element in affiliation_values:
        if affiliation_values[an_element] == "":
            missing_vals[int_idx] = an_element
            int_idx += 1
    print('Which element to get from string:')
    for an_idx in missing_vals:
        print(" ", an_idx, missing_vals[an_idx])
    print (" ", len(missing_vals)+1, 'end')
    print('Selection')
    option_sel = int(input())
    if option_sel == len(missing_vals)+1:
        opt_end = True
    elif option_sel > 0 and option_sel <= len(missing_vals):
        print("Try to extract ", missing_vals[option_sel])
        affiliation_values[missing_vals[option_sel]], affiliation_values['address'] = get_from_string(affiliation_values['address'], missing_vals[option_sel])

# %%
institutions_list

# %%
splitting_this ="School of Chemistry and Chemical Engineering, Queen’s University Belfast, David-Keir Building, Stranmillis Road, Belfast BT9 5AG, U.K."
inst_str, splitting_this = check_list(splitting_this,institutions_list)
inst_str

# %%
splitting_this

# %%
return_str = temp_str = ""
for an_item in institutions_list:
    if "Queen" in an_item:
        print(an_item)
    if an_item in splitting_this:
        if len(an_item) > len(temp_str):
            temp_str = an_item
if len(temp_str)>0:
    splitting_this = splitting_this.replace(temp_str,"")
    return_str = temp_str
print(return_str, splitting_this)

# %%
"Queen's University Belfast" in "School of Chemistry and Chemical Engineering, Queen’s University Belfast, David-Keir Building, Stranmillis Road, Belfast BT9 5AG, U.K."

# %%
len(aut_affi_ids)
len(non_parsed_affis)
len(non_parsed_cr_affi_ids)

# %%
print(aut_affi_id)
print(non_parsed_affis)
print(non_parsed_cr_affi_ids)

# %%
aut_affis= [('Johnson Matthey Technology Centre, Sonning Common, Reading, RG4 9NH United Kingdom',)]
len(aut_affis[0])
